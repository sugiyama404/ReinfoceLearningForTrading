# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/sarsa_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
import pickle

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, ReLU
from tensorflow.keras.optimizers import RMSprop
from sklearn.preprocessing import StandardScaler

optimizer = RMSprop()

mode = 'test'
name = 'sarsa'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'

exp_dir = 'Colab Notebooks/workspace/export/'
mdl_dir = '/content/drive/My Drive/' + exp_dir + 'models'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
class Brain:
    def __init__(self):

        self.gamma = 0.9
        n_mid, n_state, n_action = 3, 3, 3

        model = Sequential()
        model.add(Dense(n_mid, input_shape=(n_state,)))
        model.add(ReLU()) 
        model.add(Dense(n_mid))
        model.add(ReLU())
        model.add(Dense(n_action))
        model.compile(loss="mse", optimizer=optimizer)

        print((model.summary()))
        self.model = model

    def train(self, state, action, reward, next_state, next_act, done):
        q = self.model.predict(state)  
        target = np.copy(q)
        if done:
            target[:, action] = reward
        else:
            target[:, action] = reward + self.gamma*next_act
        self.model.train_on_batch(state, target)

    def predict(self, state):
        return self.model.predict(state)

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
class Agent(Brain):
    def __init__(self):

        super().__init__()
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.r = 0.995

    def act(self, state, act, reward, info, next_state, done, mode = 'train'):

        next_act = self._next_act(state)
        if mode == 'train':
            self.train(state, act, reward, next_state, next_act, done)

        return next_act

    def _next_act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(3)
        act_values = self.predict(state)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.r
        return np.argmax(act_values[0])

# %%
class Main:
    def __init__(self, env, agent, mdl_dir, name, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.agent = agent
        self.mdl_dir = mdl_dir
        self.scaler = self._standard_scaler(self.env)
        self.episodes_times = episodes_times
        self.mode = mode
        self.name = name

        if self.mode == 'test':
            with open('{}/{}.pkl'.format(self.mdl_dir, self.name), 'rb') as f:
                self.scaler = pickle.load(f)
            self.agent.epsilon = 0.01
            self.agent.load('{}/{}.h5'.format(self.mdl_dir, self.name))

            self.df_rec = pd.DataFrame(index=[], columns=['FixedProfit','TradeTimes','TradeWin'])
        else:
            self.df_rec = pd.DataFrame(index=[], columns=['FixedProfit'])

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            state = self.scaler.transform([state])
            done = False
            start_time = datetime.now()
            reward = 0.0
            info = None
            next_state = copy.copy(state)
            next_act = 1
            act = 1
        
            while not done:
                action = self.agent.act(state, act, reward, info, next_state, done, mode)
                state = next_state
                next_state, reward, done, info = self.env.step(action)
                next_state = self.scaler.transform([next_state])
                act = copy.copy(action)
                
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                record = pd.Series([info['cur_revenue'],info['trade_time'],info['trade_win']], index=self.df_rec.columns)
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f} TradeTimes: {} TradeWin: {}".format(episode + 1, self.episodes_times, play_time, info['cur_revenue'], info['trade_time'], info['trade_win']))
            else:
                record = pd.Series(info['cur_revenue'], index=self.df_rec.columns)
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f}".format(episode + 1, self.episodes_times, play_time, info['cur_revenue']))

            state = next_state
            self.df_rec = self.df_rec.append(record, ignore_index=True)

        if self.mode == 'train':
            self._save_scaler()
        self._save_csv()

    def _standard_scaler(self, env):
        states = []
        for _ in range(env.df_total_steps):
            action = np.random.choice(env.action_space)
            state, reward, done, info = env.step(action)
            states.append(state)
            if done:
                break
        
        scaler = StandardScaler()
        scaler.fit(states)
        return scaler

    def _save_scaler(self):
        self.agent.save('{}/{}.h5'.format(self.mdl_dir, self.name))
        with open('{}/{}.pkl'.format(self.mdl_dir, self.name), 'wb') as f:
            pickle.dump(self.scaler, f)

    def _save_csv(self):
        self.df_rec.to_csv(csv_path)

# %%
initial_money=1000000
episodes_times = 100

agent = Agent()
env = Environment(df, initial_money, mode)
main = Main(env, agent, mdl_dir, name, episodes_times, mode)
main.play_game()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 12
# _________________________________________________________________
# re_lu (ReLU)                 (None, 3)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________
# None
# Episode: 1/100 RapTime: 0:00:27.496210 FixedProfit: 1526519 TradeTimes: 7 TradeWin: 7
# Episode: 2/100 RapTime: 0:00:27.353185 FixedProfit: 1550486 TradeTimes: 5 TradeWin: 5
# Episode: 3/100 RapTime: 0:00:25.243856 FixedProfit: 1499680 TradeTimes: 5 TradeWin: 4
# Episode: 4/100 RapTime: 0:00:27.238928 FixedProfit: 1559726 TradeTimes: 7 TradeWin: 5
# Episode: 5/100 RapTime: 0:00:26.220540 FixedProfit: 1533358 TradeTimes: 4 TradeWin: 4
# Episode: 6/100 RapTime: 0:00:26.097935 FixedProfit: 1570063 TradeTimes: 4 TradeWin: 3
# Episode: 7/100 RapTime: 0:00:26.420175 FixedProfit: 1554414 TradeTimes: 4 TradeWin: 3
# Episode: 8/100 RapTime: 0:00:26.796195 FixedProfit: 1548703 TradeTimes: 4 TradeWin: 4
# Episode: 9/100 RapTime: 0:00:25.344436 FixedProfit: 1525989 TradeTimes: 3 TradeWin: 2
# Episode: 10/100 RapTime: 0:00:26.656658 FixedProfit: 1466529 TradeTimes: 5 TradeWin: 4
# Episode: 11/100 RapTime: 0:00:26.410771 FixedProfit: 1535199 TradeTimes: 4 TradeWin: 4
# Episode: 12/100 RapTime: 0:00:25.907283 FixedProfit: 1526540 TradeTimes: 5 TradeWin: 5
# Episode: 13/100 RapTime: 0:00:26.508404 FixedProfit: 1536997 TradeTimes: 3 TradeWin: 3
# Episode: 14/100 RapTime: 0:00:25.686407 FixedProfit: 1451763 TradeTimes: 6 TradeWin: 4
# Episode: 15/100 RapTime: 0:00:26.571737 FixedProfit: 1561568 TradeTimes: 3 TradeWin: 3
# Episode: 16/100 RapTime: 0:00:25.885853 FixedProfit: 1519097 TradeTimes: 2 TradeWin: 2
# Episode: 17/100 RapTime: 0:00:25.772915 FixedProfit: 1525563 TradeTimes: 6 TradeWin: 6
# Episode: 18/100 RapTime: 0:00:26.826737 FixedProfit: 1545155 TradeTimes: 2 TradeWin: 2
# Episode: 19/100 RapTime: 0:00:25.471079 FixedProfit: 1549019 TradeTimes: 3 TradeWin: 3
# Episode: 20/100 RapTime: 0:00:26.445003 FixedProfit: 1501131 TradeTimes: 5 TradeWin: 4
# Episode: 21/100 RapTime: 0:00:26.777642 FixedProfit: 1511685 TradeTimes: 4 TradeWin: 3
# Episode: 22/100 RapTime: 0:00:26.625829 FixedProfit: 1495760 TradeTimes: 4 TradeWin: 2
# Episode: 23/100 RapTime: 0:00:25.613951 FixedProfit: 1538151 TradeTimes: 3 TradeWin: 3
# Episode: 24/100 RapTime: 0:00:26.791694 FixedProfit: 1547770 TradeTimes: 4 TradeWin: 4
# Episode: 25/100 RapTime: 0:00:25.545545 FixedProfit: 1481147 TradeTimes: 9 TradeWin: 8
# Episode: 26/100 RapTime: 0:00:25.870069 FixedProfit: 1535457 TradeTimes: 4 TradeWin: 4
# Episode: 27/100 RapTime: 0:00:26.885126 FixedProfit: 1540999 TradeTimes: 4 TradeWin: 3
# Episode: 28/100 RapTime: 0:00:25.247513 FixedProfit: 1491638 TradeTimes: 4 TradeWin: 2
# Episode: 29/100 RapTime: 0:00:26.422762 FixedProfit: 1529434 TradeTimes: 5 TradeWin: 5
# Episode: 30/100 RapTime: 0:00:26.154708 FixedProfit: 1714033 TradeTimes: 4 TradeWin: 3
# Episode: 31/100 RapTime: 0:00:25.734521 FixedProfit: 1537980 TradeTimes: 6 TradeWin: 4
# Episode: 32/100 RapTime: 0:00:26.617453 FixedProfit: 1516849 TradeTimes: 4 TradeWin: 3
# Episode: 33/100 RapTime: 0:00:27.627667 FixedProfit: 1511997 TradeTimes: 3 TradeWin: 2
# Episode: 34/100 RapTime: 0:00:25.445638 FixedProfit: 1543971 TradeTimes: 1 TradeWin: 1
# Episode: 35/100 RapTime: 0:00:26.188512 FixedProfit: 1553260 TradeTimes: 6 TradeWin: 5
# Episode: 36/100 RapTime: 0:00:26.477072 FixedProfit: 1557762 TradeTimes: 4 TradeWin: 4
# Episode: 37/100 RapTime: 0:00:25.402314 FixedProfit: 1511079 TradeTimes: 6 TradeWin: 4
# Episode: 38/100 RapTime: 0:00:26.835961 FixedProfit: 1532570 TradeTimes: 6 TradeWin: 5
# Episode: 39/100 RapTime: 0:00:25.788308 FixedProfit: 1577582 TradeTimes: 5 TradeWin: 4
# Episode: 40/100 RapTime: 0:00:26.244151 FixedProfit: 1530345 TradeTimes: 3 TradeWin: 2
# Episode: 41/100 RapTime: 0:00:26.139293 FixedProfit: 1510802 TradeTimes: 4 TradeWin: 4
# Episode: 42/100 RapTime: 0:00:25.406366 FixedProfit: 1530191 TradeTimes: 3 TradeWin: 3
# Episode: 43/100 RapTime: 0:00:26.745590 FixedProfit: 1540301 TradeTimes: 4 TradeWin: 4
# Episode: 44/100 RapTime: 0:00:27.117298 FixedProfit: 1532661 TradeTimes: 4 TradeWin: 4
# Episode: 45/100 RapTime: 0:00:26.631866 FixedProfit: 1540284 TradeTimes: 3 TradeWin: 3
# Episode: 46/100 RapTime: 0:00:26.440166 FixedProfit: 1570771 TradeTimes: 3 TradeWin: 3
# Episode: 47/100 RapTime: 0:00:27.035363 FixedProfit: 1530073 TradeTimes: 5 TradeWin: 5
# Episode: 48/100 RapTime: 0:00:25.809474 FixedProfit: 1545229 TradeTimes: 2 TradeWin: 2
# Episode: 49/100 RapTime: 0:00:26.876963 FixedProfit: 1545955 TradeTimes: 4 TradeWin: 4
# Episode: 50/100 RapTime: 0:00:25.866528 FixedProfit: 1478863 TradeTimes: 4 TradeWin: 4
# Episode: 51/100 RapTime: 0:00:25.879810 FixedProfit: 1539593 TradeTimes: 6 TradeWin: 6
# Episode: 52/100 RapTime: 0:00:26.966173 FixedProfit: 1543971 TradeTimes: 1 TradeWin: 1
# Episode: 53/100 RapTime: 0:00:25.529060 FixedProfit: 1484969 TradeTimes: 6 TradeWin: 4
# Episode: 54/100 RapTime: 0:00:26.737619 FixedProfit: 1541579 TradeTimes: 2 TradeWin: 2
# Episode: 55/100 RapTime: 0:00:26.287223 FixedProfit: 1495054 TradeTimes: 6 TradeWin: 6
# Episode: 56/100 RapTime: 0:00:25.932878 FixedProfit: 1568680 TradeTimes: 3 TradeWin: 3
# Episode: 57/100 RapTime: 0:00:27.192405 FixedProfit: 1526728 TradeTimes: 5 TradeWin: 5
# Episode: 58/100 RapTime: 0:00:27.161108 FixedProfit: 1627372 TradeTimes: 4 TradeWin: 3
# Episode: 59/100 RapTime: 0:00:25.540575 FixedProfit: 1506672 TradeTimes: 3 TradeWin: 3
# Episode: 60/100 RapTime: 0:00:25.870045 FixedProfit: 1531044 TradeTimes: 7 TradeWin: 7
# Episode: 61/100 RapTime: 0:00:26.229649 FixedProfit: 1698965 TradeTimes: 8 TradeWin: 6
# Episode: 62/100 RapTime: 0:00:25.321203 FixedProfit: 1558845 TradeTimes: 7 TradeWin: 6
# Episode: 63/100 RapTime: 0:00:27.062735 FixedProfit: 1547777 TradeTimes: 3 TradeWin: 3
# Episode: 64/100 RapTime: 0:00:25.822414 FixedProfit: 1546589 TradeTimes: 2 TradeWin: 2
# Episode: 65/100 RapTime: 0:00:26.018413 FixedProfit: 1528921 TradeTimes: 3 TradeWin: 2
# Episode: 66/100 RapTime: 0:00:26.471771 FixedProfit: 1511263 TradeTimes: 5 TradeWin: 3
# Episode: 67/100 RapTime: 0:00:25.798498 FixedProfit: 1536364 TradeTimes: 3 TradeWin: 3
# Episode: 68/100 RapTime: 0:00:27.070645 FixedProfit: 1558980 TradeTimes: 5 TradeWin: 4
# Episode: 69/100 RapTime: 0:00:26.884381 FixedProfit: 1525794 TradeTimes: 3 TradeWin: 3
# Episode: 70/100 RapTime: 0:00:26.230383 FixedProfit: 1565667 TradeTimes: 3 TradeWin: 3
# Episode: 71/100 RapTime: 0:00:25.564198 FixedProfit: 1513418 TradeTimes: 4 TradeWin: 4
# Episode: 72/100 RapTime: 0:00:27.130689 FixedProfit: 1554466 TradeTimes: 2 TradeWin: 2
# Episode: 73/100 RapTime: 0:00:25.462654 FixedProfit: 1526498 TradeTimes: 8 TradeWin: 5
# Episode: 74/100 RapTime: 0:00:26.455921 FixedProfit: 1572042 TradeTimes: 3 TradeWin: 3
# Episode: 75/100 RapTime: 0:00:26.239099 FixedProfit: 1545479 TradeTimes: 2 TradeWin: 2
# Episode: 76/100 RapTime: 0:00:25.422782 FixedProfit: 1534026 TradeTimes: 4 TradeWin: 4
# Episode: 77/100 RapTime: 0:00:27.089210 FixedProfit: 1517454 TradeTimes: 3 TradeWin: 3
# Episode: 78/100 RapTime: 0:00:25.759434 FixedProfit: 1556462 TradeTimes: 2 TradeWin: 2
# Episode: 79/100 RapTime: 0:00:26.594852 FixedProfit: 1537340 TradeTimes: 3 TradeWin: 3
# Episode: 80/100 RapTime: 0:00:26.362241 FixedProfit: 1537167 TradeTimes: 4 TradeWin: 4
# Episode: 81/100 RapTime: 0:00:25.512430 FixedProfit: 1525910 TradeTimes: 6 TradeWin: 5
# Episode: 82/100 RapTime: 0:00:27.274901 FixedProfit: 1529998 TradeTimes: 3 TradeWin: 3
# Episode: 83/100 RapTime: 0:00:27.075415 FixedProfit: 1540037 TradeTimes: 3 TradeWin: 3
# Episode: 84/100 RapTime: 0:00:25.811245 FixedProfit: 1505451 TradeTimes: 3 TradeWin: 3
# Episode: 85/100 RapTime: 0:00:26.030154 FixedProfit: 1513826 TradeTimes: 3 TradeWin: 3
# Episode: 86/100 RapTime: 0:00:26.531333 FixedProfit: 1522973 TradeTimes: 4 TradeWin: 4
# Episode: 87/100 RapTime: 0:00:25.773917 FixedProfit: 1543971 TradeTimes: 1 TradeWin: 1
# Episode: 88/100 RapTime: 0:00:27.146700 FixedProfit: 1522237 TradeTimes: 3 TradeWin: 3
# Episode: 89/100 RapTime: 0:00:25.979226 FixedProfit: 1579003 TradeTimes: 4 TradeWin: 4
# Episode: 90/100 RapTime: 0:00:26.043126 FixedProfit: 1537715 TradeTimes: 3 TradeWin: 3
# Episode: 91/100 RapTime: 0:00:26.550930 FixedProfit: 1540185 TradeTimes: 2 TradeWin: 2
# Episode: 92/100 RapTime: 0:00:25.666621 FixedProfit: 1507408 TradeTimes: 7 TradeWin: 5
# Episode: 93/100 RapTime: 0:00:26.948678 FixedProfit: 1530775 TradeTimes: 2 TradeWin: 2
# Episode: 94/100 RapTime: 0:00:26.928072 FixedProfit: 1553151 TradeTimes: 2 TradeWin: 2
# Episode: 95/100 RapTime: 0:00:26.378809 FixedProfit: 1541326 TradeTimes: 5 TradeWin: 5
# Episode: 96/100 RapTime: 0:00:25.696239 FixedProfit: 1555045 TradeTimes: 4 TradeWin: 3
# Episode: 97/100 RapTime: 0:00:26.928141 FixedProfit: 1543971 TradeTimes: 1 TradeWin: 1
# Episode: 98/100 RapTime: 0:00:25.762173 FixedProfit: 1586821 TradeTimes: 3 TradeWin: 3
# Episode: 99/100 RapTime: 0:00:26.391158 FixedProfit: 1556901 TradeTimes: 4 TradeWin: 4
# Episode: 100/100 RapTime: 0:00:26.370415 FixedProfit: 1538001 TradeTimes: 3 TradeWin: 3
