# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_thread_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from concurrent.futures import ThreadPoolExecutor as PoolExecutor

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_process_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
    
        while not done:
            action = random.randrange(3)
            state, reward, done, info = env.step(action)
        
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)

thread_num = 4
datas = []
for i in range(thread_num):
    e = Environment(df, initial_money=initial_money,mode = mode)
    datas.append(e)

features = []
with PoolExecutor(max_workers=thread_num) as executor:
    for env in datas:
        job = lambda: play_game(env)
        features.append(executor.submit(job))
# Out:
# Episode: 1/25 RapTime: 0:00:00.097017 FixedProfit: 1317357 TradeTimes: 135 TradeWin: 92
# Episode: 1/25 RapTime: 0:00:00.124634 FixedProfit: 1610249 TradeTimes: 142 TradeWin: 89
# Episode: 1/25 RapTime: 0:00:00.135017 FixedProfit: 1133741 TradeTimes: 147 TradeWin: 89
# Episode: 1/25 RapTime: 0:00:00.145169 FixedProfit: 1247727 TradeTimes: 145 TradeWin: 93
# Episode: 2/25 RapTime: 0:00:00.117683 FixedProfit: 1250604 TradeTimes: 145 TradeWin: 90Episode: 2/25 RapTime: 0:00:00.116755 FixedProfit: 1518191 TradeTimes: 143 TradeWin: 91
#
# Episode: 2/25 RapTime: 0:00:00.069228 FixedProfit: 958744 TradeTimes: 142 TradeWin: 85
# Episode: 2/25 RapTime: 0:00:00.069033 FixedProfit: 1183672 TradeTimes: 141 TradeWin: 87
# Episode: 3/25 RapTime: 0:00:00.087484 FixedProfit: 1204749 TradeTimes: 146 TradeWin: 79Episode: 3/25 RapTime: 0:00:00.086196 FixedProfit: 1024930 TradeTimes: 152 TradeWin: 98
#
# Episode: 3/25 RapTime: 0:00:00.124383 FixedProfit: 900564 TradeTimes: 142 TradeWin: 86
# Episode: 3/25 RapTime: 0:00:00.147490 FixedProfit: 1110297 TradeTimes: 131 TradeWin: 86
# Episode: 4/25 RapTime: 0:00:00.059467 FixedProfit: 1189879 TradeTimes: 150 TradeWin: 100
# Episode: 4/25 RapTime: 0:00:00.050084 FixedProfit: 1305117 TradeTimes: 147 TradeWin: 89
# Episode: 4/25 RapTime: 0:00:00.064926 FixedProfit: 1434703 TradeTimes: 141 TradeWin: 86
# Episode: 5/25 RapTime: 0:00:00.104226 FixedProfit: 1087785 TradeTimes: 151 TradeWin: 88
# Episode: 4/25 RapTime: 0:00:00.103263 FixedProfit: 1267731 TradeTimes: 148 TradeWin: 85
# Episode: 5/25 RapTime: 0:00:00.076982 FixedProfit: 1385530 TradeTimes: 141 TradeWin: 87
# Episode: 5/25 RapTime: 0:00:00.117573 FixedProfit: 1304669 TradeTimes: 142 TradeWin: 79
# Episode: 5/25 RapTime: 0:00:00.083356 FixedProfit: 1112997 TradeTimes: 151 TradeWin: 89
# Episode: 6/25 RapTime: 0:00:00.101539 FixedProfit: 1272217 TradeTimes: 152 TradeWin: 94
# Episode: 6/25 RapTime: 0:00:00.044275 FixedProfit: 981702 TradeTimes: 136 TradeWin: 82
# Episode: 7/25 RapTime: 0:00:00.068708 FixedProfit: 1156551 TradeTimes: 143 TradeWin: 87
# Episode: 6/25 RapTime: 0:00:00.134138 FixedProfit: 1221810 TradeTimes: 149 TradeWin: 96
# Episode: 6/25 RapTime: 0:00:00.104529 FixedProfit: 1236248 TradeTimes: 147 TradeWin: 93
# Episode: 7/25 RapTime: 0:00:00.047491 FixedProfit: 1189487 TradeTimes: 149 TradeWin: 96
# Episode: 7/25 RapTime: 0:00:00.074197 FixedProfit: 1313597 TradeTimes: 151 TradeWin: 94Episode: 8/25 RapTime: 0:00:00.077359 FixedProfit: 1024572 TradeTimes: 146 TradeWin: 85
#
# Episode: 7/25 RapTime: 0:00:00.059752 FixedProfit: 1197296 TradeTimes: 146 TradeWin: 87Episode: 8/25 RapTime: 0:00:00.083703 FixedProfit: 1111961 TradeTimes: 145 TradeWin: 81
#
# Episode: 9/25 RapTime: 0:00:00.071040 FixedProfit: 916270 TradeTimes: 154 TradeWin: 87
# Episode: 8/25 RapTime: 0:00:00.101651 FixedProfit: 1324164 TradeTimes: 144 TradeWin: 92
# Episode: 9/25 RapTime: 0:00:00.134188 FixedProfit: 1302944 TradeTimes: 145 TradeWin: 93
# Episode: 8/25 RapTime: 0:00:00.058254 FixedProfit: 1017199 TradeTimes: 142 TradeWin: 84
# Episode: 10/25 RapTime: 0:00:00.035154 FixedProfit: 1158972 TradeTimes: 147 TradeWin: 89
# Episode: 9/25 RapTime: 0:00:00.098727 FixedProfit: 1408083 TradeTimes: 155 TradeWin: 96
# Episode: 9/25 RapTime: 0:00:00.107538 FixedProfit: 937323 TradeTimes: 149 TradeWin: 92
# Episode: 10/25 RapTime: 0:00:00.076482 FixedProfit: 1319286 TradeTimes: 135 TradeWin: 85
# Episode: 11/25 RapTime: 0:00:00.071702 FixedProfit: 1488805 TradeTimes: 151 TradeWin: 89
# Episode: 12/25 RapTime: 0:00:00.067638 FixedProfit: 1389345 TradeTimes: 153 TradeWin: 98
# Episode: 10/25 RapTime: 0:00:00.102416 FixedProfit: 1405688 TradeTimes: 148 TradeWin: 92
# Episode: 10/25 RapTime: 0:00:00.086451 FixedProfit: 1332877 TradeTimes: 142 TradeWin: 80
# Episode: 11/25 RapTime: 0:00:00.058371 FixedProfit: 1045395 TradeTimes: 148 TradeWin: 93
# Episode: 13/25 RapTime: 0:00:00.047070 FixedProfit: 1086537 TradeTimes: 143 TradeWin: 78
# Episode: 11/25 RapTime: 0:00:00.083844 FixedProfit: 1284905 TradeTimes: 153 TradeWin: 97Episode: 11/25 RapTime: 0:00:00.108657 FixedProfit: 1588082 TradeTimes: 150 TradeWin: 91
#
# Episode: 12/25 RapTime: 0:00:00.077149 FixedProfit: 1163729 TradeTimes: 141 TradeWin: 87
# Episode: 14/25 RapTime: 0:00:00.070368 FixedProfit: 1641954 TradeTimes: 136 TradeWin: 92
# Episode: 13/25 RapTime: 0:00:00.086710 FixedProfit: 1246654 TradeTimes: 147 TradeWin: 90
# Episode: 12/25 RapTime: 0:00:00.123750 FixedProfit: 1263262 TradeTimes: 150 TradeWin: 92
# Episode: 12/25 RapTime: 0:00:00.078473 FixedProfit: 919330 TradeTimes: 140 TradeWin: 84
# Episode: 15/25 RapTime: 0:00:00.064213 FixedProfit: 794512 TradeTimes: 149 TradeWin: 87
# Episode: 14/25 RapTime: 0:00:00.062782 FixedProfit: 1278801 TradeTimes: 157 TradeWin: 94
# Episode: 13/25 RapTime: 0:00:00.062687 FixedProfit: 1781328 TradeTimes: 132 TradeWin: 85
# Episode: 15/25 RapTime: 0:00:00.065901 FixedProfit: 876447 TradeTimes: 146 TradeWin: 93
# Episode: 13/25 RapTime: 0:00:00.161289 FixedProfit: 943485 TradeTimes: 152 TradeWin: 85
# Episode: 14/25 RapTime: 0:00:00.081469 FixedProfit: 1215056 TradeTimes: 152 TradeWin: 88
# Episode: 16/25 RapTime: 0:00:00.157410 FixedProfit: 1342107 TradeTimes: 144 TradeWin: 94
# Episode: 14/25 RapTime: 0:00:00.064814 FixedProfit: 1191755 TradeTimes: 138 TradeWin: 92
# Episode: 17/25 RapTime: 0:00:00.058426 FixedProfit: 1406400 TradeTimes: 135 TradeWin: 91Episode: 15/25 RapTime: 0:00:00.134157 FixedProfit: 962404 TradeTimes: 156 TradeWin: 94
#
# Episode: 16/25 RapTime: 0:00:00.154829 FixedProfit: 1228580 TradeTimes: 154 TradeWin: 90
# Episode: 15/25 RapTime: 0:00:00.052366 FixedProfit: 1378345 TradeTimes: 140 TradeWin: 93
# Episode: 17/25 RapTime: 0:00:00.073176 FixedProfit: 858423 TradeTimes: 140 TradeWin: 87
# Episode: 16/25 RapTime: 0:00:00.070933 FixedProfit: 1328894 TradeTimes: 133 TradeWin: 77
# Episode: 18/25 RapTime: 0:00:00.138041 FixedProfit: 1077770 TradeTimes: 142 TradeWin: 83
# Episode: 16/25 RapTime: 0:00:00.124315 FixedProfit: 902458 TradeTimes: 143 TradeWin: 75
# Episode: 18/25 RapTime: 0:00:00.055579 FixedProfit: 1428685 TradeTimes: 163 TradeWin: 97
# Episode: 17/25 RapTime: 0:00:00.059049 FixedProfit: 905889 TradeTimes: 141 TradeWin: 85
# Episode: 17/25 RapTime: 0:00:00.094243 FixedProfit: 1415236 TradeTimes: 138 TradeWin: 93
# Episode: 19/25 RapTime: 0:00:00.078699 FixedProfit: 1237408 TradeTimes: 139 TradeWin: 89
# Episode: 19/25 RapTime: 0:00:00.139251 FixedProfit: 1494318 TradeTimes: 168 TradeWin: 104
# Episode: 20/25 RapTime: 0:00:00.075457 FixedProfit: 1743039 TradeTimes: 139 TradeWin: 90
# Episode: 20/25 RapTime: 0:00:00.074534 FixedProfit: 1218988 TradeTimes: 144 TradeWin: 93
# Episode: 18/25 RapTime: 0:00:00.160714 FixedProfit: 1486132 TradeTimes: 156 TradeWin: 89
# Episode: 18/25 RapTime: 0:00:00.144289 FixedProfit: 2083200 TradeTimes: 148 TradeWin: 99
# Episode: 21/25 RapTime: 0:00:00.058764 FixedProfit: 854302 TradeTimes: 142 TradeWin: 84
# Episode: 19/25 RapTime: 0:00:00.090165 FixedProfit: 1044911 TradeTimes: 148 TradeWin: 98
# Episode: 21/25 RapTime: 0:00:00.133336 FixedProfit: 1271660 TradeTimes: 150 TradeWin: 96
# Episode: 19/25 RapTime: 0:00:00.085630 FixedProfit: 1079262 TradeTimes: 154 TradeWin: 92
# Episode: 20/25 RapTime: 0:00:00.049591 FixedProfit: 954083 TradeTimes: 152 TradeWin: 93
# Episode: 22/25 RapTime: 0:00:00.105726 FixedProfit: 1722816 TradeTimes: 151 TradeWin: 97
# Episode: 22/25 RapTime: 0:00:00.064961 FixedProfit: 913212 TradeTimes: 140 TradeWin: 79
# Episode: 20/25 RapTime: 0:00:00.045704 FixedProfit: 1178694 TradeTimes: 151 TradeWin: 92
# Episode: 21/25 RapTime: 0:00:00.130737 FixedProfit: 1222093 TradeTimes: 155 TradeWin: 98
# Episode: 23/25 RapTime: 0:00:00.111345 FixedProfit: 1414309 TradeTimes: 148 TradeWin: 95
# Episode: 21/25 RapTime: 0:00:00.103083 FixedProfit: 1155058 TradeTimes: 149 TradeWin: 79
# Episode: 23/25 RapTime: 0:00:00.146346 FixedProfit: 1850177 TradeTimes: 132 TradeWin: 87
# Episode: 24/25 RapTime: 0:00:00.101044 FixedProfit: 1499042 TradeTimes: 147 TradeWin: 103
# Episode: 22/25 RapTime: 0:00:00.104815 FixedProfit: 1141734 TradeTimes: 153 TradeWin: 83
# Episode: 24/25 RapTime: 0:00:00.104293 FixedProfit: 1540900 TradeTimes: 142 TradeWin: 91
# Episode: 22/25 RapTime: 0:00:00.149312 FixedProfit: 1567976 TradeTimes: 136 TradeWin: 87
# Episode: 25/25 RapTime: 0:00:00.063704 FixedProfit: 1010700 TradeTimes: 141 TradeWin: 85
# Episode: 23/25 RapTime: 0:00:00.068515 FixedProfit: 954306 TradeTimes: 155 TradeWin: 91
# Episode: 23/25 RapTime: 0:00:00.075066 FixedProfit: 1503978 TradeTimes: 136 TradeWin: 84
# Episode: 25/25 RapTime: 0:00:00.165939 FixedProfit: 1167542 TradeTimes: 157 TradeWin: 101
# Episode: 24/25 RapTime: 0:00:00.053289 FixedProfit: 1160782 TradeTimes: 141 TradeWin: 79
# Episode: 24/25 RapTime: 0:00:00.065087 FixedProfit: 987460 TradeTimes: 152 TradeWin: 93
# Episode: 25/25 RapTime: 0:00:00.075040 FixedProfit: 1809970 TradeTimes: 158 TradeWin: 100
# Episode: 25/25 RapTime: 0:00:00.034415 FixedProfit: 927957 TradeTimes: 143 TradeWin: 81
