# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_thread_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from concurrent.futures import ThreadPoolExecutor

mode = 'test'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/m_thread_random_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=1000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2])
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.now_step        = 0
        self.end_step        = self.df_total_steps
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()

        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }


        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand

        return state

    def _get_revenue(self):
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):

        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
        else:
            if self.action_space[0] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1 
            if self.action_space[2] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False

# %%
class Main:
    def __init__(self, env, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.episodes_times = episodes_times
        self.mode = mode

        if self.mode == 'test':
            with open(csv_path, 'w') as f:
                row = 'FixedProfit,TradeTimes,TradeWin'
                print(row, file=f)
        else:
            with open(csv_path, 'w') as f:
                row = 'FixedProfit'
                print(row, file=f)

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            done = False
            start_time = datetime.now()
        
            while not done:
                action = random.randrange(3)
                state, reward, done, info = self.env.step(action)
            
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                    print(row, file=f)
            else:
                print(f"Episode: {episode + 1}/{self.episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue'])
                    print(row, file=f)

# %%
initial_money  = 1000000
episodes_times = 25

thread_num = 4
datas = []
for i in range(thread_num):
    env  = Environment(df, initial_money=initial_money,mode = mode)
    main = Main(env, episodes_times, mode)
    datas.append(main)

features = []
with ThreadPoolExecutor(max_workers=thread_num) as executor:
    for env in datas:
        job = lambda: env.play_game()
        features.append(executor.submit(job))
# Out:
# Episode: 1/25 RapTime: 0:00:00.068697 FixedProfit: 1382480 TradeTimes: 148 TradeWin: 87
# Episode: 1/25 RapTime: 0:00:00.060751 FixedProfit: 1477933 TradeTimes: 132 TradeWin: 80
# Episode: 1/25 RapTime: 0:00:00.117331 FixedProfit: 934277 TradeTimes: 151 TradeWin: 99
# Episode: 1/25 RapTime: 0:00:00.149046 FixedProfit: 1129642 TradeTimes: 144 TradeWin: 88
# Episode: 2/25 RapTime: 0:00:00.064586 FixedProfit: 1486679 TradeTimes: 143 TradeWin: 79
# Episode: 2/25 RapTime: 0:00:00.069079 FixedProfit: 1073802 TradeTimes: 140 TradeWin: 82
# Episode: 2/25 RapTime: 0:00:00.106188 FixedProfit: 1462853 TradeTimes: 150 TradeWin: 92
# Episode: 3/25 RapTime: 0:00:00.060101 FixedProfit: 1223919 TradeTimes: 136 TradeWin: 83
# Episode: 2/25 RapTime: 0:00:00.077206 FixedProfit: 1449642 TradeTimes: 149 TradeWin: 86
# Episode: 4/25 RapTime: 0:00:00.065180 FixedProfit: 1100441 TradeTimes: 149 TradeWin: 87
# Episode: 3/25 RapTime: 0:00:00.086954 FixedProfit: 1178462 TradeTimes: 147 TradeWin: 87
# Episode: 3/25 RapTime: 0:00:00.109835 FixedProfit: 1212102 TradeTimes: 158 TradeWin: 92
# Episode: 3/25 RapTime: 0:00:00.220070 FixedProfit: 1312224 TradeTimes: 139 TradeWin: 78
# Episode: 5/25 RapTime: 0:00:00.066249 FixedProfit: 1615886 TradeTimes: 136 TradeWin: 87
# Episode: 4/25 RapTime: 0:00:00.074950 FixedProfit: 1366160 TradeTimes: 152 TradeWin: 91
# Episode: 4/25 RapTime: 0:00:00.112232 FixedProfit: 1258493 TradeTimes: 146 TradeWin: 93
# Episode: 4/25 RapTime: 0:00:00.074193 FixedProfit: 1009234 TradeTimes: 138 TradeWin: 83
# Episode: 6/25 RapTime: 0:00:00.110247 FixedProfit: 1552594 TradeTimes: 151 TradeWin: 104
# Episode: 5/25 RapTime: 0:00:00.077260 FixedProfit: 1155662 TradeTimes: 146 TradeWin: 93
# Episode: 5/25 RapTime: 0:00:00.106367 FixedProfit: 1638703 TradeTimes: 149 TradeWin: 93
# Episode: 5/25 RapTime: 0:00:00.099165 FixedProfit: 1374231 TradeTimes: 143 TradeWin: 83Episode: 6/25 RapTime: 0:00:00.081326 FixedProfit: 1536272 TradeTimes: 147 TradeWin: 87Episode: 7/25 RapTime: 0:00:00.144427 FixedProfit: 1399511 TradeTimes: 147 TradeWin: 91
#
#
# Episode: 6/25 RapTime: 0:00:00.106760 FixedProfit: 870168 TradeTimes: 144 TradeWin: 81
# Episode: 7/25 RapTime: 0:00:00.066337 FixedProfit: 1197344 TradeTimes: 148 TradeWin: 92
# Episode: 8/25 RapTime: 0:00:00.082857 FixedProfit: 1285137 TradeTimes: 146 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.103867 FixedProfit: 1361594 TradeTimes: 143 TradeWin: 85
# Episode: 6/25 RapTime: 0:00:00.156343 FixedProfit: 1632309 TradeTimes: 128 TradeWin: 82
# Episode: 9/25 RapTime: 0:00:00.075498 FixedProfit: 1282755 TradeTimes: 147 TradeWin: 92
# Episode: 8/25 RapTime: 0:00:00.134220 FixedProfit: 993749 TradeTimes: 157 TradeWin: 90
# Episode: 8/25 RapTime: 0:00:00.068936 FixedProfit: 1961195 TradeTimes: 155 TradeWin: 104
# Episode: 7/25 RapTime: 0:00:00.108360 FixedProfit: 989109 TradeTimes: 140 TradeWin: 78
# Episode: 10/25 RapTime: 0:00:00.105042 FixedProfit: 1373327 TradeTimes: 142 TradeWin: 91
# Episode: 9/25 RapTime: 0:00:00.066461 FixedProfit: 1181772 TradeTimes: 148 TradeWin: 88
# Episode: 9/25 RapTime: 0:00:00.105405 FixedProfit: 1229088 TradeTimes: 145 TradeWin: 85
# Episode: 11/25 RapTime: 0:00:00.065884 FixedProfit: 1493503 TradeTimes: 140 TradeWin: 100
# Episode: 10/25 RapTime: 0:00:00.094609 FixedProfit: 1221336 TradeTimes: 125 TradeWin: 86
# Episode: 8/25 RapTime: 0:00:00.067032 FixedProfit: 1055530 TradeTimes: 151 TradeWin: 92
# Episode: 10/25 RapTime: 0:00:00.066648 FixedProfit: 1331938 TradeTimes: 144 TradeWin: 87
# Episode: 12/25 RapTime: 0:00:00.064552 FixedProfit: 802396 TradeTimes: 133 TradeWin: 79
# Episode: 11/25 RapTime: 0:00:00.120457 FixedProfit: 1277489 TradeTimes: 149 TradeWin: 88
# Episode: 11/25 RapTime: 0:00:00.077559 FixedProfit: 1205711 TradeTimes: 152 TradeWin: 88
# Episode: 9/25 RapTime: 0:00:00.058524 FixedProfit: 1150122 TradeTimes: 144 TradeWin: 92
# Episode: 13/25 RapTime: 0:00:00.142630 FixedProfit: 1149861 TradeTimes: 148 TradeWin: 87
# Episode: 12/25 RapTime: 0:00:00.101084 FixedProfit: 1036673 TradeTimes: 164 TradeWin: 97
# Episode: 10/25 RapTime: 0:00:00.060954 FixedProfit: 1371351 TradeTimes: 144 TradeWin: 86
# Episode: 14/25 RapTime: 0:00:00.064753 FixedProfit: 1894036 TradeTimes: 145 TradeWin: 98
# Episode: 12/25 RapTime: 0:00:00.156228 FixedProfit: 1516186 TradeTimes: 150 TradeWin: 93
# Episode: 11/25 RapTime: 0:00:00.061644 FixedProfit: 1634394 TradeTimes: 156 TradeWin: 96
# Episode: 13/25 RapTime: 0:00:00.054558 FixedProfit: 916327 TradeTimes: 140 TradeWin: 89Episode: 13/25 RapTime: 0:00:00.060275 FixedProfit: 1926659 TradeTimes: 135 TradeWin: 84
#
# Episode: 12/25 RapTime: 0:00:00.065159 FixedProfit: 1546421 TradeTimes: 159 TradeWin: 104Episode: 15/25 RapTime: 0:00:00.100499 FixedProfit: 1254000 TradeTimes: 145 TradeWin: 90
#
# Episode: 14/25 RapTime: 0:00:00.078078 FixedProfit: 1279069 TradeTimes: 151 TradeWin: 89
# Episode: 13/25 RapTime: 0:00:00.067720 FixedProfit: 1246184 TradeTimes: 152 TradeWin: 92
# Episode: 14/25 RapTime: 0:00:00.133817 FixedProfit: 911082 TradeTimes: 150 TradeWin: 93
# Episode: 16/25 RapTime: 0:00:00.137335 FixedProfit: 1034287 TradeTimes: 158 TradeWin: 101
# Episode: 15/25 RapTime: 0:00:00.076491 FixedProfit: 984279 TradeTimes: 161 TradeWin: 89
# Episode: 15/25 RapTime: 0:00:00.129298 FixedProfit: 1169003 TradeTimes: 140 TradeWin: 89Episode: 17/25 RapTime: 0:00:00.089644 FixedProfit: 1959121 TradeTimes: 144 TradeWin: 94
#
# Episode: 14/25 RapTime: 0:00:00.058337 FixedProfit: 1549826 TradeTimes: 146 TradeWin: 92
# Episode: 16/25 RapTime: 0:00:00.091629 FixedProfit: 1323811 TradeTimes: 138 TradeWin: 87
# Episode: 16/25 RapTime: 0:00:00.133100 FixedProfit: 1393619 TradeTimes: 148 TradeWin: 96
# Episode: 18/25 RapTime: 0:00:00.119698 FixedProfit: 1450302 TradeTimes: 149 TradeWin: 94
# Episode: 17/25 RapTime: 0:00:00.136660 FixedProfit: 1081280 TradeTimes: 153 TradeWin: 95
# Episode: 19/25 RapTime: 0:00:00.083137 FixedProfit: 1331888 TradeTimes: 150 TradeWin: 92
# Episode: 17/25 RapTime: 0:00:00.087566 FixedProfit: 1237513 TradeTimes: 153 TradeWin: 92Episode: 15/25 RapTime: 0:00:00.197553 FixedProfit: 1133407 TradeTimes: 147 TradeWin: 93
#
# Episode: 18/25 RapTime: 0:00:00.077680 FixedProfit: 946495 TradeTimes: 141 TradeWin: 83
# Episode: 16/25 RapTime: 0:00:00.111023 FixedProfit: 1228663 TradeTimes: 148 TradeWin: 92
# Episode: 20/25 RapTime: 0:00:00.157477 FixedProfit: 1910350 TradeTimes: 142 TradeWin: 104
# Episode: 18/25 RapTime: 0:00:00.174944 FixedProfit: 1134797 TradeTimes: 147 TradeWin: 84
# Episode: 19/25 RapTime: 0:00:00.078219 FixedProfit: 1675334 TradeTimes: 140 TradeWin: 92
# Episode: 21/25 RapTime: 0:00:00.081006 FixedProfit: 1439438 TradeTimes: 152 TradeWin: 102
# Episode: 17/25 RapTime: 0:00:00.092013 FixedProfit: 1326435 TradeTimes: 136 TradeWin: 82
# Episode: 19/25 RapTime: 0:00:00.127566 FixedProfit: 1281309 TradeTimes: 155 TradeWin: 93
# Episode: 20/25 RapTime: 0:00:00.096484 FixedProfit: 1228243 TradeTimes: 145 TradeWin: 83
# Episode: 22/25 RapTime: 0:00:00.099218 FixedProfit: 1275613 TradeTimes: 149 TradeWin: 91
# Episode: 20/25 RapTime: 0:00:00.102960 FixedProfit: 1405365 TradeTimes: 131 TradeWin: 84
# Episode: 21/25 RapTime: 0:00:00.090708 FixedProfit: 1048899 TradeTimes: 137 TradeWin: 79
# Episode: 18/25 RapTime: 0:00:00.077843 FixedProfit: 1335629 TradeTimes: 159 TradeWin: 104
# Episode: 22/25 RapTime: 0:00:00.082465 FixedProfit: 1087305 TradeTimes: 147 TradeWin: 90
# Episode: 23/25 RapTime: 0:00:00.097862 FixedProfit: 1259296 TradeTimes: 147 TradeWin: 88
# Episode: 21/25 RapTime: 0:00:00.097186 FixedProfit: 1238865 TradeTimes: 146 TradeWin: 95
# Episode: 19/25 RapTime: 0:00:00.121139 FixedProfit: 1222103 TradeTimes: 147 TradeWin: 90
# Episode: 24/25 RapTime: 0:00:00.075177 FixedProfit: 1668768 TradeTimes: 141 TradeWin: 84
# Episode: 23/25 RapTime: 0:00:00.093365 FixedProfit: 1644187 TradeTimes: 157 TradeWin: 98
# Episode: 22/25 RapTime: 0:00:00.147856 FixedProfit: 1717366 TradeTimes: 157 TradeWin: 96
# Episode: 20/25 RapTime: 0:00:00.049254 FixedProfit: 1071190 TradeTimes: 148 TradeWin: 85
# Episode: 23/25 RapTime: 0:00:00.056519 FixedProfit: 1037068 TradeTimes: 149 TradeWin: 83
# Episode: 25/25 RapTime: 0:00:00.070638 FixedProfit: 1589803 TradeTimes: 152 TradeWin: 97
# Episode: 24/25 RapTime: 0:00:00.135617 FixedProfit: 1060250 TradeTimes: 158 TradeWin: 93
# Episode: 24/25 RapTime: 0:00:00.052841 FixedProfit: 1356893 TradeTimes: 148 TradeWin: 88
# Episode: 21/25 RapTime: 0:00:00.148288 FixedProfit: 1027522 TradeTimes: 142 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.078148 FixedProfit: 1150987 TradeTimes: 144 TradeWin: 82
# Episode: 25/25 RapTime: 0:00:00.071534 FixedProfit: 954545 TradeTimes: 146 TradeWin: 81
# Episode: 22/25 RapTime: 0:00:00.102765 FixedProfit: 918347 TradeTimes: 154 TradeWin: 95
# Episode: 23/25 RapTime: 0:00:00.040959 FixedProfit: 1325331 TradeTimes: 150 TradeWin: 99
# Episode: 24/25 RapTime: 0:00:00.040093 FixedProfit: 1680428 TradeTimes: 144 TradeWin: 97
# Episode: 25/25 RapTime: 0:00:00.043946 FixedProfit: 1508624 TradeTimes: 159 TradeWin: 93
