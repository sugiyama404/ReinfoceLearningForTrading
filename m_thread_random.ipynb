# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_thread_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from concurrent.futures import ThreadPoolExecutor

mode = 'test'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/m_thread_random_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.end_step        = self.df_total_steps
        self.now_step        = 0
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
class Main:
    def __init__(self, env, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.episodes_times = episodes_times
        self.mode = mode

        if self.mode == 'test':
            with open(csv_path, 'w') as f:
                row = 'FixedProfit,TradeTimes,TradeWin'
                print(row, file=f)
        else:
            with open(csv_path, 'w') as f:
                row = 'FixedProfit'
                print(row, file=f)

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            done = False
            start_time = datetime.now()
        
            while not done:
                action = random.randrange(3)
                state, reward, done, info = self.env.step(action)
            
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                    print(row, file=f)
            else:
                print(f"Episode: {episode + 1}/{self.episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue'])
                    print(row, file=f)

# %%
initial_money  = 1000000
episodes_times = 25

thread_num = 4
datas = []
for i in range(thread_num):
    env  = Environment(df, initial_money=initial_money,mode = mode)
    main = Main(env, episodes_times, mode)
    datas.append(main)

features = []
with ThreadPoolExecutor(max_workers=thread_num) as executor:
    for env in datas:
        job = lambda: env.play_game()
        features.append(executor.submit(job))
# Out:
# Episode: 1/25 RapTime: 0:00:00.086261 FixedProfit: 1362232 TradeTimes: 154 TradeWin: 101
# Episode: 1/25 RapTime: 0:00:00.099141 FixedProfit: 1130834 TradeTimes: 145 TradeWin: 91
# Episode: 1/25 RapTime: 0:00:00.072756 FixedProfit: 1389796 TradeTimes: 150 TradeWin: 92
# Episode: 1/25 RapTime: 0:00:00.098554 FixedProfit: 1301946 TradeTimes: 154 TradeWin: 98
# Episode: 2/25 RapTime: 0:00:00.066621 FixedProfit: 942857 TradeTimes: 143 TradeWin: 87
# Episode: 2/25 RapTime: 0:00:00.102152 FixedProfit: 1588988 TradeTimes: 148 TradeWin: 95
# Episode: 2/25 RapTime: 0:00:00.124457 FixedProfit: 931027 TradeTimes: 156 TradeWin: 93
# Episode: 2/25 RapTime: 0:00:00.065103 FixedProfit: 1446612 TradeTimes: 147 TradeWin: 93
# Episode: 3/25 RapTime: 0:00:00.050021 FixedProfit: 914607 TradeTimes: 152 TradeWin: 94
# Episode: 3/25 RapTime: 0:00:00.115055 FixedProfit: 1281313 TradeTimes: 139 TradeWin: 87
# Episode: 4/25 RapTime: 0:00:00.099364 FixedProfit: 1039809 TradeTimes: 141 TradeWin: 89
# Episode: 3/25 RapTime: 0:00:00.121659 FixedProfit: 1147343 TradeTimes: 149 TradeWin: 93
# Episode: 4/25 RapTime: 0:00:00.056179 FixedProfit: 1012182 TradeTimes: 139 TradeWin: 83
# Episode: 3/25 RapTime: 0:00:00.123785 FixedProfit: 1479979 TradeTimes: 158 TradeWin: 103
# Episode: 4/25 RapTime: 0:00:00.068004 FixedProfit: 946468 TradeTimes: 145 TradeWin: 88
# Episode: 5/25 RapTime: 0:00:00.108318 FixedProfit: 1244772 TradeTimes: 149 TradeWin: 95
# Episode: 4/25 RapTime: 0:00:00.067349 FixedProfit: 1079226 TradeTimes: 141 TradeWin: 80
# Episode: 5/25 RapTime: 0:00:00.120117 FixedProfit: 1146583 TradeTimes: 147 TradeWin: 89
# Episode: 5/25 RapTime: 0:00:00.079158 FixedProfit: 1108722 TradeTimes: 154 TradeWin: 101
# Episode: 6/25 RapTime: 0:00:00.088812 FixedProfit: 1495946 TradeTimes: 160 TradeWin: 95
# Episode: 6/25 RapTime: 0:00:00.080257 FixedProfit: 1222622 TradeTimes: 131 TradeWin: 87
# Episode: 5/25 RapTime: 0:00:00.131867 FixedProfit: 1193901 TradeTimes: 157 TradeWin: 95
# Episode: 6/25 RapTime: 0:00:00.077531 FixedProfit: 965865 TradeTimes: 145 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.066488 FixedProfit: 1168944 TradeTimes: 142 TradeWin: 83
# Episode: 7/25 RapTime: 0:00:00.072269 FixedProfit: 1154487 TradeTimes: 151 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.056733 FixedProfit: 1577257 TradeTimes: 137 TradeWin: 85
# Episode: 8/25 RapTime: 0:00:00.082979 FixedProfit: 942581 TradeTimes: 136 TradeWin: 83
# Episode: 6/25 RapTime: 0:00:00.164498 FixedProfit: 1107150 TradeTimes: 149 TradeWin: 94
# Episode: 8/25 RapTime: 0:00:00.140101 FixedProfit: 1122411 TradeTimes: 148 TradeWin: 79
# Episode: 8/25 RapTime: 0:00:00.127384 FixedProfit: 1504781 TradeTimes: 150 TradeWin: 96
# Episode: 9/25 RapTime: 0:00:00.102475 FixedProfit: 1109599 TradeTimes: 146 TradeWin: 88
# Episode: 7/25 RapTime: 0:00:00.087239 FixedProfit: 1542265 TradeTimes: 149 TradeWin: 88
# Episode: 9/25 RapTime: 0:00:00.087768 FixedProfit: 957056 TradeTimes: 150 TradeWin: 90
# Episode: 9/25 RapTime: 0:00:00.103999 FixedProfit: 975484 TradeTimes: 162 TradeWin: 88
# Episode: 10/25 RapTime: 0:00:00.064340 FixedProfit: 976893 TradeTimes: 149 TradeWin: 88
# Episode: 8/25 RapTime: 0:00:00.090174 FixedProfit: 1133943 TradeTimes: 156 TradeWin: 90
# Episode: 10/25 RapTime: 0:00:00.083194 FixedProfit: 1048701 TradeTimes: 140 TradeWin: 82
# Episode: 10/25 RapTime: 0:00:00.113577 FixedProfit: 1175638 TradeTimes: 148 TradeWin: 85
# Episode: 9/25 RapTime: 0:00:00.099695 FixedProfit: 1351292 TradeTimes: 150 TradeWin: 94
# Episode: 11/25 RapTime: 0:00:00.060064 FixedProfit: 928666 TradeTimes: 147 TradeWin: 80
# Episode: 11/25 RapTime: 0:00:00.171308 FixedProfit: 1210540 TradeTimes: 139 TradeWin: 89
# Episode: 11/25 RapTime: 0:00:00.121189 FixedProfit: 1356599 TradeTimes: 147 TradeWin: 94
# Episode: 10/25 RapTime: 0:00:00.075928 FixedProfit: 946272 TradeTimes: 157 TradeWin: 93
# Episode: 12/25 RapTime: 0:00:00.070361 FixedProfit: 1537121 TradeTimes: 138 TradeWin: 86
# Episode: 12/25 RapTime: 0:00:00.103781 FixedProfit: 1161019 TradeTimes: 145 TradeWin: 84
# Episode: 11/25 RapTime: 0:00:00.082293 FixedProfit: 1076491 TradeTimes: 141 TradeWin: 90
# Episode: 12/25 RapTime: 0:00:00.062007 FixedProfit: 1230975 TradeTimes: 153 TradeWin: 103
# Episode: 13/25 RapTime: 0:00:00.074932 FixedProfit: 945821 TradeTimes: 148 TradeWin: 94
# Episode: 12/25 RapTime: 0:00:00.144890 FixedProfit: 1406771 TradeTimes: 149 TradeWin: 94Episode: 13/25 RapTime: 0:00:00.117807 FixedProfit: 1499813 TradeTimes: 145 TradeWin: 96
#
# Episode: 14/25 RapTime: 0:00:00.072116 FixedProfit: 1236654 TradeTimes: 157 TradeWin: 95
# Episode: 13/25 RapTime: 0:00:00.041074 FixedProfit: 1052767 TradeTimes: 138 TradeWin: 79
# Episode: 14/25 RapTime: 0:00:00.080192 FixedProfit: 1276135 TradeTimes: 133 TradeWin: 83
# Episode: 13/25 RapTime: 0:00:00.110192 FixedProfit: 1041105 TradeTimes: 148 TradeWin: 92
# Episode: 15/25 RapTime: 0:00:00.076495 FixedProfit: 1228657 TradeTimes: 159 TradeWin: 93
# Episode: 15/25 RapTime: 0:00:00.050009 FixedProfit: 1468747 TradeTimes: 151 TradeWin: 98
# Episode: 14/25 RapTime: 0:00:00.158753 FixedProfit: 958625 TradeTimes: 138 TradeWin: 86
# Episode: 16/25 RapTime: 0:00:00.059080 FixedProfit: 814063 TradeTimes: 141 TradeWin: 86
# Episode: 14/25 RapTime: 0:00:00.102390 FixedProfit: 1105198 TradeTimes: 149 TradeWin: 91
# Episode: 15/25 RapTime: 0:00:00.089389 FixedProfit: 1280783 TradeTimes: 154 TradeWin: 97
# Episode: 17/25 RapTime: 0:00:00.086485 FixedProfit: 1595872 TradeTimes: 146 TradeWin: 88
# Episode: 16/25 RapTime: 0:00:00.137570 FixedProfit: 1237100 TradeTimes: 148 TradeWin: 89
# Episode: 15/25 RapTime: 0:00:00.113888 FixedProfit: 1149534 TradeTimes: 150 TradeWin: 90
# Episode: 18/25 RapTime: 0:00:00.073996 FixedProfit: 1236333 TradeTimes: 149 TradeWin: 98
# Episode: 16/25 RapTime: 0:00:00.095807 FixedProfit: 1440544 TradeTimes: 153 TradeWin: 101
# Episode: 17/25 RapTime: 0:00:00.114673 FixedProfit: 1015757 TradeTimes: 147 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.083689 FixedProfit: 1193151 TradeTimes: 140 TradeWin: 89Episode: 19/25 RapTime: 0:00:00.118764 FixedProfit: 1422511 TradeTimes: 146 TradeWin: 87
#
# Episode: 18/25 RapTime: 0:00:00.121209 FixedProfit: 1293347 TradeTimes: 151 TradeWin: 96Episode: 16/25 RapTime: 0:00:00.154701 FixedProfit: 984565 TradeTimes: 157 TradeWin: 94
#
# Episode: 20/25 RapTime: 0:00:00.076676 FixedProfit: 1296325 TradeTimes: 140 TradeWin: 94
# Episode: 18/25 RapTime: 0:00:00.113225 FixedProfit: 1079306 TradeTimes: 149 TradeWin: 84Episode: 17/25 RapTime: 0:00:00.096159 FixedProfit: 1178413 TradeTimes: 148 TradeWin: 88
#
# Episode: 19/25 RapTime: 0:00:00.066481 FixedProfit: 1424164 TradeTimes: 144 TradeWin: 93
# Episode: 21/25 RapTime: 0:00:00.055252 FixedProfit: 1012889 TradeTimes: 149 TradeWin: 80
# Episode: 19/25 RapTime: 0:00:00.156929 FixedProfit: 1242162 TradeTimes: 148 TradeWin: 88
# Episode: 22/25 RapTime: 0:00:00.078286 FixedProfit: 957736 TradeTimes: 150 TradeWin: 97
# Episode: 20/25 RapTime: 0:00:00.098795 FixedProfit: 1353068 TradeTimes: 149 TradeWin: 94
# Episode: 18/25 RapTime: 0:00:00.145312 FixedProfit: 1152248 TradeTimes: 157 TradeWin: 95
# Episode: 23/25 RapTime: 0:00:00.138011 FixedProfit: 1477000 TradeTimes: 146 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.099362 FixedProfit: 952766 TradeTimes: 148 TradeWin: 91
# Episode: 21/25 RapTime: 0:00:00.147248 FixedProfit: 1414550 TradeTimes: 152 TradeWin: 91
# Episode: 20/25 RapTime: 0:00:00.095948 FixedProfit: 1489344 TradeTimes: 145 TradeWin: 87
# Episode: 24/25 RapTime: 0:00:00.075627 FixedProfit: 1347581 TradeTimes: 161 TradeWin: 94
# Episode: 20/25 RapTime: 0:00:00.076765 FixedProfit: 1465480 TradeTimes: 149 TradeWin: 93
# Episode: 22/25 RapTime: 0:00:00.058319 FixedProfit: 1083109 TradeTimes: 145 TradeWin: 88
# Episode: 21/25 RapTime: 0:00:00.084646 FixedProfit: 1052634 TradeTimes: 156 TradeWin: 95
# Episode: 25/25 RapTime: 0:00:00.102263 FixedProfit: 1303245 TradeTimes: 135 TradeWin: 86
# Episode: 23/25 RapTime: 0:00:00.102644 FixedProfit: 1433922 TradeTimes: 152 TradeWin: 94
# Episode: 21/25 RapTime: 0:00:00.102501 FixedProfit: 1381392 TradeTimes: 156 TradeWin: 100
# Episode: 22/25 RapTime: 0:00:00.066291 FixedProfit: 1137023 TradeTimes: 138 TradeWin: 74
# Episode: 24/25 RapTime: 0:00:00.048731 FixedProfit: 1287181 TradeTimes: 136 TradeWin: 81
# Episode: 23/25 RapTime: 0:00:00.094476 FixedProfit: 1441789 TradeTimes: 153 TradeWin: 97Episode: 22/25 RapTime: 0:00:00.106966 FixedProfit: 1252618 TradeTimes: 157 TradeWin: 93
# Episode: 25/25 RapTime: 0:00:00.063090 FixedProfit: 1351692 TradeTimes: 145 TradeWin: 88
#
# Episode: 23/25 RapTime: 0:00:00.068968 FixedProfit: 1458071 TradeTimes: 144 TradeWin: 95
# Episode: 24/25 RapTime: 0:00:00.061335 FixedProfit: 1104920 TradeTimes: 155 TradeWin: 98
# Episode: 24/25 RapTime: 0:00:00.076966 FixedProfit: 1539684 TradeTimes: 146 TradeWin: 96Episode: 25/25 RapTime: 0:00:00.071110 FixedProfit: 1212191 TradeTimes: 157 TradeWin: 98
#
# Episode: 25/25 RapTime: 0:00:00.042593 FixedProfit: 1315315 TradeTimes: 156 TradeWin: 103
