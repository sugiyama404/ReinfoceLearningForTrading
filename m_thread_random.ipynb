# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_thread_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from concurrent.futures import ThreadPoolExecutor

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_thread_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
    
        while not done:
            action = random.randrange(3)
            state, reward, done, info = env.step(action)
        
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)

thread_num = 4
datas = []
for i in range(thread_num):
    e = Environment(df, initial_money=initial_money,mode = mode)
    datas.append(e)

features = []
with ThreadPoolExecutor(max_workers=thread_num) as executor:
    for env in datas:
        job = lambda: play_game(env)
        features.append(executor.submit(job))
# Out:
# Episode: 1/25 RapTime: 0:00:00.147979 FixedProfit: 1516315 TradeTimes: 147 TradeWin: 98
# Episode: 1/25 RapTime: 0:00:00.139498 FixedProfit: 1655023 TradeTimes: 150 TradeWin: 93
# Episode: 1/25 RapTime: 0:00:00.180091 FixedProfit: 1624512 TradeTimes: 151 TradeWin: 92
# Episode: 1/25 RapTime: 0:00:00.175612 FixedProfit: 1173340 TradeTimes: 150 TradeWin: 91
# Episode: 2/25 RapTime: 0:00:00.121002 FixedProfit: 1645270 TradeTimes: 135 TradeWin: 90
# Episode: 2/25 RapTime: 0:00:00.171710 FixedProfit: 1034272 TradeTimes: 147 TradeWin: 93
# Episode: 2/25 RapTime: 0:00:00.167449 FixedProfit: 1184352 TradeTimes: 155 TradeWin: 96
# Episode: 2/25 RapTime: 0:00:00.165194 FixedProfit: 1039332 TradeTimes: 153 TradeWin: 91
# Episode: 3/25 RapTime: 0:00:00.064524 FixedProfit: 897777 TradeTimes: 168 TradeWin: 94
# Episode: 3/25 RapTime: 0:00:00.124238 FixedProfit: 1302857 TradeTimes: 149 TradeWin: 93
# Episode: 3/25 RapTime: 0:00:00.110093 FixedProfit: 1415993 TradeTimes: 141 TradeWin: 87
# Episode: 3/25 RapTime: 0:00:00.146639 FixedProfit: 1527679 TradeTimes: 144 TradeWin: 96
# Episode: 4/25 RapTime: 0:00:00.108897 FixedProfit: 1105624 TradeTimes: 161 TradeWin: 99
# Episode: 4/25 RapTime: 0:00:00.125380 FixedProfit: 967493 TradeTimes: 149 TradeWin: 86
# Episode: 4/25 RapTime: 0:00:00.173057 FixedProfit: 1095818 TradeTimes: 163 TradeWin: 102
# Episode: 4/25 RapTime: 0:00:00.110273 FixedProfit: 1777043 TradeTimes: 150 TradeWin: 91
# Episode: 5/25 RapTime: 0:00:00.086955 FixedProfit: 964397 TradeTimes: 152 TradeWin: 93
# Episode: 5/25 RapTime: 0:00:00.085920 FixedProfit: 1520448 TradeTimes: 151 TradeWin: 86
# Episode: 5/25 RapTime: 0:00:00.119213 FixedProfit: 995332 TradeTimes: 150 TradeWin: 88
# Episode: 5/25 RapTime: 0:00:00.143790 FixedProfit: 1116170 TradeTimes: 145 TradeWin: 87
# Episode: 6/25 RapTime: 0:00:00.138554 FixedProfit: 1854214 TradeTimes: 152 TradeWin: 102
# Episode: 6/25 RapTime: 0:00:00.158033 FixedProfit: 1778671 TradeTimes: 154 TradeWin: 104
# Episode: 6/25 RapTime: 0:00:00.116065 FixedProfit: 1060596 TradeTimes: 149 TradeWin: 94
# Episode: 6/25 RapTime: 0:00:00.196067 FixedProfit: 1312303 TradeTimes: 147 TradeWin: 88
# Episode: 7/25 RapTime: 0:00:00.143944 FixedProfit: 1485957 TradeTimes: 151 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.083823 FixedProfit: 1388588 TradeTimes: 145 TradeWin: 95
# Episode: 7/25 RapTime: 0:00:00.093718 FixedProfit: 1189680 TradeTimes: 136 TradeWin: 81
# Episode: 8/25 RapTime: 0:00:00.108547 FixedProfit: 1774287 TradeTimes: 143 TradeWin: 96
# Episode: 8/25 RapTime: 0:00:00.166107 FixedProfit: 1273428 TradeTimes: 151 TradeWin: 87
# Episode: 7/25 RapTime: 0:00:00.198507 FixedProfit: 1283686 TradeTimes: 141 TradeWin: 94
# Episode: 8/25 RapTime: 0:00:00.120937 FixedProfit: 1522197 TradeTimes: 152 TradeWin: 95
# Episode: 9/25 RapTime: 0:00:00.152845 FixedProfit: 1395273 TradeTimes: 143 TradeWin: 89
# Episode: 8/25 RapTime: 0:00:00.176091 FixedProfit: 1533517 TradeTimes: 139 TradeWin: 86
# Episode: 9/25 RapTime: 0:00:00.205605 FixedProfit: 866365 TradeTimes: 158 TradeWin: 87
# Episode: 9/25 RapTime: 0:00:00.096475 FixedProfit: 1132597 TradeTimes: 161 TradeWin: 97
# Episode: 10/25 RapTime: 0:00:00.120143 FixedProfit: 1050129 TradeTimes: 164 TradeWin: 102
# Episode: 9/25 RapTime: 0:00:00.147930 FixedProfit: 1243948 TradeTimes: 144 TradeWin: 85
# Episode: 10/25 RapTime: 0:00:00.132766 FixedProfit: 1378724 TradeTimes: 152 TradeWin: 94
# Episode: 11/25 RapTime: 0:00:00.061580 FixedProfit: 1257783 TradeTimes: 133 TradeWin: 82
# Episode: 11/25 RapTime: 0:00:00.110389 FixedProfit: 1076169 TradeTimes: 152 TradeWin: 94
# Episode: 10/25 RapTime: 0:00:00.105792 FixedProfit: 1462804 TradeTimes: 149 TradeWin: 93
# Episode: 10/25 RapTime: 0:00:00.193007 FixedProfit: 877829 TradeTimes: 148 TradeWin: 86
# Episode: 12/25 RapTime: 0:00:00.147196 FixedProfit: 1522868 TradeTimes: 149 TradeWin: 95
# Episode: 11/25 RapTime: 0:00:00.145471 FixedProfit: 964633 TradeTimes: 143 TradeWin: 80
# Episode: 12/25 RapTime: 0:00:00.173363 FixedProfit: 1958110 TradeTimes: 140 TradeWin: 87
# Episode: 11/25 RapTime: 0:00:00.223797 FixedProfit: 1445931 TradeTimes: 150 TradeWin: 96Episode: 12/25 RapTime: 0:00:00.100192 FixedProfit: 1243188 TradeTimes: 145 TradeWin: 88
#
# Episode: 13/25 RapTime: 0:00:00.119785 FixedProfit: 1008497 TradeTimes: 146 TradeWin: 77
# Episode: 13/25 RapTime: 0:00:00.068107 FixedProfit: 1358568 TradeTimes: 133 TradeWin: 85
# Episode: 13/25 RapTime: 0:00:00.066821 FixedProfit: 902000 TradeTimes: 150 TradeWin: 88
# Episode: 14/25 RapTime: 0:00:00.146591 FixedProfit: 1398127 TradeTimes: 149 TradeWin: 96
# Episode: 14/25 RapTime: 0:00:00.184301 FixedProfit: 1214806 TradeTimes: 163 TradeWin: 93
# Episode: 12/25 RapTime: 0:00:00.176643 FixedProfit: 1146101 TradeTimes: 152 TradeWin: 95
# Episode: 14/25 RapTime: 0:00:00.101833 FixedProfit: 1546925 TradeTimes: 144 TradeWin: 90
# Episode: 15/25 RapTime: 0:00:00.099290 FixedProfit: 943701 TradeTimes: 146 TradeWin: 83
# Episode: 13/25 RapTime: 0:00:00.135440 FixedProfit: 1191876 TradeTimes: 142 TradeWin: 93
# Episode: 15/25 RapTime: 0:00:00.159330 FixedProfit: 891093 TradeTimes: 150 TradeWin: 90
# Episode: 15/25 RapTime: 0:00:00.118269 FixedProfit: 1113619 TradeTimes: 147 TradeWin: 91
# Episode: 16/25 RapTime: 0:00:00.098589 FixedProfit: 1016004 TradeTimes: 148 TradeWin: 89
# Episode: 14/25 RapTime: 0:00:00.146074 FixedProfit: 983307 TradeTimes: 148 TradeWin: 101
# Episode: 16/25 RapTime: 0:00:00.133030 FixedProfit: 985315 TradeTimes: 154 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.139172 FixedProfit: 1768015 TradeTimes: 158 TradeWin: 111
# Episode: 15/25 RapTime: 0:00:00.104047 FixedProfit: 1497448 TradeTimes: 139 TradeWin: 84Episode: 16/25 RapTime: 0:00:00.160786 FixedProfit: 997255 TradeTimes: 147 TradeWin: 86
#
# Episode: 17/25 RapTime: 0:00:00.133768 FixedProfit: 1258550 TradeTimes: 160 TradeWin: 97
# Episode: 18/25 RapTime: 0:00:00.139214 FixedProfit: 1293533 TradeTimes: 145 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.177384 FixedProfit: 1280949 TradeTimes: 150 TradeWin: 101
# Episode: 16/25 RapTime: 0:00:00.179362 FixedProfit: 1198549 TradeTimes: 146 TradeWin: 89
# Episode: 18/25 RapTime: 0:00:00.107806 FixedProfit: 1652178 TradeTimes: 146 TradeWin: 100
# Episode: 17/25 RapTime: 0:00:00.122048 FixedProfit: 1648579 TradeTimes: 154 TradeWin: 101
# Episode: 18/25 RapTime: 0:00:00.118368 FixedProfit: 1371542 TradeTimes: 142 TradeWin: 90
# Episode: 19/25 RapTime: 0:00:00.189144 FixedProfit: 1544853 TradeTimes: 144 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.077885 FixedProfit: 1404502 TradeTimes: 141 TradeWin: 81
# Episode: 19/25 RapTime: 0:00:00.117772 FixedProfit: 1130779 TradeTimes: 137 TradeWin: 85
# Episode: 18/25 RapTime: 0:00:00.088733 FixedProfit: 1116254 TradeTimes: 162 TradeWin: 98
# Episode: 20/25 RapTime: 0:00:00.110689 FixedProfit: 1096565 TradeTimes: 138 TradeWin: 92
# Episode: 20/25 RapTime: 0:00:00.166010 FixedProfit: 1203373 TradeTimes: 146 TradeWin: 93
# Episode: 19/25 RapTime: 0:00:00.112915 FixedProfit: 1097488 TradeTimes: 147 TradeWin: 93
# Episode: 20/25 RapTime: 0:00:00.096004 FixedProfit: 1176582 TradeTimes: 139 TradeWin: 87
# Episode: 21/25 RapTime: 0:00:00.084382 FixedProfit: 1013834 TradeTimes: 144 TradeWin: 79
# Episode: 21/25 RapTime: 0:00:00.098630 FixedProfit: 1143232 TradeTimes: 143 TradeWin: 88
# Episode: 22/25 RapTime: 0:00:00.086789 FixedProfit: 1555121 TradeTimes: 141 TradeWin: 85
# Episode: 21/25 RapTime: 0:00:00.108166 FixedProfit: 1471305 TradeTimes: 141 TradeWin: 95
# Episode: 20/25 RapTime: 0:00:00.229566 FixedProfit: 1266747 TradeTimes: 145 TradeWin: 96
# Episode: 22/25 RapTime: 0:00:00.167256 FixedProfit: 873069 TradeTimes: 144 TradeWin: 81
# Episode: 23/25 RapTime: 0:00:00.077012 FixedProfit: 1401164 TradeTimes: 140 TradeWin: 89
# Episode: 22/25 RapTime: 0:00:00.143523 FixedProfit: 1240951 TradeTimes: 137 TradeWin: 78
# Episode: 23/25 RapTime: 0:00:00.067212 FixedProfit: 1414829 TradeTimes: 159 TradeWin: 93
# Episode: 21/25 RapTime: 0:00:00.197602 FixedProfit: 1140544 TradeTimes: 153 TradeWin: 105
# Episode: 23/25 RapTime: 0:00:00.123527 FixedProfit: 921476 TradeTimes: 150 TradeWin: 84
# Episode: 24/25 RapTime: 0:00:00.126134 FixedProfit: 1239902 TradeTimes: 151 TradeWin: 95
# Episode: 24/25 RapTime: 0:00:00.178498 FixedProfit: 1398377 TradeTimes: 148 TradeWin: 88
# Episode: 22/25 RapTime: 0:00:00.159812 FixedProfit: 1472698 TradeTimes: 163 TradeWin: 94
# Episode: 24/25 RapTime: 0:00:00.142569 FixedProfit: 1320119 TradeTimes: 140 TradeWin: 83Episode: 25/25 RapTime: 0:00:00.140428 FixedProfit: 1466727 TradeTimes: 145 TradeWin: 91
# Episode: 25/25 RapTime: 0:00:00.149070 FixedProfit: 1383238 TradeTimes: 141 TradeWin: 88
#
# Episode: 23/25 RapTime: 0:00:00.091559 FixedProfit: 765993 TradeTimes: 145 TradeWin: 80
# Episode: 25/25 RapTime: 0:00:00.078012 FixedProfit: 1092648 TradeTimes: 146 TradeWin: 91
# Episode: 24/25 RapTime: 0:00:00.088449 FixedProfit: 1492312 TradeTimes: 145 TradeWin: 100
# Episode: 25/25 RapTime: 0:00:00.047358 FixedProfit: 1053817 TradeTimes: 146 TradeWin: 84
