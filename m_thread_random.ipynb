# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_thread_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from concurrent.futures import ThreadPoolExecutor as PoolExecutor

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_thread_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
    
        while not done:
            action = random.randrange(3)
            state, reward, done, info = env.step(action)
        
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)

thread_num = 4
datas = []
for i in range(thread_num):
    e = Environment(df, initial_money=initial_money,mode = mode)
    datas.append(e)

features = []
with PoolExecutor(max_workers=thread_num) as executor:
    for env in datas:
        job = play_game(env)
        features.append(executor.submit(job))
# Out:
# Episode: 1/25 RapTime: 0:00:00.037352 FixedProfit: 1122850 TradeTimes: 152 TradeWin: 91
# Episode: 2/25 RapTime: 0:00:00.039455 FixedProfit: 1445747 TradeTimes: 150 TradeWin: 92
# Episode: 3/25 RapTime: 0:00:00.041954 FixedProfit: 1069888 TradeTimes: 155 TradeWin: 99
# Episode: 4/25 RapTime: 0:00:00.036319 FixedProfit: 1268949 TradeTimes: 138 TradeWin: 85
# Episode: 5/25 RapTime: 0:00:00.042031 FixedProfit: 1598163 TradeTimes: 144 TradeWin: 94
# Episode: 6/25 RapTime: 0:00:00.037718 FixedProfit: 1017695 TradeTimes: 154 TradeWin: 99
# Episode: 7/25 RapTime: 0:00:00.037346 FixedProfit: 1168936 TradeTimes: 146 TradeWin: 94
# Episode: 8/25 RapTime: 0:00:00.042910 FixedProfit: 1424094 TradeTimes: 157 TradeWin: 91
# Episode: 9/25 RapTime: 0:00:00.037521 FixedProfit: 1132547 TradeTimes: 153 TradeWin: 90
# Episode: 10/25 RapTime: 0:00:00.037531 FixedProfit: 1748807 TradeTimes: 125 TradeWin: 82
# Episode: 11/25 RapTime: 0:00:00.035217 FixedProfit: 1092771 TradeTimes: 143 TradeWin: 89
# Episode: 12/25 RapTime: 0:00:00.036792 FixedProfit: 1299996 TradeTimes: 154 TradeWin: 95
# Episode: 13/25 RapTime: 0:00:00.042551 FixedProfit: 1226476 TradeTimes: 152 TradeWin: 93
# Episode: 14/25 RapTime: 0:00:00.038673 FixedProfit: 1406950 TradeTimes: 150 TradeWin: 104
# Episode: 15/25 RapTime: 0:00:00.049911 FixedProfit: 1770250 TradeTimes: 145 TradeWin: 92
# Episode: 16/25 RapTime: 0:00:00.033885 FixedProfit: 1019247 TradeTimes: 150 TradeWin: 81
# Episode: 17/25 RapTime: 0:00:00.042257 FixedProfit: 1506447 TradeTimes: 158 TradeWin: 98
# Episode: 18/25 RapTime: 0:00:00.037217 FixedProfit: 1065773 TradeTimes: 149 TradeWin: 90
# Episode: 19/25 RapTime: 0:00:00.036480 FixedProfit: 1416913 TradeTimes: 139 TradeWin: 85
# Episode: 20/25 RapTime: 0:00:00.042048 FixedProfit: 1368430 TradeTimes: 151 TradeWin: 96
# Episode: 21/25 RapTime: 0:00:00.041345 FixedProfit: 1781275 TradeTimes: 136 TradeWin: 91
# Episode: 22/25 RapTime: 0:00:00.041345 FixedProfit: 1100717 TradeTimes: 153 TradeWin: 98
# Episode: 23/25 RapTime: 0:00:00.038090 FixedProfit: 1256402 TradeTimes: 149 TradeWin: 91
# Episode: 24/25 RapTime: 0:00:00.045115 FixedProfit: 1670225 TradeTimes: 154 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.033425 FixedProfit: 1234668 TradeTimes: 139 TradeWin: 78
# Episode: 1/25 RapTime: 0:00:00.041483 FixedProfit: 1241610 TradeTimes: 155 TradeWin: 91
# Episode: 2/25 RapTime: 0:00:00.038105 FixedProfit: 1143671 TradeTimes: 146 TradeWin: 91
# Episode: 3/25 RapTime: 0:00:00.038184 FixedProfit: 1541814 TradeTimes: 160 TradeWin: 100
# Episode: 4/25 RapTime: 0:00:00.043556 FixedProfit: 1316094 TradeTimes: 148 TradeWin: 94
# Episode: 5/25 RapTime: 0:00:00.036914 FixedProfit: 1250969 TradeTimes: 151 TradeWin: 100
# Episode: 6/25 RapTime: 0:00:00.040405 FixedProfit: 1056412 TradeTimes: 149 TradeWin: 80
# Episode: 7/25 RapTime: 0:00:00.040267 FixedProfit: 1300965 TradeTimes: 155 TradeWin: 92
# Episode: 8/25 RapTime: 0:00:00.040786 FixedProfit: 1257757 TradeTimes: 146 TradeWin: 88
# Episode: 9/25 RapTime: 0:00:00.037412 FixedProfit: 1072750 TradeTimes: 137 TradeWin: 81
# Episode: 10/25 RapTime: 0:00:00.041930 FixedProfit: 1374544 TradeTimes: 154 TradeWin: 108
# Episode: 11/25 RapTime: 0:00:00.043620 FixedProfit: 1256043 TradeTimes: 157 TradeWin: 90
# Episode: 12/25 RapTime: 0:00:00.034811 FixedProfit: 1341119 TradeTimes: 143 TradeWin: 86
# Episode: 13/25 RapTime: 0:00:00.039382 FixedProfit: 1319074 TradeTimes: 143 TradeWin: 88
# Episode: 14/25 RapTime: 0:00:00.039091 FixedProfit: 771441 TradeTimes: 140 TradeWin: 85
# Episode: 15/25 RapTime: 0:00:00.036963 FixedProfit: 1481214 TradeTimes: 142 TradeWin: 97
# Episode: 16/25 RapTime: 0:00:00.044219 FixedProfit: 1739067 TradeTimes: 148 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.038836 FixedProfit: 1755207 TradeTimes: 140 TradeWin: 84
# Episode: 18/25 RapTime: 0:00:00.038357 FixedProfit: 1250509 TradeTimes: 145 TradeWin: 88
# Episode: 19/25 RapTime: 0:00:00.040110 FixedProfit: 1534459 TradeTimes: 146 TradeWin: 100
# Episode: 20/25 RapTime: 0:00:00.036690 FixedProfit: 983269 TradeTimes: 162 TradeWin: 103
# Episode: 21/25 RapTime: 0:00:00.040364 FixedProfit: 951617 TradeTimes: 146 TradeWin: 90
# Episode: 22/25 RapTime: 0:00:00.037510 FixedProfit: 1137008 TradeTimes: 152 TradeWin: 100
# Episode: 23/25 RapTime: 0:00:00.040129 FixedProfit: 1277628 TradeTimes: 146 TradeWin: 96
# Episode: 24/25 RapTime: 0:00:00.035100 FixedProfit: 1033451 TradeTimes: 138 TradeWin: 81
# Episode: 25/25 RapTime: 0:00:00.034507 FixedProfit: 1153583 TradeTimes: 138 TradeWin: 89
# Episode: 1/25 RapTime: 0:00:00.046342 FixedProfit: 1446603 TradeTimes: 155 TradeWin: 95
# Episode: 2/25 RapTime: 0:00:00.037905 FixedProfit: 1296513 TradeTimes: 145 TradeWin: 91
# Episode: 3/25 RapTime: 0:00:00.038157 FixedProfit: 1367204 TradeTimes: 144 TradeWin: 94
# Episode: 4/25 RapTime: 0:00:00.038934 FixedProfit: 1467670 TradeTimes: 144 TradeWin: 95
# Episode: 5/25 RapTime: 0:00:00.033603 FixedProfit: 1102365 TradeTimes: 140 TradeWin: 84
# Episode: 6/25 RapTime: 0:00:00.044287 FixedProfit: 1579356 TradeTimes: 151 TradeWin: 89
# Episode: 7/25 RapTime: 0:00:00.034704 FixedProfit: 1322554 TradeTimes: 134 TradeWin: 86
# Episode: 8/25 RapTime: 0:00:00.040467 FixedProfit: 1220690 TradeTimes: 152 TradeWin: 94
# Episode: 9/25 RapTime: 0:00:00.038721 FixedProfit: 1448461 TradeTimes: 153 TradeWin: 95
# Episode: 10/25 RapTime: 0:00:00.036404 FixedProfit: 1138002 TradeTimes: 151 TradeWin: 90
# Episode: 11/25 RapTime: 0:00:00.041221 FixedProfit: 1264982 TradeTimes: 150 TradeWin: 94
# Episode: 12/25 RapTime: 0:00:00.031643 FixedProfit: 844830 TradeTimes: 133 TradeWin: 77
# Episode: 13/25 RapTime: 0:00:00.034512 FixedProfit: 1144247 TradeTimes: 147 TradeWin: 90
# Episode: 14/25 RapTime: 0:00:00.044990 FixedProfit: 1597707 TradeTimes: 148 TradeWin: 97
# Episode: 15/25 RapTime: 0:00:00.033671 FixedProfit: 1284612 TradeTimes: 144 TradeWin: 91
# Episode: 16/25 RapTime: 0:00:00.040344 FixedProfit: 1429499 TradeTimes: 152 TradeWin: 92
# Episode: 17/25 RapTime: 0:00:00.037113 FixedProfit: 1192310 TradeTimes: 134 TradeWin: 74
# Episode: 18/25 RapTime: 0:00:00.036484 FixedProfit: 1158166 TradeTimes: 149 TradeWin: 96
# Episode: 19/25 RapTime: 0:00:00.038672 FixedProfit: 1115328 TradeTimes: 144 TradeWin: 79
# Episode: 20/25 RapTime: 0:00:00.041718 FixedProfit: 1504023 TradeTimes: 139 TradeWin: 91
# Episode: 21/25 RapTime: 0:00:00.033722 FixedProfit: 1107781 TradeTimes: 138 TradeWin: 89
# Episode: 22/25 RapTime: 0:00:00.041131 FixedProfit: 1104505 TradeTimes: 137 TradeWin: 82
# Episode: 23/25 RapTime: 0:00:00.034221 FixedProfit: 1137223 TradeTimes: 132 TradeWin: 84
# Episode: 24/25 RapTime: 0:00:00.039919 FixedProfit: 1222056 TradeTimes: 148 TradeWin: 89
# Episode: 25/25 RapTime: 0:00:00.039265 FixedProfit: 1137239 TradeTimes: 150 TradeWin: 92
# Episode: 1/25 RapTime: 0:00:00.043376 FixedProfit: 1673590 TradeTimes: 150 TradeWin: 105
# Episode: 2/25 RapTime: 0:00:00.042868 FixedProfit: 980583 TradeTimes: 138 TradeWin: 79
# Episode: 3/25 RapTime: 0:00:00.038973 FixedProfit: 981687 TradeTimes: 156 TradeWin: 90
# Episode: 4/25 RapTime: 0:00:00.036987 FixedProfit: 1009212 TradeTimes: 155 TradeWin: 99
# Episode: 5/25 RapTime: 0:00:00.039705 FixedProfit: 1037613 TradeTimes: 154 TradeWin: 88
# Episode: 6/25 RapTime: 0:00:00.039762 FixedProfit: 1373979 TradeTimes: 154 TradeWin: 95
# Episode: 7/25 RapTime: 0:00:00.038991 FixedProfit: 1201629 TradeTimes: 143 TradeWin: 88
# Episode: 8/25 RapTime: 0:00:00.034763 FixedProfit: 1079216 TradeTimes: 144 TradeWin: 85
# Episode: 9/25 RapTime: 0:00:00.045103 FixedProfit: 1909611 TradeTimes: 154 TradeWin: 97
# Episode: 10/25 RapTime: 0:00:00.038460 FixedProfit: 1115944 TradeTimes: 152 TradeWin: 96
# Episode: 11/25 RapTime: 0:00:00.036274 FixedProfit: 1752636 TradeTimes: 138 TradeWin: 95
# Episode: 12/25 RapTime: 0:00:00.042291 FixedProfit: 1385990 TradeTimes: 150 TradeWin: 94
# Episode: 13/25 RapTime: 0:00:00.035250 FixedProfit: 1157966 TradeTimes: 132 TradeWin: 73
# Episode: 14/25 RapTime: 0:00:00.035770 FixedProfit: 1154326 TradeTimes: 142 TradeWin: 85
# Episode: 15/25 RapTime: 0:00:00.038306 FixedProfit: 999187 TradeTimes: 147 TradeWin: 70
# Episode: 16/25 RapTime: 0:00:00.035285 FixedProfit: 1204556 TradeTimes: 145 TradeWin: 85
# Episode: 17/25 RapTime: 0:00:00.044640 FixedProfit: 1743605 TradeTimes: 148 TradeWin: 94
# Episode: 18/25 RapTime: 0:00:00.036194 FixedProfit: 1379200 TradeTimes: 143 TradeWin: 89
# Episode: 19/25 RapTime: 0:00:00.037294 FixedProfit: 1541710 TradeTimes: 149 TradeWin: 95
# Episode: 20/25 RapTime: 0:00:00.042075 FixedProfit: 1379634 TradeTimes: 149 TradeWin: 95
# Episode: 21/25 RapTime: 0:00:00.033571 FixedProfit: 1285446 TradeTimes: 134 TradeWin: 84
# Episode: 22/25 RapTime: 0:00:00.037254 FixedProfit: 1267407 TradeTimes: 145 TradeWin: 87
# Episode: 23/25 RapTime: 0:00:00.039874 FixedProfit: 1068602 TradeTimes: 152 TradeWin: 90
# Episode: 24/25 RapTime: 0:00:00.036894 FixedProfit: 1573986 TradeTimes: 147 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.039833 FixedProfit: 1179269 TradeTimes: 150 TradeWin: 96
