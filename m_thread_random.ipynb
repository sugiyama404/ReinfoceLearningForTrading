# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_thread_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from concurrent.futures import ThreadPoolExecutor as PoolExecutor

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_thread_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
    
        while not done:
            action = random.randrange(3)
            state, reward, done, info = env.step(action)
        
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)

thread_num = 4
datas = []
for i in range(thread_num):
    e = Environment(df, initial_money=initial_money,mode = mode)
    datas.append(e)

features = []
with PoolExecutor(max_workers=thread_num) as executor:
    for env in datas:
        job = lambda: play_game(env)
        features.append(executor.submit(job))
# Out:
# Episode: 1/25 RapTime: 0:00:00.085028 FixedProfit: 786291 TradeTimes: 147 TradeWin: 82Episode: 1/25 RapTime: 0:00:00.091349 FixedProfit: 1155850 TradeTimes: 152 TradeWin: 85
#
# Episode: 1/25 RapTime: 0:00:00.120924 FixedProfit: 959058 TradeTimes: 150 TradeWin: 88
# Episode: 1/25 RapTime: 0:00:00.093377 FixedProfit: 1078848 TradeTimes: 138 TradeWin: 83
# Episode: 2/25 RapTime: 0:00:00.074374 FixedProfit: 984651 TradeTimes: 155 TradeWin: 96
# Episode: 2/25 RapTime: 0:00:00.068488 FixedProfit: 829898 TradeTimes: 162 TradeWin: 89
# Episode: 2/25 RapTime: 0:00:00.116960 FixedProfit: 1260325 TradeTimes: 142 TradeWin: 87
# Episode: 2/25 RapTime: 0:00:00.085506 FixedProfit: 1255471 TradeTimes: 153 TradeWin: 92
# Episode: 3/25 RapTime: 0:00:00.063014 FixedProfit: 1260505 TradeTimes: 146 TradeWin: 84
# Episode: 3/25 RapTime: 0:00:00.092689 FixedProfit: 1370753 TradeTimes: 151 TradeWin: 88
# Episode: 3/25 RapTime: 0:00:00.097508 FixedProfit: 1304697 TradeTimes: 163 TradeWin: 102
# Episode: 4/25 RapTime: 0:00:00.083576 FixedProfit: 1711009 TradeTimes: 131 TradeWin: 91
# Episode: 3/25 RapTime: 0:00:00.122417 FixedProfit: 1455622 TradeTimes: 148 TradeWin: 90
# Episode: 4/25 RapTime: 0:00:00.034136 FixedProfit: 1055600 TradeTimes: 140 TradeWin: 83
# Episode: 4/25 RapTime: 0:00:00.079863 FixedProfit: 1080450 TradeTimes: 136 TradeWin: 78
# Episode: 5/25 RapTime: 0:00:00.076814 FixedProfit: 1428951 TradeTimes: 142 TradeWin: 91
# Episode: 4/25 RapTime: 0:00:00.143279 FixedProfit: 1097250 TradeTimes: 156 TradeWin: 96
# Episode: 5/25 RapTime: 0:00:00.150688 FixedProfit: 1491548 TradeTimes: 163 TradeWin: 105
# Episode: 5/25 RapTime: 0:00:00.082306 FixedProfit: 1663168 TradeTimes: 147 TradeWin: 88
# Episode: 5/25 RapTime: 0:00:00.131870 FixedProfit: 1052317 TradeTimes: 157 TradeWin: 98
# Episode: 6/25 RapTime: 0:00:00.155781 FixedProfit: 1486276 TradeTimes: 146 TradeWin: 87
# Episode: 6/25 RapTime: 0:00:00.093337 FixedProfit: 1068976 TradeTimes: 143 TradeWin: 86
# Episode: 6/25 RapTime: 0:00:00.064352 FixedProfit: 1088080 TradeTimes: 148 TradeWin: 84
# Episode: 6/25 RapTime: 0:00:00.104696 FixedProfit: 1160520 TradeTimes: 150 TradeWin: 83Episode: 7/25 RapTime: 0:00:00.085338 FixedProfit: 1317851 TradeTimes: 156 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.128829 FixedProfit: 1167828 TradeTimes: 133 TradeWin: 81
# Episode: 7/25 RapTime: 0:00:00.113359 FixedProfit: 1180653 TradeTimes: 142 TradeWin: 84
#
# Episode: 8/25 RapTime: 0:00:00.072081 FixedProfit: 1535250 TradeTimes: 156 TradeWin: 96
# Episode: 8/25 RapTime: 0:00:00.099681 FixedProfit: 1143791 TradeTimes: 133 TradeWin: 78
# Episode: 7/25 RapTime: 0:00:00.102774 FixedProfit: 1497454 TradeTimes: 152 TradeWin: 95
# Episode: 8/25 RapTime: 0:00:00.077552 FixedProfit: 927745 TradeTimes: 149 TradeWin: 89
# Episode: 9/25 RapTime: 0:00:00.075426 FixedProfit: 949223 TradeTimes: 142 TradeWin: 86
# Episode: 8/25 RapTime: 0:00:00.081232 FixedProfit: 1622573 TradeTimes: 131 TradeWin: 84
# Episode: 9/25 RapTime: 0:00:00.091356 FixedProfit: 994598 TradeTimes: 140 TradeWin: 86
# Episode: 9/25 RapTime: 0:00:00.109349 FixedProfit: 1694787 TradeTimes: 150 TradeWin: 104
# Episode: 10/25 RapTime: 0:00:00.070694 FixedProfit: 898976 TradeTimes: 151 TradeWin: 86
# Episode: 10/25 RapTime: 0:00:00.064294 FixedProfit: 1388052 TradeTimes: 146 TradeWin: 89
# Episode: 9/25 RapTime: 0:00:00.107466 FixedProfit: 1202895 TradeTimes: 155 TradeWin: 92
# Episode: 10/25 RapTime: 0:00:00.038769 FixedProfit: 972723 TradeTimes: 136 TradeWin: 81
# Episode: 11/25 RapTime: 0:00:00.094964 FixedProfit: 1191878 TradeTimes: 153 TradeWin: 90
# Episode: 11/25 RapTime: 0:00:00.130346 FixedProfit: 1370046 TradeTimes: 161 TradeWin: 99
# Episode: 11/25 RapTime: 0:00:00.128794 FixedProfit: 1367856 TradeTimes: 160 TradeWin: 99
# Episode: 10/25 RapTime: 0:00:00.137879 FixedProfit: 1144202 TradeTimes: 144 TradeWin: 90
# Episode: 12/25 RapTime: 0:00:00.084840 FixedProfit: 1159911 TradeTimes: 162 TradeWin: 93
# Episode: 12/25 RapTime: 0:00:00.104642 FixedProfit: 1047099 TradeTimes: 138 TradeWin: 77
# Episode: 12/25 RapTime: 0:00:00.110009 FixedProfit: 1189153 TradeTimes: 154 TradeWin: 98
# Episode: 11/25 RapTime: 0:00:00.069616 FixedProfit: 1124402 TradeTimes: 154 TradeWin: 85
# Episode: 13/25 RapTime: 0:00:00.065188 FixedProfit: 1009102 TradeTimes: 145 TradeWin: 89
# Episode: 13/25 RapTime: 0:00:00.073240 FixedProfit: 1422670 TradeTimes: 148 TradeWin: 93
# Episode: 13/25 RapTime: 0:00:00.156173 FixedProfit: 1361344 TradeTimes: 139 TradeWin: 88
# Episode: 12/25 RapTime: 0:00:00.080703 FixedProfit: 1468122 TradeTimes: 155 TradeWin: 99
# Episode: 14/25 RapTime: 0:00:00.092409 FixedProfit: 1118921 TradeTimes: 152 TradeWin: 97Episode: 14/25 RapTime: 0:00:00.095129 FixedProfit: 1287354 TradeTimes: 153 TradeWin: 95
#
# Episode: 13/25 RapTime: 0:00:00.063015 FixedProfit: 1030717 TradeTimes: 144 TradeWin: 92
# Episode: 14/25 RapTime: 0:00:00.069986 FixedProfit: 1128420 TradeTimes: 144 TradeWin: 88
# Episode: 15/25 RapTime: 0:00:00.070387 FixedProfit: 1862328 TradeTimes: 150 TradeWin: 97
# Episode: 15/25 RapTime: 0:00:00.082353 FixedProfit: 986062 TradeTimes: 149 TradeWin: 87
# Episode: 15/25 RapTime: 0:00:00.074792 FixedProfit: 1081349 TradeTimes: 144 TradeWin: 85
# Episode: 14/25 RapTime: 0:00:00.082707 FixedProfit: 1263166 TradeTimes: 153 TradeWin: 101
# Episode: 16/25 RapTime: 0:00:00.068254 FixedProfit: 1418190 TradeTimes: 134 TradeWin: 81Episode: 16/25 RapTime: 0:00:00.046101 FixedProfit: 1067220 TradeTimes: 134 TradeWin: 77
#
# Episode: 15/25 RapTime: 0:00:00.109267 FixedProfit: 1628002 TradeTimes: 162 TradeWin: 103
# Episode: 17/25 RapTime: 0:00:00.084108 FixedProfit: 1225594 TradeTimes: 147 TradeWin: 99
# Episode: 16/25 RapTime: 0:00:00.103443 FixedProfit: 1007428 TradeTimes: 140 TradeWin: 93
# Episode: 17/25 RapTime: 0:00:00.041461 FixedProfit: 1455180 TradeTimes: 148 TradeWin: 83
# Episode: 18/25 RapTime: 0:00:00.059771 FixedProfit: 1078016 TradeTimes: 147 TradeWin: 92
# Episode: 16/25 RapTime: 0:00:00.083675 FixedProfit: 1217680 TradeTimes: 143 TradeWin: 92
# Episode: 18/25 RapTime: 0:00:00.083163 FixedProfit: 1183261 TradeTimes: 165 TradeWin: 101
# Episode: 17/25 RapTime: 0:00:00.098594 FixedProfit: 1054591 TradeTimes: 139 TradeWin: 82
# Episode: 17/25 RapTime: 0:00:00.062880 FixedProfit: 1015906 TradeTimes: 140 TradeWin: 82
# Episode: 19/25 RapTime: 0:00:00.060425 FixedProfit: 1306931 TradeTimes: 152 TradeWin: 98
# Episode: 19/25 RapTime: 0:00:00.045723 FixedProfit: 1149853 TradeTimes: 149 TradeWin: 98
# Episode: 18/25 RapTime: 0:00:00.076567 FixedProfit: 1158379 TradeTimes: 145 TradeWin: 88
# Episode: 18/25 RapTime: 0:00:00.047975 FixedProfit: 1117903 TradeTimes: 159 TradeWin: 98
# Episode: 19/25 RapTime: 0:00:00.060703 FixedProfit: 1448224 TradeTimes: 137 TradeWin: 91
# Episode: 20/25 RapTime: 0:00:00.046026 FixedProfit: 951906 TradeTimes: 138 TradeWin: 84
# Episode: 20/25 RapTime: 0:00:00.105137 FixedProfit: 808073 TradeTimes: 143 TradeWin: 81
# Episode: 21/25 RapTime: 0:00:00.080166 FixedProfit: 1031944 TradeTimes: 144 TradeWin: 87
# Episode: 20/25 RapTime: 0:00:00.077446 FixedProfit: 925277 TradeTimes: 148 TradeWin: 85
# Episode: 19/25 RapTime: 0:00:00.107926 FixedProfit: 973664 TradeTimes: 147 TradeWin: 86
# Episode: 21/25 RapTime: 0:00:00.050822 FixedProfit: 1328067 TradeTimes: 141 TradeWin: 93
# Episode: 22/25 RapTime: 0:00:00.081550 FixedProfit: 932014 TradeTimes: 142 TradeWin: 86Episode: 21/25 RapTime: 0:00:00.071940 FixedProfit: 1261102 TradeTimes: 149 TradeWin: 98
#
# Episode: 20/25 RapTime: 0:00:00.096330 FixedProfit: 1279457 TradeTimes: 159 TradeWin: 102
# Episode: 22/25 RapTime: 0:00:00.056409 FixedProfit: 1024140 TradeTimes: 130 TradeWin: 77
# Episode: 22/25 RapTime: 0:00:00.067200 FixedProfit: 1673221 TradeTimes: 153 TradeWin: 99
# Episode: 23/25 RapTime: 0:00:00.090285 FixedProfit: 1564298 TradeTimes: 150 TradeWin: 96
# Episode: 21/25 RapTime: 0:00:00.071428 FixedProfit: 1244643 TradeTimes: 151 TradeWin: 90Episode: 23/25 RapTime: 0:00:00.100657 FixedProfit: 1394286 TradeTimes: 135 TradeWin: 83
#
# Episode: 24/25 RapTime: 0:00:00.105859 FixedProfit: 1361139 TradeTimes: 146 TradeWin: 101
# Episode: 23/25 RapTime: 0:00:00.072420 FixedProfit: 1504722 TradeTimes: 152 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.064621 FixedProfit: 1218517 TradeTimes: 146 TradeWin: 86
# Episode: 22/25 RapTime: 0:00:00.100277 FixedProfit: 1280917 TradeTimes: 149 TradeWin: 94Episode: 24/25 RapTime: 0:00:00.100181 FixedProfit: 1451341 TradeTimes: 155 TradeWin: 96
#
# Episode: 24/25 RapTime: 0:00:00.079786 FixedProfit: 1084444 TradeTimes: 148 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.084396 FixedProfit: 976267 TradeTimes: 167 TradeWin: 99
# Episode: 23/25 RapTime: 0:00:00.094085 FixedProfit: 1176078 TradeTimes: 143 TradeWin: 81
# Episode: 25/25 RapTime: 0:00:00.034895 FixedProfit: 1386018 TradeTimes: 140 TradeWin: 88
# Episode: 24/25 RapTime: 0:00:00.035970 FixedProfit: 856736 TradeTimes: 155 TradeWin: 91
# Episode: 25/25 RapTime: 0:00:00.036813 FixedProfit: 1860431 TradeTimes: 146 TradeWin: 97
