# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/R2D2/R2D2_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from matplotlib import pyplot as plt
import pickle

import tensorflow as tf
from tensorflow.keras.models import Sequential, clone_model
from tensorflow.keras.layers import Dense, ReLU, Input, Lambda
from tensorflow.keras.optimizers import Adam
from statistics import mean
import tensorflow.keras as keras
from tensorflow.keras.losses import Huber
from tensorflow.keras import backend as K

from sklearn.preprocessing import StandardScaler
from concurrent.futures import ThreadPoolExecutor, as_completed
from queue import Queue
from time import sleep
import random, string

from tensorflow.keras.utils import Progbar

mode = 'train'
name = 'r2d2'
level = 1
if level == 2:
    name += name + 'lv2'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'

exp_dir = 'Colab Notebooks/workspace/export/'
mdl_dir = '/content/drive/My Drive/' + exp_dir + 'models'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test', commission = 0):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.commission      = commission
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None
        self.sell_price      = None
        self.buy_price       = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.end_step        = self.df_total_steps
        self.now_step        = 0
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money
        self.sell_price      = 0
        self.buy_price       = 0

        return self._get_now_state()

    def step(self, action):

        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self.sell_price = 0
        self._trade(action,done)
        reward = 0
        if (self.sell_price > 0) and (self.buy_price > 0) and ((self.sell_price - self.buy_price) != 0):
            reward = (self.sell_price - self.buy_price) / self.buy_price
            self.buy_price = 0
        cur_revenue = self._get_revenue()
 
        info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            self.trade_time += 1
            if self.cash_in_hand > self.brfore_buy_cash:
                self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.buy_price += self.now_price
                            self.cash_in_hand -= self.now_price + self.commission * self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.sell_price += self.now_price * self.hold_a_position
                    self.cash_in_hand += self.now_price * self.hold_a_position - self.commission * self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    self.trade_time += 1
                    if self.cash_in_hand > self.brfore_buy_cash:
                        self.trade_win += 1

# %%
class Brain:
    def __init__(self):

        conv_filter = 12
        units = 16
        look_back = 10

        model = Sequential()
        model.add(Conv1D(filters=conv_filter, kernel_size=1, padding="same", activation="tanh",batch_input_shape=(1, look_back, 3)))
        model.add(MaxPool1D(pool_size=1, padding='same'))
        model.add(Activation("relu"))
        model.add(LSTM(units, stateful=True, name="lstm"))
        model.add(Dense(4, kernel_initializer='random_uniform'))
        model.add(Lambda(lambda a: K.expand_dims(a[:, 0], -1) + a[:, 1:] - 0.0*K.mean(a[:, 1:], keepdims=True),output_shape=(3,)))
        model.compile(loss = "mean_absolute_error", optimizer=Adam(learning_rate=0.001, clipvalue=40))
        model.summary()
        self.model = model

# %%
class Learner:
    def __init__(self, model1, model2, memory):

        self.model1 = model1
        self.model2 = model2
        self.memory = memory
        self.gamma  = 0.99

    def learn(self, queue):
        while True:
            val = queue.get()
            if (val == 'done_prosess'):
                break

            for state, next_state, action, reward, done, hidden_state1, hidden_state2 in zip(states, next_states, actions, rewards, dones, hidden_states1, hidden_states2):
                self.reset_model_state()
                self._set_hidden_states(hidden_state1, hidden_state2)
                s_flag = 11 if np.random.random() <= 0.5 else 22

                next_state = np.reshape(next_state, [1, 10, 3])
                state = np.reshape(state, [1, 10, 3])

                if s_flag == 11:
                    target = reward + (1 - done) * self.gamma * np.amax(self.model2.predict(next_state), axis=1)
                    target_full = self.model1.predict(state)

                    target_full[0][action] = target
                    self.model1.fit(state, target_full, verbose=0)

                else:
                    target = reward + (1 - done) * self.gamma * np.amax(self.model1.predict(next_state), axis=1)
                    target_full = self.model2.predict(state)

                    target_full[0][action] = target
                    self.model2.fit(state, target_full, verbose=0)


            self._tderror()
            self.memory.placement(self.model1, self.model2)
            queue.task_done()

    def _predict(self, state, s_flag = 12):
        values = None
        q1 = self.model1.predict(state)
        q2 = self.model2.predict(state)
        if s_flag == 12:
            values = q1 + q2
        elif s_flag == 11:
            values = q1 + q1
        else:
            values = q2 + q2
        return values

    def _tderror(self):
        states, next_states, actions, rewards, done, hidden_state1, hidden_state2, tderror = self.memory.findall()
        
        n2_rewards = rewards[2:-1]
        next_rewards = rewards[1:-2]
        n3_action = acts[3:]
        n3_next_states = next_states[3:]

        states = states[:-3]
        next_states = next_states[:-3]
        acts = acts[:-3]
        rewards = rewards[:-3]
        done = done[:-3]

        next_action = np.argmax(self._predict(n3_next_states), axis = 1)
        next_action = next_action.reshape(-1)

        acts = acts.reshape(-1)

        acts_one = np.eye(3)[acts]
        next_action_one = np.eye(3)[next_action]
        n3_q = np.max(self._predict(n3_next_states) * next_action_one, axis = 1)

        target = rewards + self.gamma * next_rewards + (self.gamma ** 2) * n2_rewards + (self.gamma ** 3) * n3_q
        tderror = target - np.max(self._predict(states) * acts_one, axis = 1)
        self.memory.replace_tderror(tderror)

    def _get_hidden_state(self):
        lstm1 = self.model.get_layer("lstm")
        hidden_states1 = np.concatenate([K.get_value(lstm1.states[0]), K.get_value(lstm1.states[1])])
        lstm2 = self.model.get_layer("lstm")
        hidden_states2 = np.concatenate([K.get_value(lstm2.states[0]), K.get_value(lstm2.states[1])])
        return hidden_states1, hidden_states2

    def reset_model_state(self):
        self.model1.reset_states()
        self.model2.reset_states()

    def _set_hidden_states(self, hidden_states1, hidden_states2):
        a0, a1 = np.split(hidden_states1, 2, 0)# (16, 2, 16)
        self.model1.get_layer("lstm").reset_states([a0, a1])
        a2, a3 = np.split(hidden_states2, 2, 0)# (16, 2, 16)
        self.model2.get_layer("lstm").reset_states([a2, a3])

# %%
class Memory:
    def __init__(self, model1, model2, max_size=500, batch_size=32):

        self.cntr = 0
        self.size = 0
        self.max_size = max_size
        self.batch_size = batch_size
        self.model1 = model1
        self.model2 = model2
        self.code = ''
        self.states_memory = np.zeros([self.max_size, 3], dtype=np.float32)
        self.next_states_memory = np.zeros([self.max_size, 3], dtype=np.float32)
        self.acts_memory = np.zeros(self.max_size, dtype=np.uint8)
        self.rewards_memory = np.zeros(self.max_size, dtype=np.float32)
        self.done_memory = np.zeros(self.max_size, dtype=np.uint8)
        self.hidden_state1_memory = np.zeros([self.max_size, 2, 16], dtype=np.float32)
        self.hidden_state2_memory = np.zeros([self.max_size, 2, 16], dtype=np.float32)
        self.tderrors_memory = np.zeros(self.max_size, dtype=np.float32)

    def store_transition(self, state, act, reward, next_state, done, hidden_states1, hidden_states2):
        self.states_memory[self.cntr] = state
        self.next_states_memory[self.cntr] = next_state
        self.acts_memory[self.cntr] = act
        self.rewards_memory[self.cntr] = reward
        self.done_memory[self.cntr] = done
        self.hidden_state1_memory[self.cntr] = hidden_state1
        self.hidden_state2_memory[self.cntr] = hidden_state2
        self.cntr = (self.cntr+1) % self.max_size
        self.size = min(self.size+1, self.max_size)

    def random_sampling(self):
        dice = np.arange(10, self.size)
        mb_index = np.random.choice(dice, self.batch_size, replace=False)
        mb_index_min = mb_index - 10

        states_3d = np.empty((0, 10, 3))
        next_states_3d = np.empty((0, 10, 3))
        for a,b in zip(mb_index, mb_index_min):
            states_tmp = self.states_memory[b:a]
            next_states_tmp = self.next_states_memory[b:a]

            states_tmp  = np.reshape(states_tmp, (1, 10, 3))
            next_states_tmp  = np.reshape(next_states_tmp, (1, 10, 3))

            states_3d = np.append(states_3d, states_tmp,axis=0)
            next_states_3d = np.append(next_states_3d, next_states_tmp,axis=0)

        key = ['state','next_state','act','reward','done', 'hidden_state1', 'hidden_state2']
        value = [states_3d ,next_states_3d, self.acts_memory[mb_index], self.rewards_memory[mb_index], self.done_memory[mb_index], self.hidden_state1_memory[mb_index], self.hidden_state2_memory[mb_index]]
        dict1=dict(zip(key,value))
        return dict1

    def findall(self):
        return self.states_memory,self.next_states_memory,self.acts_memory,self.rewards_memory,self.done_memory,self.hidden_state1_memory,self.hidden_state2_memory,self.tderrors_memory

    def replace_tderror(self, val):
        np.put(self.tderrors_memory, range(val.shape[0]), val)

    def placement(self, model1, model2):
        self.model1.set_weights(model1.get_weights())
        self.model2.set_weights(model2.get_weights())
        self.code = self._make_random_code()

    def integration(self, model1, model2, code):
        if self.code == code:
            return
        model1.set_weights(self.model1.get_weights())
        model2.set_weights(self.model2.get_weights()) 
        code = self.code

    def _make_random_code(self, n=10):
       return ''.join(random.choices(string.ascii_letters + string.digits, k=n))

# %%
class Agent:
    def __init__(self, model1, model2, memory, epsilon, batch_size=32):
        self.model1 = model1
        self.model2 = model2
        self.memory = memory
        self.gamma = 0.99
        self.epsilon = epsilon
        self.batch_size = batch_size
        self.epsilon_min = 0.01
        self.code = 'init'
        self.local_state = np.empty((0,3), float)

    def local_state_reset(self):
        self.local_state = np.empty((0,3), float)

    def update_replay_memory(self, state, action, reward, next_state, done, hidden_states1, hidden_states2):
        self.memory.store_transition(state, action, reward, next_state, done, hidden_states1, hidden_states2)

    def act(self, state, s_flag=12):
        if len(self.local_state) >= 10:
            self.local_state = self.local_state[1:]
            self.local_state = np.append(self.local_state, np.array(state), axis=0)
            tmp_state = copy.deepcopy(self.local_state)
            tmp_state  = np.reshape(tmp_state, (1, 10, 3))

            ran_num = np.random.rand()
            if (ran_num <= self.epsilon) and (ran_num > self.epsilon_min):
                _ = self._predict(state,s_flag)
                return np.random.choice(3), self._get_hidden_state()
            act_values = self._predict(state,s_flag)
            return np.argmax(act_values), self._get_hidden_state()
        else:
            self.local_state = np.append(self.local_state, np.array(state), axis=0)
            return 1, self._get_hidden_state()

    def _predict(self, state, s_flag = 12):
        values = None
        q1 = self.model1.predict(state)
        q2 = self.model2.predict(state)
        if s_flag == 12:
            values = q1 + q2
        elif s_flag == 11:
            values = q1 + q1
        else:
            values = q2 + q2
        return values

    def replay(self):
        m_batch = self.memory.random_sampling()
        return m_batch

    def pioritized_experience_replay(self):

        sum_ab_tderror = self._absolute_tderror()
        td_list = np.random.uniform(0, sum_ab_tderror, self.batch_size)
        td_list = np.sort(td_list)

        num_np = np.array([], dtype=np.int16)
        i, sum_ab_tderror_tmp = 0, 0
        states, next_states, actions, rewards, done, hidden_state1, hidden_state2, tderror = self.memory.findall()
        for item in td_list:
            while sum_ab_tderror_tmp < item:
                sum_ab_tderror_tmp += abs(tderror[i]) + 0.0001
                i += 1
            num_np = np.append(num_np, i)

        key = ['state','next_state','act','reward','done', 'hidden_state1', 'hidden_state2']
        value = [states[num_np],next_states[num_np],
                 actions[num_np],rewards[num_np],
                 done[num_np], hidden_state1[num_np], hidden_state2[num_np]]
        dict1=dict(zip(key,value))
        return dict1

    def tderror(self):
        states, next_states, actions, rewards, done, hidden_state1, hidden_state2, tderror = self.memory.findall()
        
        n2_rewards = rewards[2:-1]
        next_rewards = rewards[1:-2]
        n3_action = acts[3:]
        n3_next_states = next_states[3:]

        states = states[:-3]
        next_states = next_states[:-3]
        acts = acts[:-3]
        rewards = rewards[:-3]
        done = done[:-3]

        next_action = np.argmax(self._predict(n3_next_states), axis = 1)
        next_action = next_action.reshape(-1)

        acts = acts.reshape(-1)

        acts_one = np.eye(3)[acts]
        next_action_one = np.eye(3)[next_action]
        n3_q = np.max(self._predict(n3_next_states) * next_action_one, axis = 1)

        target = rewards + self.gamma * next_rewards + (self.gamma ** 2) * n2_rewards + (self.gamma ** 3) * n3_q
        tderror = target - np.max(self._predict(states) * acts_one, axis = 1)
        self.memory.replace_tderror(tderror)

    def _absolute_tderror(self):
        absolute_tderror = 0
        tderror = self.memory.tderrors_memory
        for i in range(0, (len(tderror)-1)):
            absolute_tderror += abs(tderror[i]) + 0.0001
        return absolute_tderror

    def _get_hidden_state(self):
        lstm1 = self.model.get_layer("lstm")
        hidden_states1 = np.concatenate([K.get_value(lstm1.states[0]), K.get_value(lstm1.states[1])])
        lstm2 = self.model.get_layer("lstm")
        hidden_states2 = np.concatenate([K.get_value(lstm2.states[0]), K.get_value(lstm2.states[1])])
        return hidden_states1, hidden_states2

    def reset_model_state(self):
        self.model1.reset_states()
        self.model2.reset_states()

    def integration(self):
        self.memory.integration(self.model1, self.model2, self.code)

    def load(self, name, name2):
        self.model1.load_weights(name)
        self.model2.load_weights(name2)

    def save(self, name, name2):
        self.model1.save_weights(name)
        self.model2.save_weights(name2)

# %%
class Main:
    def __init__(self, env, agent, mdl_dir, name, i, term, episodes_times = 200, mode = 'test'):
        self.env            = env
        self.agent          = agent
        self.mdl_dir        = mdl_dir
        self.scaler         = self._standard_scaler(self.env)
        self.episodes_times = episodes_times
        self.mode           = mode
        self.name           = name
        self.agent_num      = i
        self.term           = term

        with open(csv_path, 'w') as f:
            row = 'FixedProfit,TradeTimes,TradeWin'
            print(row, file=f)

        if self.mode == 'test':
            self._load()
            self.agent.epsilon = 0.01

    def play_game(self, q):

        total_reward = [1000000]

        for episode in range(self.episodes_times):

            if (episode % 10 == 0):
                metrics_names = ['FixedProfit','TradeTimes','TradeWin']
                pb_i = Progbar(10, stateful_metrics=metrics_names)
                p_mean,trade_time,win_time = np.array([]),np.array([]),np.array([])

            state = self.env.reset()
            state = self.scaler.transform([state])
            done  = False
            self.agent.reset_model_state()
            self.agent.local_state_reset()
        
            while not done:
                action, hidden_states1, hidden_states2 = self.agent.act(state)
                next_state, reward, done, info = self.env.step(action)
                next_state = self.scaler.transform([next_state])
                reward = self._reward_clipping(reward)

                if self.mode == 'train':
                    self.agent.update_replay_memory(state, action, reward, next_state, done, hidden_states1, hidden_states2)
                    if (self.agent.memory.size > self.agent.memory.batch_size) and (self.agent.memory.cntr % 100 == 0):
                        self.agent.tderror()
                        m_batch = None
                        if mean(total_reward) < 1050000:
                            m_batch = self.agent.replay()
                        else:
                            m_batch = self.agent.pioritized_experience_replay()
                        q.put(m_batch)
                    self.agent.integration()

                state = next_state

            if self.mode == 'train':
                self.agent.integration()
                total_reward.append(info['cur_revenue'])

            p_mean,trade_time,win_time = np.append(p_mean,info['cur_revenue']),np.append(trade_time,info['trade_time']),np.append(win_time,info['trade_win'])
            values=[('FixedProfit',int(np.mean(p_mean))), ('TradeTimes',int(np.mean(trade_time))), ('TradeWin',int(np.mean(win_time)))]
            pb_i.add(1, values=values)
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)

        if self.mode == 'train':
            self._save()
            self.term[self.agent_num] = True
            if self.term.all():
                q.put("done_prosess")

    def _standard_scaler(self, env):
        states = []
        for _ in range(env.df_total_steps):
            action = np.random.choice(env.action_space)
            state, reward, done, info = env.step(action)
            states.append(state)
            if done:
                break
        
        scaler = StandardScaler()
        scaler.fit(states)
        return scaler

    def _reward_clipping(self, val):
        if val > 0:
            return 1
        elif val == 0:
            return 0
        else:
            return -1

    def _load(self):
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, str(self.agent_num)), 'rb') as f:
            self.scaler = pickle.load(f)
        self.agent.load('{}/{}_1.h5'.format(self.mdl_dir, self.name), '{}/{}_2.h5'.format(self.mdl_dir, self.name))

    def _save(self):
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, str(self.agent_num)), 'wb') as f:
            pickle.dump(self.scaler, f)
        self.agent.save('{}/{}_1.h5'.format(self.mdl_dir, self.name), '{}/{}_2.h5'.format(self.mdl_dir, self.name))

# %%
initial_money=1000000
episodes_times = 150
commission = 0 if level == 1 else 0.002
batch_size = 32
max_size = 1000

brain1 = Brain()
model1 = brain1.model
brain2 = Brain()
model2 = brain2.model

memory = Memory(clone_model(model1), clone_model(model2), max_size, batch_size)
learner = Learner(model1, model2, memory)

thread_num = 4
epsilon_list = np.array([])
epsilon = 0.4
alfa = 7
for i in range(thread_num):
    num = 0.0
    if (not (thread_num - 1) == 0):
        num = epsilon ** (1 + i * alfa / (thread_num - 1))
    else:
        num = epsilon
    epsilon_list = np.append(epsilon_list, num)

workers = []
term = np.full((thread_num,), False)
for i in range(thread_num):
    env = Environment(df, initial_money=initial_money, mode = mode, commission = commission)
    epsilon = epsilon_list[i]
    agent = Agent(clone_model(model1), clone_model(model2), memory, epsilon, batch_size)
    main  = Main(env, agent, mdl_dir, name, i, term, episodes_times, mode)
    workers.append(main)

data = []
q = Queue()
with ThreadPoolExecutor() as executor:
    for i, w in enumerate(workers):
        print(f'start worker_{i}')
        def job1(): return w.play_game(q,)
        data.append(executor.submit(job1))

    if mode == 'train':
        print('start learner')
        def job2(): return learner.learn(q,)
        data.append(executor.submit(job2))
    for future in as_completed(data):
        print(future.result())
    executor.shutdown()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense (Dense)                (None, 48)                192
# _________________________________________________________________
# dense_1 (Dense)              (None, 96)                4704
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 388
# _________________________________________________________________
# lambda (Lambda)              (None, 3)                 0
# =================================================================
# Total params: 5,284
# Trainable params: 5,284
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 3)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 48)                192
# _________________________________________________________________
# dense_4 (Dense)              (None, 96)                4704
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 388
# _________________________________________________________________
# lambda_1 (Lambda)            (None, 3)                 0
# =================================================================
# Total params: 5,284
# Trainable params: 5,284
# Non-trainable params: 0
# _________________________________________________________________
# start worker_0
# start worker_1
# start worker_2
# start worker_3
# start learner
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f839e1d5680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f839e194050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Agent: 0 Episode: 1/150 RapTime: 0:02:48.468320 FixedProfit: 1303978
# Agent: 2 Episode: 1/150 RapTime: 0:04:12.714843 FixedProfit: 1197165
# Agent: 1 Episode: 1/150 RapTime: 0:04:13.790181 FixedProfit: 1226790
# Agent: 3 Episode: 1/150 RapTime: 0:04:14.824595 FixedProfit: 1147850
# Agent: 0 Episode: 2/150 RapTime: 0:02:57.093733 FixedProfit: 1082390
# Agent: 1 Episode: 2/150 RapTime: 0:04:09.783608 FixedProfit: 1225727
# Agent: 2 Episode: 2/150 RapTime: 0:04:11.949949 FixedProfit: 1197165
# Agent: 3 Episode: 2/150 RapTime: 0:04:13.079670 FixedProfit: 1197165
# Agent: 0 Episode: 3/150 RapTime: 0:02:51.434278 FixedProfit: 1100750
# Agent: 0 Episode: 4/150 RapTime: 0:02:54.296351 FixedProfit: 1254193
# Agent: 1 Episode: 3/150 RapTime: 0:04:07.920067 FixedProfit: 1252283
# Agent: 2 Episode: 3/150 RapTime: 0:04:08.987448 FixedProfit: 1197165
# Agent: 3 Episode: 3/150 RapTime: 0:04:10.093320 FixedProfit: 1197165
# Agent: 0 Episode: 5/150 RapTime: 0:02:58.433403 FixedProfit: 1250394
# Agent: 1 Episode: 4/150 RapTime: 0:04:09.875130 FixedProfit: 1223813
# Agent: 2 Episode: 4/150 RapTime: 0:04:07.848931 FixedProfit: 1197165
# Agent: 3 Episode: 4/150 RapTime: 0:04:13.224201 FixedProfit: 1197165
# Agent: 0 Episode: 6/150 RapTime: 0:03:00.359196 FixedProfit: 1173555
# Agent: 0 Episode: 7/150 RapTime: 0:02:52.817571 FixedProfit: 1019192
# Agent: 1 Episode: 5/150 RapTime: 0:04:04.873334 FixedProfit: 1160262
# Agent: 2 Episode: 5/150 RapTime: 0:04:17.076006 FixedProfit: 1197165
# Agent: 3 Episode: 5/150 RapTime: 0:04:20.387775 FixedProfit: 1197165
# Agent: 0 Episode: 8/150 RapTime: 0:02:54.341940 FixedProfit: 1216424
# Agent: 1 Episode: 6/150 RapTime: 0:04:04.087091 FixedProfit: 1168760
# Agent: 2 Episode: 6/150 RapTime: 0:04:18.646296 FixedProfit: 1197165
# Agent: 3 Episode: 6/150 RapTime: 0:04:16.601245 FixedProfit: 1197165
# Agent: 0 Episode: 9/150 RapTime: 0:02:53.622899 FixedProfit: 988756
# Agent: 0 Episode: 10/150 RapTime: 0:02:49.279030 FixedProfit: 1176743
# Agent: 1 Episode: 7/150 RapTime: 0:04:10.887431 FixedProfit: 1167753
# Agent: 2 Episode: 7/150 RapTime: 0:04:20.072346 FixedProfit: 1197165
# Agent: 3 Episode: 7/150 RapTime: 0:04:18.266247 FixedProfit: 1197165
# Agent: 0 Episode: 11/150 RapTime: 0:02:59.671319 FixedProfit: 1124368
# Agent: 1 Episode: 8/150 RapTime: 0:04:04.776402 FixedProfit: 1164096
# Agent: 2 Episode: 8/150 RapTime: 0:04:20.255807 FixedProfit: 1197165
# Agent: 3 Episode: 8/150 RapTime: 0:04:20.391975 FixedProfit: 1197165
# Agent: 0 Episode: 12/150 RapTime: 0:02:51.682683 FixedProfit: 1219910
# Agent: 1 Episode: 9/150 RapTime: 0:04:15.699139 FixedProfit: 1193207
# Agent: 0 Episode: 13/150 RapTime: 0:03:10.653688 FixedProfit: 1003282
# Agent: 2 Episode: 9/150 RapTime: 0:04:12.486073 FixedProfit: 1197165
# Agent: 3 Episode: 9/150 RapTime: 0:04:09.817431 FixedProfit: 1197165
# Agent: 0 Episode: 14/150 RapTime: 0:03:02.860792 FixedProfit: 1276346
# Agent: 1 Episode: 10/150 RapTime: 0:04:02.860328 FixedProfit: 1186755
# Agent: 2 Episode: 10/150 RapTime: 0:04:20.720756 FixedProfit: 1197165
# Agent: 3 Episode: 10/150 RapTime: 0:04:15.260400 FixedProfit: 1197165
# Agent: 0 Episode: 15/150 RapTime: 0:02:59.217936 FixedProfit: 1255992
# Agent: 1 Episode: 11/150 RapTime: 0:04:11.869230 FixedProfit: 1172133
# Agent: 2 Episode: 11/150 RapTime: 0:04:10.927812 FixedProfit: 1197165
# Agent: 3 Episode: 11/150 RapTime: 0:04:15.771381 FixedProfit: 1197165
# Agent: 0 Episode: 16/150 RapTime: 0:03:00.891933 FixedProfit: 1210250
# Agent: 1 Episode: 12/150 RapTime: 0:04:10.680482 FixedProfit: 1182624
# Agent: 0 Episode: 17/150 RapTime: 0:02:57.713438 FixedProfit: 1105043
# Agent: 2 Episode: 12/150 RapTime: 0:04:19.804673 FixedProfit: 1197165
# Agent: 3 Episode: 12/150 RapTime: 0:04:14.705434 FixedProfit: 1197165
# Agent: 0 Episode: 18/150 RapTime: 0:02:54.712067 FixedProfit: 1543734
# Agent: 1 Episode: 13/150 RapTime: 0:04:01.516549 FixedProfit: 1208908
# Agent: 3 Episode: 13/150 RapTime: 0:04:14.268406 FixedProfit: 1197165
# Agent: 2 Episode: 13/150 RapTime: 0:04:18.123803 FixedProfit: 1197165
# Agent: 0 Episode: 19/150 RapTime: 0:02:52.119469 FixedProfit: 1123906
# Agent: 1 Episode: 14/150 RapTime: 0:04:10.953218 FixedProfit: 1212369
# Agent: 0 Episode: 20/150 RapTime: 0:02:46.472372 FixedProfit: 1038623
# Agent: 3 Episode: 14/150 RapTime: 0:04:13.190617 FixedProfit: 1197165
# Agent: 2 Episode: 14/150 RapTime: 0:04:22.652398 FixedProfit: 1197165
# Agent: 0 Episode: 21/150 RapTime: 0:02:54.893363 FixedProfit: 1195606
# Agent: 1 Episode: 15/150 RapTime: 0:04:08.918736 FixedProfit: 1211817
# Agent: 3 Episode: 15/150 RapTime: 0:04:13.003513 FixedProfit: 1197165
# Agent: 2 Episode: 15/150 RapTime: 0:04:12.850098 FixedProfit: 1197165
# Agent: 0 Episode: 22/150 RapTime: 0:02:58.339793 FixedProfit: 1020814
# Agent: 1 Episode: 16/150 RapTime: 0:04:10.736536 FixedProfit: 1229272
# Agent: 0 Episode: 23/150 RapTime: 0:03:06.232154 FixedProfit: 1224374
# Agent: 3 Episode: 16/150 RapTime: 0:04:12.227693 FixedProfit: 1197165
# Agent: 2 Episode: 16/150 RapTime: 0:04:10.870849 FixedProfit: 1197165
# Agent: 1 Episode: 17/150 RapTime: 0:03:58.651488 FixedProfit: 1153599
# Agent: 0 Episode: 24/150 RapTime: 0:02:58.401804 FixedProfit: 1269086
# Agent: 3 Episode: 17/150 RapTime: 0:04:20.008888 FixedProfit: 1197165
# Agent: 2 Episode: 17/150 RapTime: 0:04:10.279361 FixedProfit: 1197165
# Agent: 0 Episode: 25/150 RapTime: 0:02:52.157886 FixedProfit: 1064868
# Agent: 1 Episode: 18/150 RapTime: 0:04:05.206436 FixedProfit: 1204035
# Agent: 0 Episode: 26/150 RapTime: 0:02:57.633509 FixedProfit: 1141468
# Agent: 3 Episode: 18/150 RapTime: 0:04:12.358047 FixedProfit: 1197165
# Agent: 2 Episode: 18/150 RapTime: 0:04:12.890729 FixedProfit: 1197165
# Agent: 1 Episode: 19/150 RapTime: 0:04:03.213864 FixedProfit: 1165760
# Agent: 0 Episode: 27/150 RapTime: 0:03:00.253277 FixedProfit: 1107002
# Agent: 3 Episode: 19/150 RapTime: 0:04:07.548883 FixedProfit: 1197165
# Agent: 2 Episode: 19/150 RapTime: 0:04:15.703705 FixedProfit: 1197165
# Agent: 0 Episode: 28/150 RapTime: 0:02:55.647619 FixedProfit: 1163944
# Agent: 1 Episode: 20/150 RapTime: 0:04:07.437485 FixedProfit: 1191220
# Agent: 3 Episode: 20/150 RapTime: 0:04:08.888423 FixedProfit: 1197165
# Agent: 2 Episode: 20/150 RapTime: 0:04:14.974514 FixedProfit: 1197165
# Agent: 0 Episode: 29/150 RapTime: 0:02:58.978766 FixedProfit: 1190972
# Agent: 1 Episode: 21/150 RapTime: 0:04:04.230932 FixedProfit: 1212498
# Agent: 0 Episode: 30/150 RapTime: 0:03:00.747139 FixedProfit: 1444857
# Agent: 3 Episode: 21/150 RapTime: 0:04:16.506148 FixedProfit: 1197165
# Agent: 2 Episode: 21/150 RapTime: 0:04:19.904673 FixedProfit: 1197165
# Agent: 1 Episode: 22/150 RapTime: 0:04:00.500477 FixedProfit: 1177695
# Agent: 0 Episode: 31/150 RapTime: 0:02:59.625816 FixedProfit: 1085427
# Agent: 3 Episode: 22/150 RapTime: 0:04:16.631842 FixedProfit: 1197165
# Agent: 2 Episode: 22/150 RapTime: 0:04:10.535460 FixedProfit: 1197165
# Agent: 0 Episode: 32/150 RapTime: 0:02:49.913707 FixedProfit: 1082187
# Agent: 1 Episode: 23/150 RapTime: 0:03:58.874149 FixedProfit: 1229977
# Agent: 0 Episode: 33/150 RapTime: 0:02:51.750801 FixedProfit: 1129473
# Agent: 3 Episode: 23/150 RapTime: 0:04:14.475833 FixedProfit: 1197165
# Agent: 2 Episode: 23/150 RapTime: 0:04:13.769788 FixedProfit: 1197165
# Agent: 1 Episode: 24/150 RapTime: 0:04:09.110039 FixedProfit: 1153944
# Agent: 0 Episode: 34/150 RapTime: 0:02:46.173962 FixedProfit: 1286757
# Agent: 3 Episode: 24/150 RapTime: 0:04:12.589015 FixedProfit: 1197165
# Agent: 2 Episode: 24/150 RapTime: 0:04:16.403318 FixedProfit: 1197165
# Agent: 0 Episode: 35/150 RapTime: 0:02:54.630008 FixedProfit: 1268369
# Agent: 1 Episode: 25/150 RapTime: 0:04:06.523940 FixedProfit: 1203081
# Agent: 0 Episode: 36/150 RapTime: 0:02:52.596071 FixedProfit: 1115845
# Agent: 3 Episode: 25/150 RapTime: 0:04:09.465531 FixedProfit: 1197165
# Agent: 2 Episode: 25/150 RapTime: 0:04:14.427002 FixedProfit: 1197165
# Agent: 1 Episode: 26/150 RapTime: 0:04:12.120380 FixedProfit: 1216507
# Agent: 0 Episode: 37/150 RapTime: 0:02:49.574382 FixedProfit: 1145659
# Agent: 3 Episode: 26/150 RapTime: 0:04:09.535995 FixedProfit: 1197165
# Agent: 2 Episode: 26/150 RapTime: 0:04:09.132317 FixedProfit: 1197165
# Agent: 1 Episode: 27/150 RapTime: 0:04:06.076909 FixedProfit: 1189755
# Agent: 0 Episode: 38/150 RapTime: 0:02:52.414861 FixedProfit: 1179997
# Agent: 0 Episode: 39/150 RapTime: 0:03:01.284241 FixedProfit: 1160668
# Agent: 3 Episode: 27/150 RapTime: 0:04:17.413586 FixedProfit: 1197165
# Agent: 2 Episode: 27/150 RapTime: 0:04:12.020197 FixedProfit: 1197165
# Agent: 1 Episode: 28/150 RapTime: 0:04:02.571196 FixedProfit: 1212405
# Agent: 0 Episode: 40/150 RapTime: 0:03:00.846114 FixedProfit: 1191539
# Agent: 3 Episode: 28/150 RapTime: 0:04:19.522298 FixedProfit: 1197165
# Agent: 2 Episode: 28/150 RapTime: 0:04:12.485706 FixedProfit: 1197165
# Agent: 1 Episode: 29/150 RapTime: 0:04:12.664404 FixedProfit: 1221254
# Agent: 0 Episode: 41/150 RapTime: 0:02:56.072544 FixedProfit: 1213757
# Agent: 3 Episode: 29/150 RapTime: 0:04:09.614815 FixedProfit: 1197165
# Agent: 2 Episode: 29/150 RapTime: 0:04:18.422806 FixedProfit: 1197165
# Agent: 0 Episode: 42/150 RapTime: 0:02:53.022927 FixedProfit: 987365
# Agent: 1 Episode: 30/150 RapTime: 0:04:06.101009 FixedProfit: 1188836
# Agent: 0 Episode: 43/150 RapTime: 0:02:56.808631 FixedProfit: 1256253
# Agent: 3 Episode: 30/150 RapTime: 0:04:12.907478 FixedProfit: 1197165
# Agent: 2 Episode: 30/150 RapTime: 0:04:14.219958 FixedProfit: 1197165
# Agent: 1 Episode: 31/150 RapTime: 0:04:05.222075 FixedProfit: 1188067
# Agent: 0 Episode: 44/150 RapTime: 0:03:05.282096 FixedProfit: 1106883
# Agent: 3 Episode: 31/150 RapTime: 0:04:16.285559 FixedProfit: 1197165
# Agent: 2 Episode: 31/150 RapTime: 0:04:14.066462 FixedProfit: 1197165
# Agent: 1 Episode: 32/150 RapTime: 0:04:03.224628 FixedProfit: 1145274
# Agent: 0 Episode: 45/150 RapTime: 0:02:53.667028 FixedProfit: 1202219
# Agent: 0 Episode: 46/150 RapTime: 0:02:45.575289 FixedProfit: 1149516
# Agent: 3 Episode: 32/150 RapTime: 0:04:15.611278 FixedProfit: 1197165
# Agent: 2 Episode: 32/150 RapTime: 0:04:17.532161 FixedProfit: 1197165
# Agent: 1 Episode: 33/150 RapTime: 0:04:12.234020 FixedProfit: 1160519
# Agent: 0 Episode: 47/150 RapTime: 0:02:46.671978 FixedProfit: 1314908
# Agent: 3 Episode: 33/150 RapTime: 0:04:10.598159 FixedProfit: 1197165
# Agent: 1 Episode: 34/150 RapTime: 0:04:04.745437 FixedProfit: 1218345
# Agent: 2 Episode: 33/150 RapTime: 0:04:17.729681 FixedProfit: 1197165
# Agent: 0 Episode: 48/150 RapTime: 0:03:01.323403 FixedProfit: 1142330
# Agent: 0 Episode: 49/150 RapTime: 0:02:57.229524 FixedProfit: 1196222
# Agent: 3 Episode: 34/150 RapTime: 0:04:12.955973 FixedProfit: 1197165
# Agent: 1 Episode: 35/150 RapTime: 0:04:05.027218 FixedProfit: 1210227
# Agent: 2 Episode: 34/150 RapTime: 0:04:16.041608 FixedProfit: 1197165
# Agent: 0 Episode: 50/150 RapTime: 0:03:04.794109 FixedProfit: 1073270
# Agent: 1 Episode: 36/150 RapTime: 0:04:07.911022 FixedProfit: 1165708
# Agent: 3 Episode: 35/150 RapTime: 0:04:16.038378 FixedProfit: 1197165
# Agent: 2 Episode: 35/150 RapTime: 0:04:12.944572 FixedProfit: 1197165
# Agent: 0 Episode: 51/150 RapTime: 0:03:06.383262 FixedProfit: 1111998
# Agent: 1 Episode: 37/150 RapTime: 0:04:04.890034 FixedProfit: 1187161
# Agent: 3 Episode: 36/150 RapTime: 0:04:13.078701 FixedProfit: 1197165
# Agent: 0 Episode: 52/150 RapTime: 0:02:53.439931 FixedProfit: 1166342
# Agent: 2 Episode: 36/150 RapTime: 0:04:14.090016 FixedProfit: 1197165
# Agent: 0 Episode: 53/150 RapTime: 0:02:57.781744 FixedProfit: 1104869
# Agent: 1 Episode: 38/150 RapTime: 0:04:07.152122 FixedProfit: 1133476
# Agent: 3 Episode: 37/150 RapTime: 0:04:14.532665 FixedProfit: 1197165
# Agent: 2 Episode: 37/150 RapTime: 0:04:12.015773 FixedProfit: 1197165
# Agent: 0 Episode: 54/150 RapTime: 0:02:55.206099 FixedProfit: 1115950
# Agent: 1 Episode: 39/150 RapTime: 0:04:05.217545 FixedProfit: 1202398
# Agent: 3 Episode: 38/150 RapTime: 0:04:15.710591 FixedProfit: 1197165
# Agent: 2 Episode: 38/150 RapTime: 0:04:13.634842 FixedProfit: 1197165
# Agent: 0 Episode: 55/150 RapTime: 0:02:53.046014 FixedProfit: 1073296
# Agent: 0 Episode: 56/150 RapTime: 0:02:56.056852 FixedProfit: 1264474
# Agent: 1 Episode: 40/150 RapTime: 0:04:03.857193 FixedProfit: 1212471
# Agent: 3 Episode: 39/150 RapTime: 0:04:15.338997 FixedProfit: 1197165
# Agent: 2 Episode: 39/150 RapTime: 0:04:16.521150 FixedProfit: 1197165
# Agent: 0 Episode: 57/150 RapTime: 0:02:51.783450 FixedProfit: 1222012
# Agent: 1 Episode: 41/150 RapTime: 0:04:03.281834 FixedProfit: 1171275
# Agent: 3 Episode: 40/150 RapTime: 0:04:08.729636 FixedProfit: 1197165
# Agent: 2 Episode: 40/150 RapTime: 0:04:13.248617 FixedProfit: 1197165
# Agent: 0 Episode: 58/150 RapTime: 0:02:55.610706 FixedProfit: 1282503
# Agent: 1 Episode: 42/150 RapTime: 0:04:03.876223 FixedProfit: 1166723
# Agent: 0 Episode: 59/150 RapTime: 0:03:01.980446 FixedProfit: 1259081
# Agent: 3 Episode: 41/150 RapTime: 0:04:18.878191 FixedProfit: 1197165
# Agent: 2 Episode: 41/150 RapTime: 0:04:17.557989 FixedProfit: 1197165
# Agent: 0 Episode: 60/150 RapTime: 0:02:58.118848 FixedProfit: 1144974
# Agent: 1 Episode: 43/150 RapTime: 0:04:04.319778 FixedProfit: 1182140
# Agent: 3 Episode: 42/150 RapTime: 0:04:16.259476 FixedProfit: 1197165
# Agent: 2 Episode: 42/150 RapTime: 0:04:14.778135 FixedProfit: 1197165
# Agent: 0 Episode: 61/150 RapTime: 0:02:50.439585 FixedProfit: 1195449
# Agent: 1 Episode: 44/150 RapTime: 0:04:05.684273 FixedProfit: 1189673
# Agent: 0 Episode: 62/150 RapTime: 0:03:05.326598 FixedProfit: 1323399
# Agent: 3 Episode: 43/150 RapTime: 0:04:14.305241 FixedProfit: 1197165
# Agent: 2 Episode: 43/150 RapTime: 0:04:14.987535 FixedProfit: 1197165
# Agent: 1 Episode: 45/150 RapTime: 0:04:02.199481 FixedProfit: 1203435
# Agent: 0 Episode: 63/150 RapTime: 0:02:50.508991 FixedProfit: 1321458
# Agent: 3 Episode: 44/150 RapTime: 0:04:15.816893 FixedProfit: 1197165
# Agent: 2 Episode: 44/150 RapTime: 0:04:17.977787 FixedProfit: 1197165
# Agent: 0 Episode: 64/150 RapTime: 0:02:54.054694 FixedProfit: 1157217
# Agent: 1 Episode: 46/150 RapTime: 0:04:07.394786 FixedProfit: 1208662
# Agent: 3 Episode: 45/150 RapTime: 0:04:25.605805 FixedProfit: 1197165
# Agent: 0 Episode: 65/150 RapTime: 0:03:03.902920 FixedProfit: 1170600
# Agent: 2 Episode: 45/150 RapTime: 0:04:10.737213 FixedProfit: 1197165
# Agent: 1 Episode: 47/150 RapTime: 0:04:09.559788 FixedProfit: 1150174
# Agent: 0 Episode: 66/150 RapTime: 0:02:55.788169 FixedProfit: 1201741
# Agent: 3 Episode: 46/150 RapTime: 0:04:17.476746 FixedProfit: 1197165
# Agent: 2 Episode: 46/150 RapTime: 0:04:17.440208 FixedProfit: 1197165
# Agent: 0 Episode: 67/150 RapTime: 0:02:45.891873 FixedProfit: 1101513
# Agent: 1 Episode: 48/150 RapTime: 0:04:07.885942 FixedProfit: 1230692
# Agent: 3 Episode: 47/150 RapTime: 0:04:14.300876 FixedProfit: 1197165
# Agent: 0 Episode: 68/150 RapTime: 0:02:54.149263 FixedProfit: 1253643
# Agent: 2 Episode: 47/150 RapTime: 0:04:20.000236 FixedProfit: 1197165
# Agent: 1 Episode: 49/150 RapTime: 0:04:08.757901 FixedProfit: 1190925
# Agent: 0 Episode: 69/150 RapTime: 0:02:55.284988 FixedProfit: 1051720
# Agent: 3 Episode: 48/150 RapTime: 0:04:13.293881 FixedProfit: 1197165
# Agent: 2 Episode: 48/150 RapTime: 0:04:19.636078 FixedProfit: 1197165
# Agent: 0 Episode: 70/150 RapTime: 0:02:59.368979 FixedProfit: 1219785
# Agent: 1 Episode: 50/150 RapTime: 0:04:05.055328 FixedProfit: 1172189
# Agent: 3 Episode: 49/150 RapTime: 0:04:13.237406 FixedProfit: 1197165
# Agent: 0 Episode: 71/150 RapTime: 0:02:53.520716 FixedProfit: 960741
# Agent: 2 Episode: 49/150 RapTime: 0:04:22.917020 FixedProfit: 1197165
# Agent: 1 Episode: 51/150 RapTime: 0:04:07.065560 FixedProfit: 1192988
# Agent: 0 Episode: 72/150 RapTime: 0:02:51.986355 FixedProfit: 1068518
# Agent: 3 Episode: 50/150 RapTime: 0:04:14.600341 FixedProfit: 1197165
# Agent: 2 Episode: 50/150 RapTime: 0:04:18.400616 FixedProfit: 1197165
# Agent: 1 Episode: 52/150 RapTime: 0:04:06.741272 FixedProfit: 1201567
# Agent: 0 Episode: 73/150 RapTime: 0:02:55.119700 FixedProfit: 1169058
# Agent: 3 Episode: 51/150 RapTime: 0:04:18.442760 FixedProfit: 1197165
# Agent: 2 Episode: 51/150 RapTime: 0:04:08.836079 FixedProfit: 1197165
# Agent: 0 Episode: 74/150 RapTime: 0:02:54.170462 FixedProfit: 988611
# Agent: 1 Episode: 53/150 RapTime: 0:04:03.910415 FixedProfit: 1227171
# Agent: 0 Episode: 75/150 RapTime: 0:02:53.558956 FixedProfit: 1229754
# Agent: 3 Episode: 52/150 RapTime: 0:04:17.459476 FixedProfit: 1197165
# Agent: 2 Episode: 52/150 RapTime: 0:04:11.306258 FixedProfit: 1197165
# Agent: 1 Episode: 54/150 RapTime: 0:04:04.817700 FixedProfit: 1172133
# Agent: 0 Episode: 76/150 RapTime: 0:02:54.973952 FixedProfit: 1226406
# Agent: 3 Episode: 53/150 RapTime: 0:04:19.028904 FixedProfit: 1197165
# Agent: 2 Episode: 53/150 RapTime: 0:04:05.696977 FixedProfit: 1197165
# Agent: 0 Episode: 77/150 RapTime: 0:02:51.375433 FixedProfit: 1023831
# Agent: 1 Episode: 55/150 RapTime: 0:04:08.939697 FixedProfit: 1216389
# Agent: 0 Episode: 78/150 RapTime: 0:02:51.327617 FixedProfit: 1118099
# Agent: 3 Episode: 54/150 RapTime: 0:04:21.205669 FixedProfit: 1197165
# Agent: 2 Episode: 54/150 RapTime: 0:04:18.125378 FixedProfit: 1197165
# Agent: 1 Episode: 56/150 RapTime: 0:04:03.592876 FixedProfit: 1192341
# Agent: 0 Episode: 79/150 RapTime: 0:02:51.821232 FixedProfit: 1163576
# Agent: 3 Episode: 55/150 RapTime: 0:04:11.571236 FixedProfit: 1197165
# Agent: 2 Episode: 55/150 RapTime: 0:04:16.397342 FixedProfit: 1197165
# Agent: 1 Episode: 57/150 RapTime: 0:04:02.316741 FixedProfit: 1183348
# Agent: 0 Episode: 80/150 RapTime: 0:02:48.478125 FixedProfit: 1203680
# Agent: 0 Episode: 81/150 RapTime: 0:02:56.641527 FixedProfit: 1149289
# Agent: 3 Episode: 56/150 RapTime: 0:04:21.545613 FixedProfit: 1197165
# Agent: 2 Episode: 56/150 RapTime: 0:04:21.531755 FixedProfit: 1197165
# Agent: 1 Episode: 58/150 RapTime: 0:04:07.142688 FixedProfit: 1250342
# Agent: 0 Episode: 82/150 RapTime: 0:02:53.955795 FixedProfit: 1240544
# Agent: 3 Episode: 57/150 RapTime: 0:04:16.540835 FixedProfit: 1197165
# Agent: 1 Episode: 59/150 RapTime: 0:04:03.255426 FixedProfit: 1206041
# Agent: 2 Episode: 57/150 RapTime: 0:04:20.037421 FixedProfit: 1197165
# Agent: 0 Episode: 83/150 RapTime: 0:02:55.506069 FixedProfit: 1123266
# Agent: 0 Episode: 84/150 RapTime: 0:03:08.014743 FixedProfit: 1174907
# Agent: 1 Episode: 60/150 RapTime: 0:03:54.299644 FixedProfit: 1201025
# Agent: 3 Episode: 58/150 RapTime: 0:04:21.332692 FixedProfit: 1197165
# Agent: 2 Episode: 58/150 RapTime: 0:04:20.212976 FixedProfit: 1197165
# Agent: 0 Episode: 85/150 RapTime: 0:02:55.558545 FixedProfit: 1132070
# Agent: 1 Episode: 61/150 RapTime: 0:04:12.381207 FixedProfit: 1226564
# Agent: 3 Episode: 59/150 RapTime: 0:04:06.533803 FixedProfit: 1197165
# Agent: 2 Episode: 59/150 RapTime: 0:04:21.106347 FixedProfit: 1197165
# Agent: 0 Episode: 86/150 RapTime: 0:02:58.328277 FixedProfit: 1264088
# Agent: 1 Episode: 62/150 RapTime: 0:04:11.245093 FixedProfit: 1194063
# Agent: 0 Episode: 87/150 RapTime: 0:02:49.328447 FixedProfit: 1050561
# Agent: 3 Episode: 60/150 RapTime: 0:04:20.830753 FixedProfit: 1197165
# Agent: 2 Episode: 60/150 RapTime: 0:04:10.475846 FixedProfit: 1197165
# Agent: 0 Episode: 88/150 RapTime: 0:02:53.686571 FixedProfit: 1369107
# Agent: 1 Episode: 63/150 RapTime: 0:04:00.192723 FixedProfit: 1229135
# Agent: 3 Episode: 61/150 RapTime: 0:04:17.048358 FixedProfit: 1197165
# Agent: 2 Episode: 61/150 RapTime: 0:04:17.825440 FixedProfit: 1197165
# Agent: 0 Episode: 89/150 RapTime: 0:03:00.636939 FixedProfit: 1135750
# Agent: 1 Episode: 64/150 RapTime: 0:04:01.931109 FixedProfit: 1221573
# Agent: 3 Episode: 62/150 RapTime: 0:04:14.880863 FixedProfit: 1197165
# Agent: 0 Episode: 90/150 RapTime: 0:02:53.457071 FixedProfit: 1096080
# Agent: 2 Episode: 62/150 RapTime: 0:04:15.315996 FixedProfit: 1197165
# Agent: 0 Episode: 91/150 RapTime: 0:02:52.719188 FixedProfit: 1180058
# Agent: 1 Episode: 65/150 RapTime: 0:04:06.061539 FixedProfit: 1253644
# Agent: 3 Episode: 63/150 RapTime: 0:04:17.440654 FixedProfit: 1197165
# Agent: 2 Episode: 63/150 RapTime: 0:04:17.095630 FixedProfit: 1197165
# Agent: 0 Episode: 92/150 RapTime: 0:02:54.379946 FixedProfit: 1061175
# Agent: 1 Episode: 66/150 RapTime: 0:04:08.608637 FixedProfit: 1217384
# Agent: 3 Episode: 64/150 RapTime: 0:04:19.160917 FixedProfit: 1197165
# Agent: 0 Episode: 93/150 RapTime: 0:02:59.012093 FixedProfit: 1207193
# Agent: 2 Episode: 64/150 RapTime: 0:04:17.823909 FixedProfit: 1197165
# Agent: 1 Episode: 67/150 RapTime: 0:04:00.289378 FixedProfit: 1179329
# Agent: 0 Episode: 94/150 RapTime: 0:02:57.740494 FixedProfit: 1237208
# Agent: 3 Episode: 65/150 RapTime: 0:04:18.407705 FixedProfit: 1197165
# Agent: 2 Episode: 65/150 RapTime: 0:04:15.833332 FixedProfit: 1197165
# Agent: 0 Episode: 95/150 RapTime: 0:02:53.648483 FixedProfit: 995161
# Agent: 1 Episode: 68/150 RapTime: 0:04:02.104578 FixedProfit: 1220575
# Agent: 3 Episode: 66/150 RapTime: 0:04:16.645565 FixedProfit: 1197165
# Agent: 2 Episode: 66/150 RapTime: 0:04:13.546038 FixedProfit: 1197165
# Agent: 0 Episode: 96/150 RapTime: 0:02:59.337007 FixedProfit: 1125133
# Agent: 1 Episode: 69/150 RapTime: 0:04:04.812450 FixedProfit: 1215586
# Agent: 0 Episode: 97/150 RapTime: 0:02:44.236690 FixedProfit: 1179666
# Agent: 3 Episode: 67/150 RapTime: 0:04:15.415840 FixedProfit: 1197165
# Agent: 2 Episode: 67/150 RapTime: 0:04:11.999143 FixedProfit: 1197165
# Agent: 0 Episode: 98/150 RapTime: 0:02:57.048367 FixedProfit: 1178265
# Agent: 1 Episode: 70/150 RapTime: 0:04:11.617314 FixedProfit: 1218213
# Agent: 3 Episode: 68/150 RapTime: 0:04:15.473533 FixedProfit: 1197165
# Agent: 2 Episode: 68/150 RapTime: 0:04:10.671173 FixedProfit: 1197165
# Agent: 0 Episode: 99/150 RapTime: 0:02:41.649398 FixedProfit: 923425
# Agent: 1 Episode: 71/150 RapTime: 0:04:05.705632 FixedProfit: 1191621
# Agent: 0 Episode: 100/150 RapTime: 0:03:01.165442 FixedProfit: 1154865
# Agent: 3 Episode: 69/150 RapTime: 0:04:14.281821 FixedProfit: 1197165
# Agent: 2 Episode: 69/150 RapTime: 0:04:22.069506 FixedProfit: 1197165
# Agent: 1 Episode: 72/150 RapTime: 0:03:59.699886 FixedProfit: 1189511
# Agent: 0 Episode: 101/150 RapTime: 0:03:02.149567 FixedProfit: 961637
# Agent: 3 Episode: 70/150 RapTime: 0:04:15.795492 FixedProfit: 1197165
# Agent: 2 Episode: 70/150 RapTime: 0:04:21.923384 FixedProfit: 1197165
# Agent: 0 Episode: 102/150 RapTime: 0:02:55.568784 FixedProfit: 1030048
# Agent: 1 Episode: 73/150 RapTime: 0:04:05.841550 FixedProfit: 1188580
# Agent: 0 Episode: 103/150 RapTime: 0:03:10.396048 FixedProfit: 1304401
# Agent: 3 Episode: 71/150 RapTime: 0:04:20.112161 FixedProfit: 1197165
# Agent: 2 Episode: 71/150 RapTime: 0:04:18.866022 FixedProfit: 1197165
# Agent: 1 Episode: 74/150 RapTime: 0:04:13.113304 FixedProfit: 1167840
# Agent: 0 Episode: 104/150 RapTime: 0:03:00.789633 FixedProfit: 1277974
# Agent: 3 Episode: 72/150 RapTime: 0:04:25.234846 FixedProfit: 1197165
# Agent: 2 Episode: 72/150 RapTime: 0:04:19.218829 FixedProfit: 1197165
# Agent: 1 Episode: 75/150 RapTime: 0:04:06.765342 FixedProfit: 1191160
# Agent: 0 Episode: 105/150 RapTime: 0:02:59.249758 FixedProfit: 1155197
# Agent: 0 Episode: 106/150 RapTime: 0:02:52.215017 FixedProfit: 1109859
# Agent: 3 Episode: 73/150 RapTime: 0:04:24.479997 FixedProfit: 1197165
# Agent: 2 Episode: 73/150 RapTime: 0:04:19.101237 FixedProfit: 1197165
# Agent: 1 Episode: 76/150 RapTime: 0:04:09.516741 FixedProfit: 1196488
# Agent: 0 Episode: 107/150 RapTime: 0:02:51.659915 FixedProfit: 1174355
# Agent: 2 Episode: 74/150 RapTime: 0:04:14.337477 FixedProfit: 1197165
# Agent: 3 Episode: 74/150 RapTime: 0:04:19.512914 FixedProfit: 1197165
# Agent: 1 Episode: 77/150 RapTime: 0:04:09.031670 FixedProfit: 1184886
# Agent: 0 Episode: 108/150 RapTime: 0:03:02.737866 FixedProfit: 1113266
# Agent: 0 Episode: 109/150 RapTime: 0:02:55.142927 FixedProfit: 1158278
# Agent: 2 Episode: 75/150 RapTime: 0:04:17.135562 FixedProfit: 1197165
# Agent: 3 Episode: 75/150 RapTime: 0:04:20.699356 FixedProfit: 1197165
# Agent: 1 Episode: 78/150 RapTime: 0:04:06.896241 FixedProfit: 1149875
# Agent: 0 Episode: 110/150 RapTime: 0:02:54.210444 FixedProfit: 1181115
# Agent: 2 Episode: 76/150 RapTime: 0:04:17.281683 FixedProfit: 1197165
# Agent: 3 Episode: 76/150 RapTime: 0:04:21.860461 FixedProfit: 1197165
# Agent: 1 Episode: 79/150 RapTime: 0:04:07.583336 FixedProfit: 1268615
# Agent: 0 Episode: 111/150 RapTime: 0:02:50.649476 FixedProfit: 1103255
# Agent: 2 Episode: 77/150 RapTime: 0:04:18.821393 FixedProfit: 1197165
# Agent: 0 Episode: 112/150 RapTime: 0:02:59.779228 FixedProfit: 1130937
# Agent: 3 Episode: 77/150 RapTime: 0:04:19.200614 FixedProfit: 1197165
# Agent: 1 Episode: 80/150 RapTime: 0:04:08.894691 FixedProfit: 1212586
# Agent: 0 Episode: 113/150 RapTime: 0:03:00.486232 FixedProfit: 1091048
# Agent: 2 Episode: 78/150 RapTime: 0:04:13.082720 FixedProfit: 1197165
# Agent: 3 Episode: 78/150 RapTime: 0:04:17.146664 FixedProfit: 1197165
# Agent: 1 Episode: 81/150 RapTime: 0:04:12.263576 FixedProfit: 1198487
# Agent: 0 Episode: 114/150 RapTime: 0:03:06.551463 FixedProfit: 1368832
# Agent: 2 Episode: 79/150 RapTime: 0:04:18.653801 FixedProfit: 1197165
# Agent: 1 Episode: 82/150 RapTime: 0:04:02.964857 FixedProfit: 1223220
# Agent: 3 Episode: 79/150 RapTime: 0:04:18.970620 FixedProfit: 1197165
# Agent: 0 Episode: 115/150 RapTime: 0:03:06.241691 FixedProfit: 1158892
# Agent: 0 Episode: 116/150 RapTime: 0:02:59.907601 FixedProfit: 1254044
# Agent: 1 Episode: 83/150 RapTime: 0:04:08.150239 FixedProfit: 1181808
# Agent: 2 Episode: 80/150 RapTime: 0:04:17.265133 FixedProfit: 1197165
# Agent: 3 Episode: 80/150 RapTime: 0:04:20.772641 FixedProfit: 1197165
# Agent: 0 Episode: 117/150 RapTime: 0:02:50.738271 FixedProfit: 1136953
# Agent: 1 Episode: 84/150 RapTime: 0:04:05.692069 FixedProfit: 1218105
# Agent: 2 Episode: 81/150 RapTime: 0:04:23.451559 FixedProfit: 1197165
# Agent: 3 Episode: 81/150 RapTime: 0:04:17.902514 FixedProfit: 1197165
# Agent: 0 Episode: 118/150 RapTime: 0:03:08.273390 FixedProfit: 1110561
# Agent: 1 Episode: 85/150 RapTime: 0:04:11.461033 FixedProfit: 1184576
# Agent: 0 Episode: 119/150 RapTime: 0:02:57.644923 FixedProfit: 1261639
# Agent: 2 Episode: 82/150 RapTime: 0:04:15.911049 FixedProfit: 1197165
# Agent: 3 Episode: 82/150 RapTime: 0:04:20.027814 FixedProfit: 1197165
# Agent: 0 Episode: 120/150 RapTime: 0:03:05.493817 FixedProfit: 1197275
# Agent: 1 Episode: 86/150 RapTime: 0:04:15.684118 FixedProfit: 1177503
# Agent: 2 Episode: 83/150 RapTime: 0:04:24.804096 FixedProfit: 1197165
# Agent: 3 Episode: 83/150 RapTime: 0:04:14.494719 FixedProfit: 1197165
# Agent: 0 Episode: 121/150 RapTime: 0:02:57.538554 FixedProfit: 1071410
# Agent: 1 Episode: 87/150 RapTime: 0:04:11.501293 FixedProfit: 1163652
# Agent: 2 Episode: 84/150 RapTime: 0:04:17.342229 FixedProfit: 1197165
# Agent: 3 Episode: 84/150 RapTime: 0:04:13.142391 FixedProfit: 1197165
# Agent: 0 Episode: 122/150 RapTime: 0:02:55.610028 FixedProfit: 1133982
# Agent: 0 Episode: 123/150 RapTime: 0:02:50.234473 FixedProfit: 1075688
# Agent: 1 Episode: 88/150 RapTime: 0:04:15.786128 FixedProfit: 1202492
# Agent: 2 Episode: 85/150 RapTime: 0:04:15.581234 FixedProfit: 1197165
# Agent: 3 Episode: 85/150 RapTime: 0:04:24.163177 FixedProfit: 1197165
# Agent: 0 Episode: 124/150 RapTime: 0:03:11.047749 FixedProfit: 1205017
# Agent: 1 Episode: 89/150 RapTime: 0:04:01.913035 FixedProfit: 1189971
# Agent: 2 Episode: 86/150 RapTime: 0:04:17.187451 FixedProfit: 1197165
# Agent: 3 Episode: 86/150 RapTime: 0:04:20.010586 FixedProfit: 1197165
# Agent: 0 Episode: 125/150 RapTime: 0:02:58.297947 FixedProfit: 1314941
# Agent: 1 Episode: 90/150 RapTime: 0:04:09.015484 FixedProfit: 1170396
# Agent: 0 Episode: 126/150 RapTime: 0:02:55.087098 FixedProfit: 1070973
# Agent: 2 Episode: 87/150 RapTime: 0:04:17.842348 FixedProfit: 1197165
# Agent: 3 Episode: 87/150 RapTime: 0:04:24.442708 FixedProfit: 1197165
# Agent: 0 Episode: 127/150 RapTime: 0:02:49.517061 FixedProfit: 1236106
# Agent: 1 Episode: 91/150 RapTime: 0:04:04.648920 FixedProfit: 1205046
# Agent: 2 Episode: 88/150 RapTime: 0:04:22.199784 FixedProfit: 1197165
# Agent: 3 Episode: 88/150 RapTime: 0:04:17.065435 FixedProfit: 1197165
# Agent: 0 Episode: 128/150 RapTime: 0:02:58.014323 FixedProfit: 1021447
# Agent: 1 Episode: 92/150 RapTime: 0:04:11.688931 FixedProfit: 1196854
# Agent: 0 Episode: 129/150 RapTime: 0:02:56.576256 FixedProfit: 1174700
# Agent: 2 Episode: 89/150 RapTime: 0:04:17.244769 FixedProfit: 1197165
# Agent: 3 Episode: 89/150 RapTime: 0:04:20.013325 FixedProfit: 1197165
# Agent: 0 Episode: 130/150 RapTime: 0:02:55.878176 FixedProfit: 1207389
# Agent: 1 Episode: 93/150 RapTime: 0:04:10.336673 FixedProfit: 1198625
# Agent: 2 Episode: 90/150 RapTime: 0:04:17.966236 FixedProfit: 1197165
# Agent: 3 Episode: 90/150 RapTime: 0:04:22.279327 FixedProfit: 1197165
# Agent: 0 Episode: 131/150 RapTime: 0:02:55.844659 FixedProfit: 1254878
# Agent: 1 Episode: 94/150 RapTime: 0:04:07.308141 FixedProfit: 1168571
# Agent: 0 Episode: 132/150 RapTime: 0:02:49.655306 FixedProfit: 1199433
# Agent: 2 Episode: 91/150 RapTime: 0:04:21.007656 FixedProfit: 1197165
# Agent: 3 Episode: 91/150 RapTime: 0:04:19.337995 FixedProfit: 1197165
# Agent: 0 Episode: 133/150 RapTime: 0:02:57.788868 FixedProfit: 1225154
# Agent: 1 Episode: 95/150 RapTime: 0:04:08.246412 FixedProfit: 1148712
# Agent: 2 Episode: 92/150 RapTime: 0:04:20.789189 FixedProfit: 1197165
# Agent: 3 Episode: 92/150 RapTime: 0:04:22.971936 FixedProfit: 1197165
# Agent: 0 Episode: 134/150 RapTime: 0:02:51.853649 FixedProfit: 1059361
# Agent: 1 Episode: 96/150 RapTime: 0:04:10.802387 FixedProfit: 1190871
# Agent: 0 Episode: 135/150 RapTime: 0:02:54.973680 FixedProfit: 1324379
# Agent: 2 Episode: 93/150 RapTime: 0:04:16.448940 FixedProfit: 1197165
# Agent: 3 Episode: 93/150 RapTime: 0:04:20.141117 FixedProfit: 1197165
# Agent: 1 Episode: 97/150 RapTime: 0:04:06.806723 FixedProfit: 1170279
# Agent: 0 Episode: 136/150 RapTime: 0:02:58.553806 FixedProfit: 1187196
# Agent: 2 Episode: 94/150 RapTime: 0:04:21.312065 FixedProfit: 1197165
# Agent: 3 Episode: 94/150 RapTime: 0:04:10.836216 FixedProfit: 1197165
# Agent: 0 Episode: 137/150 RapTime: 0:03:07.262698 FixedProfit: 1357515
# Agent: 1 Episode: 98/150 RapTime: 0:04:15.275624 FixedProfit: 1181040
# Agent: 0 Episode: 138/150 RapTime: 0:02:55.117327 FixedProfit: 1038285
# Agent: 2 Episode: 95/150 RapTime: 0:04:19.521910 FixedProfit: 1197165
# Agent: 3 Episode: 95/150 RapTime: 0:04:18.775373 FixedProfit: 1197165
# Agent: 1 Episode: 99/150 RapTime: 0:04:05.678831 FixedProfit: 1189227
# Agent: 0 Episode: 139/150 RapTime: 0:02:58.779034 FixedProfit: 1259430
# Agent: 2 Episode: 96/150 RapTime: 0:04:17.809981 FixedProfit: 1197165
# Agent: 3 Episode: 96/150 RapTime: 0:04:19.635131 FixedProfit: 1197165
# Agent: 1 Episode: 100/150 RapTime: 0:04:05.795912 FixedProfit: 1220209
# Agent: 0 Episode: 140/150 RapTime: 0:03:03.699334 FixedProfit: 1087627
# Agent: 0 Episode: 141/150 RapTime: 0:02:52.529444 FixedProfit: 1081696
# Agent: 2 Episode: 97/150 RapTime: 0:04:22.865210 FixedProfit: 1197165
# Agent: 3 Episode: 97/150 RapTime: 0:04:18.562201 FixedProfit: 1197165
# Agent: 1 Episode: 101/150 RapTime: 0:04:13.089536 FixedProfit: 1215116
# Agent: 0 Episode: 142/150 RapTime: 0:03:00.269656 FixedProfit: 1176564
# Agent: 2 Episode: 98/150 RapTime: 0:04:21.926566 FixedProfit: 1197165
# Agent: 3 Episode: 98/150 RapTime: 0:04:23.426663 FixedProfit: 1197165
# Agent: 1 Episode: 102/150 RapTime: 0:04:03.897852 FixedProfit: 1180137
# Agent: 0 Episode: 143/150 RapTime: 0:02:56.263787 FixedProfit: 1303589
# Agent: 2 Episode: 99/150 RapTime: 0:04:16.811056 FixedProfit: 1197165
# Agent: 0 Episode: 144/150 RapTime: 0:02:49.239921 FixedProfit: 1279921
# Agent: 3 Episode: 99/150 RapTime: 0:04:24.452594 FixedProfit: 1197165
# Agent: 1 Episode: 103/150 RapTime: 0:04:15.499308 FixedProfit: 1211068
# Agent: 0 Episode: 145/150 RapTime: 0:02:55.222533 FixedProfit: 1290230
# Agent: 2 Episode: 100/150 RapTime: 0:04:20.794212 FixedProfit: 1197165
# Agent: 3 Episode: 100/150 RapTime: 0:04:14.905793 FixedProfit: 1197165
# Agent: 1 Episode: 104/150 RapTime: 0:04:08.684380 FixedProfit: 1207467
# Agent: 0 Episode: 146/150 RapTime: 0:03:05.392129 FixedProfit: 1084211
# Agent: 2 Episode: 101/150 RapTime: 0:04:17.228182 FixedProfit: 1197165
# Agent: 3 Episode: 101/150 RapTime: 0:04:17.849777 FixedProfit: 1197165
# Agent: 0 Episode: 147/150 RapTime: 0:03:02.683085 FixedProfit: 1099306
# Agent: 1 Episode: 105/150 RapTime: 0:04:12.795546 FixedProfit: 1188650
# Agent: 0 Episode: 148/150 RapTime: 0:02:55.436223 FixedProfit: 1241673
# Agent: 2 Episode: 102/150 RapTime: 0:04:10.535834 FixedProfit: 1197165
# Agent: 3 Episode: 102/150 RapTime: 0:04:22.812138 FixedProfit: 1197165
# Agent: 1 Episode: 106/150 RapTime: 0:04:07.047562 FixedProfit: 1184763
# Agent: 0 Episode: 149/150 RapTime: 0:02:59.760054 FixedProfit: 1313917
# Agent: 2 Episode: 103/150 RapTime: 0:04:16.124992 FixedProfit: 1197165
# Agent: 1 Episode: 107/150 RapTime: 0:04:13.439469 FixedProfit: 1208807
# Agent: 3 Episode: 103/150 RapTime: 0:04:21.223965 FixedProfit: 1197165
# Agent: 0 Episode: 150/150 RapTime: 0:02:58.323285 FixedProfit: 1288561
# None
# Agent: 2 Episode: 104/150 RapTime: 0:03:26.511430 FixedProfit: 1197165
# Agent: 1 Episode: 108/150 RapTime: 0:03:04.990816 FixedProfit: 1174587
# Agent: 3 Episode: 104/150 RapTime: 0:03:07.727386 FixedProfit: 1197165
# Agent: 2 Episode: 105/150 RapTime: 0:03:06.075564 FixedProfit: 1197165
# Agent: 1 Episode: 109/150 RapTime: 0:02:55.451764 FixedProfit: 1191605
# Agent: 3 Episode: 105/150 RapTime: 0:03:05.914774 FixedProfit: 1197165
# Agent: 1 Episode: 110/150 RapTime: 0:02:55.171700 FixedProfit: 1192965
# Agent: 2 Episode: 106/150 RapTime: 0:03:02.522954 FixedProfit: 1197165
# Agent: 3 Episode: 106/150 RapTime: 0:03:07.951736 FixedProfit: 1197165
# Agent: 1 Episode: 111/150 RapTime: 0:03:02.515207 FixedProfit: 1171140
# Agent: 2 Episode: 107/150 RapTime: 0:03:01.988808 FixedProfit: 1197165
# Agent: 3 Episode: 107/150 RapTime: 0:03:03.199682 FixedProfit: 1197165
# Agent: 1 Episode: 112/150 RapTime: 0:02:57.570680 FixedProfit: 1210641
# Agent: 2 Episode: 108/150 RapTime: 0:03:01.535130 FixedProfit: 1197165
# Agent: 3 Episode: 108/150 RapTime: 0:03:04.053465 FixedProfit: 1197165
# Agent: 1 Episode: 113/150 RapTime: 0:02:54.306765 FixedProfit: 1161531
# Agent: 2 Episode: 109/150 RapTime: 0:03:04.202318 FixedProfit: 1197165
# Agent: 3 Episode: 109/150 RapTime: 0:03:08.991656 FixedProfit: 1197165
# Agent: 1 Episode: 114/150 RapTime: 0:02:56.435198 FixedProfit: 1196749
# Agent: 2 Episode: 110/150 RapTime: 0:03:07.086101 FixedProfit: 1197165
# Agent: 3 Episode: 110/150 RapTime: 0:03:05.097229 FixedProfit: 1197165
# Agent: 1 Episode: 115/150 RapTime: 0:02:58.638235 FixedProfit: 1189514
# Agent: 2 Episode: 111/150 RapTime: 0:03:03.455958 FixedProfit: 1197165
# Agent: 3 Episode: 111/150 RapTime: 0:03:05.435490 FixedProfit: 1197165
# Agent: 1 Episode: 116/150 RapTime: 0:03:00.277587 FixedProfit: 1187286
# Agent: 2 Episode: 112/150 RapTime: 0:03:01.725857 FixedProfit: 1197165
# Agent: 3 Episode: 112/150 RapTime: 0:03:03.691584 FixedProfit: 1197165
# Agent: 1 Episode: 117/150 RapTime: 0:02:58.129783 FixedProfit: 1159211
# Agent: 2 Episode: 113/150 RapTime: 0:03:06.003479 FixedProfit: 1197165
# Agent: 3 Episode: 113/150 RapTime: 0:03:03.263198 FixedProfit: 1197165
# Agent: 1 Episode: 118/150 RapTime: 0:03:01.107068 FixedProfit: 1211353
# Agent: 2 Episode: 114/150 RapTime: 0:03:02.480247 FixedProfit: 1197165
# Agent: 3 Episode: 114/150 RapTime: 0:03:00.965972 FixedProfit: 1197165
# Agent: 1 Episode: 119/150 RapTime: 0:02:58.129132 FixedProfit: 1240218
# Agent: 2 Episode: 115/150 RapTime: 0:03:01.442101 FixedProfit: 1197165
# Agent: 3 Episode: 115/150 RapTime: 0:03:03.686434 FixedProfit: 1197165
# Agent: 1 Episode: 120/150 RapTime: 0:02:57.358432 FixedProfit: 1202679
# Agent: 2 Episode: 116/150 RapTime: 0:03:02.658016 FixedProfit: 1197165
# Agent: 3 Episode: 116/150 RapTime: 0:02:57.306307 FixedProfit: 1197165
# Agent: 1 Episode: 121/150 RapTime: 0:02:54.793225 FixedProfit: 1188759
# Agent: 2 Episode: 117/150 RapTime: 0:03:02.971380 FixedProfit: 1197165
# Agent: 3 Episode: 117/150 RapTime: 0:03:03.907172 FixedProfit: 1197165
# Agent: 1 Episode: 122/150 RapTime: 0:02:54.139458 FixedProfit: 1123124
# Agent: 2 Episode: 118/150 RapTime: 0:02:59.799929 FixedProfit: 1197165
# Agent: 3 Episode: 118/150 RapTime: 0:03:01.722464 FixedProfit: 1197165
# Agent: 1 Episode: 123/150 RapTime: 0:02:51.274869 FixedProfit: 1207528
# Agent: 2 Episode: 119/150 RapTime: 0:02:59.198696 FixedProfit: 1197165
# Agent: 3 Episode: 119/150 RapTime: 0:03:03.542195 FixedProfit: 1197165
# Agent: 1 Episode: 124/150 RapTime: 0:02:54.513289 FixedProfit: 1141900
# Agent: 2 Episode: 120/150 RapTime: 0:03:01.164630 FixedProfit: 1197165
# Agent: 3 Episode: 120/150 RapTime: 0:02:58.408786 FixedProfit: 1197165
# Agent: 1 Episode: 125/150 RapTime: 0:02:52.584001 FixedProfit: 1210813
# Agent: 2 Episode: 121/150 RapTime: 0:03:03.385312 FixedProfit: 1197165
# Agent: 3 Episode: 121/150 RapTime: 0:02:58.667625 FixedProfit: 1197165
# Agent: 1 Episode: 126/150 RapTime: 0:02:52.918817 FixedProfit: 1221921
# Agent: 2 Episode: 122/150 RapTime: 0:03:00.569023 FixedProfit: 1197165
# Agent: 3 Episode: 122/150 RapTime: 0:03:03.192738 FixedProfit: 1197165
# Agent: 1 Episode: 127/150 RapTime: 0:02:50.733362 FixedProfit: 1191692
# Agent: 2 Episode: 123/150 RapTime: 0:03:01.133673 FixedProfit: 1197165
# Agent: 3 Episode: 123/150 RapTime: 0:02:58.773975 FixedProfit: 1197165
# Agent: 1 Episode: 128/150 RapTime: 0:02:53.113106 FixedProfit: 1195040
# Agent: 2 Episode: 124/150 RapTime: 0:03:00.424148 FixedProfit: 1197165
# Agent: 3 Episode: 124/150 RapTime: 0:03:03.771044 FixedProfit: 1197165
# Agent: 1 Episode: 129/150 RapTime: 0:02:54.427729 FixedProfit: 1207613
# Agent: 2 Episode: 125/150 RapTime: 0:02:58.424965 FixedProfit: 1197165
# Agent: 3 Episode: 125/150 RapTime: 0:03:01.252505 FixedProfit: 1197165
# Agent: 1 Episode: 130/150 RapTime: 0:02:49.194248 FixedProfit: 1189607
# Agent: 2 Episode: 126/150 RapTime: 0:03:01.158383 FixedProfit: 1197165
# Agent: 3 Episode: 126/150 RapTime: 0:03:01.494414 FixedProfit: 1197165
# Agent: 1 Episode: 131/150 RapTime: 0:02:50.758282 FixedProfit: 1204858
# Agent: 2 Episode: 127/150 RapTime: 0:03:00.890726 FixedProfit: 1197165
# Agent: 3 Episode: 127/150 RapTime: 0:03:00.760112 FixedProfit: 1197165
# Agent: 1 Episode: 132/150 RapTime: 0:02:56.032985 FixedProfit: 1182151
# Agent: 2 Episode: 128/150 RapTime: 0:03:03.837730 FixedProfit: 1197165
# Agent: 3 Episode: 128/150 RapTime: 0:02:56.676261 FixedProfit: 1197165
# Agent: 1 Episode: 133/150 RapTime: 0:02:59.426949 FixedProfit: 1210221
# Agent: 2 Episode: 129/150 RapTime: 0:03:07.489334 FixedProfit: 1197165
# Agent: 1 Episode: 134/150 RapTime: 0:02:48.457427 FixedProfit: 1170069
# Agent: 3 Episode: 129/150 RapTime: 0:03:01.105228 FixedProfit: 1197165
# Agent: 2 Episode: 130/150 RapTime: 0:02:59.654276 FixedProfit: 1197165
# Agent: 1 Episode: 135/150 RapTime: 0:02:59.107890 FixedProfit: 1145184
# Agent: 3 Episode: 130/150 RapTime: 0:03:00.012114 FixedProfit: 1197165
# Agent: 2 Episode: 131/150 RapTime: 0:03:02.223895 FixedProfit: 1197165
# Agent: 1 Episode: 136/150 RapTime: 0:03:01.755001 FixedProfit: 1168377
# Agent: 3 Episode: 131/150 RapTime: 0:02:58.858386 FixedProfit: 1197165
# Agent: 1 Episode: 137/150 RapTime: 0:02:53.713632 FixedProfit: 1188537
# Agent: 2 Episode: 132/150 RapTime: 0:03:04.308638 FixedProfit: 1197165
# Agent: 3 Episode: 132/150 RapTime: 0:03:01.289782 FixedProfit: 1197165
# Agent: 1 Episode: 138/150 RapTime: 0:02:59.697915 FixedProfit: 1173684
# Agent: 2 Episode: 133/150 RapTime: 0:03:00.357443 FixedProfit: 1197165
# Agent: 3 Episode: 133/150 RapTime: 0:02:59.780679 FixedProfit: 1197165
# Agent: 1 Episode: 139/150 RapTime: 0:02:58.468212 FixedProfit: 1198352
# Agent: 2 Episode: 134/150 RapTime: 0:02:58.644399 FixedProfit: 1197165
# Agent: 3 Episode: 134/150 RapTime: 0:03:01.953881 FixedProfit: 1197165
# Agent: 1 Episode: 140/150 RapTime: 0:02:53.232390 FixedProfit: 1290969
# Agent: 2 Episode: 135/150 RapTime: 0:03:08.002555 FixedProfit: 1197165
# Agent: 3 Episode: 135/150 RapTime: 0:02:56.960714 FixedProfit: 1197165
# Agent: 1 Episode: 141/150 RapTime: 0:02:51.321300 FixedProfit: 1177716
# Agent: 2 Episode: 136/150 RapTime: 0:02:58.755900 FixedProfit: 1197165
# Agent: 3 Episode: 136/150 RapTime: 0:03:05.168495 FixedProfit: 1197165
# Agent: 1 Episode: 142/150 RapTime: 0:02:53.348701 FixedProfit: 1178733
# Agent: 2 Episode: 137/150 RapTime: 0:03:03.357654 FixedProfit: 1197165
# Agent: 3 Episode: 137/150 RapTime: 0:03:02.821396 FixedProfit: 1197165
# Agent: 1 Episode: 143/150 RapTime: 0:02:52.739593 FixedProfit: 1223250
# Agent: 2 Episode: 138/150 RapTime: 0:03:03.374274 FixedProfit: 1197165
# Agent: 3 Episode: 138/150 RapTime: 0:03:03.204568 FixedProfit: 1197165
# Agent: 1 Episode: 144/150 RapTime: 0:02:54.525087 FixedProfit: 1189527
# Agent: 2 Episode: 139/150 RapTime: 0:03:01.237796 FixedProfit: 1197165
# Agent: 3 Episode: 139/150 RapTime: 0:03:01.076142 FixedProfit: 1197165
# Agent: 1 Episode: 145/150 RapTime: 0:02:58.901658 FixedProfit: 1189384
# Agent: 2 Episode: 140/150 RapTime: 0:03:03.561138 FixedProfit: 1197165
# Agent: 3 Episode: 140/150 RapTime: 0:03:01.320323 FixedProfit: 1197165
# Agent: 1 Episode: 146/150 RapTime: 0:02:58.833229 FixedProfit: 1172685
# Agent: 2 Episode: 141/150 RapTime: 0:03:00.323297 FixedProfit: 1197165
# Agent: 3 Episode: 141/150 RapTime: 0:03:01.572784 FixedProfit: 1197165
# Agent: 1 Episode: 147/150 RapTime: 0:02:57.031486 FixedProfit: 1159567
# Agent: 2 Episode: 142/150 RapTime: 0:03:00.676746 FixedProfit: 1197165
# Agent: 3 Episode: 142/150 RapTime: 0:03:01.860515 FixedProfit: 1197165
# Agent: 1 Episode: 148/150 RapTime: 0:02:58.661194 FixedProfit: 1220788
# Agent: 2 Episode: 143/150 RapTime: 0:03:02.119753 FixedProfit: 1197165
# Agent: 3 Episode: 143/150 RapTime: 0:03:04.512570 FixedProfit: 1197165
# Agent: 1 Episode: 149/150 RapTime: 0:02:51.846988 FixedProfit: 1186559
# Agent: 2 Episode: 144/150 RapTime: 0:03:00.586463 FixedProfit: 1197165
# Agent: 3 Episode: 144/150 RapTime: 0:03:05.182471 FixedProfit: 1197165
# Agent: 1 Episode: 150/150 RapTime: 0:02:55.860204 FixedProfit: 1231281
# None
# Agent: 2 Episode: 145/150 RapTime: 0:02:29.582245 FixedProfit: 1197165
# Agent: 3 Episode: 145/150 RapTime: 0:02:22.290589 FixedProfit: 1197165
# Agent: 2 Episode: 146/150 RapTime: 0:01:50.633498 FixedProfit: 1197165
# Agent: 3 Episode: 146/150 RapTime: 0:01:49.447859 FixedProfit: 1197165
# Agent: 2 Episode: 147/150 RapTime: 0:01:50.564387 FixedProfit: 1197165
# Agent: 3 Episode: 147/150 RapTime: 0:01:52.014706 FixedProfit: 1197165
# Agent: 2 Episode: 148/150 RapTime: 0:01:50.786115 FixedProfit: 1197165
# Agent: 3 Episode: 148/150 RapTime: 0:01:50.729470 FixedProfit: 1197165
# Agent: 2 Episode: 149/150 RapTime: 0:01:50.241589 FixedProfit: 1197165
# Agent: 3 Episode: 149/150 RapTime: 0:01:49.829770 FixedProfit: 1197165
# Agent: 2 Episode: 150/150 RapTime: 0:01:50.535623 FixedProfit: 1197165
# None
# Agent: 3 Episode: 150/150 RapTime: 0:01:47.890781 FixedProfit: 1197165
# None
# None
