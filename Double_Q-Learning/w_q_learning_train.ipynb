# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/w_q_learning_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
import pickle

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, ReLU
from tensorflow.keras.optimizers import RMSprop
from sklearn.preprocessing import StandardScaler

optimizer = RMSprop()

mode = 'train'
name = 'w_qlearning'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'

exp_dir = 'Colab Notebooks/workspace/export/'
mdl_dir = '/content/drive/My Drive/' + exp_dir + 'models'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.end_step        = self.df_total_steps
        self.now_step        = 0
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
class Brain:
    def __init__(self):

        self.gamma = 0.9
        n_mid, n_state, n_action = 3, 3, 3

        model = Sequential()
        model.add(Dense(n_mid, input_shape=(n_state,)))
        model.add(ReLU()) 
        model.add(Dense(n_mid))
        model.add(ReLU())
        model.add(Dense(n_action))
        model.compile(loss="mse", optimizer=optimizer)

        model.summary()
        self.model = model
    
        model_2 = Sequential()
        model_2.add(Dense(n_mid, input_shape=(n_state,)))
        model_2.add(ReLU()) 
        model_2.add(Dense(n_mid))
        model_2.add(ReLU()) 
        model_2.add(Dense(n_action))
        model_2.compile(loss="mse", optimizer=optimizer)

        model_2.summary()
        self.model_2 = model_2

    def train(self, state, action, reward, next_state, done, s_flag):

        next_act_values = self._predict(next_state,s_flag)
        next_action =np.argmax(next_act_values)

        if s_flag == 11:
            q = self.model.predict(state)  
            next_q = self.model_2.predict(next_state)
            target = np.copy(q)

            target[:, action] = reward + (1 - done) * self.gamma*np.max(next_q, axis=1)
            self.model.train_on_batch(state, target)
        else:
            q = self.model_2.predict(state)  
            next_q = self.model.predict(next_state)
            target = np.copy(q)

            target[:, action] = reward + (1 - done) * self.gamma*np.max(next_q, axis=1)
            self.model_2.train_on_batch(state, target)


    def _predict(self, state, s_flag = 12):
        values = None
        q1 = self.model.predict(state)
        q2 = self.model_2.predict(state)
        if s_flag == 12:
            values = np.array([q1[0,a] + q2[0,a] for a in range(3)])
        elif s_flag == 11:
            values = np.array([q1[0,a] + q1[0,a] for a in range(3)])
        else:
            values = np.array([q2[0,a] + q2[0,a] for a in range(3)])
        return values

    def load(self, name, name2):
        self.model.load_weights(name)
        self.model_2.load_weights(name2)

    def save(self, name, name2):
        self.model.save_weights(name)
        self.model_2.save_weights(name2)

# %%
class Agent(Brain):
    def __init__(self):

        super().__init__()
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.r = 0.995

    def act(self, state,s_flag=12):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(3)
        act_values = self._predict(state,s_flag)
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.r
        return np.argmax(act_values)

# %%
class Main:
    def __init__(self, env, agent, mdl_dir, name, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.agent = agent
        self.mdl_dir = mdl_dir
        self.scaler = self._standard_scaler(self.env)
        self.episodes_times = episodes_times
        self.mode = mode
        self.name = name

        if self.mode == 'test':
            self._load()
            self.agent.epsilon = 0.01
            self.df_rec = pd.DataFrame(index=[], columns=['FixedProfit','TradeTimes','TradeWin'])
        else:
            self.df_rec = pd.DataFrame(index=[], columns=['FixedProfit'])

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            state = self.scaler.transform([state])
            done = False
            start_time = datetime.now()
        
            while not done:
                s_flag = 12
                action = self.agent.act(state)
                next_state, reward, done, info = self.env.step(action)
                next_state = self.scaler.transform([next_state])

                if self.mode == 'train':
                    rand = np.random.random()
                    if rand <= 0.5:
                        s_flag = 11
                    else:
                        s_flag = 22
                    agent.train(state, action, reward, next_state, done, s_flag)
                    
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                record = pd.Series([info['cur_revenue'],info['trade_time'],info['trade_win']], index=self.df_rec.columns)
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f} TradeTimes: {} TradeWin: {}".format(episode + 1, self.episodes_times, play_time, info['cur_revenue'], info['trade_time'], info['trade_win']))
            else:
                record = pd.Series(info['cur_revenue'], index=self.df_rec.columns)
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f}".format(episode + 1, self.episodes_times, play_time, info['cur_revenue']))

            state = next_state
            self.df_rec = self.df_rec.append(record, ignore_index=True)

        if self.mode == 'train':
            self._save()
        self._save_csv()

    def _standard_scaler(self, env):
        states = []
        for _ in range(env.df_total_steps):
            action = np.random.choice(env.action_space)
            state, reward, done, info = env.step(action)
            states.append(state)
            if done:
                break
        
        scaler = StandardScaler()
        scaler.fit(states)
        return scaler

    def _load(self):
        with open('{}/{}.pkl'.format(self.mdl_dir, self.name), 'rb') as f:
            self.scaler = pickle.load(f)
        self.agent.load('{}/{}.h5'.format(self.mdl_dir, self.name), '{}/{}_2.h5'.format(self.mdl_dir, self.name))


    def _save(self):
        self.agent.save('{}/{}.h5'.format(self.mdl_dir, self.name), '{}/{}_2.h5'.format(self.mdl_dir, self.name))
        with open('{}/{}.pkl'.format(self.mdl_dir, self.name), 'wb') as f:
            pickle.dump(self.scaler, f)

    def _save_csv(self):
        self.df_rec.to_csv(csv_path)

# %%
initial_money=1000000
episodes_times = 200

agent = Agent()
env = Environment(df, initial_money, mode)
main = Main(env, agent, mdl_dir, name, episodes_times, mode)
main.play_game()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 3)                 12
# _________________________________________________________________
# re_lu (ReLU)                 (None, 3)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 12
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 3)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 3)                 12
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 3)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 12
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 3)                 0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 12
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________
# Episode: 1/200 RapTime: 0:01:48.450254 FixedProfit: 1354131
# Episode: 2/200 RapTime: 0:01:47.951649 FixedProfit: 1011327
# Episode: 3/200 RapTime: 0:01:46.808860 FixedProfit: 1015886
# Episode: 4/200 RapTime: 0:01:47.089965 FixedProfit: 1219501
# Episode: 5/200 RapTime: 0:01:47.104553 FixedProfit: 1007784
# Episode: 6/200 RapTime: 0:01:47.731781 FixedProfit: 1038727
# Episode: 7/200 RapTime: 0:01:48.114090 FixedProfit: 972667
# Episode: 8/200 RapTime: 0:01:47.881378 FixedProfit: 1069326
# Episode: 9/200 RapTime: 0:01:47.473241 FixedProfit: 1345971
# Episode: 10/200 RapTime: 0:01:47.247059 FixedProfit: 1042736
# Episode: 11/200 RapTime: 0:01:48.098540 FixedProfit: 1156240
# Episode: 12/200 RapTime: 0:01:48.722475 FixedProfit: 1073598
# Episode: 13/200 RapTime: 0:01:47.891384 FixedProfit: 1137828
# Episode: 14/200 RapTime: 0:01:47.592675 FixedProfit: 1060325
# Episode: 15/200 RapTime: 0:01:48.905050 FixedProfit: 984209
# Episode: 16/200 RapTime: 0:01:49.063953 FixedProfit: 1192036
# Episode: 17/200 RapTime: 0:01:48.686646 FixedProfit: 1153073
# Episode: 18/200 RapTime: 0:01:48.835507 FixedProfit: 1137013
# Episode: 19/200 RapTime: 0:01:48.125726 FixedProfit: 1099068
# Episode: 20/200 RapTime: 0:01:48.750613 FixedProfit: 1160090
# Episode: 21/200 RapTime: 0:01:48.026861 FixedProfit: 1132827
# Episode: 22/200 RapTime: 0:01:47.775843 FixedProfit: 984146
# Episode: 23/200 RapTime: 0:01:47.869191 FixedProfit: 1052291
# Episode: 24/200 RapTime: 0:01:48.025278 FixedProfit: 867847
# Episode: 25/200 RapTime: 0:01:48.011151 FixedProfit: 1009482
# Episode: 26/200 RapTime: 0:01:49.110630 FixedProfit: 1027421
# Episode: 27/200 RapTime: 0:01:49.847604 FixedProfit: 981990
# Episode: 28/200 RapTime: 0:01:50.021914 FixedProfit: 1118681
# Episode: 29/200 RapTime: 0:01:49.747539 FixedProfit: 1019940
# Episode: 30/200 RapTime: 0:01:50.238636 FixedProfit: 1338204
# Episode: 31/200 RapTime: 0:01:50.444547 FixedProfit: 962321
# Episode: 32/200 RapTime: 0:01:50.979497 FixedProfit: 1217402
# Episode: 33/200 RapTime: 0:01:51.126718 FixedProfit: 1117460
# Episode: 34/200 RapTime: 0:01:50.700001 FixedProfit: 983268
# Episode: 35/200 RapTime: 0:01:50.647714 FixedProfit: 1303368
# Episode: 36/200 RapTime: 0:01:50.586744 FixedProfit: 1179678
# Episode: 37/200 RapTime: 0:01:50.687922 FixedProfit: 1230598
# Episode: 38/200 RapTime: 0:01:50.831994 FixedProfit: 1041957
# Episode: 39/200 RapTime: 0:01:50.624643 FixedProfit: 1137453
# Episode: 40/200 RapTime: 0:01:50.380462 FixedProfit: 957751
# Episode: 41/200 RapTime: 0:01:50.208418 FixedProfit: 1019158
# Episode: 42/200 RapTime: 0:01:50.615811 FixedProfit: 1256313
# Episode: 43/200 RapTime: 0:01:51.164079 FixedProfit: 1284547
# Episode: 44/200 RapTime: 0:01:51.090900 FixedProfit: 1003176
# Episode: 45/200 RapTime: 0:01:51.226933 FixedProfit: 1177586
# Episode: 46/200 RapTime: 0:01:51.136278 FixedProfit: 1033241
# Episode: 47/200 RapTime: 0:01:51.414579 FixedProfit: 1262000
# Episode: 48/200 RapTime: 0:01:51.241235 FixedProfit: 953874
# Episode: 49/200 RapTime: 0:01:51.064810 FixedProfit: 1155827
# Episode: 50/200 RapTime: 0:01:51.088877 FixedProfit: 1247689
# Episode: 51/200 RapTime: 0:01:50.714981 FixedProfit: 938738
# Episode: 52/200 RapTime: 0:01:50.986866 FixedProfit: 1237125
# Episode: 53/200 RapTime: 0:01:49.483088 FixedProfit: 1028239
# Episode: 54/200 RapTime: 0:01:49.340317 FixedProfit: 1101242
# Episode: 55/200 RapTime: 0:01:48.446585 FixedProfit: 1273009
# Episode: 56/200 RapTime: 0:01:48.878736 FixedProfit: 1010935
# Episode: 57/200 RapTime: 0:01:48.209536 FixedProfit: 1263273
# Episode: 58/200 RapTime: 0:01:48.208427 FixedProfit: 1241728
# Episode: 59/200 RapTime: 0:01:48.550397 FixedProfit: 1270146
# Episode: 60/200 RapTime: 0:01:47.904507 FixedProfit: 1128409
# Episode: 61/200 RapTime: 0:01:48.344294 FixedProfit: 1072000
# Episode: 62/200 RapTime: 0:01:47.450929 FixedProfit: 1079401
# Episode: 63/200 RapTime: 0:01:47.452412 FixedProfit: 1211351
# Episode: 64/200 RapTime: 0:01:48.116246 FixedProfit: 1141146
# Episode: 65/200 RapTime: 0:01:48.037377 FixedProfit: 1056151
# Episode: 66/200 RapTime: 0:01:48.106340 FixedProfit: 1404611
# Episode: 67/200 RapTime: 0:01:47.826669 FixedProfit: 1141788
# Episode: 68/200 RapTime: 0:01:47.316368 FixedProfit: 1040915
# Episode: 69/200 RapTime: 0:01:47.251718 FixedProfit: 1208423
# Episode: 70/200 RapTime: 0:01:48.629992 FixedProfit: 915251
# Episode: 71/200 RapTime: 0:01:49.157192 FixedProfit: 1157794
# Episode: 72/200 RapTime: 0:01:48.635710 FixedProfit: 1072194
# Episode: 73/200 RapTime: 0:01:48.239996 FixedProfit: 1123336
# Episode: 74/200 RapTime: 0:01:48.346712 FixedProfit: 1121957
# Episode: 75/200 RapTime: 0:01:48.640636 FixedProfit: 1120418
# Episode: 76/200 RapTime: 0:01:49.020878 FixedProfit: 1265267
# Episode: 77/200 RapTime: 0:01:48.791844 FixedProfit: 992957
# Episode: 78/200 RapTime: 0:01:48.564369 FixedProfit: 1081166
# Episode: 79/200 RapTime: 0:01:47.922526 FixedProfit: 1154281
# Episode: 80/200 RapTime: 0:01:47.621855 FixedProfit: 1076111
# Episode: 81/200 RapTime: 0:01:48.190724 FixedProfit: 1058365
# Episode: 82/200 RapTime: 0:01:48.190978 FixedProfit: 1227643
# Episode: 83/200 RapTime: 0:01:48.153165 FixedProfit: 1129588
# Episode: 84/200 RapTime: 0:01:48.650317 FixedProfit: 1076629
# Episode: 85/200 RapTime: 0:01:48.694124 FixedProfit: 1061162
# Episode: 86/200 RapTime: 0:01:48.110003 FixedProfit: 1167697
# Episode: 87/200 RapTime: 0:01:48.015038 FixedProfit: 1156046
# Episode: 88/200 RapTime: 0:01:48.467147 FixedProfit: 1198676
# Episode: 89/200 RapTime: 0:01:48.245395 FixedProfit: 916395
# Episode: 90/200 RapTime: 0:01:48.643628 FixedProfit: 1032807
# Episode: 91/200 RapTime: 0:01:48.680990 FixedProfit: 1065774
# Episode: 92/200 RapTime: 0:01:48.638694 FixedProfit: 1080770
# Episode: 93/200 RapTime: 0:01:48.458155 FixedProfit: 1110891
# Episode: 94/200 RapTime: 0:01:48.087943 FixedProfit: 1125644
# Episode: 95/200 RapTime: 0:01:48.286387 FixedProfit: 1125520
# Episode: 96/200 RapTime: 0:01:48.648699 FixedProfit: 1113527
# Episode: 97/200 RapTime: 0:01:48.320055 FixedProfit: 1015541
# Episode: 98/200 RapTime: 0:01:49.054099 FixedProfit: 1109984
# Episode: 99/200 RapTime: 0:01:48.620350 FixedProfit: 1083632
# Episode: 100/200 RapTime: 0:01:47.976884 FixedProfit: 1269729
# Episode: 101/200 RapTime: 0:01:48.650607 FixedProfit: 1276634
# Episode: 102/200 RapTime: 0:01:47.608005 FixedProfit: 1203158
# Episode: 103/200 RapTime: 0:01:47.917983 FixedProfit: 1062150
# Episode: 104/200 RapTime: 0:01:48.147106 FixedProfit: 1135942
# Episode: 105/200 RapTime: 0:01:47.182850 FixedProfit: 1192942
# Episode: 106/200 RapTime: 0:01:46.898046 FixedProfit: 1198953
# Episode: 107/200 RapTime: 0:01:46.342127 FixedProfit: 1079321
# Episode: 108/200 RapTime: 0:01:45.338301 FixedProfit: 1156052
# Episode: 109/200 RapTime: 0:01:44.422470 FixedProfit: 1335715
# Episode: 110/200 RapTime: 0:01:45.701615 FixedProfit: 1135688
# Episode: 111/200 RapTime: 0:01:45.903017 FixedProfit: 1130892
# Episode: 112/200 RapTime: 0:01:48.502424 FixedProfit: 1245720
# Episode: 113/200 RapTime: 0:01:47.862060 FixedProfit: 1282569
# Episode: 114/200 RapTime: 0:01:47.882678 FixedProfit: 1113974
# Episode: 115/200 RapTime: 0:01:48.327317 FixedProfit: 1176989
# Episode: 116/200 RapTime: 0:01:48.524544 FixedProfit: 1117906
# Episode: 117/200 RapTime: 0:01:48.041017 FixedProfit: 1255676
# Episode: 118/200 RapTime: 0:01:48.422242 FixedProfit: 974815
# Episode: 119/200 RapTime: 0:01:48.374114 FixedProfit: 1115667
# Episode: 120/200 RapTime: 0:01:48.022956 FixedProfit: 904836
# Episode: 121/200 RapTime: 0:01:48.903699 FixedProfit: 1085289
# Episode: 122/200 RapTime: 0:01:48.440270 FixedProfit: 1011680
# Episode: 123/200 RapTime: 0:01:48.061345 FixedProfit: 1272672
# Episode: 124/200 RapTime: 0:01:48.461276 FixedProfit: 1348161
# Episode: 125/200 RapTime: 0:01:48.309127 FixedProfit: 1039991
# Episode: 126/200 RapTime: 0:01:48.436912 FixedProfit: 1122070
# Episode: 127/200 RapTime: 0:01:48.537413 FixedProfit: 1127819
# Episode: 128/200 RapTime: 0:01:47.371886 FixedProfit: 956164
# Episode: 129/200 RapTime: 0:01:47.727763 FixedProfit: 1192589
# Episode: 130/200 RapTime: 0:01:46.827334 FixedProfit: 1277316
# Episode: 131/200 RapTime: 0:01:47.123187 FixedProfit: 999964
# Episode: 132/200 RapTime: 0:01:46.312223 FixedProfit: 1082748
# Episode: 133/200 RapTime: 0:01:47.018015 FixedProfit: 1066279
# Episode: 134/200 RapTime: 0:01:48.395377 FixedProfit: 952860
# Episode: 135/200 RapTime: 0:01:49.107888 FixedProfit: 934733
# Episode: 136/200 RapTime: 0:01:49.923073 FixedProfit: 1120236
# Episode: 137/200 RapTime: 0:01:50.201752 FixedProfit: 898820
# Episode: 138/200 RapTime: 0:01:50.696671 FixedProfit: 1073730
# Episode: 139/200 RapTime: 0:01:50.483085 FixedProfit: 1025562
# Episode: 140/200 RapTime: 0:01:50.490766 FixedProfit: 1095226
# Episode: 141/200 RapTime: 0:01:50.342106 FixedProfit: 995652
# Episode: 142/200 RapTime: 0:01:50.960994 FixedProfit: 1049408
# Episode: 143/200 RapTime: 0:01:50.862503 FixedProfit: 1084137
# Episode: 144/200 RapTime: 0:01:50.644361 FixedProfit: 1056100
# Episode: 145/200 RapTime: 0:01:50.209575 FixedProfit: 1178557
# Episode: 146/200 RapTime: 0:01:50.305434 FixedProfit: 1309744
# Episode: 147/200 RapTime: 0:01:49.816664 FixedProfit: 1053680
# Episode: 148/200 RapTime: 0:01:49.119015 FixedProfit: 1137300
# Episode: 149/200 RapTime: 0:01:48.887978 FixedProfit: 1244856
# Episode: 150/200 RapTime: 0:01:48.725001 FixedProfit: 1000387
# Episode: 151/200 RapTime: 0:01:48.380912 FixedProfit: 1299091
# Episode: 152/200 RapTime: 0:01:48.693017 FixedProfit: 1292149
# Episode: 153/200 RapTime: 0:01:49.148160 FixedProfit: 1298664
# Episode: 154/200 RapTime: 0:01:48.353915 FixedProfit: 1158473
# Episode: 155/200 RapTime: 0:01:48.061941 FixedProfit: 1084441
# Episode: 156/200 RapTime: 0:01:48.566288 FixedProfit: 1039659
# Episode: 157/200 RapTime: 0:01:48.913337 FixedProfit: 1003445
# Episode: 158/200 RapTime: 0:01:47.964417 FixedProfit: 1066300
# Episode: 159/200 RapTime: 0:01:48.475105 FixedProfit: 1195484
# Episode: 160/200 RapTime: 0:01:47.788805 FixedProfit: 1085524
# Episode: 161/200 RapTime: 0:01:48.181179 FixedProfit: 916770
# Episode: 162/200 RapTime: 0:01:47.824902 FixedProfit: 1242393
# Episode: 163/200 RapTime: 0:01:48.062534 FixedProfit: 1071166
# Episode: 164/200 RapTime: 0:01:48.503676 FixedProfit: 1403311
# Episode: 165/200 RapTime: 0:01:48.142215 FixedProfit: 1161923
# Episode: 166/200 RapTime: 0:01:48.326905 FixedProfit: 1035272
# Episode: 167/200 RapTime: 0:01:48.152313 FixedProfit: 1104945
# Episode: 168/200 RapTime: 0:01:48.036140 FixedProfit: 1106187
# Episode: 169/200 RapTime: 0:01:48.726299 FixedProfit: 1209269
# Episode: 170/200 RapTime: 0:01:48.566412 FixedProfit: 1054510
# Episode: 171/200 RapTime: 0:01:47.722387 FixedProfit: 1310696
# Episode: 172/200 RapTime: 0:01:47.365283 FixedProfit: 1167020
# Episode: 173/200 RapTime: 0:01:48.138081 FixedProfit: 1180704
# Episode: 174/200 RapTime: 0:01:47.694469 FixedProfit: 1364280
# Episode: 175/200 RapTime: 0:01:47.808683 FixedProfit: 1236288
# Episode: 176/200 RapTime: 0:01:47.490573 FixedProfit: 1025748
# Episode: 177/200 RapTime: 0:01:47.915689 FixedProfit: 1303341
# Episode: 178/200 RapTime: 0:01:48.009416 FixedProfit: 1051506
# Episode: 179/200 RapTime: 0:01:47.911399 FixedProfit: 1003490
# Episode: 180/200 RapTime: 0:01:48.067995 FixedProfit: 1093773
# Episode: 181/200 RapTime: 0:01:47.984274 FixedProfit: 1377983
# Episode: 182/200 RapTime: 0:01:48.553392 FixedProfit: 1112545
# Episode: 183/200 RapTime: 0:01:48.374183 FixedProfit: 1225478
# Episode: 184/200 RapTime: 0:01:48.554705 FixedProfit: 913948
# Episode: 185/200 RapTime: 0:01:48.019567 FixedProfit: 1104189
# Episode: 186/200 RapTime: 0:01:48.319990 FixedProfit: 916880
# Episode: 187/200 RapTime: 0:01:48.160526 FixedProfit: 984804
# Episode: 188/200 RapTime: 0:01:47.599590 FixedProfit: 1017053
# Episode: 189/200 RapTime: 0:01:47.664301 FixedProfit: 1214297
# Episode: 190/200 RapTime: 0:01:48.681572 FixedProfit: 1014440
# Episode: 191/200 RapTime: 0:01:49.026358 FixedProfit: 1023086
# Episode: 192/200 RapTime: 0:01:48.516894 FixedProfit: 1080922
# Episode: 193/200 RapTime: 0:01:47.582893 FixedProfit: 1041461
# Episode: 194/200 RapTime: 0:01:47.246363 FixedProfit: 994885
# Episode: 195/200 RapTime: 0:01:49.100869 FixedProfit: 1143059
# Episode: 196/200 RapTime: 0:01:48.791904 FixedProfit: 1086249
# Episode: 197/200 RapTime: 0:01:48.076008 FixedProfit: 986686
# Episode: 198/200 RapTime: 0:01:48.187336 FixedProfit: 890832
# Episode: 199/200 RapTime: 0:01:48.230721 FixedProfit: 947951
# Episode: 200/200 RapTime: 0:01:48.134228 FixedProfit: 1210231
