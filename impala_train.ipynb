# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/impala_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time
from datetime import datetime
import random
import copy
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPool1D, Activation, concatenate
from tensorflow.keras import Input
from tensorflow.keras.models import clone_model

from sklearn.preprocessing import StandardScaler
import math

from google.colab import drive

from concurrent.futures import ThreadPoolExecutor

from dataclasses import dataclass, field
from typing import List

mode = 'train'
name = 'impala'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'

exp_dir = 'Colab Notebooks/workspace/export/'
mdl_dir = '/content/drive/My Drive/' + exp_dir + 'models'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.end_step        = self.df_total_steps
        self.now_step        = 0
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
class Critic:
    def __init__(self, model):
        self.model = model
        self.n_action = 3
        self.gamma = 0.99
        self.alfa = 0.5
        self.beta = 0.00025

    def valuenetwork(self, state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu):

        with tf.GradientTape() as tape:

            actions = tf.one_hot(action, self.n_action) # (10, 3)

            state = state.reshape(1,10,3)
            prev_action = prev_action.reshape(1,10,1)
            prev_reward = prev_reward.reshape(1,10,1)

            pai, v_theta  = self.model([state, prev_action, prev_reward])

            pai = tf.reshape(pai, [10,3]) # (10, 3)

            actions = tf.cast(actions, tf.float32)

            pais = tf.reduce_sum(actions * pai, axis=1, keepdims=True)

            mu = self._reshape_and_cast(mu, 3)
            ratio = tf.math.divide_no_nan(pais, mu)
            rhoi = ci = tf.minimum(1.0, ratio)

            n_num, _ = ratio.shape

            rhoi = self._reshape_and_cast(rhoi,3)
            ci = self._reshape_and_cast(ci,3)
            reward = self._reshape_and_cast(reward,1)
            v_next = self._reshape_and_cast(v_next,1)
            v = self._reshape_and_cast(v,1)
            v_theta = self._reshape_and_cast(v_theta,1)

            b4_delta_v = (reward + self.gamma * v_next - v)
            b4_delta_v  =  tf.cast(b4_delta_v, tf.float32)
            delta_v = tf.multiply(rhoi, b4_delta_v)
            delta_v = self._reshape_and_cast(delta_v,3)
            v_trace =v + self._sigma(ci, delta_v, n_num)
            total_loss = self._compute_baseline_loss(v_trace - v_theta)
            total_loss += self._compute_policy_gradient_loss(pai, actions, delta_v)
            total_loss += self._compute_entropy_loss(pai)

        gradients = tape.gradient(total_loss, self.model.trainable_variables)
        self.model.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))

    def _reshape_and_cast(self, x, num):
        x = tf.reshape(x, [10,num])
        x  =  tf.cast(x, tf.float32)
        return x

    def _infinite_product(self, x, max_num):
        num = tf.ones([3, ], tf.float32)
        for i in range(max_num):
            num *= x[i]   
        return num

    def _sigma(self, x, delta_v, b):
        
        num = 0.0
        for i in range(b):
            num += pow(self.gamma, i) * self._infinite_product(x, i) * delta_v[i]
        return tf.cast(num, tf.float32)

    def _compute_baseline_loss(self, advantages):
        return .5 * tf.reduce_sum(tf.square(advantages))

    def _compute_policy_gradient_loss(self, logits, actions, advantages):
        cross_entropy = tf.losses.categorical_crossentropy(y_true=actions, y_pred=logits)
        cross_entropy = tf.reshape(cross_entropy, [10,1])
        advantages = tf.stop_gradient(advantages)
        policy_gradient_loss_per_timestep = cross_entropy * advantages
        return tf.reduce_sum(policy_gradient_loss_per_timestep)

    def _compute_entropy_loss(self, logits):
        log_policy = tf.math.log(logits)
        entropy_per_timestep = tf.reduce_sum(-logits * log_policy, axis=-1)
        return -tf.reduce_sum(entropy_per_timestep)

# %%
class Learner(Critic):
    def __init__(self):

        conv_filter = 12
        units = 28
        look_back = 10
        opt = Adam(learning_rate=0.001)

        input1_ = Input(shape=(look_back, 3))
        input2_ = Input(shape=(look_back, 1))
        input3_ = Input(shape=(look_back, 1))

        x = Conv1D(filters=conv_filter, kernel_size=1, padding="same", activation="tanh")(input1_)
        x = MaxPool1D(pool_size=1, padding='same')(x)
        x = Activation("relu")(x)
        combined = concatenate([x, input2_, input3_],axis=-1)
        common = LSTM(units, return_sequences=True)(combined)
        common = Dense(units, kernel_initializer='random_uniform')(common)
        common = Activation("relu")(common)

        actor  = Dense(3, activation="softmax")(common)
        critic = Dense(1, activation="linear")(common)

        model = keras.Model([input1_, input2_, input3_], [actor, critic])
        model.compile(loss = "mean_absolute_error", optimizer=opt)
        model.summary()
        #dot_img_file = './f"{name}_model.png"'
        #tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
        self.model = model
        super().__init__(model)

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

    def placement(self, memory):
        length = memory.max_length_memory()
        for i in range(length):
            min = i
            max = (i + 10)
            state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu = memory.get_experiences(min, max)
            self.valuenetwork(state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu)

# %%
class Actor:
    def __init__(self, learner):

        self.learner = learner
        self.model = clone_model(learner.model)
        self.n_action = 3
        self.state_arr = np.array([])
        self.p_action_arr = np.array([])
        self.p_reward_arr = np.array([])

        self.next_state_arr = np.array([])
        self.action_arr = np.array([])
        self.reward_arr = np.array([])

    def reset(self):
        self.state_arr = np.empty((0,3), int)
        self.p_action_arr = np.array([])
        self.p_reward_arr = np.array([])

        self.next_state_arr = np.empty((0,3), int)
        self.action_arr = np.array([])
        self.reward_arr = np.array([])

    def policynetwork(self, state, prev_action, prev_reward):

        if len(self.state_arr) == 10:
            self.state_arr[0:-1] = self.state_arr[1:]
            self.p_action_arr[0:-1] = self.p_action_arr[1:]
            self.p_reward_arr[0:-1] = self.p_reward_arr[1:]
            self.state_arr[-1] = state
            self.p_action_arr[-1] = prev_action
            self.p_reward_arr[-1] = prev_reward
            tmp_state = copy.deepcopy(self.state_arr)
            tmp_action = copy.deepcopy(self.p_action_arr)
            tmp_reward = copy.deepcopy(self.p_reward_arr)
            tmp_state = tmp_state.reshape(1,10,3)
            tmp_action = tmp_action.reshape(1,10,1)
            tmp_reward = tmp_reward.reshape(1,10,1)
            act_p, v = self.model([tmp_state, tmp_action, tmp_reward]) # [-1.03245259 -0.55189404  0.87892511] 1 0
            v_np = v.numpy()
            p_np = act_p.numpy()
            one_hot_actions = tf.one_hot([0,1,2], 3)
            act_p = p_np[0][9]
            mu = tf.reduce_sum(one_hot_actions * act_p, axis=1)
            return np.random.choice(3, p=p_np[0][9]), v_np[0][9][0], mu.numpy()

        self.state_arr = np.append(self.state_arr, np.array([state]), axis=0)
        self.p_action_arr = np.append(self.p_action_arr, np.array([prev_action]))
        self.p_reward_arr = np.append(self.p_reward_arr, np.array([prev_reward]))
        return 1, 1, [0.0, 1.0, 0.0]

    def policynetwork_next(self, next_state, action, reward):

        if len(self.next_state_arr) == 10:
            self.next_state_arr[0:-1] = self.next_state_arr[1:]
            self.action_arr[0:-1] = self.action_arr[1:]
            self.reward_arr[0:-1] = self.reward_arr[1:]
            self.next_state_arr[-1] = next_state
            self.action_arr[-1] = action
            self.reward_arr[-1] = reward

            tmp_n_state = copy.deepcopy(self.next_state_arr)
            tmp_action = copy.deepcopy(self.action_arr)
            tmp_reward = copy.deepcopy(self.reward_arr)
            tmp_n_state = tmp_n_state.reshape(1,10,3)
            tmp_action = tmp_action.reshape(1,10,1)
            tmp_reward = tmp_reward.reshape(1,10,1)

            _, v_next = self.model([tmp_n_state, tmp_action, tmp_reward])
            v_next_np = v_next.numpy()
            return v_next_np[0][9][0]

        self.next_state_arr = np.append(self.next_state_arr, np.array([next_state]), axis=0)
        self.action_arr = np.append(self.action_arr, np.array([action]))
        self.reward_arr = np.append(self.reward_arr, np.array([reward]))
        return 1.0

    def load(self, name):
        self.learner.load(name)

    def save(self, name):
        self.learner.save(name)

    def integration(self):
        self.model = clone_model(self.learner.model)

    def placement(self, memory):
        self.learner.placement(memory)

# %%
@dataclass
class ExperiencesMemory:
    state : np.ndarray = np.empty((0,3), int)
    next_state : np.ndarray = np.empty((0,3), int)
    prev_action : np.ndarray = np.array([])
    action : np.ndarray = np.array([])
    prev_reward : np.ndarray = np.array([])
    reward : np.ndarray = np.array([])
    done : np.ndarray = np.array([])
    v : np.ndarray = np.array([])
    v_next : np.ndarray = np.array([])
    mu : np.ndarray = np.empty((0,3), int)
    minibatch_size : int = 64

    def append_experiences(self, state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu):
        self.state = np.append(self.state, np.array([state]), axis=0)
        self.next_state = np.append(self.next_state, np.array([next_state]), axis=0)
        self.prev_action = np.append(self.prev_action, np.array(prev_action))
        self.action = np.append(self.action, np.array(action))
        self.prev_reward = np.append(self.prev_reward, np.array(prev_reward))
        self.reward = np.append(self.reward, np.array(reward))
        self.done = np.append(self.done, np.array(done))
        self.v = np.append(self.v, np.array(v))
        self.v_next = np.append(self.v_next, np.array(v_next))
        self.mu = np.append(self.mu, np.array([mu]), axis=0)

    def max_length_memory(self):
        max_len = len(self.state)
        max_len = int(max_len) - 11

        return max_len

    def get_experiences(self, min, max):
        state, next_state, mu = np.empty((0,3), int), np.empty((0,3), int), np.empty((0,3), int)
        prev_action, action, prev_reward, reward, done, v, v_next = np.array([]), np.array([]), np.array([]), np.array([]), np.array([]), np.array([]), np.array([])
        for i in range(min, max):
            state = np.append(state, np.array([self.state[i]]), axis=0)
            next_state = np.append(next_state, self.action[i])
            prev_action = np.append(prev_action, self.prev_action[i])
            action = np.append(action, self.action[i])
            prev_reward = np.append(prev_reward, self.prev_reward[i])
            reward = np.append(reward, self.reward[i])
            done = np.append(done, self.done[i])
            v = np.append(v, self.v[i])
            v_next = np.append(v_next, self.v_next[i])
            mu = np.append(mu, np.array([self.mu[i]]), axis=0)

        return state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu

# %%
class Main:
    def __init__(self, env, actor, num, mdl_dir, name, batch_size = 10, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.actor = actor
        self.num = str(num)
        self.mdl_dir = mdl_dir
        self.scaler = self._standard_scaler(self.env)
        self.episodes_times = episodes_times
        self.batch_size = batch_size
        self.mode = mode
        self.name = name

        if self.mode == 'test':
            self._load()
            with open(csv_path, 'w') as f:
                row = 'FixedProfit,TradeTimes,TradeWin'
                print(row, file=f)
        else:
            with open(csv_path, 'w') as f:
                row = 'FixedProfit'
                print(row, file=f)
        
    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            state = self.scaler.transform([state])
            self.actor.reset()
            state = state.flatten()
            done = False
            start_time = datetime.now()
            memory = ExperiencesMemory()
            prev_action = 1
            prev_reward = 0
            i = 0
    
            while not done:
                action, v, mu = self.actor.policynetwork(state, prev_action, prev_reward)
                next_state, reward, done, info = self.env.step(action)
                next_state = self.scaler.transform([next_state])
                next_state = next_state.flatten()
                v_next = self.actor.policynetwork_next(next_state, action, reward)

                if (i > self.batch_size) and (self.mode == 'train'):
                    memory.append_experiences(state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu)

                state = next_state
                prev_action = action
                prev_reward = reward
                i += 1
               
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f} TradeTimes: {} TradeWin: {}".format(episode + 1, episodes_times, play_time, info['cur_revenue'], info['trade_time'], info['trade_win']))
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                    print(row, file=f)
            else:
                self.actor.placement(memory)
                self.actor.integration()
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f}".format(episode + 1, episodes_times, play_time, info['cur_revenue']))
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue'])
                    print(row, file=f)

        if self.mode == 'train':
            self._save()

    def _standard_scaler(self, env):
        states = []
        for _ in range(env.df_total_steps):
            action = np.random.choice(env.action_space)
            state, reward, done, info = env.step(action)
            states.append(state)
            if done:
                break
        
        scaler = StandardScaler()
        scaler.fit(states)
        return scaler

    def _load(self):
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, self.num), 'rb') as f:
            self.scaler = pickle.load(f)
        self.actor.load('{}/{}.h5'.format(self.mdl_dir, self.name))

    def _save(self):
        self.actor.save('{}/{}.h5'.format(self.mdl_dir, self.name))
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, self.num), 'wb') as f:
            pickle.dump(self.scaler, f)

# %%
initial_money=1000000
episodes_times = 150
batch_size = 10
learner = Learner()

thread_num = 4
envs = []
for i in range(thread_num):
    env = Environment(df, initial_money=initial_money, mode = mode)
    actor = Actor(learner)
    main = Main(env, actor, i, mdl_dir, name, batch_size, episodes_times, mode)
    envs.append(main)

datas = []
with ThreadPoolExecutor(max_workers=thread_num) as executor:
    for env in envs:
        job = lambda: env.play_game()
        datas.append(executor.submit(job))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10, 3)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 10, 12)       48          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 10, 12)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 10, 12)       0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 14)       0           activation[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 28)       4816        concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10, 28)       812         lstm[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10, 28)       0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10, 3)        87          activation_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10, 1)        29          activation_1[0][0]
# ==================================================================================================
# Total params: 5,792
# Trainable params: 5,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Episode: 1/150 RapTime: 0:01:15.576795 FixedProfit: 1085388
# Episode: 1/150 RapTime: 0:01:16.117172 FixedProfit: 1098546
# Episode: 1/150 RapTime: 0:01:15.948205 FixedProfit: 1130187
# Episode: 1/150 RapTime: 0:01:15.908861 FixedProfit: 1115125
# Episode: 2/150 RapTime: 0:01:13.279538 FixedProfit: 926356
# Episode: 2/150 RapTime: 0:01:12.234239 FixedProfit: 1164551
# Episode: 2/150 RapTime: 0:01:12.439242 FixedProfit: 1035619
# Episode: 2/150 RapTime: 0:01:12.378281 FixedProfit: 969696
# Episode: 3/150 RapTime: 0:01:13.586836 FixedProfit: 1136862
# Episode: 3/150 RapTime: 0:01:13.513023 FixedProfit: 1020855
# Episode: 3/150 RapTime: 0:01:13.324214 FixedProfit: 971395
# Episode: 3/150 RapTime: 0:01:12.708568 FixedProfit: 1278677
# Episode: 4/150 RapTime: 0:01:12.917599 FixedProfit: 1081220
# Episode: 4/150 RapTime: 0:01:13.569862 FixedProfit: 988396
# Episode: 4/150 RapTime: 0:01:12.136186 FixedProfit: 979595
# Episode: 4/150 RapTime: 0:01:11.895616 FixedProfit: 1172993
# Episode: 5/150 RapTime: 0:01:13.068348 FixedProfit: 1072296
# Episode: 5/150 RapTime: 0:01:13.020040 FixedProfit: 897926
# Episode: 5/150 RapTime: 0:01:12.385299 FixedProfit: 1252524
# Episode: 5/150 RapTime: 0:01:12.103413 FixedProfit: 1096329
# Episode: 6/150 RapTime: 0:01:12.802338 FixedProfit: 1047157
# Episode: 6/150 RapTime: 0:01:13.072902 FixedProfit: 1173161
# Episode: 6/150 RapTime: 0:01:12.859568 FixedProfit: 940638
# Episode: 6/150 RapTime: 0:01:11.806792 FixedProfit: 1088779
# Episode: 7/150 RapTime: 0:01:13.169767 FixedProfit: 1060094
# Episode: 7/150 RapTime: 0:01:13.095862 FixedProfit: 1177520
# Episode: 7/150 RapTime: 0:01:12.056586 FixedProfit: 1169948
# Episode: 7/150 RapTime: 0:01:12.579592 FixedProfit: 1046926
# Episode: 8/150 RapTime: 0:01:12.938056 FixedProfit: 1033526
# Episode: 8/150 RapTime: 0:01:12.945667 FixedProfit: 1245896
# Episode: 8/150 RapTime: 0:01:12.581521 FixedProfit: 931728
# Episode: 8/150 RapTime: 0:01:11.891175 FixedProfit: 1121110
# Episode: 9/150 RapTime: 0:01:11.858613 FixedProfit: 1187625
# Episode: 9/150 RapTime: 0:01:11.986976 FixedProfit: 1060725
# Episode: 9/150 RapTime: 0:01:11.378636 FixedProfit: 1047472
# Episode: 9/150 RapTime: 0:01:11.077405 FixedProfit: 1090298
# Episode: 10/150 RapTime: 0:01:12.183023 FixedProfit: 1299239
# Episode: 10/150 RapTime: 0:01:12.453629 FixedProfit: 1300457
# Episode: 10/150 RapTime: 0:01:11.555377 FixedProfit: 1062868
# Episode: 10/150 RapTime: 0:01:11.231138 FixedProfit: 1041793
# Episode: 11/150 RapTime: 0:01:13.016114 FixedProfit: 995235
# Episode: 11/150 RapTime: 0:01:13.296169 FixedProfit: 1138665
# Episode: 11/150 RapTime: 0:01:12.752288 FixedProfit: 1164326
# Episode: 11/150 RapTime: 0:01:12.398259 FixedProfit: 943850
# Episode: 12/150 RapTime: 0:01:12.148616 FixedProfit: 954873
# Episode: 12/150 RapTime: 0:01:12.291668 FixedProfit: 1265590
# Episode: 12/150 RapTime: 0:01:11.995517 FixedProfit: 1079029
# Episode: 12/150 RapTime: 0:01:11.120483 FixedProfit: 1079474
# Episode: 13/150 RapTime: 0:01:12.398403 FixedProfit: 1087834
# Episode: 13/150 RapTime: 0:01:12.684546 FixedProfit: 1243083
# Episode: 13/150 RapTime: 0:01:12.180969 FixedProfit: 1369260
# Episode: 13/150 RapTime: 0:01:11.374268 FixedProfit: 1050014
# Episode: 14/150 RapTime: 0:01:12.153508 FixedProfit: 1030533
# Episode: 14/150 RapTime: 0:01:11.928894 FixedProfit: 1180223
# Episode: 14/150 RapTime: 0:01:12.453544 FixedProfit: 1136206
# Episode: 14/150 RapTime: 0:01:11.032594 FixedProfit: 1112985
# Episode: 15/150 RapTime: 0:01:12.489157 FixedProfit: 1060495
# Episode: 15/150 RapTime: 0:01:12.597236 FixedProfit: 1111984
# Episode: 15/150 RapTime: 0:01:12.379184 FixedProfit: 973331
# Episode: 15/150 RapTime: 0:01:11.521812 FixedProfit: 1064744
# Episode: 16/150 RapTime: 0:01:12.564116 FixedProfit: 1093462
# Episode: 16/150 RapTime: 0:01:12.640573 FixedProfit: 1248051
# Episode: 16/150 RapTime: 0:01:12.041632 FixedProfit: 1302230
# Episode: 16/150 RapTime: 0:01:11.081177 FixedProfit: 1251574
# Episode: 17/150 RapTime: 0:01:12.334408 FixedProfit: 1092710
# Episode: 17/150 RapTime: 0:01:12.612816 FixedProfit: 1124808
# Episode: 17/150 RapTime: 0:01:12.218883 FixedProfit: 1102874
# Episode: 17/150 RapTime: 0:01:11.309249 FixedProfit: 1034276
# Episode: 18/150 RapTime: 0:01:12.515338 FixedProfit: 1009394
# Episode: 18/150 RapTime: 0:01:12.291734 FixedProfit: 1303922
# Episode: 18/150 RapTime: 0:01:12.218061 FixedProfit: 1028816
# Episode: 18/150 RapTime: 0:01:10.396236 FixedProfit: 1131252
# Episode: 19/150 RapTime: 0:01:11.434357 FixedProfit: 1119782
# Episode: 19/150 RapTime: 0:01:12.049931 FixedProfit: 1008283
# Episode: 19/150 RapTime: 0:01:11.716688 FixedProfit: 1020053
# Episode: 19/150 RapTime: 0:01:10.318218 FixedProfit: 1178933
# Episode: 20/150 RapTime: 0:01:11.413479 FixedProfit: 972807
# Episode: 20/150 RapTime: 0:01:11.838415 FixedProfit: 1214225
# Episode: 20/150 RapTime: 0:01:11.621679 FixedProfit: 912051
# Episode: 20/150 RapTime: 0:01:10.253124 FixedProfit: 1210639
# Episode: 21/150 RapTime: 0:01:10.923175 FixedProfit: 990727
# Episode: 21/150 RapTime: 0:01:11.678449 FixedProfit: 971346
# Episode: 21/150 RapTime: 0:01:11.054459 FixedProfit: 1052290
# Episode: 21/150 RapTime: 0:01:09.694491 FixedProfit: 960269
# Episode: 22/150 RapTime: 0:01:11.311161 FixedProfit: 1347511
# Episode: 22/150 RapTime: 0:01:11.892454 FixedProfit: 1045053
# Episode: 22/150 RapTime: 0:01:11.725690 FixedProfit: 1115879
# Episode: 22/150 RapTime: 0:01:10.397269 FixedProfit: 1197759
# Episode: 23/150 RapTime: 0:01:11.163923 FixedProfit: 1017672
# Episode: 23/150 RapTime: 0:01:11.697680 FixedProfit: 990441
# Episode: 23/150 RapTime: 0:01:11.589289 FixedProfit: 932175
# Episode: 23/150 RapTime: 0:01:10.291532 FixedProfit: 1030000
# Episode: 24/150 RapTime: 0:01:10.885484 FixedProfit: 1046951
# Episode: 24/150 RapTime: 0:01:12.087460 FixedProfit: 1081024
# Episode: 24/150 RapTime: 0:01:11.481852 FixedProfit: 1079521
# Episode: 24/150 RapTime: 0:01:11.092561 FixedProfit: 1003878
# Episode: 25/150 RapTime: 0:01:11.222699 FixedProfit: 1076076
# Episode: 25/150 RapTime: 0:01:11.646604 FixedProfit: 1122481
# Episode: 25/150 RapTime: 0:01:11.640040 FixedProfit: 946017
# Episode: 25/150 RapTime: 0:01:10.583643 FixedProfit: 884941
# Episode: 26/150 RapTime: 0:01:11.481118 FixedProfit: 1044667
# Episode: 26/150 RapTime: 0:01:11.983168 FixedProfit: 960779
# Episode: 26/150 RapTime: 0:01:12.001088 FixedProfit: 965424
# Episode: 26/150 RapTime: 0:01:10.745516 FixedProfit: 944692
# Episode: 27/150 RapTime: 0:01:11.834731 FixedProfit: 1015338
# Episode: 27/150 RapTime: 0:01:12.470401 FixedProfit: 1115854
# Episode: 27/150 RapTime: 0:01:11.821959 FixedProfit: 1227614
# Episode: 27/150 RapTime: 0:01:11.494287 FixedProfit: 1053777
# Episode: 28/150 RapTime: 0:01:11.372538 FixedProfit: 1298226
# Episode: 28/150 RapTime: 0:01:11.909719 FixedProfit: 1177520
# Episode: 28/150 RapTime: 0:01:11.036158 FixedProfit: 985487
# Episode: 28/150 RapTime: 0:01:11.767296 FixedProfit: 1053368
# Episode: 29/150 RapTime: 0:01:11.031727 FixedProfit: 1115338
# Episode: 29/150 RapTime: 0:01:11.931561 FixedProfit: 1250123
# Episode: 29/150 RapTime: 0:01:11.130475 FixedProfit: 941668
# Episode: 29/150 RapTime: 0:01:11.475670 FixedProfit: 1238799
# Episode: 30/150 RapTime: 0:01:10.769791 FixedProfit: 1412139
# Episode: 30/150 RapTime: 0:01:11.888979 FixedProfit: 1160294
# Episode: 30/150 RapTime: 0:01:11.249102 FixedProfit: 1013287
# Episode: 30/150 RapTime: 0:01:10.884648 FixedProfit: 1148049
# Episode: 31/150 RapTime: 0:01:11.571892 FixedProfit: 1147196
# Episode: 31/150 RapTime: 0:01:12.306729 FixedProfit: 1162244
# Episode: 31/150 RapTime: 0:01:11.762953 FixedProfit: 1098905
# Episode: 31/150 RapTime: 0:01:11.582462 FixedProfit: 1030490
# Episode: 32/150 RapTime: 0:01:11.075669 FixedProfit: 903828
# Episode: 32/150 RapTime: 0:01:11.724637 FixedProfit: 1016420
# Episode: 32/150 RapTime: 0:01:11.320965 FixedProfit: 952784
# Episode: 32/150 RapTime: 0:01:10.209519 FixedProfit: 1097807
# Episode: 33/150 RapTime: 0:01:11.124319 FixedProfit: 1094768
# Episode: 33/150 RapTime: 0:01:11.796336 FixedProfit: 1130335
# Episode: 33/150 RapTime: 0:01:11.232480 FixedProfit: 1117987
# Episode: 33/150 RapTime: 0:01:10.198002 FixedProfit: 805774
# Episode: 34/150 RapTime: 0:01:11.577585 FixedProfit: 1295829
# Episode: 34/150 RapTime: 0:01:11.533300 FixedProfit: 1288629
# Episode: 34/150 RapTime: 0:01:11.374838 FixedProfit: 1175104
# Episode: 34/150 RapTime: 0:01:10.109592 FixedProfit: 1074060
# Episode: 35/150 RapTime: 0:01:11.530599 FixedProfit: 1155872
# Episode: 35/150 RapTime: 0:01:11.531739 FixedProfit: 1080868
# Episode: 35/150 RapTime: 0:01:11.362439 FixedProfit: 1023135
# Episode: 35/150 RapTime: 0:01:09.987297 FixedProfit: 1017934
# Episode: 36/150 RapTime: 0:01:11.595854 FixedProfit: 1105183
# Episode: 36/150 RapTime: 0:01:11.640969 FixedProfit: 1181015
# Episode: 36/150 RapTime: 0:01:11.324092 FixedProfit: 1172798
# Episode: 36/150 RapTime: 0:01:10.481980 FixedProfit: 1298734
# Episode: 37/150 RapTime: 0:01:11.581036 FixedProfit: 1108183
# Episode: 37/150 RapTime: 0:01:11.416107 FixedProfit: 1161555
# Episode: 37/150 RapTime: 0:01:10.944892 FixedProfit: 1224756
# Episode: 37/150 RapTime: 0:01:09.942474 FixedProfit: 953895
# Episode: 38/150 RapTime: 0:01:11.659764 FixedProfit: 983212
# Episode: 38/150 RapTime: 0:01:11.461520 FixedProfit: 1106922
# Episode: 38/150 RapTime: 0:01:11.318617 FixedProfit: 1145732
# Episode: 38/150 RapTime: 0:01:09.984716 FixedProfit: 988325
# Episode: 39/150 RapTime: 0:01:11.621007 FixedProfit: 1115954
# Episode: 39/150 RapTime: 0:01:11.760812 FixedProfit: 1240255
# Episode: 39/150 RapTime: 0:01:11.232309 FixedProfit: 1207921
# Episode: 39/150 RapTime: 0:01:10.271993 FixedProfit: 1339141
# Episode: 40/150 RapTime: 0:01:11.080579 FixedProfit: 1027642
# Episode: 40/150 RapTime: 0:01:10.836890 FixedProfit: 1007600
# Episode: 40/150 RapTime: 0:01:10.378144 FixedProfit: 1283989
# Episode: 40/150 RapTime: 0:01:09.164589 FixedProfit: 1021990
# Episode: 41/150 RapTime: 0:01:11.043076 FixedProfit: 1480336
# Episode: 41/150 RapTime: 0:01:11.410251 FixedProfit: 1234125
# Episode: 41/150 RapTime: 0:01:10.630971 FixedProfit: 1331016
# Episode: 41/150 RapTime: 0:01:09.765702 FixedProfit: 1066237
# Episode: 42/150 RapTime: 0:01:10.740356 FixedProfit: 903420
# Episode: 42/150 RapTime: 0:01:10.921700 FixedProfit: 1042838
# Episode: 42/150 RapTime: 0:01:10.690660 FixedProfit: 1063273
# Episode: 42/150 RapTime: 0:01:09.409614 FixedProfit: 1193990
# Episode: 43/150 RapTime: 0:01:10.881489 FixedProfit: 1051643
# Episode: 43/150 RapTime: 0:01:11.626778 FixedProfit: 1073311
# Episode: 43/150 RapTime: 0:01:11.280850 FixedProfit: 1028438
# Episode: 43/150 RapTime: 0:01:09.768601 FixedProfit: 1092288
# Episode: 44/150 RapTime: 0:01:10.910673 FixedProfit: 1132521
# Episode: 44/150 RapTime: 0:01:10.913992 FixedProfit: 986024
# Episode: 44/150 RapTime: 0:01:10.498639 FixedProfit: 1151179
# Episode: 44/150 RapTime: 0:01:09.563202 FixedProfit: 1033257
# Episode: 45/150 RapTime: 0:01:10.508970 FixedProfit: 1011462
# Episode: 45/150 RapTime: 0:01:10.700755 FixedProfit: 1344214
# Episode: 45/150 RapTime: 0:01:10.354513 FixedProfit: 988942
# Episode: 45/150 RapTime: 0:01:09.076529 FixedProfit: 1179002
# Episode: 46/150 RapTime: 0:01:11.290771 FixedProfit: 1050660
# Episode: 46/150 RapTime: 0:01:11.602075 FixedProfit: 1299661
# Episode: 46/150 RapTime: 0:01:11.444779 FixedProfit: 1273026
# Episode: 46/150 RapTime: 0:01:10.524289 FixedProfit: 1090482
# Episode: 47/150 RapTime: 0:01:11.475461 FixedProfit: 1138433
# Episode: 47/150 RapTime: 0:01:11.643925 FixedProfit: 1102423
# Episode: 47/150 RapTime: 0:01:11.044183 FixedProfit: 1228585
# Episode: 47/150 RapTime: 0:01:09.960199 FixedProfit: 1165247
# Episode: 48/150 RapTime: 0:01:10.796637 FixedProfit: 1194116
# Episode: 48/150 RapTime: 0:01:11.108535 FixedProfit: 1090723
# Episode: 48/150 RapTime: 0:01:10.699385 FixedProfit: 1098989
# Episode: 48/150 RapTime: 0:01:09.588422 FixedProfit: 1163839
# Episode: 49/150 RapTime: 0:01:10.143732 FixedProfit: 1073925
# Episode: 49/150 RapTime: 0:01:10.671955 FixedProfit: 1217498
# Episode: 49/150 RapTime: 0:01:10.026638 FixedProfit: 1036573
# Episode: 49/150 RapTime: 0:01:08.923354 FixedProfit: 1051165
# Episode: 50/150 RapTime: 0:01:11.909496 FixedProfit: 975361
# Episode: 50/150 RapTime: 0:01:12.228738 FixedProfit: 1085576
# Episode: 50/150 RapTime: 0:01:11.522182 FixedProfit: 1225739
# Episode: 50/150 RapTime: 0:01:10.225948 FixedProfit: 943921
# Episode: 51/150 RapTime: 0:01:11.226772 FixedProfit: 1385144
# Episode: 51/150 RapTime: 0:01:12.068204 FixedProfit: 894189
# Episode: 51/150 RapTime: 0:01:11.332210 FixedProfit: 1046003
# Episode: 51/150 RapTime: 0:01:09.978287 FixedProfit: 1046066
# Episode: 52/150 RapTime: 0:01:11.139335 FixedProfit: 1171519
# Episode: 52/150 RapTime: 0:01:12.201328 FixedProfit: 1212930
# Episode: 52/150 RapTime: 0:01:11.604080 FixedProfit: 1026397
# Episode: 52/150 RapTime: 0:01:09.789408 FixedProfit: 1113451
# Episode: 53/150 RapTime: 0:01:11.004840 FixedProfit: 1138019
# Episode: 53/150 RapTime: 0:01:12.134736 FixedProfit: 977274
# Episode: 53/150 RapTime: 0:01:11.426417 FixedProfit: 1080030
# Episode: 53/150 RapTime: 0:01:10.206956 FixedProfit: 955950
# Episode: 54/150 RapTime: 0:01:11.061240 FixedProfit: 957144
# Episode: 54/150 RapTime: 0:01:12.017472 FixedProfit: 1137711
# Episode: 54/150 RapTime: 0:01:11.390968 FixedProfit: 1223793
# Episode: 54/150 RapTime: 0:01:10.050121 FixedProfit: 1157721
# Episode: 55/150 RapTime: 0:01:11.564349 FixedProfit: 1225130
# Episode: 55/150 RapTime: 0:01:11.983129 FixedProfit: 893733
# Episode: 55/150 RapTime: 0:01:11.916247 FixedProfit: 1081732
# Episode: 55/150 RapTime: 0:01:10.202810 FixedProfit: 1194712
# Episode: 56/150 RapTime: 0:01:11.296138 FixedProfit: 984363
# Episode: 56/150 RapTime: 0:01:11.314602 FixedProfit: 1108181
# Episode: 56/150 RapTime: 0:01:11.046089 FixedProfit: 956092
# Episode: 56/150 RapTime: 0:01:09.804063 FixedProfit: 1139247
# Episode: 57/150 RapTime: 0:01:10.962913 FixedProfit: 1138425
# Episode: 57/150 RapTime: 0:01:11.386980 FixedProfit: 1100967
# Episode: 57/150 RapTime: 0:01:10.580698 FixedProfit: 1142669
# Episode: 57/150 RapTime: 0:01:08.874628 FixedProfit: 1161243
# Episode: 58/150 RapTime: 0:01:11.647801 FixedProfit: 1189594
# Episode: 58/150 RapTime: 0:01:11.678030 FixedProfit: 1150265
# Episode: 58/150 RapTime: 0:01:11.142302 FixedProfit: 978189
# Episode: 58/150 RapTime: 0:01:09.586482 FixedProfit: 1135096
# Episode: 59/150 RapTime: 0:01:11.092968 FixedProfit: 1168550
# Episode: 59/150 RapTime: 0:01:11.375712 FixedProfit: 1086750
# Episode: 59/150 RapTime: 0:01:11.008329 FixedProfit: 987478
# Episode: 59/150 RapTime: 0:01:09.369630 FixedProfit: 973808
# Episode: 60/150 RapTime: 0:01:09.981790 FixedProfit: 919976
# Episode: 60/150 RapTime: 0:01:10.817852 FixedProfit: 1107222
# Episode: 60/150 RapTime: 0:01:10.517461 FixedProfit: 1179645
# Episode: 60/150 RapTime: 0:01:08.392240 FixedProfit: 1152821
# Episode: 61/150 RapTime: 0:01:10.617672 FixedProfit: 1186400
# Episode: 61/150 RapTime: 0:01:10.853603 FixedProfit: 1011378
# Episode: 61/150 RapTime: 0:01:10.562005 FixedProfit: 1124243
# Episode: 61/150 RapTime: 0:01:08.697896 FixedProfit: 1043988
# Episode: 62/150 RapTime: 0:01:10.781161 FixedProfit: 1064741
# Episode: 62/150 RapTime: 0:01:11.001519 FixedProfit: 1420184
# Episode: 62/150 RapTime: 0:01:10.604007 FixedProfit: 982441
# Episode: 62/150 RapTime: 0:01:08.738822 FixedProfit: 1126175
# Episode: 63/150 RapTime: 0:01:10.850709 FixedProfit: 1064039
# Episode: 63/150 RapTime: 0:01:10.929846 FixedProfit: 1095345
# Episode: 63/150 RapTime: 0:01:10.704273 FixedProfit: 1133118
# Episode: 63/150 RapTime: 0:01:07.868956 FixedProfit: 1020863
# Episode: 64/150 RapTime: 0:01:10.401788 FixedProfit: 970804
# Episode: 64/150 RapTime: 0:01:10.872329 FixedProfit: 1287629
# Episode: 64/150 RapTime: 0:01:10.428681 FixedProfit: 1048714
# Episode: 64/150 RapTime: 0:01:07.774868 FixedProfit: 983721
# Episode: 65/150 RapTime: 0:01:11.328509 FixedProfit: 1131466
# Episode: 65/150 RapTime: 0:01:10.953168 FixedProfit: 1157402
# Episode: 65/150 RapTime: 0:01:10.663535 FixedProfit: 896774
# Episode: 65/150 RapTime: 0:01:08.297776 FixedProfit: 966901
# Episode: 66/150 RapTime: 0:01:11.450653 FixedProfit: 1179885
# Episode: 66/150 RapTime: 0:01:11.019608 FixedProfit: 1165590
# Episode: 66/150 RapTime: 0:01:10.597929 FixedProfit: 1182659
# Episode: 66/150 RapTime: 0:01:07.950075 FixedProfit: 1225276
# Episode: 67/150 RapTime: 0:01:10.783596 FixedProfit: 1013128
# Episode: 67/150 RapTime: 0:01:10.481568 FixedProfit: 1124702
# Episode: 67/150 RapTime: 0:01:10.308054 FixedProfit: 1121572
# Episode: 67/150 RapTime: 0:01:07.367328 FixedProfit: 960945
# Episode: 68/150 RapTime: 0:01:11.177290 FixedProfit: 1032085
# Episode: 68/150 RapTime: 0:01:10.998352 FixedProfit: 1273063
# Episode: 68/150 RapTime: 0:01:10.402692 FixedProfit: 961974
# Episode: 68/150 RapTime: 0:01:07.242613 FixedProfit: 1072087
# Episode: 69/150 RapTime: 0:01:10.749361 FixedProfit: 896587
# Episode: 69/150 RapTime: 0:01:10.751595 FixedProfit: 1153770
# Episode: 69/150 RapTime: 0:01:09.780709 FixedProfit: 1048276
# Episode: 69/150 RapTime: 0:01:07.133327 FixedProfit: 1097184
# Episode: 70/150 RapTime: 0:01:10.531880 FixedProfit: 1245179
# Episode: 70/150 RapTime: 0:01:10.153825 FixedProfit: 1298988
# Episode: 70/150 RapTime: 0:01:10.171123 FixedProfit: 1037319
# Episode: 70/150 RapTime: 0:01:07.181153 FixedProfit: 1005694
# Episode: 71/150 RapTime: 0:01:11.121174 FixedProfit: 1168133
# Episode: 71/150 RapTime: 0:01:11.292543 FixedProfit: 1023671
# Episode: 71/150 RapTime: 0:01:10.414088 FixedProfit: 1014071
# Episode: 71/150 RapTime: 0:01:07.106765 FixedProfit: 1085926
# Episode: 72/150 RapTime: 0:01:10.779726 FixedProfit: 1235762
# Episode: 72/150 RapTime: 0:01:10.477215 FixedProfit: 1072003
# Episode: 72/150 RapTime: 0:01:10.135063 FixedProfit: 899768
# Episode: 72/150 RapTime: 0:01:06.793799 FixedProfit: 1137831
# Episode: 73/150 RapTime: 0:01:10.849226 FixedProfit: 1078564
# Episode: 73/150 RapTime: 0:01:10.371184 FixedProfit: 1096115
# Episode: 73/150 RapTime: 0:01:09.908305 FixedProfit: 1078259
# Episode: 73/150 RapTime: 0:01:06.614958 FixedProfit: 943322
# Episode: 74/150 RapTime: 0:01:10.518814 FixedProfit: 1147794
# Episode: 74/150 RapTime: 0:01:10.319544 FixedProfit: 1178080
# Episode: 74/150 RapTime: 0:01:10.046871 FixedProfit: 1030679
# Episode: 74/150 RapTime: 0:01:06.769055 FixedProfit: 1126883
# Episode: 75/150 RapTime: 0:01:10.864339 FixedProfit: 965796
# Episode: 75/150 RapTime: 0:01:10.343843 FixedProfit: 1159479
# Episode: 75/150 RapTime: 0:01:09.918116 FixedProfit: 1099453
# Episode: 75/150 RapTime: 0:01:06.402146 FixedProfit: 944291
# Episode: 76/150 RapTime: 0:01:10.942095 FixedProfit: 1174941
# Episode: 76/150 RapTime: 0:01:10.590422 FixedProfit: 1058580
# Episode: 76/150 RapTime: 0:01:10.251111 FixedProfit: 1228544
# Episode: 76/150 RapTime: 0:01:06.466086 FixedProfit: 1013554
# Episode: 77/150 RapTime: 0:01:10.234114 FixedProfit: 1042103
# Episode: 77/150 RapTime: 0:01:10.400475 FixedProfit: 1072727
# Episode: 77/150 RapTime: 0:01:10.035048 FixedProfit: 1058768
# Episode: 77/150 RapTime: 0:01:06.384333 FixedProfit: 1135362
# Episode: 78/150 RapTime: 0:01:10.590051 FixedProfit: 987103
# Episode: 78/150 RapTime: 0:01:10.540809 FixedProfit: 1137151
# Episode: 78/150 RapTime: 0:01:09.822027 FixedProfit: 1052915
# Episode: 78/150 RapTime: 0:01:06.048153 FixedProfit: 951352
# Episode: 79/150 RapTime: 0:01:10.559510 FixedProfit: 969942
# Episode: 79/150 RapTime: 0:01:10.195666 FixedProfit: 1090112
# Episode: 79/150 RapTime: 0:01:09.890089 FixedProfit: 1081827
# Episode: 79/150 RapTime: 0:01:05.536165 FixedProfit: 1114883
# Episode: 80/150 RapTime: 0:01:10.522754 FixedProfit: 1176460
# Episode: 80/150 RapTime: 0:01:10.571111 FixedProfit: 976794
# Episode: 80/150 RapTime: 0:01:10.198366 FixedProfit: 1229299
# Episode: 80/150 RapTime: 0:01:05.569121 FixedProfit: 926522
# Episode: 81/150 RapTime: 0:01:10.554489 FixedProfit: 1062952
# Episode: 81/150 RapTime: 0:01:10.419050 FixedProfit: 1175715
# Episode: 81/150 RapTime: 0:01:10.179641 FixedProfit: 1242967
# Episode: 81/150 RapTime: 0:01:05.427100 FixedProfit: 1335690
# Episode: 82/150 RapTime: 0:01:10.516790 FixedProfit: 984950
# Episode: 82/150 RapTime: 0:01:10.018695 FixedProfit: 1129927
# Episode: 82/150 RapTime: 0:01:09.822224 FixedProfit: 1040137
# Episode: 82/150 RapTime: 0:01:04.881248 FixedProfit: 1169573
# Episode: 83/150 RapTime: 0:01:09.529132 FixedProfit: 1039013
# Episode: 83/150 RapTime: 0:01:09.808871 FixedProfit: 1062168
# Episode: 83/150 RapTime: 0:01:09.283302 FixedProfit: 933355
# Episode: 83/150 RapTime: 0:01:04.669660 FixedProfit: 950572
# Episode: 84/150 RapTime: 0:01:09.969143 FixedProfit: 1263420
# Episode: 84/150 RapTime: 0:01:10.012669 FixedProfit: 1160841
# Episode: 84/150 RapTime: 0:01:09.739609 FixedProfit: 1007283
# Episode: 84/150 RapTime: 0:01:05.170681 FixedProfit: 1158455
# Episode: 85/150 RapTime: 0:01:10.349423 FixedProfit: 1091520
# Episode: 85/150 RapTime: 0:01:10.333277 FixedProfit: 1062349
# Episode: 85/150 RapTime: 0:01:09.557649 FixedProfit: 1191662
# Episode: 85/150 RapTime: 0:01:04.802549 FixedProfit: 1325470
# Episode: 86/150 RapTime: 0:01:10.996562 FixedProfit: 1132132
# Episode: 86/150 RapTime: 0:01:10.146995 FixedProfit: 1137802
# Episode: 86/150 RapTime: 0:01:09.623386 FixedProfit: 1089187
# Episode: 86/150 RapTime: 0:01:04.806122 FixedProfit: 1039155
# Episode: 87/150 RapTime: 0:01:10.673011 FixedProfit: 821620
# Episode: 87/150 RapTime: 0:01:10.793385 FixedProfit: 1048517
# Episode: 87/150 RapTime: 0:01:10.546576 FixedProfit: 941547
# Episode: 87/150 RapTime: 0:01:05.453721 FixedProfit: 1074867
# Episode: 88/150 RapTime: 0:01:10.535542 FixedProfit: 1102206
# Episode: 88/150 RapTime: 0:01:10.222201 FixedProfit: 923558
# Episode: 88/150 RapTime: 0:01:09.993035 FixedProfit: 881632
# Episode: 88/150 RapTime: 0:01:05.063117 FixedProfit: 1084686
# Episode: 89/150 RapTime: 0:01:10.878046 FixedProfit: 1179230
# Episode: 89/150 RapTime: 0:01:10.144949 FixedProfit: 1060732
# Episode: 89/150 RapTime: 0:01:10.078101 FixedProfit: 1332286
# Episode: 89/150 RapTime: 0:01:04.670435 FixedProfit: 1025344
# Episode: 90/150 RapTime: 0:01:10.592954 FixedProfit: 1139206
# Episode: 90/150 RapTime: 0:01:10.914271 FixedProfit: 1232060
# Episode: 90/150 RapTime: 0:01:10.363710 FixedProfit: 1267733
# Episode: 90/150 RapTime: 0:01:05.204801 FixedProfit: 1148735
# Episode: 91/150 RapTime: 0:01:10.923465 FixedProfit: 1264322
# Episode: 91/150 RapTime: 0:01:10.523355 FixedProfit: 1235939
# Episode: 91/150 RapTime: 0:01:10.366138 FixedProfit: 1327927
# Episode: 91/150 RapTime: 0:01:05.169011 FixedProfit: 1063191
# Episode: 92/150 RapTime: 0:01:09.983859 FixedProfit: 1151230
# Episode: 92/150 RapTime: 0:01:09.538243 FixedProfit: 1087199
# Episode: 92/150 RapTime: 0:01:09.540276 FixedProfit: 1091289
# Episode: 92/150 RapTime: 0:01:03.566353 FixedProfit: 1106614
# Episode: 93/150 RapTime: 0:01:09.664017 FixedProfit: 1128190
# Episode: 93/150 RapTime: 0:01:09.442334 FixedProfit: 1277541
# Episode: 93/150 RapTime: 0:01:09.015149 FixedProfit: 1095427
# Episode: 93/150 RapTime: 0:01:03.803129 FixedProfit: 972123
# Episode: 94/150 RapTime: 0:01:11.309080 FixedProfit: 1153550
# Episode: 94/150 RapTime: 0:01:10.819309 FixedProfit: 1191098
# Episode: 94/150 RapTime: 0:01:10.190759 FixedProfit: 1131523
# Episode: 94/150 RapTime: 0:01:04.792866 FixedProfit: 1148401
# Episode: 95/150 RapTime: 0:01:10.966261 FixedProfit: 977219
# Episode: 95/150 RapTime: 0:01:10.635170 FixedProfit: 1100670
# Episode: 95/150 RapTime: 0:01:10.260745 FixedProfit: 1374245
# Episode: 95/150 RapTime: 0:01:04.647392 FixedProfit: 1067927
# Episode: 96/150 RapTime: 0:01:10.918931 FixedProfit: 1010208
# Episode: 96/150 RapTime: 0:01:11.000345 FixedProfit: 1275194
# Episode: 96/150 RapTime: 0:01:10.473169 FixedProfit: 1262384
# Episode: 96/150 RapTime: 0:01:04.240007 FixedProfit: 1168267
# Episode: 97/150 RapTime: 0:01:10.960779 FixedProfit: 1043969
# Episode: 97/150 RapTime: 0:01:10.891547 FixedProfit: 1135792
# Episode: 97/150 RapTime: 0:01:10.191640 FixedProfit: 1017580
# Episode: 97/150 RapTime: 0:01:04.264960 FixedProfit: 1216872
# Episode: 98/150 RapTime: 0:01:11.396294 FixedProfit: 1078212
# Episode: 98/150 RapTime: 0:01:11.171784 FixedProfit: 1256678
# Episode: 98/150 RapTime: 0:01:10.931030 FixedProfit: 1152002
# Episode: 98/150 RapTime: 0:01:04.651369 FixedProfit: 952474
# Episode: 99/150 RapTime: 0:01:11.210298 FixedProfit: 884171
# Episode: 99/150 RapTime: 0:01:10.908294 FixedProfit: 1181838
# Episode: 99/150 RapTime: 0:01:10.824134 FixedProfit: 1267063
# Episode: 99/150 RapTime: 0:01:04.201565 FixedProfit: 1034031
# Episode: 100/150 RapTime: 0:01:11.002458 FixedProfit: 987856
# Episode: 100/150 RapTime: 0:01:10.859591 FixedProfit: 1258581
# Episode: 100/150 RapTime: 0:01:10.556041 FixedProfit: 1188077
# Episode: 100/150 RapTime: 0:01:04.219136 FixedProfit: 1086321
# Episode: 101/150 RapTime: 0:01:11.124287 FixedProfit: 1191133
# Episode: 101/150 RapTime: 0:01:11.186139 FixedProfit: 1162932
# Episode: 101/150 RapTime: 0:01:10.625951 FixedProfit: 1104878
# Episode: 101/150 RapTime: 0:01:03.863241 FixedProfit: 1034285
# Episode: 102/150 RapTime: 0:01:11.116106 FixedProfit: 1122217
# Episode: 102/150 RapTime: 0:01:10.440643 FixedProfit: 933172
# Episode: 102/150 RapTime: 0:01:10.090537 FixedProfit: 1053309
# Episode: 102/150 RapTime: 0:01:04.170329 FixedProfit: 1293669
# Episode: 103/150 RapTime: 0:01:11.172330 FixedProfit: 1046453
# Episode: 103/150 RapTime: 0:01:10.694746 FixedProfit: 1146921
# Episode: 103/150 RapTime: 0:01:10.166853 FixedProfit: 1057096
# Episode: 103/150 RapTime: 0:01:04.400038 FixedProfit: 1074816
# Episode: 104/150 RapTime: 0:01:10.924727 FixedProfit: 1380688
# Episode: 104/150 RapTime: 0:01:10.601894 FixedProfit: 1109968
# Episode: 104/150 RapTime: 0:01:10.463006 FixedProfit: 1230418
# Episode: 104/150 RapTime: 0:01:03.892852 FixedProfit: 1062358
# Episode: 105/150 RapTime: 0:01:10.714258 FixedProfit: 1045754
# Episode: 105/150 RapTime: 0:01:10.661966 FixedProfit: 1027546
# Episode: 105/150 RapTime: 0:01:10.431126 FixedProfit: 1142921
# Episode: 105/150 RapTime: 0:01:03.961823 FixedProfit: 1214024
# Episode: 106/150 RapTime: 0:01:10.821625 FixedProfit: 1161563
# Episode: 106/150 RapTime: 0:01:11.017527 FixedProfit: 1087942
# Episode: 106/150 RapTime: 0:01:10.524434 FixedProfit: 1137067
# Episode: 106/150 RapTime: 0:01:03.803340 FixedProfit: 1177560
# Episode: 107/150 RapTime: 0:01:11.318546 FixedProfit: 1090899
# Episode: 107/150 RapTime: 0:01:10.938309 FixedProfit: 1008464
# Episode: 107/150 RapTime: 0:01:10.640563 FixedProfit: 1127632
# Episode: 107/150 RapTime: 0:01:03.771602 FixedProfit: 872957
# Episode: 108/150 RapTime: 0:01:10.748345 FixedProfit: 1213750
# Episode: 108/150 RapTime: 0:01:10.516421 FixedProfit: 970869
# Episode: 108/150 RapTime: 0:01:10.332368 FixedProfit: 976157
# Episode: 108/150 RapTime: 0:01:03.347637 FixedProfit: 1199903
# Episode: 109/150 RapTime: 0:01:10.261981 FixedProfit: 965933
# Episode: 109/150 RapTime: 0:01:10.314395 FixedProfit: 1084135
# Episode: 109/150 RapTime: 0:01:10.151251 FixedProfit: 923946
# Episode: 109/150 RapTime: 0:01:03.714367 FixedProfit: 1120059
# Episode: 110/150 RapTime: 0:01:10.430104 FixedProfit: 1026368
# Episode: 110/150 RapTime: 0:01:10.101553 FixedProfit: 966988
# Episode: 110/150 RapTime: 0:01:09.746716 FixedProfit: 1193709
# Episode: 110/150 RapTime: 0:01:03.338822 FixedProfit: 1041157
# Episode: 111/150 RapTime: 0:01:10.662702 FixedProfit: 1063085
# Episode: 111/150 RapTime: 0:01:10.307472 FixedProfit: 909953
# Episode: 111/150 RapTime: 0:01:09.982762 FixedProfit: 938391
# Episode: 111/150 RapTime: 0:01:02.864024 FixedProfit: 1027227
# Episode: 112/150 RapTime: 0:01:10.289670 FixedProfit: 1314435
# Episode: 112/150 RapTime: 0:01:10.412639 FixedProfit: 1084628
# Episode: 112/150 RapTime: 0:01:09.894178 FixedProfit: 1119593
# Episode: 112/150 RapTime: 0:01:02.767942 FixedProfit: 1092984
# Episode: 113/150 RapTime: 0:01:09.775117 FixedProfit: 1040227
# Episode: 113/150 RapTime: 0:01:10.173954 FixedProfit: 1161645
# Episode: 113/150 RapTime: 0:01:09.621809 FixedProfit: 1256025
# Episode: 113/150 RapTime: 0:01:02.165994 FixedProfit: 995530
# Episode: 114/150 RapTime: 0:01:09.949976 FixedProfit: 1129944
# Episode: 114/150 RapTime: 0:01:10.173017 FixedProfit: 1040106
# Episode: 114/150 RapTime: 0:01:09.739230 FixedProfit: 1075510
# Episode: 114/150 RapTime: 0:01:01.874911 FixedProfit: 1155331
# Episode: 115/150 RapTime: 0:01:10.167289 FixedProfit: 1250142
# Episode: 115/150 RapTime: 0:01:10.089577 FixedProfit: 1063904
# Episode: 115/150 RapTime: 0:01:09.473769 FixedProfit: 1305673
# Episode: 115/150 RapTime: 0:01:01.946781 FixedProfit: 1029371
# Episode: 116/150 RapTime: 0:01:10.456828 FixedProfit: 1084850
# Episode: 116/150 RapTime: 0:01:09.967290 FixedProfit: 1080208
# Episode: 116/150 RapTime: 0:01:09.576440 FixedProfit: 1092532
# Episode: 116/150 RapTime: 0:01:01.748930 FixedProfit: 1103325
# Episode: 117/150 RapTime: 0:01:09.561357 FixedProfit: 945304
# Episode: 117/150 RapTime: 0:01:09.639020 FixedProfit: 1000564
# Episode: 117/150 RapTime: 0:01:09.137478 FixedProfit: 1203007
# Episode: 117/150 RapTime: 0:01:02.025316 FixedProfit: 1016477
# Episode: 118/150 RapTime: 0:01:09.526873 FixedProfit: 955375
# Episode: 118/150 RapTime: 0:01:09.520651 FixedProfit: 1030258
# Episode: 118/150 RapTime: 0:01:09.049266 FixedProfit: 1103781
# Episode: 118/150 RapTime: 0:01:01.541271 FixedProfit: 1460581
# Episode: 119/150 RapTime: 0:01:09.353799 FixedProfit: 1272425
# Episode: 119/150 RapTime: 0:01:09.449120 FixedProfit: 1286348
# Episode: 119/150 RapTime: 0:01:09.140234 FixedProfit: 1034562
# Episode: 119/150 RapTime: 0:01:01.592890 FixedProfit: 1096958
# Episode: 120/150 RapTime: 0:01:09.446254 FixedProfit: 1269206
# Episode: 120/150 RapTime: 0:01:09.139583 FixedProfit: 1427057
# Episode: 120/150 RapTime: 0:01:08.967875 FixedProfit: 1052935
# Episode: 120/150 RapTime: 0:01:01.201142 FixedProfit: 1046456
# Episode: 121/150 RapTime: 0:01:08.754115 FixedProfit: 946376
# Episode: 121/150 RapTime: 0:01:08.911075 FixedProfit: 1227592
# Episode: 121/150 RapTime: 0:01:08.340368 FixedProfit: 1113881
# Episode: 121/150 RapTime: 0:01:01.028430 FixedProfit: 1135479
# Episode: 122/150 RapTime: 0:01:07.747880 FixedProfit: 1198476
# Episode: 122/150 RapTime: 0:01:07.724923 FixedProfit: 1173344
# Episode: 122/150 RapTime: 0:01:07.301988 FixedProfit: 1011549
# Episode: 122/150 RapTime: 0:00:59.795741 FixedProfit: 972663
# Episode: 123/150 RapTime: 0:01:07.819395 FixedProfit: 1204429
# Episode: 123/150 RapTime: 0:01:07.654208 FixedProfit: 1175002
# Episode: 123/150 RapTime: 0:01:07.889556 FixedProfit: 867821
# Episode: 123/150 RapTime: 0:00:59.370981 FixedProfit: 999068
# Episode: 124/150 RapTime: 0:01:08.464744 FixedProfit: 787463
# Episode: 124/150 RapTime: 0:01:08.015591 FixedProfit: 1108611
# Episode: 124/150 RapTime: 0:01:07.524774 FixedProfit: 1055401
# Episode: 124/150 RapTime: 0:00:59.785172 FixedProfit: 1159145
# Episode: 125/150 RapTime: 0:01:08.196676 FixedProfit: 1149962
# Episode: 125/150 RapTime: 0:01:07.898123 FixedProfit: 1243167
# Episode: 125/150 RapTime: 0:01:07.856400 FixedProfit: 1154649
# Episode: 125/150 RapTime: 0:00:59.665604 FixedProfit: 897527
# Episode: 126/150 RapTime: 0:01:07.968836 FixedProfit: 926494
# Episode: 126/150 RapTime: 0:01:07.831966 FixedProfit: 1298907
# Episode: 126/150 RapTime: 0:01:07.801848 FixedProfit: 1079000
# Episode: 126/150 RapTime: 0:00:59.739979 FixedProfit: 1072383
# Episode: 127/150 RapTime: 0:01:07.455525 FixedProfit: 1061220
# Episode: 127/150 RapTime: 0:01:07.857840 FixedProfit: 1130228
# Episode: 127/150 RapTime: 0:01:07.427674 FixedProfit: 982437
# Episode: 127/150 RapTime: 0:00:59.760236 FixedProfit: 1154422
# Episode: 128/150 RapTime: 0:01:07.812429 FixedProfit: 1020431
# Episode: 128/150 RapTime: 0:01:07.389558 FixedProfit: 1187136
# Episode: 128/150 RapTime: 0:01:07.406007 FixedProfit: 1177303
# Episode: 128/150 RapTime: 0:00:59.894570 FixedProfit: 1044128
# Episode: 129/150 RapTime: 0:01:08.071954 FixedProfit: 1050231
# Episode: 129/150 RapTime: 0:01:07.924206 FixedProfit: 1181235
# Episode: 129/150 RapTime: 0:01:07.640161 FixedProfit: 1221199
# Episode: 129/150 RapTime: 0:00:59.307784 FixedProfit: 886796
# Episode: 130/150 RapTime: 0:01:08.095625 FixedProfit: 1013930
# Episode: 130/150 RapTime: 0:01:07.935077 FixedProfit: 1039568
# Episode: 130/150 RapTime: 0:01:07.432030 FixedProfit: 1241615
# Episode: 130/150 RapTime: 0:00:59.483686 FixedProfit: 994039
# Episode: 131/150 RapTime: 0:01:08.158926 FixedProfit: 931404
# Episode: 131/150 RapTime: 0:01:07.644563 FixedProfit: 1315817
# Episode: 131/150 RapTime: 0:01:06.914341 FixedProfit: 1080350
# Episode: 131/150 RapTime: 0:00:59.474952 FixedProfit: 1119635
# Episode: 132/150 RapTime: 0:01:08.276904 FixedProfit: 1321768
# Episode: 132/150 RapTime: 0:01:08.055640 FixedProfit: 1154255
# Episode: 132/150 RapTime: 0:01:07.209361 FixedProfit: 912089
# Episode: 132/150 RapTime: 0:00:59.582173 FixedProfit: 1013530
# Episode: 133/150 RapTime: 0:01:08.006114 FixedProfit: 1073797
# Episode: 133/150 RapTime: 0:01:07.414358 FixedProfit: 935276
# Episode: 133/150 RapTime: 0:01:07.070039 FixedProfit: 1072822
# Episode: 133/150 RapTime: 0:00:59.861093 FixedProfit: 1162501
# Episode: 134/150 RapTime: 0:01:07.801614 FixedProfit: 1195060
# Episode: 134/150 RapTime: 0:01:07.495180 FixedProfit: 1085039
# Episode: 134/150 RapTime: 0:01:07.157891 FixedProfit: 1067000
# Episode: 134/150 RapTime: 0:00:59.123869 FixedProfit: 1112176
# Episode: 135/150 RapTime: 0:01:07.874103 FixedProfit: 961415
# Episode: 135/150 RapTime: 0:01:07.360357 FixedProfit: 1257752
# Episode: 135/150 RapTime: 0:01:07.044503 FixedProfit: 1253078
# Episode: 135/150 RapTime: 0:00:59.810091 FixedProfit: 967650
# Episode: 136/150 RapTime: 0:01:08.009625 FixedProfit: 942929
# Episode: 136/150 RapTime: 0:01:07.701365 FixedProfit: 1189218
# Episode: 136/150 RapTime: 0:01:07.602514 FixedProfit: 1260453
# Episode: 136/150 RapTime: 0:00:59.207817 FixedProfit: 1165822
# Episode: 137/150 RapTime: 0:01:07.273006 FixedProfit: 1230226
# Episode: 137/150 RapTime: 0:01:07.419866 FixedProfit: 1212561
# Episode: 137/150 RapTime: 0:01:06.876470 FixedProfit: 1067301
# Episode: 137/150 RapTime: 0:00:59.029839 FixedProfit: 1071345
# Episode: 138/150 RapTime: 0:01:07.748311 FixedProfit: 1067619
# Episode: 138/150 RapTime: 0:01:07.890326 FixedProfit: 1432925
# Episode: 138/150 RapTime: 0:01:07.285235 FixedProfit: 1079474
# Episode: 138/150 RapTime: 0:00:58.946815 FixedProfit: 1075244
# Episode: 139/150 RapTime: 0:01:07.490322 FixedProfit: 1231193
# Episode: 139/150 RapTime: 0:01:07.367074 FixedProfit: 1047647
# Episode: 139/150 RapTime: 0:01:07.027109 FixedProfit: 1038735
# Episode: 139/150 RapTime: 0:00:58.882635 FixedProfit: 1316122
# Episode: 140/150 RapTime: 0:01:07.633962 FixedProfit: 1120701
# Episode: 140/150 RapTime: 0:01:07.752875 FixedProfit: 1196257
# Episode: 140/150 RapTime: 0:01:07.093737 FixedProfit: 1143557
# Episode: 140/150 RapTime: 0:00:58.854784 FixedProfit: 1038578
# Episode: 141/150 RapTime: 0:01:07.656786 FixedProfit: 1383253
# Episode: 141/150 RapTime: 0:01:07.340539 FixedProfit: 1125545
# Episode: 141/150 RapTime: 0:01:07.021416 FixedProfit: 1400281
# Episode: 141/150 RapTime: 0:00:59.085265 FixedProfit: 1120905
# Episode: 142/150 RapTime: 0:01:07.966618 FixedProfit: 1025230
# Episode: 142/150 RapTime: 0:01:07.630816 FixedProfit: 1318759
# Episode: 142/150 RapTime: 0:01:07.158980 FixedProfit: 1029384
# Episode: 142/150 RapTime: 0:00:59.885845 FixedProfit: 1000035
# Episode: 143/150 RapTime: 0:01:07.011221 FixedProfit: 1043133
# Episode: 143/150 RapTime: 0:01:07.058117 FixedProfit: 1133405
# Episode: 143/150 RapTime: 0:01:06.466290 FixedProfit: 977073
# Episode: 143/150 RapTime: 0:00:59.139336 FixedProfit: 1235591
# Episode: 144/150 RapTime: 0:01:07.508672 FixedProfit: 1148527
# Episode: 144/150 RapTime: 0:01:07.620478 FixedProfit: 1173152
# Episode: 144/150 RapTime: 0:01:06.657557 FixedProfit: 1015115
# Episode: 144/150 RapTime: 0:00:59.168033 FixedProfit: 1192973
# Episode: 145/150 RapTime: 0:01:07.299491 FixedProfit: 1071845
# Episode: 145/150 RapTime: 0:01:07.205825 FixedProfit: 1002285
# Episode: 145/150 RapTime: 0:01:06.596811 FixedProfit: 1013002
# Episode: 145/150 RapTime: 0:00:59.035507 FixedProfit: 1104985
# Episode: 146/150 RapTime: 0:01:07.154418 FixedProfit: 1122682
# Episode: 146/150 RapTime: 0:01:07.189878 FixedProfit: 1230973
# Episode: 146/150 RapTime: 0:01:06.161641 FixedProfit: 1120793
# Episode: 146/150 RapTime: 0:00:59.172523 FixedProfit: 925613
# Episode: 147/150 RapTime: 0:01:07.195886 FixedProfit: 1109909
# Episode: 147/150 RapTime: 0:01:07.204673 FixedProfit: 1068403
# Episode: 147/150 RapTime: 0:01:06.373801 FixedProfit: 859075
# Episode: 147/150 RapTime: 0:00:58.831975 FixedProfit: 1227955
# Episode: 148/150 RapTime: 0:01:07.418285 FixedProfit: 895669
# Episode: 148/150 RapTime: 0:01:07.888798 FixedProfit: 1208781
# Episode: 148/150 RapTime: 0:01:06.559449 FixedProfit: 1214368
# Episode: 148/150 RapTime: 0:00:59.633201 FixedProfit: 1101630
# Episode: 149/150 RapTime: 0:01:08.091237 FixedProfit: 1051120
# Episode: 149/150 RapTime: 0:01:07.934306 FixedProfit: 1254651
# Episode: 149/150 RapTime: 0:01:06.897676 FixedProfit: 1299347
# Episode: 149/150 RapTime: 0:00:59.268891 FixedProfit: 1190844
# Episode: 150/150 RapTime: 0:01:07.118806 FixedProfit: 1094733
# Episode: 150/150 RapTime: 0:01:07.597936 FixedProfit: 1118347
# Episode: 150/150 RapTime: 0:01:06.799024 FixedProfit: 1121728
# Episode: 150/150 RapTime: 0:00:59.270393 FixedProfit: 1043937
