# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/impala_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time
from datetime import datetime
import random
import copy
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPool1D, Activation, concatenate
from tensorflow.keras import Input

from sklearn.preprocessing import StandardScaler
import math

from google.colab import drive

from concurrent.futures import ThreadPoolExecutor

from dataclasses import dataclass, field
from typing import List

mode = 'train'
name = 'impala'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'

exp_dir = 'Colab Notebooks/workspace/export/'
mdl_dir = '/content/drive/My Drive/' + exp_dir + 'models'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.end_step        = self.df_total_steps
        self.now_step        = 0
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
class Critic:
    def __init__(self,model):
        self.model = model
        self.n_action = 3
        self.gamma = 0.9
        self.alfa = 0.5
        self.beta = 0.00025

    def valuenetwork(self, state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu):

        with tf.GradientTape() as tape:

            actions = tf.one_hot(action, self.n_action) # (10, 3)

            state = state.reshape(1,10,3)
            prev_action = prev_action.reshape(1,10,1)
            prev_reward = prev_reward.reshape(1,10,1)

            pai, v_theta  = self.model([state, prev_action, prev_reward])

            pai = tf.reshape(pai, [10,3]) # (10, 3)

            actions = tf.cast(actions, tf.float32)

            pais = tf.reduce_sum(actions * pai, axis=1, keepdims=True)

            mu = self._reshape_and_cast(mu, 3)
            ratio = tf.math.divide_no_nan(pais, mu)
            rhoi = ci = tf.minimum(1.0, ratio)

            n_num, _ = ratio.shape

            rhoi = self._reshape_and_cast(rhoi,3)
            ci = self._reshape_and_cast(ci,3)
            reward = self._reshape_and_cast(reward,1)
            v_next = self._reshape_and_cast(v_next,1)
            v = self._reshape_and_cast(v,1)
            v_theta = self._reshape_and_cast(v_theta,1)

            b4_delta_v = (reward + self.gamma * v_next - v)
            b4_delta_v  =  tf.cast(b4_delta_v, tf.float32)
            delta_v = tf.multiply(rhoi, b4_delta_v)
            delta_v = self._reshape_and_cast(delta_v,3)
            v_trace =v + self._sigma(ci, delta_v, n_num)
            total_loss = self._compute_baseline_loss(v_trace - v_theta)
            total_loss += self._compute_policy_gradient_loss(pai, actions, delta_v)
            total_loss += self._compute_entropy_loss(pai)

        gradients = tape.gradient(total_loss, self.model.trainable_variables)
        self.model.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))

    def _reshape_and_cast(self, x, num):
        x = tf.reshape(x, [10,num])
        x  =  tf.cast(x, tf.float32)
        return x

    def _infinite_product(self, x, max_num):
        num = tf.ones([3, ], tf.float32)
        for i in range(max_num):
            num *= x[i]   
        return num

    def _sigma(self, x, delta_v, b):
        
        num = 0.0
        for i in range(b):
            num += pow(self.gamma, i) * self._infinite_product(x, i) * delta_v[i]
        return tf.cast(num, tf.float32)

    def _compute_baseline_loss(self, advantages):
        return .5 * tf.reduce_sum(tf.square(advantages))

    def _compute_policy_gradient_loss(self, logits, actions, advantages):
        cross_entropy = tf.losses.categorical_crossentropy(y_true=actions, y_pred=logits)
        cross_entropy = tf.reshape(cross_entropy, [10,1])
        advantages = tf.stop_gradient(advantages)
        policy_gradient_loss_per_timestep = cross_entropy * advantages
        return tf.reduce_sum(policy_gradient_loss_per_timestep)

    def _compute_entropy_loss(self, logits):
        log_policy = tf.math.log(logits)
        entropy_per_timestep = tf.reduce_sum(-logits * log_policy, axis=-1)
        return -tf.reduce_sum(entropy_per_timestep)

# %%
class Learner(Critic):
    def __init__(self):

        conv_filter = 12
        units = 28
        look_back = 10
        opt = Adam(learning_rate=0.001)

        input1_ = Input(shape=(look_back, 3))
        input2_ = Input(shape=(look_back, 1))
        input3_ = Input(shape=(look_back, 1))

        x = Conv1D(filters=conv_filter, kernel_size=1, padding="same", activation="tanh")(input1_)
        x = MaxPool1D(pool_size=1, padding='same')(x)
        x = Activation("relu")(x)
        combined = concatenate([x, input2_, input3_],axis=-1)
        common = LSTM(units, return_sequences=True)(combined)
        common = Dense(units, kernel_initializer='random_uniform')(common)
        common = Activation("relu")(common)

        actor  = Dense(3, activation="softmax")(common)
        critic = Dense(1, activation="linear")(common)

        mastermodel = keras.Model([input1_, input2_, input3_], [actor, critic])
        mastermodel.compile(loss = "mean_absolute_error", optimizer=opt)
        mastermodel.summary()
        #dot_img_file = './f"{name}_model.png"'
        #tf.keras.utils.plot_model(mastermodel, to_file=dot_img_file, show_shapes=True)
        self.mastermodel = mastermodel
        super().__init__(mastermodel)

    def load(self, name):
        self.mastermodel.load_weights(name)

    def save(self, name):
        self.mastermodel.save_weights(name)

    def placement(self, memory):
        length = memory.max_length_memory()
        for i in range(length):
            min = i * 10
            max = (i + 1) * 10
            state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu = memory.get_experiences(min, max)
            self.valuenetwork(state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu)

    def layering(self, model):
        for mm, m in zip(self.mastermodel.trainable_weights, model.trainable_weights):
            mm.assign(m)

# %%
class Brain:
    def __init__(self):

        conv_filter = 12
        units = 28
        look_back = 10
        opt = Adam(learning_rate=0.001)

        input1_ = Input(shape=(look_back, 3))
        input2_ = Input(shape=(look_back, 1))
        input3_ = Input(shape=(look_back, 1))

        x = Conv1D(filters=conv_filter, kernel_size=1, padding="same", activation="tanh")(input1_)
        x = MaxPool1D(pool_size=1, padding='same')(x)
        x = Activation("relu")(x)
        combined = concatenate([x, input2_, input3_],axis=-1)
        common = LSTM(units, return_sequences=True)(combined)
        common = Dense(units, kernel_initializer='random_uniform')(common)
        common = Activation("relu")(common)

        actor  = Dense(3, activation="softmax")(common)
        critic = Dense(1, activation="linear")(common)

        model = keras.Model([input1_, input2_, input3_], [actor, critic])
        model.compile(loss = "mean_absolute_error", optimizer=opt)
        model.summary()
        self.model = model

# %%
class Actor(Brain):
    def __init__(self, learner):

        self.learner = learner
        self.model = learner.mastermodel
        self.n_action = 3
        self.state_arr = np.array([])
        self.p_action_arr = np.array([])
        self.p_reward_arr = np.array([])

        self.next_state_arr = np.array([])
        self.action_arr = np.array([])
        self.reward_arr = np.array([])
        super().__init__()

    def reset(self):
        self.state_arr = np.empty((0,3), int)
        self.p_action_arr = np.array([])
        self.p_reward_arr = np.array([])

        self.next_state_arr = np.empty((0,3), int)
        self.action_arr = np.array([])
        self.reward_arr = np.array([])

    def policynetwork(self, state, prev_action, prev_reward):

        if len(self.state_arr) == 10:
            self.state_arr[0:-1] = self.state_arr[1:]
            self.p_action_arr[0:-1] = self.p_action_arr[1:]
            self.p_reward_arr[0:-1] = self.p_reward_arr[1:]
            self.state_arr[-1] = state
            self.p_action_arr[-1] = prev_action
            self.p_reward_arr[-1] = prev_reward
            tmp_state = copy.deepcopy(self.state_arr)
            tmp_action = copy.deepcopy(self.p_action_arr)
            tmp_reward = copy.deepcopy(self.p_reward_arr)
            tmp_state = tmp_state.reshape(1,10,3)
            tmp_action = tmp_action.reshape(1,10,1)
            tmp_reward = tmp_reward.reshape(1,10,1)
            act_p, v = self.model([tmp_state, tmp_action, tmp_reward]) # [-1.03245259 -0.55189404  0.87892511] 1 0
            v_np = v.numpy()
            p_np = act_p.numpy()
            one_hot_actions = tf.one_hot([0,1,2], 3)
            act_p = p_np[0][9]
            mu = tf.reduce_sum(one_hot_actions * act_p, axis=1)
            return np.random.choice(3, p=p_np[0][9]), v_np[0][9][0], mu.numpy()

        self.state_arr = np.append(self.state_arr, np.array([state]), axis=0)
        self.p_action_arr = np.append(self.p_action_arr, np.array([prev_action]))
        self.p_reward_arr = np.append(self.p_reward_arr, np.array([prev_reward]))
        return 1, 1, [0.0, 1.0, 0.0]

    def policynetwork_next(self, next_state, action, reward):

        if len(self.next_state_arr) == 10:
            self.next_state_arr[0:-1] = self.next_state_arr[1:]
            self.action_arr[0:-1] = self.action_arr[1:]
            self.reward_arr[0:-1] = self.reward_arr[1:]
            self.next_state_arr[-1] = next_state
            self.action_arr[-1] = action
            self.reward_arr[-1] = reward

            tmp_n_state = copy.deepcopy(self.next_state_arr)
            tmp_action = copy.deepcopy(self.action_arr)
            tmp_reward = copy.deepcopy(self.reward_arr)
            tmp_n_state = tmp_n_state.reshape(1,10,3)
            tmp_action = tmp_action.reshape(1,10,1)
            tmp_reward = tmp_reward.reshape(1,10,1)

            _, v_next = self.model([tmp_n_state, tmp_action, tmp_reward])
            v_next_np = v_next.numpy()
            return v_next_np[0][9][0]

        self.next_state_arr = np.append(self.next_state_arr, np.array([next_state]), axis=0)
        self.action_arr = np.append(self.action_arr, np.array([action]))
        self.reward_arr = np.append(self.reward_arr, np.array([reward]))
        return 1.0

    def load(self, name):
        self.learner.load(name)

    def save(self, name):
        self.learner.save(name)

    def integration(self):
        self.learner.layering(self.model)

    def placement(self, memory):
        self.learner.placement(memory)

# %%
@dataclass
class ExperiencesMemory:
    state : np.ndarray = np.empty((0,3), int)
    next_state : np.ndarray = np.empty((0,3), int)
    prev_action : np.ndarray = np.array([])
    action : np.ndarray = np.array([])
    prev_reward : np.ndarray = np.array([])
    reward : np.ndarray = np.array([])
    done : np.ndarray = np.array([])
    v : np.ndarray = np.array([])
    v_next : np.ndarray = np.array([])
    mu : np.ndarray = np.empty((0,3), int)
    minibatch_size : int = 64

    def append_experiences(self, state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu):
        self.state = np.append(self.state, np.array([state]), axis=0)
        self.next_state = np.append(self.next_state, np.array([next_state]), axis=0)
        self.prev_action = np.append(self.prev_action, np.array(prev_action))
        self.action = np.append(self.action, np.array(action))
        self.prev_reward = np.append(self.prev_reward, np.array(prev_reward))
        self.reward = np.append(self.reward, np.array(reward))
        self.done = np.append(self.done, np.array(done))
        self.v = np.append(self.v, np.array(v))
        self.v_next = np.append(self.v_next, np.array(v_next))
        self.mu = np.append(self.mu, np.array([mu]), axis=0)

    def max_length_memory(self):
        max_len = len(self.state)
        max_len = int(max_len/10)

        return max_len

    def get_experiences(self, min, max):
        state, next_state, mu = np.empty((0,3), int), np.empty((0,3), int), np.empty((0,3), int)
        prev_action, action, prev_reward, reward, done, v, v_next = np.array([]), np.array([]), np.array([]), np.array([]), np.array([]), np.array([]), np.array([])
        for i in range(min, max):
            state = np.append(state, np.array([self.state[i]]), axis=0)
            next_state = np.append(next_state, self.action[i])
            prev_action = np.append(prev_action, self.prev_action[i])
            action = np.append(action, self.action[i])
            prev_reward = np.append(prev_reward, self.prev_reward[i])
            reward = np.append(reward, self.reward[i])
            done = np.append(done, self.done[i])
            v = np.append(v, self.v[i])
            v_next = np.append(v_next, self.v_next[i])
            mu = np.append(mu, np.array([self.mu[i]]), axis=0)

        return state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu

# %%
class Main:
    def __init__(self, env, actor, num, mdl_dir, name, batch_size = 32, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.actor = actor
        self.num = str(num)
        self.mdl_dir = mdl_dir
        self.scaler = self._standard_scaler(self.env)
        self.episodes_times = episodes_times
        self.batch_size = batch_size
        self.mode = mode
        self.name = name

        if self.mode == 'test':
            self._load()
            with open(csv_path, 'w') as f:
                row = 'FixedProfit,TradeTimes,TradeWin'
                print(row, file=f)
        else:
            with open(csv_path, 'w') as f:
                row = 'FixedProfit'
                print(row, file=f)
        
        self.actor.integration()

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            state = self.scaler.transform([state])
            self.actor.reset()
            state = state.flatten()
            done = False
            start_time = datetime.now()
            memory = ExperiencesMemory()
            prev_action = 1
            prev_reward = 0
            i = 0
    
            while not done:
                action, v, mu = self.actor.policynetwork(state, prev_action, prev_reward)
                next_state, reward, done, info = self.env.step(action)
                next_state = self.scaler.transform([next_state])
                next_state = next_state.flatten()
                v_next = self.actor.policynetwork_next(next_state, action, reward)

                if (i > 10) and (self.mode == 'train'):
                    memory.append_experiences(state, next_state, prev_action, action, prev_reward, reward, done, v, v_next, mu)

                state = next_state
                prev_action = action
                prev_reward = reward
                i += 1
               
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f} TradeTimes: {} TradeWin: {}".format(episode + 1, episodes_times, play_time, info['cur_revenue'], info['trade_time'], info['trade_win']))
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                    print(row, file=f)
            else:
                self.actor.placement(memory)
                self.actor.integration()
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f}".format(episode + 1, episodes_times, play_time, info['cur_revenue']))
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue'])
                    print(row, file=f)

        if self.mode == 'train':
            self._save()

    def _standard_scaler(self, env):
        states = []
        for _ in range(env.df_total_steps):
            action = np.random.choice(env.action_space)
            state, reward, done, info = env.step(action)
            states.append(state)
            if done:
                break
        
        scaler = StandardScaler()
        scaler.fit(states)
        return scaler

    def _load(self):
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, self.num), 'rb') as f:
            self.scaler = pickle.load(f)
        self.actor.load('{}/{}.h5'.format(self.mdl_dir, self.name))

    def _save(self):
        self.actor.save('{}/{}.h5'.format(self.mdl_dir, self.name))
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, self.num), 'wb') as f:
            pickle.dump(self.scaler, f)

# %%
initial_money=1000000
episodes_times = 50
batch_size = 32
Learner = Learner()

thread_num = 4
envs = []
for i in range(thread_num):
    env = Environment(df, initial_money=initial_money,mode = mode)
    actor = Actor(Learner)
    main = Main(env, actor, i, mdl_dir, name, batch_size, episodes_times, mode)
    envs.append(main)

datas = []
with ThreadPoolExecutor(max_workers=thread_num) as executor:
    for env in envs:
        job = lambda: env.play_game()
        datas.append(executor.submit(job))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10, 3)]      0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 10, 12)       48          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 10, 12)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 10, 12)       0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 14)       0           activation[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 10, 28)       4816        concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10, 28)       812         lstm[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 10, 28)       0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10, 3)        87          activation_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10, 1)        29          activation_1[0][0]
# ==================================================================================================
# Total params: 5,792
# Trainable params: 5,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 10, 3)]      0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 10, 12)       48          input_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 10, 12)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 10, 12)       0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10, 14)       0           activation_2[0][0]
#                                                                  input_5[0][0]
#                                                                  input_6[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 10, 28)       4816        concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10, 28)       812         lstm_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 10, 28)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10, 3)        87          activation_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 10, 1)        29          activation_3[0][0]
# ==================================================================================================
# Total params: 5,792
# Trainable params: 5,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 10, 3)]      0
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 10, 12)       48          input_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 10, 12)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 10, 12)       0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 10, 14)       0           activation_4[0][0]
#                                                                  input_8[0][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 10, 28)       4816        concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 10, 28)       812         lstm_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 10, 28)       0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 10, 3)        87          activation_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 10, 1)        29          activation_5[0][0]
# ==================================================================================================
# Total params: 5,792
# Trainable params: 5,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 10, 3)]      0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 10, 12)       48          input_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 10, 12)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 10, 12)       0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# input_11 (InputLayer)           [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 10, 14)       0           activation_6[0][0]
#                                                                  input_11[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 10, 28)       4816        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 10, 28)       812         lstm_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 10, 28)       0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 10, 3)        87          activation_7[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 10, 1)        29          activation_7[0][0]
# ==================================================================================================
# Total params: 5,792
# Trainable params: 5,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 10, 3)]      0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 10, 12)       48          input_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 10, 12)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 10, 12)       0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# input_14 (InputLayer)           [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           [(None, 10, 1)]      0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 10, 14)       0           activation_8[0][0]
#                                                                  input_14[0][0]
#                                                                  input_15[0][0]
# __________________________________________________________________________________________________
# lstm_4 (LSTM)                   (None, 10, 28)       4816        concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 10, 28)       812         lstm_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 10, 28)       0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10, 3)        87          activation_9[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 10, 1)        29          activation_9[0][0]
# ==================================================================================================
# Total params: 5,792
# Trainable params: 5,792
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Episode: 1/50 RapTime: 0:01:14.479901 FixedProfit: 1310343
# Episode: 1/50 RapTime: 0:01:15.042394 FixedProfit: 1061179
# Episode: 1/50 RapTime: 0:01:15.175049 FixedProfit: 1267121
# Episode: 1/50 RapTime: 0:01:15.242951 FixedProfit: 1113120
# Episode: 2/50 RapTime: 0:01:14.084480 FixedProfit: 1173447
# Episode: 2/50 RapTime: 0:01:14.497730 FixedProfit: 1205533
# Episode: 2/50 RapTime: 0:01:14.236563 FixedProfit: 1061438
# Episode: 2/50 RapTime: 0:01:14.243369 FixedProfit: 1212351
# Episode: 3/50 RapTime: 0:01:14.006573 FixedProfit: 1014175
# Episode: 3/50 RapTime: 0:01:13.832112 FixedProfit: 880228
# Episode: 3/50 RapTime: 0:01:14.131870 FixedProfit: 1002767
# Episode: 3/50 RapTime: 0:01:14.344511 FixedProfit: 917835
# Episode: 4/50 RapTime: 0:01:14.017354 FixedProfit: 1184770
# Episode: 4/50 RapTime: 0:01:14.244705 FixedProfit: 1146884
# Episode: 4/50 RapTime: 0:01:14.444555 FixedProfit: 1018380
# Episode: 4/50 RapTime: 0:01:14.404157 FixedProfit: 1294777
# Episode: 5/50 RapTime: 0:01:14.047777 FixedProfit: 1102497
# Episode: 5/50 RapTime: 0:01:14.396450 FixedProfit: 1044455
# Episode: 5/50 RapTime: 0:01:14.519693 FixedProfit: 1044445
# Episode: 5/50 RapTime: 0:01:14.194809 FixedProfit: 997528
# Episode: 6/50 RapTime: 0:01:13.792076 FixedProfit: 1144187
# Episode: 6/50 RapTime: 0:01:14.065716 FixedProfit: 995288
# Episode: 6/50 RapTime: 0:01:14.400313 FixedProfit: 1005494
# Episode: 6/50 RapTime: 0:01:13.979266 FixedProfit: 1070175
# Episode: 7/50 RapTime: 0:01:13.252425 FixedProfit: 1061200
# Episode: 7/50 RapTime: 0:01:13.664328 FixedProfit: 1068519
# Episode: 7/50 RapTime: 0:01:13.628924 FixedProfit: 1022874
# Episode: 7/50 RapTime: 0:01:14.014188 FixedProfit: 1161801
# Episode: 8/50 RapTime: 0:01:13.672500 FixedProfit: 1223271
# Episode: 8/50 RapTime: 0:01:13.911104 FixedProfit: 965246
# Episode: 8/50 RapTime: 0:01:13.767099 FixedProfit: 1329902
# Episode: 8/50 RapTime: 0:01:14.128168 FixedProfit: 1137824
# Episode: 9/50 RapTime: 0:01:12.980832 FixedProfit: 953563
# Episode: 9/50 RapTime: 0:01:13.382121 FixedProfit: 1238801
# Episode: 9/50 RapTime: 0:01:13.665080 FixedProfit: 1050561
# Episode: 9/50 RapTime: 0:01:13.782727 FixedProfit: 957223
# Episode: 10/50 RapTime: 0:01:12.818527 FixedProfit: 1170667
# Episode: 10/50 RapTime: 0:01:13.513431 FixedProfit: 1104558
# Episode: 10/50 RapTime: 0:01:13.387162 FixedProfit: 977600
# Episode: 10/50 RapTime: 0:01:13.370246 FixedProfit: 1201180
# Episode: 11/50 RapTime: 0:01:12.961682 FixedProfit: 1241899
# Episode: 11/50 RapTime: 0:01:13.438610 FixedProfit: 1009356
# Episode: 11/50 RapTime: 0:01:13.521017 FixedProfit: 1046485
# Episode: 11/50 RapTime: 0:01:13.565306 FixedProfit: 1304105
# Episode: 12/50 RapTime: 0:01:12.660315 FixedProfit: 1183397
# Episode: 12/50 RapTime: 0:01:13.157253 FixedProfit: 1175208
# Episode: 12/50 RapTime: 0:01:13.452108 FixedProfit: 1178227
# Episode: 12/50 RapTime: 0:01:13.502548 FixedProfit: 1197410
# Episode: 13/50 RapTime: 0:01:12.288750 FixedProfit: 1057897
# Episode: 13/50 RapTime: 0:01:13.127578 FixedProfit: 1308105
# Episode: 13/50 RapTime: 0:01:13.352701 FixedProfit: 993999
# Episode: 13/50 RapTime: 0:01:12.954342 FixedProfit: 1182737
# Episode: 14/50 RapTime: 0:01:12.700023 FixedProfit: 1108269
# Episode: 14/50 RapTime: 0:01:13.272680 FixedProfit: 1079001
# Episode: 14/50 RapTime: 0:01:13.240728 FixedProfit: 1132594
# Episode: 14/50 RapTime: 0:01:13.316425 FixedProfit: 1131822
# Episode: 15/50 RapTime: 0:01:11.585706 FixedProfit: 1073657
# Episode: 15/50 RapTime: 0:01:12.761179 FixedProfit: 1096598
# Episode: 15/50 RapTime: 0:01:12.594265 FixedProfit: 961216
# Episode: 15/50 RapTime: 0:01:12.644725 FixedProfit: 1092860
# Episode: 16/50 RapTime: 0:01:12.152267 FixedProfit: 1165453
# Episode: 16/50 RapTime: 0:01:12.747195 FixedProfit: 1137403
# Episode: 16/50 RapTime: 0:01:13.042716 FixedProfit: 1092731
# Episode: 16/50 RapTime: 0:01:12.752849 FixedProfit: 1163343
# Episode: 17/50 RapTime: 0:01:12.404933 FixedProfit: 936684
# Episode: 17/50 RapTime: 0:01:13.466443 FixedProfit: 1299199
# Episode: 17/50 RapTime: 0:01:13.196551 FixedProfit: 1399222
# Episode: 17/50 RapTime: 0:01:13.465023 FixedProfit: 1147640
# Episode: 18/50 RapTime: 0:01:12.146280 FixedProfit: 1204431
# Episode: 18/50 RapTime: 0:01:12.993882 FixedProfit: 1165579
# Episode: 18/50 RapTime: 0:01:13.284688 FixedProfit: 1134724
# Episode: 18/50 RapTime: 0:01:12.933863 FixedProfit: 1246331
# Episode: 19/50 RapTime: 0:01:12.058789 FixedProfit: 1311093
# Episode: 19/50 RapTime: 0:01:12.855182 FixedProfit: 1165062
# Episode: 19/50 RapTime: 0:01:13.061576 FixedProfit: 1048396
# Episode: 19/50 RapTime: 0:01:12.906197 FixedProfit: 1274160
# Episode: 20/50 RapTime: 0:01:11.970032 FixedProfit: 1332817
# Episode: 20/50 RapTime: 0:01:13.092374 FixedProfit: 1189245
# Episode: 20/50 RapTime: 0:01:13.129715 FixedProfit: 1307822
# Episode: 20/50 RapTime: 0:01:12.929456 FixedProfit: 979489
# Episode: 21/50 RapTime: 0:01:12.212071 FixedProfit: 1113810
# Episode: 21/50 RapTime: 0:01:12.939048 FixedProfit: 1087435
# Episode: 21/50 RapTime: 0:01:12.800643 FixedProfit: 1205827
# Episode: 21/50 RapTime: 0:01:12.972592 FixedProfit: 1087132
# Episode: 22/50 RapTime: 0:01:11.970567 FixedProfit: 1248766
# Episode: 22/50 RapTime: 0:01:12.817255 FixedProfit: 1452712
# Episode: 22/50 RapTime: 0:01:12.955769 FixedProfit: 1345910
# Episode: 22/50 RapTime: 0:01:12.655876 FixedProfit: 1023414
# Episode: 23/50 RapTime: 0:01:12.274534 FixedProfit: 972704
# Episode: 23/50 RapTime: 0:01:13.249733 FixedProfit: 1141490
# Episode: 23/50 RapTime: 0:01:13.288078 FixedProfit: 911708
# Episode: 23/50 RapTime: 0:01:13.058907 FixedProfit: 1067239
# Episode: 24/50 RapTime: 0:01:11.728272 FixedProfit: 1088531
# Episode: 24/50 RapTime: 0:01:12.607303 FixedProfit: 1174814
# Episode: 24/50 RapTime: 0:01:13.146714 FixedProfit: 1045240
# Episode: 24/50 RapTime: 0:01:12.573652 FixedProfit: 1041261
# Episode: 25/50 RapTime: 0:01:11.950024 FixedProfit: 791548
# Episode: 25/50 RapTime: 0:01:13.412708 FixedProfit: 1303756
# Episode: 25/50 RapTime: 0:01:13.050261 FixedProfit: 1011608
# Episode: 25/50 RapTime: 0:01:12.608966 FixedProfit: 976631
# Episode: 26/50 RapTime: 0:01:12.290663 FixedProfit: 1153780
# Episode: 26/50 RapTime: 0:01:13.054533 FixedProfit: 1127235
# Episode: 26/50 RapTime: 0:01:13.325359 FixedProfit: 1113175
# Episode: 26/50 RapTime: 0:01:12.699173 FixedProfit: 1022062
# Episode: 27/50 RapTime: 0:01:11.552424 FixedProfit: 1107324
# Episode: 27/50 RapTime: 0:01:12.968539 FixedProfit: 965045
# Episode: 27/50 RapTime: 0:01:12.852717 FixedProfit: 1185436
# Episode: 27/50 RapTime: 0:01:13.010543 FixedProfit: 1043129
# Episode: 28/50 RapTime: 0:01:11.890778 FixedProfit: 1150080
# Episode: 28/50 RapTime: 0:01:12.524633 FixedProfit: 1049099
# Episode: 28/50 RapTime: 0:01:12.894137 FixedProfit: 1223687
# Episode: 28/50 RapTime: 0:01:12.255895 FixedProfit: 1060450
# Episode: 29/50 RapTime: 0:01:11.806104 FixedProfit: 998337
# Episode: 29/50 RapTime: 0:01:12.956736 FixedProfit: 1168443
# Episode: 29/50 RapTime: 0:01:12.823317 FixedProfit: 957993
# Episode: 29/50 RapTime: 0:01:12.411050 FixedProfit: 1050256
# Episode: 30/50 RapTime: 0:01:11.530332 FixedProfit: 1087527
# Episode: 30/50 RapTime: 0:01:12.732918 FixedProfit: 1180299
# Episode: 30/50 RapTime: 0:01:12.856120 FixedProfit: 828994
# Episode: 30/50 RapTime: 0:01:12.166265 FixedProfit: 1070516
# Episode: 31/50 RapTime: 0:01:11.758884 FixedProfit: 889894
# Episode: 31/50 RapTime: 0:01:13.265226 FixedProfit: 1040891
# Episode: 31/50 RapTime: 0:01:12.872895 FixedProfit: 947853
# Episode: 31/50 RapTime: 0:01:12.303013 FixedProfit: 969448
# Episode: 32/50 RapTime: 0:01:11.617459 FixedProfit: 1079461
# Episode: 32/50 RapTime: 0:01:12.919072 FixedProfit: 1205404
# Episode: 32/50 RapTime: 0:01:12.949903 FixedProfit: 1123667
# Episode: 32/50 RapTime: 0:01:12.345178 FixedProfit: 1162578
# Episode: 33/50 RapTime: 0:01:11.422551 FixedProfit: 1114495
# Episode: 33/50 RapTime: 0:01:12.611682 FixedProfit: 1073855
# Episode: 33/50 RapTime: 0:01:12.618684 FixedProfit: 1139525
# Episode: 33/50 RapTime: 0:01:11.871045 FixedProfit: 1001652
# Episode: 34/50 RapTime: 0:01:11.558649 FixedProfit: 997430
# Episode: 34/50 RapTime: 0:01:13.006807 FixedProfit: 1068835
# Episode: 34/50 RapTime: 0:01:12.893652 FixedProfit: 1117678
# Episode: 34/50 RapTime: 0:01:12.215671 FixedProfit: 1169154
# Episode: 35/50 RapTime: 0:01:11.559770 FixedProfit: 983876
# Episode: 35/50 RapTime: 0:01:12.937640 FixedProfit: 1148451
# Episode: 35/50 RapTime: 0:01:12.764572 FixedProfit: 1069939
# Episode: 35/50 RapTime: 0:01:12.099370 FixedProfit: 949574
# Episode: 36/50 RapTime: 0:01:11.249215 FixedProfit: 936963
# Episode: 36/50 RapTime: 0:01:12.971830 FixedProfit: 1177387
# Episode: 36/50 RapTime: 0:01:12.577566 FixedProfit: 1076727
# Episode: 36/50 RapTime: 0:01:11.623482 FixedProfit: 1176144
# Episode: 37/50 RapTime: 0:01:11.415990 FixedProfit: 1199361
# Episode: 37/50 RapTime: 0:01:12.927706 FixedProfit: 1149551
# Episode: 37/50 RapTime: 0:01:12.573207 FixedProfit: 1106626
# Episode: 37/50 RapTime: 0:01:11.839632 FixedProfit: 1276646
# Episode: 38/50 RapTime: 0:01:11.413443 FixedProfit: 885294
# Episode: 38/50 RapTime: 0:01:12.946774 FixedProfit: 1206996
# Episode: 38/50 RapTime: 0:01:12.904559 FixedProfit: 1067700
# Episode: 38/50 RapTime: 0:01:11.599194 FixedProfit: 1051474
# Episode: 39/50 RapTime: 0:01:10.774008 FixedProfit: 1236718
# Episode: 39/50 RapTime: 0:01:12.594581 FixedProfit: 1173711
# Episode: 39/50 RapTime: 0:01:12.593316 FixedProfit: 873102
# Episode: 39/50 RapTime: 0:01:11.659804 FixedProfit: 1094303
# Episode: 40/50 RapTime: 0:01:10.753956 FixedProfit: 1062888
# Episode: 40/50 RapTime: 0:01:12.144330 FixedProfit: 1012396
# Episode: 40/50 RapTime: 0:01:12.686515 FixedProfit: 1002597
# Episode: 40/50 RapTime: 0:01:11.526458 FixedProfit: 1158584
# Episode: 41/50 RapTime: 0:01:10.617000 FixedProfit: 1128902
# Episode: 41/50 RapTime: 0:01:12.230367 FixedProfit: 926487
# Episode: 41/50 RapTime: 0:01:12.378096 FixedProfit: 1190430
# Episode: 41/50 RapTime: 0:01:11.107698 FixedProfit: 1055860
# Episode: 42/50 RapTime: 0:01:10.661461 FixedProfit: 1318861
# Episode: 42/50 RapTime: 0:01:12.197770 FixedProfit: 1133315
# Episode: 42/50 RapTime: 0:01:12.204682 FixedProfit: 1027088
# Episode: 42/50 RapTime: 0:01:11.384324 FixedProfit: 989634
# Episode: 43/50 RapTime: 0:01:10.937577 FixedProfit: 993929
# Episode: 43/50 RapTime: 0:01:12.489346 FixedProfit: 1042686
# Episode: 43/50 RapTime: 0:01:12.414474 FixedProfit: 1120097
# Episode: 43/50 RapTime: 0:01:11.242179 FixedProfit: 1143529
# Episode: 44/50 RapTime: 0:01:10.523967 FixedProfit: 961137
# Episode: 44/50 RapTime: 0:01:12.461159 FixedProfit: 1042461
# Episode: 44/50 RapTime: 0:01:12.293065 FixedProfit: 967143
# Episode: 44/50 RapTime: 0:01:11.069769 FixedProfit: 1224555
# Episode: 45/50 RapTime: 0:01:10.406300 FixedProfit: 906295
# Episode: 45/50 RapTime: 0:01:12.177647 FixedProfit: 942712
# Episode: 45/50 RapTime: 0:01:12.025410 FixedProfit: 1114109
# Episode: 45/50 RapTime: 0:01:11.349694 FixedProfit: 1065353
# Episode: 46/50 RapTime: 0:01:10.673468 FixedProfit: 1012015
# Episode: 46/50 RapTime: 0:01:12.222440 FixedProfit: 1009948
# Episode: 46/50 RapTime: 0:01:11.949464 FixedProfit: 1066906
# Episode: 46/50 RapTime: 0:01:10.632149 FixedProfit: 1157316
# Episode: 47/50 RapTime: 0:01:10.447080 FixedProfit: 982807
# Episode: 47/50 RapTime: 0:01:11.746024 FixedProfit: 1306394
# Episode: 47/50 RapTime: 0:01:12.086318 FixedProfit: 1361798
# Episode: 47/50 RapTime: 0:01:10.878338 FixedProfit: 1245888
# Episode: 48/50 RapTime: 0:01:10.479728 FixedProfit: 883260
# Episode: 48/50 RapTime: 0:01:11.798922 FixedProfit: 969052
# Episode: 48/50 RapTime: 0:01:12.221290 FixedProfit: 1474518
# Episode: 48/50 RapTime: 0:01:10.786114 FixedProfit: 899663
# Episode: 49/50 RapTime: 0:01:10.373208 FixedProfit: 937256
# Episode: 49/50 RapTime: 0:01:11.916282 FixedProfit: 1140163
# Episode: 49/50 RapTime: 0:01:12.101443 FixedProfit: 1042068
# Episode: 49/50 RapTime: 0:01:11.019539 FixedProfit: 1016958
# Episode: 50/50 RapTime: 0:01:10.519986 FixedProfit: 975110
# Episode: 50/50 RapTime: 0:01:11.916920 FixedProfit: 1173773
# Episode: 50/50 RapTime: 0:01:12.262187 FixedProfit: 1342992
# Episode: 50/50 RapTime: 0:01:10.827366 FixedProfit: 1135578
