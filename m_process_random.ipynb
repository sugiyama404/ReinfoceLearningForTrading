# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_process_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from multiprocessing import Process,Manager,Array

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_process_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
    
        while not done:
            action = random.randrange(3)
            state, reward, done, info = env.step(action)
        
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)


envs = []
for i in range(4):
    e = Environment(df, initial_money=initial_money,mode = mode)
    envs.append(e)

worker = []
for env in envs:
    p = Process(target=play_game, args=(env,))
    worker.append(p)
    p.start()

for w in worker:
    w.join()
# Out:
# Episode: 1/25 RapTime: 0:00:00.088892 FixedProfit: 931004 TradeTimes: 148 TradeWin: 87
# Episode: 1/25 RapTime: 0:00:00.108075 FixedProfit: 1651903 TradeTimes: 146 TradeWin: 98
# Episode: 1/25 RapTime: 0:00:00.108813 FixedProfit: 1545854 TradeTimes: 151 TradeWin: 98
# Episode: 1/25 RapTime: 0:00:00.101394 FixedProfit: 1267150 TradeTimes: 151 TradeWin: 94
# Episode: 2/25 RapTime: 0:00:00.088485 FixedProfit: 1694929 TradeTimes: 137 TradeWin: 91
# Episode: 2/25 RapTime: 0:00:00.090621 FixedProfit: 1688171 TradeTimes: 146 TradeWin: 94
# Episode: 2/25 RapTime: 0:00:00.099066 FixedProfit: 1282856 TradeTimes: 156 TradeWin: 89
# Episode: 2/25 RapTime: 0:00:00.094008 FixedProfit: 1232464 TradeTimes: 143 TradeWin: 85
# Episode: 3/25 RapTime: 0:00:00.098394 FixedProfit: 1871281 TradeTimes: 147 TradeWin: 101
# Episode: 3/25 RapTime: 0:00:00.104743 FixedProfit: 1486063 TradeTimes: 150 TradeWin: 98
# Episode: 3/25 RapTime: 0:00:00.088085 FixedProfit: 1421302 TradeTimes: 151 TradeWin: 90
# Episode: 3/25 RapTime: 0:00:00.085462 FixedProfit: 1422427 TradeTimes: 134 TradeWin: 85
# Episode: 4/25 RapTime: 0:00:00.099659 FixedProfit: 1511126 TradeTimes: 152 TradeWin: 95
# Episode: 4/25 RapTime: 0:00:00.082512 FixedProfit: 1078386 TradeTimes: 149 TradeWin: 84
# Episode: 4/25 RapTime: 0:00:00.086864 FixedProfit: 1328562 TradeTimes: 139 TradeWin: 90
# Episode: 4/25 RapTime: 0:00:00.084834 FixedProfit: 1142207 TradeTimes: 151 TradeWin: 94
# Episode: 5/25 RapTime: 0:00:00.093250 FixedProfit: 1552247 TradeTimes: 145 TradeWin: 98
# Episode: 5/25 RapTime: 0:00:00.091263 FixedProfit: 996326 TradeTimes: 143 TradeWin: 85
# Episode: 5/25 RapTime: 0:00:00.103332 FixedProfit: 1142144 TradeTimes: 150 TradeWin: 87
# Episode: 5/25 RapTime: 0:00:00.090288 FixedProfit: 1289301 TradeTimes: 155 TradeWin: 97
# Episode: 6/25 RapTime: 0:00:00.078372 FixedProfit: 1236964 TradeTimes: 152 TradeWin: 91
# Episode: 6/25 RapTime: 0:00:00.079963 FixedProfit: 1740863 TradeTimes: 154 TradeWin: 99
# Episode: 6/25 RapTime: 0:00:00.094429 FixedProfit: 1279405 TradeTimes: 147 TradeWin: 88
# Episode: 6/25 RapTime: 0:00:00.104024 FixedProfit: 1786577 TradeTimes: 147 TradeWin: 95
# Episode: 7/25 RapTime: 0:00:00.082971 FixedProfit: 936127 TradeTimes: 150 TradeWin: 92
# Episode: 7/25 RapTime: 0:00:00.099219 FixedProfit: 1815288 TradeTimes: 142 TradeWin: 98
# Episode: 7/25 RapTime: 0:00:00.085918 FixedProfit: 1453609 TradeTimes: 137 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.103979 FixedProfit: 1531998 TradeTimes: 144 TradeWin: 95
# Episode: 8/25 RapTime: 0:00:00.088885 FixedProfit: 1529166 TradeTimes: 147 TradeWin: 94
# Episode: 8/25 RapTime: 0:00:00.096777 FixedProfit: 1334614 TradeTimes: 157 TradeWin: 92
# Episode: 8/25 RapTime: 0:00:00.113816 FixedProfit: 1961381 TradeTimes: 152 TradeWin: 97
# Episode: 8/25 RapTime: 0:00:00.089682 FixedProfit: 1063676 TradeTimes: 139 TradeWin: 79
# Episode: 9/25 RapTime: 0:00:00.090782 FixedProfit: 1010203 TradeTimes: 152 TradeWin: 90
# Episode: 9/25 RapTime: 0:00:00.101154 FixedProfit: 1410296 TradeTimes: 155 TradeWin: 105
# Episode: 9/25 RapTime: 0:00:00.093931 FixedProfit: 1330108 TradeTimes: 158 TradeWin: 95
# Episode: 9/25 RapTime: 0:00:00.102639 FixedProfit: 1276894 TradeTimes: 162 TradeWin: 95
# Episode: 10/25 RapTime: 0:00:00.095136 FixedProfit: 1302122 TradeTimes: 153 TradeWin: 100
# Episode: 10/25 RapTime: 0:00:00.091387 FixedProfit: 958031 TradeTimes: 151 TradeWin: 82
# Episode: 10/25 RapTime: 0:00:00.100154 FixedProfit: 1270735 TradeTimes: 158 TradeWin: 101
# Episode: 10/25 RapTime: 0:00:00.101068 FixedProfit: 1120092 TradeTimes: 151 TradeWin: 91
# Episode: 11/25 RapTime: 0:00:00.094153 FixedProfit: 1088013 TradeTimes: 147 TradeWin: 89
# Episode: 11/25 RapTime: 0:00:00.098053 FixedProfit: 1127814 TradeTimes: 158 TradeWin: 95
# Episode: 11/25 RapTime: 0:00:00.092999 FixedProfit: 1194315 TradeTimes: 152 TradeWin: 100
# Episode: 11/25 RapTime: 0:00:00.079358 FixedProfit: 911422 TradeTimes: 136 TradeWin: 90
# Episode: 12/25 RapTime: 0:00:00.108966 FixedProfit: 1225684 TradeTimes: 143 TradeWin: 80
# Episode: 12/25 RapTime: 0:00:00.094546 FixedProfit: 1156055 TradeTimes: 137 TradeWin: 79
# Episode: 12/25 RapTime: 0:00:00.081669 FixedProfit: 854681 TradeTimes: 150 TradeWin: 91
# Episode: 12/25 RapTime: 0:00:00.086271 FixedProfit: 1324902 TradeTimes: 139 TradeWin: 97
# Episode: 13/25 RapTime: 0:00:00.090293 FixedProfit: 1752218 TradeTimes: 152 TradeWin: 98
# Episode: 13/25 RapTime: 0:00:00.077207 FixedProfit: 821106 TradeTimes: 146 TradeWin: 85
# Episode: 13/25 RapTime: 0:00:00.115440 FixedProfit: 1598935 TradeTimes: 145 TradeWin: 90
# Episode: 13/25 RapTime: 0:00:00.089006 FixedProfit: 1192827 TradeTimes: 140 TradeWin: 88
# Episode: 14/25 RapTime: 0:00:00.088147 FixedProfit: 1366834 TradeTimes: 155 TradeWin: 98
# Episode: 14/25 RapTime: 0:00:00.081750 FixedProfit: 1071485 TradeTimes: 154 TradeWin: 94
# Episode: 14/25 RapTime: 0:00:00.089949 FixedProfit: 1074968 TradeTimes: 135 TradeWin: 81
# Episode: 14/25 RapTime: 0:00:00.090992 FixedProfit: 1090192 TradeTimes: 153 TradeWin: 89
# Episode: 15/25 RapTime: 0:00:00.087422 FixedProfit: 1130676 TradeTimes: 142 TradeWin: 92
# Episode: 15/25 RapTime: 0:00:00.082550 FixedProfit: 965509 TradeTimes: 144 TradeWin: 97
# Episode: 15/25 RapTime: 0:00:00.094238 FixedProfit: 1416203 TradeTimes: 146 TradeWin: 86
# Episode: 15/25 RapTime: 0:00:00.090353 FixedProfit: 1198048 TradeTimes: 142 TradeWin: 83
# Episode: 16/25 RapTime: 0:00:00.089845 FixedProfit: 1385100 TradeTimes: 148 TradeWin: 93
# Episode: 16/25 RapTime: 0:00:00.082439 FixedProfit: 1042749 TradeTimes: 147 TradeWin: 88
# Episode: 16/25 RapTime: 0:00:00.092420 FixedProfit: 1182067 TradeTimes: 157 TradeWin: 99
# Episode: 16/25 RapTime: 0:00:00.095288 FixedProfit: 1268468 TradeTimes: 146 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.094819 FixedProfit: 1128936 TradeTimes: 166 TradeWin: 103
# Episode: 17/25 RapTime: 0:00:00.113297 FixedProfit: 1119386 TradeTimes: 143 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.090300 FixedProfit: 1255327 TradeTimes: 149 TradeWin: 97
# Episode: 17/25 RapTime: 0:00:00.088574 FixedProfit: 1233245 TradeTimes: 146 TradeWin: 96
# Episode: 18/25 RapTime: 0:00:00.090891 FixedProfit: 1108783 TradeTimes: 150 TradeWin: 78
# Episode: 18/25 RapTime: 0:00:00.087609 FixedProfit: 1108775 TradeTimes: 149 TradeWin: 85
# Episode: 18/25 RapTime: 0:00:00.097365 FixedProfit: 1137948 TradeTimes: 149 TradeWin: 87
# Episode: 18/25 RapTime: 0:00:00.089281 FixedProfit: 1334858 TradeTimes: 139 TradeWin: 88
# Episode: 19/25 RapTime: 0:00:00.084752 FixedProfit: 1218970 TradeTimes: 153 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.090653 FixedProfit: 1530411 TradeTimes: 138 TradeWin: 87
# Episode: 19/25 RapTime: 0:00:00.089723 FixedProfit: 1520625 TradeTimes: 144 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.106779 FixedProfit: 1387934 TradeTimes: 151 TradeWin: 101
# Episode: 20/25 RapTime: 0:00:00.099583 FixedProfit: 1907802 TradeTimes: 154 TradeWin: 103
# Episode: 20/25 RapTime: 0:00:00.097078 FixedProfit: 1796584 TradeTimes: 146 TradeWin: 88
# Episode: 20/25 RapTime: 0:00:00.099717 FixedProfit: 1439187 TradeTimes: 142 TradeWin: 86
# Episode: 20/25 RapTime: 0:00:00.098370 FixedProfit: 991362 TradeTimes: 141 TradeWin: 81
# Episode: 21/25 RapTime: 0:00:00.103049 FixedProfit: 1608808 TradeTimes: 146 TradeWin: 92
# Episode: 21/25 RapTime: 0:00:00.094896 FixedProfit: 1064049 TradeTimes: 159 TradeWin: 93
# Episode: 21/25 RapTime: 0:00:00.085523 FixedProfit: 856286 TradeTimes: 141 TradeWin: 94
# Episode: 21/25 RapTime: 0:00:00.090988 FixedProfit: 1470021 TradeTimes: 144 TradeWin: 93
# Episode: 22/25 RapTime: 0:00:00.089776 FixedProfit: 1279595 TradeTimes: 146 TradeWin: 93
# Episode: 22/25 RapTime: 0:00:00.100500 FixedProfit: 1612531 TradeTimes: 149 TradeWin: 97
# Episode: 22/25 RapTime: 0:00:00.086256 FixedProfit: 1056085 TradeTimes: 148 TradeWin: 85
# Episode: 22/25 RapTime: 0:00:00.090585 FixedProfit: 1393123 TradeTimes: 153 TradeWin: 92
# Episode: 23/25 RapTime: 0:00:00.088935 FixedProfit: 1057205 TradeTimes: 147 TradeWin: 86
# Episode: 23/25 RapTime: 0:00:00.082632 FixedProfit: 881766 TradeTimes: 149 TradeWin: 87
# Episode: 23/25 RapTime: 0:00:00.088143 FixedProfit: 1008307 TradeTimes: 141 TradeWin: 79
# Episode: 23/25 RapTime: 0:00:00.098586 FixedProfit: 1181913 TradeTimes: 156 TradeWin: 102
# Episode: 24/25 RapTime: 0:00:00.095650 FixedProfit: 1189777 TradeTimes: 136 TradeWin: 84
# Episode: 24/25 RapTime: 0:00:00.107244 FixedProfit: 1358773 TradeTimes: 146 TradeWin: 90
# Episode: 24/25 RapTime: 0:00:00.103469 FixedProfit: 1898344 TradeTimes: 144 TradeWin: 94
# Episode: 25/25 RapTime: 0:00:00.085385 FixedProfit: 1018573 TradeTimes: 142 TradeWin: 90
# Episode: 24/25 RapTime: 0:00:00.092337 FixedProfit: 1223397 TradeTimes: 149 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.101408 FixedProfit: 1394548 TradeTimes: 150 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.068673 FixedProfit: 1085736 TradeTimes: 137 TradeWin: 85
# Episode: 25/25 RapTime: 0:00:00.060340 FixedProfit: 1679366 TradeTimes: 138 TradeWin: 93
