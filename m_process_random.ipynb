# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_process_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from multiprocessing import Process,Manager,Array

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_process_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
       
        while not done:
            action = np.random.randint(3, size=1)[0]
            state, reward, done, info = env.step(action)
           
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'
env = Environment(df, initial_money=initial_money,mode = mode)

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)

worker = []
for i in range(4):
    p = Process(target=play_game, args=(env,))
    worker.append(p)
    p.start()

for w in worker:
    w.join()
# Out:
# Episode: 1/25 RapTime: 0:00:00.112562 FixedProfit: 1449874 TradeTimes: 148 TradeWin: 94
# Episode: 1/25 RapTime: 0:00:00.126270 FixedProfit: 1449874 TradeTimes: 148 TradeWin: 94
# Episode: 1/25 RapTime: 0:00:00.122243 FixedProfit: 1449874 TradeTimes: 148 TradeWin: 94
# Episode: 1/25 RapTime: 0:00:00.134548 FixedProfit: 1449874 TradeTimes: 148 TradeWin: 94
# Episode: 2/25 RapTime: 0:00:00.131425 FixedProfit: 2052022 TradeTimes: 149 TradeWin: 102
# Episode: 2/25 RapTime: 0:00:00.132740 FixedProfit: 2052022 TradeTimes: 149 TradeWin: 102
# Episode: 2/25 RapTime: 0:00:00.131936 FixedProfit: 2052022 TradeTimes: 149 TradeWin: 102
# Episode: 2/25 RapTime: 0:00:00.134128 FixedProfit: 2052022 TradeTimes: 149 TradeWin: 102
# Episode: 3/25 RapTime: 0:00:00.130571 FixedProfit: 1268751 TradeTimes: 149 TradeWin: 95
# Episode: 3/25 RapTime: 0:00:00.123396 FixedProfit: 1268751 TradeTimes: 149 TradeWin: 95
# Episode: 3/25 RapTime: 0:00:00.122142 FixedProfit: 1268751 TradeTimes: 149 TradeWin: 95
# Episode: 3/25 RapTime: 0:00:00.126845 FixedProfit: 1268751 TradeTimes: 149 TradeWin: 95
# Episode: 4/25 RapTime: 0:00:00.136109 FixedProfit: 1171631 TradeTimes: 156 TradeWin: 93
# Episode: 4/25 RapTime: 0:00:00.130258 FixedProfit: 1171631 TradeTimes: 156 TradeWin: 93
# Episode: 4/25 RapTime: 0:00:00.133109 FixedProfit: 1171631 TradeTimes: 156 TradeWin: 93
# Episode: 4/25 RapTime: 0:00:00.127182 FixedProfit: 1171631 TradeTimes: 156 TradeWin: 93
# Episode: 5/25 RapTime: 0:00:00.122084 FixedProfit: 1129636 TradeTimes: 141 TradeWin: 83
# Episode: 5/25 RapTime: 0:00:00.123730 FixedProfit: 1129636 TradeTimes: 141 TradeWin: 83
# Episode: 5/25 RapTime: 0:00:00.120435 FixedProfit: 1129636 TradeTimes: 141 TradeWin: 83
# Episode: 5/25 RapTime: 0:00:00.125042 FixedProfit: 1129636 TradeTimes: 141 TradeWin: 83
# Episode: 6/25 RapTime: 0:00:00.121177 FixedProfit: 1314882 TradeTimes: 146 TradeWin: 93
# Episode: 6/25 RapTime: 0:00:00.132675 FixedProfit: 1314882 TradeTimes: 146 TradeWin: 93
# Episode: 6/25 RapTime: 0:00:00.123654 FixedProfit: 1314882 TradeTimes: 146 TradeWin: 93
# Episode: 6/25 RapTime: 0:00:00.121454 FixedProfit: 1314882 TradeTimes: 146 TradeWin: 93
# Episode: 7/25 RapTime: 0:00:00.124253 FixedProfit: 1584041 TradeTimes: 138 TradeWin: 86
# Episode: 7/25 RapTime: 0:00:00.128350 FixedProfit: 1584041 TradeTimes: 138 TradeWin: 86
# Episode: 7/25 RapTime: 0:00:00.131235 FixedProfit: 1584041 TradeTimes: 138 TradeWin: 86
# Episode: 7/25 RapTime: 0:00:00.127735 FixedProfit: 1584041 TradeTimes: 138 TradeWin: 86
# Episode: 8/25 RapTime: 0:00:00.123721 FixedProfit: 1052370 TradeTimes: 149 TradeWin: 84
# Episode: 8/25 RapTime: 0:00:00.118823 FixedProfit: 1052370 TradeTimes: 149 TradeWin: 84
# Episode: 8/25 RapTime: 0:00:00.131260 FixedProfit: 1052370 TradeTimes: 149 TradeWin: 84
# Episode: 8/25 RapTime: 0:00:00.130891 FixedProfit: 1052370 TradeTimes: 149 TradeWin: 84
# Episode: 9/25 RapTime: 0:00:00.127230 FixedProfit: 993343 TradeTimes: 144 TradeWin: 85
# Episode: 9/25 RapTime: 0:00:00.110976 FixedProfit: 993343 TradeTimes: 144 TradeWin: 85
# Episode: 9/25 RapTime: 0:00:00.123496 FixedProfit: 993343 TradeTimes: 144 TradeWin: 85
# Episode: 9/25 RapTime: 0:00:00.117032 FixedProfit: 993343 TradeTimes: 144 TradeWin: 85
# Episode: 10/25 RapTime: 0:00:00.134013 FixedProfit: 1064001 TradeTimes: 144 TradeWin: 85
# Episode: 10/25 RapTime: 0:00:00.119379 FixedProfit: 1064001 TradeTimes: 144 TradeWin: 85
# Episode: 10/25 RapTime: 0:00:00.129353 FixedProfit: 1064001 TradeTimes: 144 TradeWin: 85
# Episode: 10/25 RapTime: 0:00:00.126361 FixedProfit: 1064001 TradeTimes: 144 TradeWin: 85
# Episode: 11/25 RapTime: 0:00:00.120826 FixedProfit: 1185537 TradeTimes: 144 TradeWin: 83
# Episode: 11/25 RapTime: 0:00:00.123769 FixedProfit: 1185537 TradeTimes: 144 TradeWin: 83
# Episode: 11/25 RapTime: 0:00:00.118652 FixedProfit: 1185537 TradeTimes: 144 TradeWin: 83
# Episode: 11/25 RapTime: 0:00:00.121723 FixedProfit: 1185537 TradeTimes: 144 TradeWin: 83
# Episode: 12/25 RapTime: 0:00:00.133634 FixedProfit: 1158593 TradeTimes: 147 TradeWin: 96
# Episode: 12/25 RapTime: 0:00:00.119935 FixedProfit: 1158593 TradeTimes: 147 TradeWin: 96
# Episode: 12/25 RapTime: 0:00:00.122735 FixedProfit: 1158593 TradeTimes: 147 TradeWin: 96
# Episode: 12/25 RapTime: 0:00:00.127937 FixedProfit: 1158593 TradeTimes: 147 TradeWin: 96
# Episode: 13/25 RapTime: 0:00:00.127559 FixedProfit: 1244186 TradeTimes: 141 TradeWin: 89
# Episode: 13/25 RapTime: 0:00:00.136322 FixedProfit: 1244186 TradeTimes: 141 TradeWin: 89
# Episode: 13/25 RapTime: 0:00:00.141415 FixedProfit: 1244186 TradeTimes: 141 TradeWin: 89
# Episode: 13/25 RapTime: 0:00:00.137053 FixedProfit: 1244186 TradeTimes: 141 TradeWin: 89
# Episode: 14/25 RapTime: 0:00:00.111368 FixedProfit: 1061048 TradeTimes: 145 TradeWin: 79
# Episode: 14/25 RapTime: 0:00:00.112292 FixedProfit: 1061048 TradeTimes: 145 TradeWin: 79
# Episode: 14/25 RapTime: 0:00:00.120709 FixedProfit: 1061048 TradeTimes: 145 TradeWin: 79
# Episode: 14/25 RapTime: 0:00:00.128522 FixedProfit: 1061048 TradeTimes: 145 TradeWin: 79
# Episode: 15/25 RapTime: 0:00:00.117764 FixedProfit: 1437827 TradeTimes: 147 TradeWin: 94
# Episode: 15/25 RapTime: 0:00:00.128920 FixedProfit: 1437827 TradeTimes: 147 TradeWin: 94
# Episode: 15/25 RapTime: 0:00:00.124961 FixedProfit: 1437827 TradeTimes: 147 TradeWin: 94
# Episode: 15/25 RapTime: 0:00:00.144634 FixedProfit: 1437827 TradeTimes: 147 TradeWin: 94
# Episode: 16/25 RapTime: 0:00:00.144265 FixedProfit: 1468383 TradeTimes: 162 TradeWin: 108
# Episode: 16/25 RapTime: 0:00:00.138157 FixedProfit: 1468383 TradeTimes: 162 TradeWin: 108
# Episode: 16/25 RapTime: 0:00:00.153241 FixedProfit: 1468383 TradeTimes: 162 TradeWin: 108
# Episode: 16/25 RapTime: 0:00:00.157476 FixedProfit: 1468383 TradeTimes: 162 TradeWin: 108
# Episode: 17/25 RapTime: 0:00:00.126850 FixedProfit: 1647043 TradeTimes: 139 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.122895 FixedProfit: 1647043 TradeTimes: 139 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.128614 FixedProfit: 1647043 TradeTimes: 139 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.124898 FixedProfit: 1647043 TradeTimes: 139 TradeWin: 89
# Episode: 18/25 RapTime: 0:00:00.117285 FixedProfit: 1209077 TradeTimes: 130 TradeWin: 79
# Episode: 18/25 RapTime: 0:00:00.122967 FixedProfit: 1209077 TradeTimes: 130 TradeWin: 79
# Episode: 18/25 RapTime: 0:00:00.122347 FixedProfit: 1209077 TradeTimes: 130 TradeWin: 79
# Episode: 18/25 RapTime: 0:00:00.125793 FixedProfit: 1209077 TradeTimes: 130 TradeWin: 79
# Episode: 19/25 RapTime: 0:00:00.121112 FixedProfit: 1131503 TradeTimes: 157 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.121971 FixedProfit: 1131503 TradeTimes: 157 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.149366 FixedProfit: 1131503 TradeTimes: 157 TradeWin: 94
# Episode: 19/25 RapTime: 0:00:00.130943 FixedProfit: 1131503 TradeTimes: 157 TradeWin: 94
# Episode: 20/25 RapTime: 0:00:00.127976 FixedProfit: 1033262 TradeTimes: 141 TradeWin: 81
# Episode: 20/25 RapTime: 0:00:00.123024 FixedProfit: 1033262 TradeTimes: 141 TradeWin: 81
# Episode: 20/25 RapTime: 0:00:00.128835 FixedProfit: 1033262 TradeTimes: 141 TradeWin: 81
# Episode: 20/25 RapTime: 0:00:00.126101 FixedProfit: 1033262 TradeTimes: 141 TradeWin: 81
# Episode: 21/25 RapTime: 0:00:00.136081 FixedProfit: 1435500 TradeTimes: 139 TradeWin: 87
# Episode: 21/25 RapTime: 0:00:00.133520 FixedProfit: 1435500 TradeTimes: 139 TradeWin: 87
# Episode: 21/25 RapTime: 0:00:00.126447 FixedProfit: 1435500 TradeTimes: 139 TradeWin: 87
# Episode: 21/25 RapTime: 0:00:00.129126 FixedProfit: 1435500 TradeTimes: 139 TradeWin: 87
# Episode: 22/25 RapTime: 0:00:00.135360 FixedProfit: 1154814 TradeTimes: 147 TradeWin: 91
# Episode: 22/25 RapTime: 0:00:00.124790 FixedProfit: 1154814 TradeTimes: 147 TradeWin: 91
# Episode: 22/25 RapTime: 0:00:00.123148 FixedProfit: 1154814 TradeTimes: 147 TradeWin: 91
# Episode: 22/25 RapTime: 0:00:00.130012 FixedProfit: 1154814 TradeTimes: 147 TradeWin: 91
# Episode: 23/25 RapTime: 0:00:00.121133 FixedProfit: 1466591 TradeTimes: 135 TradeWin: 84
# Episode: 23/25 RapTime: 0:00:00.123806 FixedProfit: 1466591 TradeTimes: 135 TradeWin: 84
# Episode: 23/25 RapTime: 0:00:00.120875 FixedProfit: 1466591 TradeTimes: 135 TradeWin: 84
# Episode: 23/25 RapTime: 0:00:00.116594 FixedProfit: 1466591 TradeTimes: 135 TradeWin: 84
# Episode: 24/25 RapTime: 0:00:00.125469 FixedProfit: 767357 TradeTimes: 157 TradeWin: 89
# Episode: 24/25 RapTime: 0:00:00.129436 FixedProfit: 767357 TradeTimes: 157 TradeWin: 89
# Episode: 24/25 RapTime: 0:00:00.119939 FixedProfit: 767357 TradeTimes: 157 TradeWin: 89
# Episode: 24/25 RapTime: 0:00:00.127721 FixedProfit: 767357 TradeTimes: 157 TradeWin: 89
# Episode: 25/25 RapTime: 0:00:00.117041 FixedProfit: 1095346 TradeTimes: 144 TradeWin: 78
# Episode: 25/25 RapTime: 0:00:00.125845 FixedProfit: 1095346 TradeTimes: 144 TradeWin: 78
# Episode: 25/25 RapTime: 0:00:00.097920 FixedProfit: 1095346 TradeTimes: 144 TradeWin: 78
# Episode: 25/25 RapTime: 0:00:00.103538 FixedProfit: 1095346 TradeTimes: 144 TradeWin: 78
