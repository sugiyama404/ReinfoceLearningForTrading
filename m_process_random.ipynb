# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_process_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from multiprocessing import Process

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_process_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Mounted at /content/drive/

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):

    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
    
        while not done:
            action = random.randrange(3)
            state, reward, done, info = env.step(action)
        
        play_time = datetime.now() - start_time
        if mode == 'test':
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                print(row, file=f)
        else:
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
            with open(csv_path, 'a') as f:
                row = str(info['cur_revenue'])
                print(row, file=f)

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'

if mode == 'test':
    with open(csv_path, 'w') as f:
        row = 'FixedProfit,TradeTimes,TradeWin'
        print(row, file=f)
else:
    with open(csv_path, 'w') as f:
        row = 'FixedProfit'
        print(row, file=f)


envs = []
for i in range(4):
    e = Environment(df, initial_money=initial_money,mode = mode)
    envs.append(e)

worker = []
for env in envs:
    p = Process(target=play_game, args=(env,))
    worker.append(p)
    p.start()

for w in worker:
    w.join()
# Out:
# Episode: 1/25 RapTime: 0:00:00.052903 FixedProfit: 1128889 TradeTimes: 155 TradeWin: 90
# Episode: 1/25 RapTime: 0:00:00.070666 FixedProfit: 1379632 TradeTimes: 146 TradeWin: 85
# Episode: 1/25 RapTime: 0:00:00.073606 FixedProfit: 1310651 TradeTimes: 153 TradeWin: 92
# Episode: 2/25 RapTime: 0:00:00.066954 FixedProfit: 1151792 TradeTimes: 137 TradeWin: 84
# Episode: 1/25 RapTime: 0:00:00.097614 FixedProfit: 1163923 TradeTimes: 150 TradeWin: 93
# Episode: 2/25 RapTime: 0:00:00.066205 FixedProfit: 1313354 TradeTimes: 146 TradeWin: 99
# Episode: 2/25 RapTime: 0:00:00.065867 FixedProfit: 1302285 TradeTimes: 145 TradeWin: 92
# Episode: 3/25 RapTime: 0:00:00.071509 FixedProfit: 1241065 TradeTimes: 149 TradeWin: 93
# Episode: 2/25 RapTime: 0:00:00.083202 FixedProfit: 1104185 TradeTimes: 149 TradeWin: 91
# Episode: 3/25 RapTime: 0:00:00.060916 FixedProfit: 942255 TradeTimes: 148 TradeWin: 88
# Episode: 3/25 RapTime: 0:00:00.071926 FixedProfit: 1170227 TradeTimes: 145 TradeWin: 90
# Episode: 4/25 RapTime: 0:00:00.071213 FixedProfit: 1036294 TradeTimes: 141 TradeWin: 86
# Episode: 3/25 RapTime: 0:00:00.065091 FixedProfit: 1183642 TradeTimes: 139 TradeWin: 85
# Episode: 4/25 RapTime: 0:00:00.070725 FixedProfit: 1140880 TradeTimes: 155 TradeWin: 97
# Episode: 4/25 RapTime: 0:00:00.063746 FixedProfit: 912585 TradeTimes: 142 TradeWin: 80
# Episode: 5/25 RapTime: 0:00:00.055912 FixedProfit: 1045542 TradeTimes: 145 TradeWin: 81
# Episode: 4/25 RapTime: 0:00:00.062568 FixedProfit: 1440866 TradeTimes: 140 TradeWin: 89
# Episode: 5/25 RapTime: 0:00:00.070457 FixedProfit: 1090518 TradeTimes: 156 TradeWin: 99
# Episode: 5/25 RapTime: 0:00:00.066552 FixedProfit: 932391 TradeTimes: 159 TradeWin: 94
# Episode: 6/25 RapTime: 0:00:00.081002 FixedProfit: 1228657 TradeTimes: 155 TradeWin: 100
# Episode: 5/25 RapTime: 0:00:00.076303 FixedProfit: 1231355 TradeTimes: 140 TradeWin: 85
# Episode: 6/25 RapTime: 0:00:00.076042 FixedProfit: 1604952 TradeTimes: 149 TradeWin: 96
# Episode: 6/25 RapTime: 0:00:00.079339 FixedProfit: 1136644 TradeTimes: 147 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.078062 FixedProfit: 1003411 TradeTimes: 167 TradeWin: 102
# Episode: 6/25 RapTime: 0:00:00.072093 FixedProfit: 874075 TradeTimes: 154 TradeWin: 88
# Episode: 7/25 RapTime: 0:00:00.058752 FixedProfit: 1500661 TradeTimes: 157 TradeWin: 94
# Episode: 7/25 RapTime: 0:00:00.071000 FixedProfit: 1531092 TradeTimes: 144 TradeWin: 93
# Episode: 8/25 RapTime: 0:00:00.069173 FixedProfit: 1101120 TradeTimes: 148 TradeWin: 89
# Episode: 7/25 RapTime: 0:00:00.074143 FixedProfit: 1343414 TradeTimes: 153 TradeWin: 96
# Episode: 8/25 RapTime: 0:00:00.071305 FixedProfit: 1221504 TradeTimes: 143 TradeWin: 82
# Episode: 8/25 RapTime: 0:00:00.072177 FixedProfit: 1346781 TradeTimes: 150 TradeWin: 99
# Episode: 9/25 RapTime: 0:00:00.071911 FixedProfit: 1448118 TradeTimes: 145 TradeWin: 90
# Episode: 8/25 RapTime: 0:00:00.070296 FixedProfit: 1110393 TradeTimes: 156 TradeWin: 96
# Episode: 9/25 RapTime: 0:00:00.072124 FixedProfit: 966103 TradeTimes: 138 TradeWin: 80
# Episode: 9/25 RapTime: 0:00:00.067704 FixedProfit: 953831 TradeTimes: 148 TradeWin: 89
# Episode: 10/25 RapTime: 0:00:00.075147 FixedProfit: 1273006 TradeTimes: 145 TradeWin: 94
# Episode: 9/25 RapTime: 0:00:00.074536 FixedProfit: 1386440 TradeTimes: 146 TradeWin: 91
# Episode: 10/25 RapTime: 0:00:00.069478 FixedProfit: 1466070 TradeTimes: 138 TradeWin: 86
# Episode: 10/25 RapTime: 0:00:00.068442 FixedProfit: 1184928 TradeTimes: 137 TradeWin: 86
# Episode: 11/25 RapTime: 0:00:00.082662 FixedProfit: 1437190 TradeTimes: 158 TradeWin: 107
# Episode: 10/25 RapTime: 0:00:00.075047 FixedProfit: 1302669 TradeTimes: 164 TradeWin: 101
# Episode: 11/25 RapTime: 0:00:00.081825 FixedProfit: 1397047 TradeTimes: 165 TradeWin: 104
# Episode: 11/25 RapTime: 0:00:00.080202 FixedProfit: 1076380 TradeTimes: 155 TradeWin: 92
# Episode: 12/25 RapTime: 0:00:00.068421 FixedProfit: 850412 TradeTimes: 144 TradeWin: 84
# Episode: 11/25 RapTime: 0:00:00.078394 FixedProfit: 1255126 TradeTimes: 143 TradeWin: 83
# Episode: 12/25 RapTime: 0:00:00.084827 FixedProfit: 1225031 TradeTimes: 151 TradeWin: 95
# Episode: 12/25 RapTime: 0:00:00.077511 FixedProfit: 1304503 TradeTimes: 136 TradeWin: 86
# Episode: 13/25 RapTime: 0:00:00.071800 FixedProfit: 1174203 TradeTimes: 156 TradeWin: 82
# Episode: 12/25 RapTime: 0:00:00.073341 FixedProfit: 1138346 TradeTimes: 145 TradeWin: 81
# Episode: 13/25 RapTime: 0:00:00.073014 FixedProfit: 1269735 TradeTimes: 146 TradeWin: 88
# Episode: 13/25 RapTime: 0:00:00.084977 FixedProfit: 1341065 TradeTimes: 145 TradeWin: 90
# Episode: 14/25 RapTime: 0:00:00.079292 FixedProfit: 1229974 TradeTimes: 144 TradeWin: 89
# Episode: 13/25 RapTime: 0:00:00.070623 FixedProfit: 898363 TradeTimes: 156 TradeWin: 93
# Episode: 14/25 RapTime: 0:00:00.064949 FixedProfit: 1106706 TradeTimes: 142 TradeWin: 80
# Episode: 14/25 RapTime: 0:00:00.078186 FixedProfit: 949069 TradeTimes: 142 TradeWin: 91
# Episode: 15/25 RapTime: 0:00:00.079754 FixedProfit: 1406842 TradeTimes: 149 TradeWin: 92
# Episode: 14/25 RapTime: 0:00:00.078635 FixedProfit: 1802591 TradeTimes: 145 TradeWin: 92
# Episode: 15/25 RapTime: 0:00:00.067426 FixedProfit: 762624 TradeTimes: 134 TradeWin: 84
# Episode: 15/25 RapTime: 0:00:00.075358 FixedProfit: 1164667 TradeTimes: 138 TradeWin: 88
# Episode: 16/25 RapTime: 0:00:00.079607 FixedProfit: 1327736 TradeTimes: 159 TradeWin: 100
# Episode: 16/25 RapTime: 0:00:00.080590 FixedProfit: 1381681 TradeTimes: 152 TradeWin: 96
# Episode: 15/25 RapTime: 0:00:00.079566 FixedProfit: 1116714 TradeTimes: 158 TradeWin: 91
# Episode: 16/25 RapTime: 0:00:00.070588 FixedProfit: 1402708 TradeTimes: 146 TradeWin: 84
# Episode: 17/25 RapTime: 0:00:00.073365 FixedProfit: 1249414 TradeTimes: 145 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.081930 FixedProfit: 1630363 TradeTimes: 155 TradeWin: 106
# Episode: 16/25 RapTime: 0:00:00.078714 FixedProfit: 997558 TradeTimes: 153 TradeWin: 91
# Episode: 17/25 RapTime: 0:00:00.074445 FixedProfit: 882674 TradeTimes: 163 TradeWin: 98
# Episode: 18/25 RapTime: 0:00:00.077189 FixedProfit: 1443783 TradeTimes: 145 TradeWin: 90
# Episode: 17/25 RapTime: 0:00:00.066760 FixedProfit: 1035485 TradeTimes: 138 TradeWin: 84
# Episode: 18/25 RapTime: 0:00:00.097868 FixedProfit: 1813971 TradeTimes: 171 TradeWin: 105
# Episode: 18/25 RapTime: 0:00:00.078661 FixedProfit: 1152934 TradeTimes: 150 TradeWin: 102
# Episode: 19/25 RapTime: 0:00:00.074422 FixedProfit: 1552042 TradeTimes: 146 TradeWin: 97
# Episode: 18/25 RapTime: 0:00:00.094530 FixedProfit: 1054741 TradeTimes: 154 TradeWin: 97
# Episode: 19/25 RapTime: 0:00:00.074354 FixedProfit: 1051183 TradeTimes: 155 TradeWin: 93
# Episode: 19/25 RapTime: 0:00:00.081622 FixedProfit: 1348838 TradeTimes: 149 TradeWin: 88
# Episode: 20/25 RapTime: 0:00:00.074047 FixedProfit: 1416598 TradeTimes: 142 TradeWin: 91
# Episode: 19/25 RapTime: 0:00:00.071754 FixedProfit: 1297074 TradeTimes: 147 TradeWin: 95
# Episode: 20/25 RapTime: 0:00:00.090970 FixedProfit: 1392766 TradeTimes: 158 TradeWin: 101
# Episode: 20/25 RapTime: 0:00:00.072452 FixedProfit: 943714 TradeTimes: 152 TradeWin: 93
# Episode: 20/25 RapTime: 0:00:00.072789 FixedProfit: 1180195 TradeTimes: 146 TradeWin: 89
# Episode: 21/25 RapTime: 0:00:00.083084 FixedProfit: 1246685 TradeTimes: 152 TradeWin: 91
# Episode: 21/25 RapTime: 0:00:00.067697 FixedProfit: 742363 TradeTimes: 148 TradeWin: 82
# Episode: 21/25 RapTime: 0:00:00.077397 FixedProfit: 1551269 TradeTimes: 146 TradeWin: 93
# Episode: 21/25 RapTime: 0:00:00.071744 FixedProfit: 1111785 TradeTimes: 146 TradeWin: 87
# Episode: 22/25 RapTime: 0:00:00.090637 FixedProfit: 1341119 TradeTimes: 160 TradeWin: 108
# Episode: 22/25 RapTime: 0:00:00.074598 FixedProfit: 1433964 TradeTimes: 136 TradeWin: 87
# Episode: 22/25 RapTime: 0:00:00.073332 FixedProfit: 897698 TradeTimes: 148 TradeWin: 85
# Episode: 22/25 RapTime: 0:00:00.060748 FixedProfit: 1048480 TradeTimes: 140 TradeWin: 87
# Episode: 23/25 RapTime: 0:00:00.077478 FixedProfit: 1628588 TradeTimes: 147 TradeWin: 101
# Episode: 23/25 RapTime: 0:00:00.080775 FixedProfit: 934336 TradeTimes: 157 TradeWin: 89
# Episode: 23/25 RapTime: 0:00:00.078702 FixedProfit: 1137563 TradeTimes: 140 TradeWin: 80
# Episode: 23/25 RapTime: 0:00:00.077570 FixedProfit: 1571066 TradeTimes: 143 TradeWin: 95
# Episode: 24/25 RapTime: 0:00:00.074225 FixedProfit: 1011732 TradeTimes: 146 TradeWin: 89
# Episode: 24/25 RapTime: 0:00:00.075751 FixedProfit: 1339776 TradeTimes: 157 TradeWin: 103
# Episode: 24/25 RapTime: 0:00:00.075460 FixedProfit: 1232493 TradeTimes: 146 TradeWin: 87
# Episode: 24/25 RapTime: 0:00:00.082077 FixedProfit: 1458007 TradeTimes: 134 TradeWin: 86
# Episode: 25/25 RapTime: 0:00:00.067103 FixedProfit: 1313422 TradeTimes: 141 TradeWin: 80
# Episode: 25/25 RapTime: 0:00:00.062138 FixedProfit: 1151047 TradeTimes: 138 TradeWin: 82
# Episode: 25/25 RapTime: 0:00:00.073560 FixedProfit: 1077420 TradeTimes: 146 TradeWin: 86
# Episode: 25/25 RapTime: 0:00:00.057446 FixedProfit: 1255481 TradeTimes: 158 TradeWin: 97
