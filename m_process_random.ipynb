# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_process_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from multiprocessing import Process

mode = 'test'
name = 'm_process_random'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=1000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2])
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.now_step        = 0
        self.end_step        = self.df_total_steps
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()

        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }


        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand

        return state

    def _get_revenue(self):
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):

        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
        else:
            if self.action_space[0] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1 
            if self.action_space[2] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False

# %%
class Main:
    def __init__(self, env, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.episodes_times = episodes_times
        self.mode = mode

        if self.mode == 'test':
            with open(csv_path, 'w') as f:
                row = 'FixedProfit,TradeTimes,TradeWin'
                print(row, file=f)
        else:
            with open(csv_path, 'w') as f:
                row = 'FixedProfit'
                print(row, file=f)

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            done = False
            start_time = datetime.now()
        
            while not done:
                action = random.randrange(3)
                state, reward, done, info = self.env.step(action)
            
            play_time = datetime.now() - start_time
            if self.mode == 'test':
                print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                    print(row, file=f)
            else:
                print(f"Episode: {episode + 1}/{self.episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue'])
                    print(row, file=f)

# %%
initial_money  = 1000000
episodes_times = 25

envs = []
for i in range(4):
    env  = Environment(df, initial_money=initial_money,mode = mode)
    main = Main(env, episodes_times, mode)
    envs.append(main)

worker = []
for env in envs:
    p = Process(target=env.play_game)
    worker.append(p)
    p.start()

for w in worker:
    w.join()
# Out:
# Episode: 1/25 RapTime: 0:00:00.058214 FixedProfit: 999072 TradeTimes: 153 TradeWin: 85
# Episode: 1/25 RapTime: 0:00:00.070950 FixedProfit: 1471790 TradeTimes: 145 TradeWin: 90
# Episode: 1/25 RapTime: 0:00:00.075579 FixedProfit: 1054103 TradeTimes: 150 TradeWin: 93
# Episode: 1/25 RapTime: 0:00:00.073610 FixedProfit: 1689535 TradeTimes: 146 TradeWin: 84
# Episode: 2/25 RapTime: 0:00:00.072827 FixedProfit: 1459308 TradeTimes: 162 TradeWin: 103
# Episode: 2/25 RapTime: 0:00:00.068259 FixedProfit: 851706 TradeTimes: 140 TradeWin: 82
# Episode: 2/25 RapTime: 0:00:00.074844 FixedProfit: 1498193 TradeTimes: 146 TradeWin: 95
# Episode: 2/25 RapTime: 0:00:00.077759 FixedProfit: 1255050 TradeTimes: 148 TradeWin: 92
# Episode: 3/25 RapTime: 0:00:00.070957 FixedProfit: 934226 TradeTimes: 147 TradeWin: 85
# Episode: 3/25 RapTime: 0:00:00.074140 FixedProfit: 1062181 TradeTimes: 148 TradeWin: 89
# Episode: 3/25 RapTime: 0:00:00.062899 FixedProfit: 940755 TradeTimes: 142 TradeWin: 91
# Episode: 3/25 RapTime: 0:00:00.072975 FixedProfit: 1324067 TradeTimes: 158 TradeWin: 96
# Episode: 4/25 RapTime: 0:00:00.067945 FixedProfit: 1257039 TradeTimes: 150 TradeWin: 92
# Episode: 4/25 RapTime: 0:00:00.069991 FixedProfit: 1421310 TradeTimes: 131 TradeWin: 91
# Episode: 4/25 RapTime: 0:00:00.068300 FixedProfit: 1110764 TradeTimes: 140 TradeWin: 90
# Episode: 4/25 RapTime: 0:00:00.069130 FixedProfit: 1285448 TradeTimes: 150 TradeWin: 92
# Episode: 5/25 RapTime: 0:00:00.070843 FixedProfit: 1361359 TradeTimes: 147 TradeWin: 90
# Episode: 5/25 RapTime: 0:00:00.068074 FixedProfit: 1101268 TradeTimes: 153 TradeWin: 91
# Episode: 5/25 RapTime: 0:00:00.071386 FixedProfit: 1156357 TradeTimes: 156 TradeWin: 88
# Episode: 5/25 RapTime: 0:00:00.071838 FixedProfit: 903923 TradeTimes: 159 TradeWin: 92
# Episode: 6/25 RapTime: 0:00:00.072525 FixedProfit: 1279918 TradeTimes: 145 TradeWin: 94
# Episode: 6/25 RapTime: 0:00:00.072519 FixedProfit: 1239738 TradeTimes: 146 TradeWin: 94
# Episode: 6/25 RapTime: 0:00:00.071213 FixedProfit: 1338926 TradeTimes: 145 TradeWin: 89
# Episode: 6/25 RapTime: 0:00:00.073653 FixedProfit: 980071 TradeTimes: 147 TradeWin: 82
# Episode: 7/25 RapTime: 0:00:00.067315 FixedProfit: 1252539 TradeTimes: 146 TradeWin: 88
# Episode: 7/25 RapTime: 0:00:00.072608 FixedProfit: 1681771 TradeTimes: 147 TradeWin: 91
# Episode: 7/25 RapTime: 0:00:00.066265 FixedProfit: 1029457 TradeTimes: 148 TradeWin: 92
# Episode: 7/25 RapTime: 0:00:00.085099 FixedProfit: 1831173 TradeTimes: 150 TradeWin: 98
# Episode: 8/25 RapTime: 0:00:00.074182 FixedProfit: 1668083 TradeTimes: 138 TradeWin: 92
# Episode: 8/25 RapTime: 0:00:00.068011 FixedProfit: 1115330 TradeTimes: 137 TradeWin: 75
# Episode: 8/25 RapTime: 0:00:00.069650 FixedProfit: 1384449 TradeTimes: 145 TradeWin: 88
# Episode: 8/25 RapTime: 0:00:00.066847 FixedProfit: 976923 TradeTimes: 132 TradeWin: 76
# Episode: 9/25 RapTime: 0:00:00.076635 FixedProfit: 1604719 TradeTimes: 142 TradeWin: 87
# Episode: 9/25 RapTime: 0:00:00.063756 FixedProfit: 1164346 TradeTimes: 152 TradeWin: 94
# Episode: 9/25 RapTime: 0:00:00.070965 FixedProfit: 1401406 TradeTimes: 146 TradeWin: 91
# Episode: 9/25 RapTime: 0:00:00.072931 FixedProfit: 1564916 TradeTimes: 141 TradeWin: 92
# Episode: 10/25 RapTime: 0:00:00.075024 FixedProfit: 1233912 TradeTimes: 152 TradeWin: 90
# Episode: 10/25 RapTime: 0:00:00.068694 FixedProfit: 932957 TradeTimes: 146 TradeWin: 81
# Episode: 10/25 RapTime: 0:00:00.081191 FixedProfit: 1730143 TradeTimes: 152 TradeWin: 99
# Episode: 10/25 RapTime: 0:00:00.083737 FixedProfit: 1131211 TradeTimes: 159 TradeWin: 97
# Episode: 11/25 RapTime: 0:00:00.065221 FixedProfit: 1162596 TradeTimes: 146 TradeWin: 89
# Episode: 11/25 RapTime: 0:00:00.067673 FixedProfit: 918179 TradeTimes: 149 TradeWin: 90
# Episode: 11/25 RapTime: 0:00:00.071893 FixedProfit: 1579614 TradeTimes: 136 TradeWin: 84
# Episode: 11/25 RapTime: 0:00:00.071644 FixedProfit: 1001302 TradeTimes: 137 TradeWin: 79
# Episode: 12/25 RapTime: 0:00:00.071515 FixedProfit: 1553147 TradeTimes: 150 TradeWin: 100
# Episode: 12/25 RapTime: 0:00:00.077002 FixedProfit: 952983 TradeTimes: 160 TradeWin: 99
# Episode: 12/25 RapTime: 0:00:00.068040 FixedProfit: 983964 TradeTimes: 141 TradeWin: 81
# Episode: 12/25 RapTime: 0:00:00.068725 FixedProfit: 1022283 TradeTimes: 155 TradeWin: 94
# Episode: 13/25 RapTime: 0:00:00.068432 FixedProfit: 1172330 TradeTimes: 142 TradeWin: 82
# Episode: 13/25 RapTime: 0:00:00.068231 FixedProfit: 1618972 TradeTimes: 132 TradeWin: 87
# Episode: 13/25 RapTime: 0:00:00.067710 FixedProfit: 1020972 TradeTimes: 142 TradeWin: 86
# Episode: 13/25 RapTime: 0:00:00.067790 FixedProfit: 1159985 TradeTimes: 136 TradeWin: 83
# Episode: 14/25 RapTime: 0:00:00.070495 FixedProfit: 1555617 TradeTimes: 144 TradeWin: 83
# Episode: 14/25 RapTime: 0:00:00.064645 FixedProfit: 1406439 TradeTimes: 125 TradeWin: 79
# Episode: 14/25 RapTime: 0:00:00.063180 FixedProfit: 911043 TradeTimes: 141 TradeWin: 84
# Episode: 14/25 RapTime: 0:00:00.073088 FixedProfit: 1314284 TradeTimes: 149 TradeWin: 89
# Episode: 15/25 RapTime: 0:00:00.073457 FixedProfit: 1647054 TradeTimes: 140 TradeWin: 96
# Episode: 15/25 RapTime: 0:00:00.072830 FixedProfit: 1428332 TradeTimes: 144 TradeWin: 86
# Episode: 15/25 RapTime: 0:00:00.070703 FixedProfit: 1339059 TradeTimes: 148 TradeWin: 91
# Episode: 15/25 RapTime: 0:00:00.081817 FixedProfit: 1296471 TradeTimes: 143 TradeWin: 90
# Episode: 16/25 RapTime: 0:00:00.075833 FixedProfit: 1067528 TradeTimes: 152 TradeWin: 82
# Episode: 16/25 RapTime: 0:00:00.065754 FixedProfit: 1250417 TradeTimes: 145 TradeWin: 89
# Episode: 16/25 RapTime: 0:00:00.083856 FixedProfit: 1762276 TradeTimes: 144 TradeWin: 90
# Episode: 16/25 RapTime: 0:00:00.067030 FixedProfit: 937631 TradeTimes: 153 TradeWin: 91
# Episode: 17/25 RapTime: 0:00:00.075205 FixedProfit: 1022645 TradeTimes: 141 TradeWin: 77
# Episode: 17/25 RapTime: 0:00:00.067422 FixedProfit: 1486695 TradeTimes: 145 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.069389 FixedProfit: 1319668 TradeTimes: 154 TradeWin: 95
# Episode: 17/25 RapTime: 0:00:00.071015 FixedProfit: 991658 TradeTimes: 143 TradeWin: 86
# Episode: 18/25 RapTime: 0:00:00.073513 FixedProfit: 1332834 TradeTimes: 140 TradeWin: 88
# Episode: 18/25 RapTime: 0:00:00.075668 FixedProfit: 1316238 TradeTimes: 150 TradeWin: 90
# Episode: 18/25 RapTime: 0:00:00.066127 FixedProfit: 1123707 TradeTimes: 138 TradeWin: 79
# Episode: 18/25 RapTime: 0:00:00.073718 FixedProfit: 1091486 TradeTimes: 149 TradeWin: 88
# Episode: 19/25 RapTime: 0:00:00.078046 FixedProfit: 1256370 TradeTimes: 142 TradeWin: 83
# Episode: 19/25 RapTime: 0:00:00.076792 FixedProfit: 1678730 TradeTimes: 146 TradeWin: 91
# Episode: 19/25 RapTime: 0:00:00.070072 FixedProfit: 1172273 TradeTimes: 143 TradeWin: 80
# Episode: 19/25 RapTime: 0:00:00.072258 FixedProfit: 1151433 TradeTimes: 152 TradeWin: 96
# Episode: 20/25 RapTime: 0:00:00.067656 FixedProfit: 1228684 TradeTimes: 136 TradeWin: 86
# Episode: 20/25 RapTime: 0:00:00.062941 FixedProfit: 787828 TradeTimes: 150 TradeWin: 91
# Episode: 20/25 RapTime: 0:00:00.077245 FixedProfit: 1730832 TradeTimes: 148 TradeWin: 91
# Episode: 20/25 RapTime: 0:00:00.064724 FixedProfit: 1196802 TradeTimes: 137 TradeWin: 82
# Episode: 21/25 RapTime: 0:00:00.068975 FixedProfit: 1152871 TradeTimes: 150 TradeWin: 88
# Episode: 21/25 RapTime: 0:00:00.063774 FixedProfit: 1263487 TradeTimes: 141 TradeWin: 90
# Episode: 21/25 RapTime: 0:00:00.073452 FixedProfit: 1012461 TradeTimes: 150 TradeWin: 80
# Episode: 21/25 RapTime: 0:00:00.075501 FixedProfit: 1459342 TradeTimes: 148 TradeWin: 95
# Episode: 22/25 RapTime: 0:00:00.076436 FixedProfit: 975884 TradeTimes: 162 TradeWin: 100
# Episode: 22/25 RapTime: 0:00:00.075695 FixedProfit: 1446397 TradeTimes: 146 TradeWin: 90
# Episode: 22/25 RapTime: 0:00:00.068833 FixedProfit: 1139751 TradeTimes: 145 TradeWin: 92
# Episode: 22/25 RapTime: 0:00:00.065868 FixedProfit: 1160521 TradeTimes: 142 TradeWin: 91
# Episode: 23/25 RapTime: 0:00:00.080460 FixedProfit: 1359549 TradeTimes: 146 TradeWin: 91
# Episode: 23/25 RapTime: 0:00:00.067019 FixedProfit: 1456991 TradeTimes: 138 TradeWin: 82
# Episode: 23/25 RapTime: 0:00:00.076340 FixedProfit: 1434238 TradeTimes: 144 TradeWin: 88
# Episode: 23/25 RapTime: 0:00:00.081813 FixedProfit: 1976845 TradeTimes: 146 TradeWin: 101
# Episode: 24/25 RapTime: 0:00:00.081120 FixedProfit: 1469315 TradeTimes: 145 TradeWin: 93
# Episode: 24/25 RapTime: 0:00:00.064332 FixedProfit: 1077606 TradeTimes: 145 TradeWin: 80
# Episode: 24/25 RapTime: 0:00:00.074542 FixedProfit: 1451584 TradeTimes: 150 TradeWin: 102
# Episode: 24/25 RapTime: 0:00:00.073394 FixedProfit: 1818215 TradeTimes: 137 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.072562 FixedProfit: 1163195 TradeTimes: 147 TradeWin: 85
# Episode: 25/25 RapTime: 0:00:00.074742 FixedProfit: 1589430 TradeTimes: 136 TradeWin: 95
# Episode: 25/25 RapTime: 0:00:00.059467 FixedProfit: 889453 TradeTimes: 139 TradeWin: 82
# Episode: 25/25 RapTime: 0:00:00.058938 FixedProfit: 1033218 TradeTimes: 143 TradeWin: 77
