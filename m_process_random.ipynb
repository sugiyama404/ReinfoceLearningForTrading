# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/m_process_random.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random
from google.colab import drive
import copy

from datetime import datetime
from multiprocessing import Process

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + 'sp500_test.csv'
exp_dir = 'Colab Notebooks/workspace/export/'
csv_path = '/content/drive/My Drive/' + exp_dir + 'm_process_random_test.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()
        self.df_total_steps = len(self.df)-1
        self.initial_money = initial_money
        self.mode = mode
        self.trade_time = None
        self.trade_win = None
        self.brfore_buy_cash = None
        self.action_space = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price = None
        self.cash_in_hand = None

        self.reset()
        
    def reset(self):

        self.trade_time = 0
        self.trade_win = 0
        self.brfore_buy_cash = 0
        self.end_step = self.df_total_steps
        self.now_step = 0
        self.hold_a_position = 0.0
        self.now_price = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
def play_game(env, episodes_times = 25, mode = 'test'):
    '''
    if mode == 'test':
        df_rec = pd.DataFrame(index=[], columns=['FixedProfit','TradeTimes','TradeWin'])
    else:
        df_rec = pd.DataFrame(index=[], columns=['FixedProfit'])
    '''
    for episode in range(episodes_times):
        state = env.reset()
        done = False
        start_time = datetime.now()
       
        while not done:
            action = np.random.randint(3, size=1)[0]
            state, reward, done, info = env.step(action)
           
        play_time = datetime.now() - start_time
        if mode == 'test':
            # record = pd.Series([info['cur_revenue'],info['trade_time'],info['trade_win']], index=df_rec.columns)
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f} TradeTimes: {info['trade_time']} TradeWin: {info['trade_win']}")
        else:
            # record = pd.Series(info['cur_revenue'], index=df_rec.columns)
            print(f"Episode: {episode + 1}/{episodes_times} RapTime: {play_time} FixedProfit: {info['cur_revenue']:.0f}")
        # df_rec = df_rec.append(record, ignore_index=True)
    # return df_rec

# %%
initial_money=1000000
episodes_times = 25
mode = 'test'
env = Environment(df, initial_money=initial_money,mode = mode)

worker = []
for i in range(4):
    p = Process(target=play_game, args=(env,))
    worker.append(p)
    p.start()

for w in worker:
    w.join()

# df_rec = play_game(env, episodes_times = episodes_times, mode = mode)
# df_rec.to_csv(csv_path)
# Out:
# Episode: 1/25 RapTime: 0:00:00.107546 FixedProfit: 785663 TradeTimes: 150 TradeWin: 83
# Episode: 1/25 RapTime: 0:00:00.110775 FixedProfit: 785663 TradeTimes: 150 TradeWin: 83
# Episode: 1/25 RapTime: 0:00:00.112822 FixedProfit: 785663 TradeTimes: 150 TradeWin: 83
# Episode: 1/25 RapTime: 0:00:00.120975 FixedProfit: 785663 TradeTimes: 150 TradeWin: 83
# Episode: 2/25 RapTime: 0:00:00.115049 FixedProfit: 1124653 TradeTimes: 148 TradeWin: 88
# Episode: 2/25 RapTime: 0:00:00.115886 FixedProfit: 1124653 TradeTimes: 148 TradeWin: 88
# Episode: 2/25 RapTime: 0:00:00.117003 FixedProfit: 1124653 TradeTimes: 148 TradeWin: 88
# Episode: 2/25 RapTime: 0:00:00.132606 FixedProfit: 1124653 TradeTimes: 148 TradeWin: 88
# Episode: 3/25 RapTime: 0:00:00.118824 FixedProfit: 1315011 TradeTimes: 144 TradeWin: 80
# Episode: 3/25 RapTime: 0:00:00.120287 FixedProfit: 1315011 TradeTimes: 144 TradeWin: 80
# Episode: 3/25 RapTime: 0:00:00.126684 FixedProfit: 1315011 TradeTimes: 144 TradeWin: 80
# Episode: 3/25 RapTime: 0:00:00.132175 FixedProfit: 1315011 TradeTimes: 144 TradeWin: 80
# Episode: 4/25 RapTime: 0:00:00.127711 FixedProfit: 1031531 TradeTimes: 164 TradeWin: 101
# Episode: 4/25 RapTime: 0:00:00.130680 FixedProfit: 1031531 TradeTimes: 164 TradeWin: 101
# Episode: 4/25 RapTime: 0:00:00.146569 FixedProfit: 1031531 TradeTimes: 164 TradeWin: 101
# Episode: 4/25 RapTime: 0:00:00.131147 FixedProfit: 1031531 TradeTimes: 164 TradeWin: 101
# Episode: 5/25 RapTime: 0:00:00.131834 FixedProfit: 1244117 TradeTimes: 151 TradeWin: 95
# Episode: 5/25 RapTime: 0:00:00.128453 FixedProfit: 1244117 TradeTimes: 151 TradeWin: 95
# Episode: 5/25 RapTime: 0:00:00.163137 FixedProfit: 1244117 TradeTimes: 151 TradeWin: 95
# Episode: 5/25 RapTime: 0:00:00.137338 FixedProfit: 1244117 TradeTimes: 151 TradeWin: 95
# Episode: 6/25 RapTime: 0:00:00.129576 FixedProfit: 1031469 TradeTimes: 155 TradeWin: 93
# Episode: 6/25 RapTime: 0:00:00.135305 FixedProfit: 1031469 TradeTimes: 155 TradeWin: 93
# Episode: 6/25 RapTime: 0:00:00.135758 FixedProfit: 1031469 TradeTimes: 155 TradeWin: 93
# Episode: 6/25 RapTime: 0:00:00.141646 FixedProfit: 1031469 TradeTimes: 155 TradeWin: 93
# Episode: 7/25 RapTime: 0:00:00.124533 FixedProfit: 1294251 TradeTimes: 139 TradeWin: 89
# Episode: 7/25 RapTime: 0:00:00.129475 FixedProfit: 1294251 TradeTimes: 139 TradeWin: 89
# Episode: 7/25 RapTime: 0:00:00.118283 FixedProfit: 1294251 TradeTimes: 139 TradeWin: 89
# Episode: 7/25 RapTime: 0:00:00.137690 FixedProfit: 1294251 TradeTimes: 139 TradeWin: 89
# Episode: 8/25 RapTime: 0:00:00.126847 FixedProfit: 1169903 TradeTimes: 150 TradeWin: 83
# Episode: 8/25 RapTime: 0:00:00.133051 FixedProfit: 1169903 TradeTimes: 150 TradeWin: 83
# Episode: 8/25 RapTime: 0:00:00.125750 FixedProfit: 1169903 TradeTimes: 150 TradeWin: 83
# Episode: 9/25 RapTime: 0:00:00.122124 FixedProfit: 1048776 TradeTimes: 148 TradeWin: 83
# Episode: 8/25 RapTime: 0:00:00.132567 FixedProfit: 1169903 TradeTimes: 150 TradeWin: 83
# Episode: 9/25 RapTime: 0:00:00.126199 FixedProfit: 1048776 TradeTimes: 148 TradeWin: 83
# Episode: 9/25 RapTime: 0:00:00.123524 FixedProfit: 1048776 TradeTimes: 148 TradeWin: 83
# Episode: 10/25 RapTime: 0:00:00.127539 FixedProfit: 1427740 TradeTimes: 139 TradeWin: 85
# Episode: 9/25 RapTime: 0:00:00.131603 FixedProfit: 1048776 TradeTimes: 148 TradeWin: 83
# Episode: 10/25 RapTime: 0:00:00.134325 FixedProfit: 1427740 TradeTimes: 139 TradeWin: 85
# Episode: 10/25 RapTime: 0:00:00.125920 FixedProfit: 1427740 TradeTimes: 139 TradeWin: 85
# Episode: 11/25 RapTime: 0:00:00.131258 FixedProfit: 1246641 TradeTimes: 157 TradeWin: 92
# Episode: 10/25 RapTime: 0:00:00.127971 FixedProfit: 1427740 TradeTimes: 139 TradeWin: 85
# Episode: 11/25 RapTime: 0:00:00.134319 FixedProfit: 1246641 TradeTimes: 157 TradeWin: 92
# Episode: 11/25 RapTime: 0:00:00.122715 FixedProfit: 1246641 TradeTimes: 157 TradeWin: 92
# Episode: 12/25 RapTime: 0:00:00.123965 FixedProfit: 1168110 TradeTimes: 158 TradeWin: 94
# Episode: 11/25 RapTime: 0:00:00.136012 FixedProfit: 1246641 TradeTimes: 157 TradeWin: 92
# Episode: 12/25 RapTime: 0:00:00.126006 FixedProfit: 1168110 TradeTimes: 158 TradeWin: 94
# Episode: 12/25 RapTime: 0:00:00.123862 FixedProfit: 1168110 TradeTimes: 158 TradeWin: 94
# Episode: 13/25 RapTime: 0:00:00.122341 FixedProfit: 1069916 TradeTimes: 143 TradeWin: 86
# Episode: 12/25 RapTime: 0:00:00.140751 FixedProfit: 1168110 TradeTimes: 158 TradeWin: 94
# Episode: 13/25 RapTime: 0:00:00.125060 FixedProfit: 1069916 TradeTimes: 143 TradeWin: 86
# Episode: 13/25 RapTime: 0:00:00.120014 FixedProfit: 1069916 TradeTimes: 143 TradeWin: 86
# Episode: 14/25 RapTime: 0:00:00.121358 FixedProfit: 1172109 TradeTimes: 152 TradeWin: 82
# Episode: 13/25 RapTime: 0:00:00.124025 FixedProfit: 1069916 TradeTimes: 143 TradeWin: 86
# Episode: 14/25 RapTime: 0:00:00.126847 FixedProfit: 1172109 TradeTimes: 152 TradeWin: 82
# Episode: 14/25 RapTime: 0:00:00.121862 FixedProfit: 1172109 TradeTimes: 152 TradeWin: 82
# Episode: 15/25 RapTime: 0:00:00.125839 FixedProfit: 1788594 TradeTimes: 141 TradeWin: 94
# Episode: 14/25 RapTime: 0:00:00.128264 FixedProfit: 1172109 TradeTimes: 152 TradeWin: 82
# Episode: 15/25 RapTime: 0:00:00.129528 FixedProfit: 1788594 TradeTimes: 141 TradeWin: 94
# Episode: 15/25 RapTime: 0:00:00.135009 FixedProfit: 1788594 TradeTimes: 141 TradeWin: 94
# Episode: 16/25 RapTime: 0:00:00.126370 FixedProfit: 1317712 TradeTimes: 144 TradeWin: 88
# Episode: 15/25 RapTime: 0:00:00.134569 FixedProfit: 1788594 TradeTimes: 141 TradeWin: 94
# Episode: 16/25 RapTime: 0:00:00.125444 FixedProfit: 1317712 TradeTimes: 144 TradeWin: 88
# Episode: 16/25 RapTime: 0:00:00.130082 FixedProfit: 1317712 TradeTimes: 144 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.116486 FixedProfit: 1086631 TradeTimes: 144 TradeWin: 89
# Episode: 16/25 RapTime: 0:00:00.126658 FixedProfit: 1317712 TradeTimes: 144 TradeWin: 88
# Episode: 17/25 RapTime: 0:00:00.117540 FixedProfit: 1086631 TradeTimes: 144 TradeWin: 89
# Episode: 17/25 RapTime: 0:00:00.125065 FixedProfit: 1086631 TradeTimes: 144 TradeWin: 89
# Episode: 18/25 RapTime: 0:00:00.129315 FixedProfit: 1498987 TradeTimes: 159 TradeWin: 100
# Episode: 17/25 RapTime: 0:00:00.126939 FixedProfit: 1086631 TradeTimes: 144 TradeWin: 89
# Episode: 18/25 RapTime: 0:00:00.127760 FixedProfit: 1498987 TradeTimes: 159 TradeWin: 100
# Episode: 18/25 RapTime: 0:00:00.137113 FixedProfit: 1498987 TradeTimes: 159 TradeWin: 100
# Episode: 19/25 RapTime: 0:00:00.131959 FixedProfit: 1056688 TradeTimes: 144 TradeWin: 82
# Episode: 19/25 RapTime: 0:00:00.118043 FixedProfit: 1056688 TradeTimes: 144 TradeWin: 82
# Episode: 18/25 RapTime: 0:00:00.147842 FixedProfit: 1498987 TradeTimes: 159 TradeWin: 100
# Episode: 19/25 RapTime: 0:00:00.117967 FixedProfit: 1056688 TradeTimes: 144 TradeWin: 82
# Episode: 20/25 RapTime: 0:00:00.117561 FixedProfit: 975231 TradeTimes: 145 TradeWin: 95
# Episode: 20/25 RapTime: 0:00:00.113347 FixedProfit: 975231 TradeTimes: 145 TradeWin: 95
# Episode: 20/25 RapTime: 0:00:00.121537 FixedProfit: 975231 TradeTimes: 145 TradeWin: 95
# Episode: 19/25 RapTime: 0:00:00.135635 FixedProfit: 1056688 TradeTimes: 144 TradeWin: 82
# Episode: 21/25 RapTime: 0:00:00.142718 FixedProfit: 1302546 TradeTimes: 158 TradeWin: 93
# Episode: 21/25 RapTime: 0:00:00.137427 FixedProfit: 1302546 TradeTimes: 158 TradeWin: 93
# Episode: 20/25 RapTime: 0:00:00.130115 FixedProfit: 975231 TradeTimes: 145 TradeWin: 95
# Episode: 21/25 RapTime: 0:00:00.142618 FixedProfit: 1302546 TradeTimes: 158 TradeWin: 93
# Episode: 22/25 RapTime: 0:00:00.125828 FixedProfit: 1305002 TradeTimes: 149 TradeWin: 86
# Episode: 22/25 RapTime: 0:00:00.122027 FixedProfit: 1305002 TradeTimes: 149 TradeWin: 86
# Episode: 22/25 RapTime: 0:00:00.128265 FixedProfit: 1305002 TradeTimes: 149 TradeWin: 86
# Episode: 21/25 RapTime: 0:00:00.144783 FixedProfit: 1302546 TradeTimes: 158 TradeWin: 93
# Episode: 23/25 RapTime: 0:00:00.130828 FixedProfit: 1341430 TradeTimes: 143 TradeWin: 89
# Episode: 23/25 RapTime: 0:00:00.123712 FixedProfit: 1341430 TradeTimes: 143 TradeWin: 89
# Episode: 23/25 RapTime: 0:00:00.127204 FixedProfit: 1341430 TradeTimes: 143 TradeWin: 89
# Episode: 22/25 RapTime: 0:00:00.120001 FixedProfit: 1305002 TradeTimes: 149 TradeWin: 86
# Episode: 24/25 RapTime: 0:00:00.119191 FixedProfit: 1163881 TradeTimes: 138 TradeWin: 81
# Episode: 24/25 RapTime: 0:00:00.114418 FixedProfit: 1163881 TradeTimes: 138 TradeWin: 81
# Episode: 24/25 RapTime: 0:00:00.121077 FixedProfit: 1163881 TradeTimes: 138 TradeWin: 81
# Episode: 23/25 RapTime: 0:00:00.121279 FixedProfit: 1341430 TradeTimes: 143 TradeWin: 89
# Episode: 25/25 RapTime: 0:00:00.123077 FixedProfit: 1410949 TradeTimes: 142 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.126355 FixedProfit: 1410949 TradeTimes: 142 TradeWin: 92
# Episode: 24/25 RapTime: 0:00:00.095354 FixedProfit: 1163881 TradeTimes: 138 TradeWin: 81
# Episode: 25/25 RapTime: 0:00:00.112153 FixedProfit: 1410949 TradeTimes: 142 TradeWin: 92
# Episode: 25/25 RapTime: 0:00:00.073225 FixedProfit: 1410949 TradeTimes: 142 TradeWin: 92
