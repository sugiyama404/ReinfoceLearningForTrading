# %% [markdown]
# <a href="https://colab.research.google.com/github/sugiyama404/ReinfoceLearningForTrading/blob/main/ppo_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from datetime import datetime
import random
import copy
import pickle

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

import math

from google.colab import drive

from concurrent.futures import ThreadPoolExecutor

from dataclasses import dataclass, field
from typing import List

mode = 'train'
name = 'ppo'

drive.mount('/content/drive/')
nov_dir = 'Colab Notebooks/dataset/reinforcement_learning/'
nov_path = '/content/drive/My Drive/' + nov_dir + f'sp500_{mode}.csv'

exp_dir = 'Colab Notebooks/workspace/export/'
mdl_dir = '/content/drive/My Drive/' + exp_dir + 'models'
csv_path = '/content/drive/My Drive/' + exp_dir + f'csv_data/{name}_{mode}.csv'

df = pd.read_csv(nov_path)
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
class Environment:
    def __init__(self, df, initial_money=100000, mode = 'test'):

        self.df = df.dropna().reset_index()

        self.df_total_steps  = len(self.df)-1
        self.initial_money   = initial_money
        self.mode            = mode
        self.trade_time      = None
        self.trade_win       = None
        self.brfore_buy_cash = None
        self.action_space    = np.array([0, 1, 2]) # buy,hold,sell
        self.hold_a_position = None
        self.now_price       = None
        self.cash_in_hand    = None

        self.reset()
        
    def reset(self):

        self.trade_time      = 0
        self.trade_win       = 0
        self.brfore_buy_cash = 0
        self.end_step        = self.df_total_steps
        self.now_step        = 0
        self.hold_a_position = 0.0
        self.now_price       = self.df.loc[self.now_step, 'SP500']
        self.cash_in_hand    = self.initial_money

        return self._get_now_state()

    def step(self, action):

        prev_revenue = self._get_revenue()
        self.now_step += 1
        self.now_price = self.df.loc[self.now_step, 'SP500']
 
        done = (self.end_step == self.now_step)

        self._trade(action,done)
        cur_revenue = self._get_revenue()
 
        reward = cur_revenue - prev_revenue

        if self.mode == 'test':
            info = { 'cur_revenue' : cur_revenue , 'trade_time' : self.trade_time, 'trade_win' : self.trade_win }
        else:
            info = { 'cur_revenue' : cur_revenue }

        return self._get_now_state(), reward, done, info

    def _get_now_state(self):
        state = np.empty(3)
        state[0] = self.hold_a_position
        state[1] = self.now_price
        state[2] = self.cash_in_hand
        return state

    def _get_revenue(self): 
        return self.hold_a_position * self.now_price + self.cash_in_hand

    def _trade(self, action,lastorder = False):
        if lastorder:
            self.cash_in_hand += self.now_price * self.hold_a_position
            self.hold_a_position = 0
            if self.mode == 'test':
                self.trade_time += 1
                if self.cash_in_hand > self.brfore_buy_cash:
                    self.trade_win += 1
        else:
            if self.action_space[0] == action: # buy
                if self.hold_a_position == 0:
                    buy_flag = True
                    if self.mode == 'test':
                        self.brfore_buy_cash = copy.copy(self.cash_in_hand)
                    while buy_flag:
                        if self.cash_in_hand > self.now_price:
                            self.hold_a_position += 1
                            self.cash_in_hand -= self.now_price
                        else:
                            buy_flag = False
            if self.action_space[2] == action: # sell
                if self.hold_a_position != 0:
                    self.cash_in_hand += self.now_price * self.hold_a_position
                    self.hold_a_position = 0
                    if self.mode == 'test':
                        self.trade_time += 1
                        if self.cash_in_hand > self.brfore_buy_cash:
                            self.trade_win += 1

# %%
class ParameterServer:
    def __init__(self):

        n_shape = 3
        lr = 0.01

        common = input_ = keras.layers.Input(shape=n_shape)
        common = keras.layers.Dense(128, activation="relu")(common)

        actor = keras.layers.Dense(3, activation="softmax")(common)
        critic = keras.layers.Dense(1, activation="linear")(common)

        model = keras.Model(input_, [actor, critic])
        model.compile(optimizer=Adam(lr=lr))
        model.summary()
        self.model = model

    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
class Actor:
    def __init__(self, brain):
        self.model = brain.model
        self.brain = brain
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.r = 0.995

    def policynetwork(self, state):
        if np.random.rand() <= self.epsilon:
            self._reduce_epsilon()
            return np.random.choice(3)
        act_p, _ = self.model(state.reshape((1,-1)))
        self._reduce_epsilon()
        return np.random.choice(3, p=act_p[0].numpy())

    def load(self, name):
        self.brain.load(name)

    def save(self, name):
        self.brain.save(name)

    def _reduce_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.r

# %%
class Critic:
    def __init__(self,model):
        self.model = model
        self.gamma = 0.9
        self.c_gamma = 0.1

        self.beta_1 = 0.1
        self.beta_2 = 0.1

    def valuenetwork(self, experiences):

        state_batch = np.asarray([e["state"] for e in experiences])
        action_batch = np.asarray([e["action"] for e in experiences])
        advantage = np.asarray([e["advantage"] for e in experiences]).reshape((-1, 1))
        prob_batch = np.asarray([e["prob"] for e in experiences])

        advantage = (advantage - np.mean(advantage)) / (np.std(advantage) + 1e-8)
        onehot_actions = tf.one_hot(action_batch, 3).numpy()

        old_pi = tf.reduce_sum(onehot_actions * prob_batch, axis=1, keepdims=True)

        with tf.GradientTape() as tape:
            act_p, v = self.model(state_batch, training=True)

            advantage = advantage - tf.stop_gradient(v)

            # π(a|s)とlog(π(a|s))を計算
            new_pi = tf.reduce_sum(onehot_actions * act_p, axis=1, keepdims=True)
            new_logpi = tf.math.log(tf.clip_by_value(new_pi, 1e-10, 1.0))

            r_t_batch = new_pi / old_pi

            losses_clip = self._losses_clip(advantage, r_t_batch)
            losses_value = self._losses_value(advantage)
            entropy = tf.reduce_sum(new_logpi * new_pi, axis=1, keepdims=True)

            total_loss = - losses_clip + self.beta_1 * losses_value - self.beta_2 * entropy
            loss = tf.reduce_mean(total_loss)

        # WARNING:tensorflow:Gradients do not exist for variables ['dense_2/kernel:0', 'dense_2/bias:0'] when minimizing the loss.
        # gradientsがnoneになる時がある。
        gradients = tape.gradient(loss, self.model.trainable_variables)
        # gradients, _ = tf.clip_by_global_norm(gradients, 0.5)
        # self.model.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))
        self.model.optimizer.apply_gradients((grad, var) for (grad, var) in 
                                             zip(gradients, self.model.trainable_variables) if grad is not None)

    def _losses_value(self,advantage):
        return (advantage)**2

    def _losses_clip(self, advantage, r_t):

        r_clip = tf.clip_by_value(r_t, 1 - self.c_gamma, 1 + self.c_gamma)

        loss_unclipped = r_t * advantage
        loss_clipped = r_clip * advantage

        return tf.minimum(loss_clipped, loss_clipped)

# %%
@dataclass
class ExperiencesMemory:
    state : List[List[float]] = field(default_factory=list)
    action : List[int] = field(default_factory=list)
    reward : List[float] = field(default_factory=list)
    next_state : List[List[int]] = field(default_factory=list)
    done : List[bool] = field(default_factory=list)
    prob_bol : List[bool] = field(default_factory=list)
    advantage : List[float] = field(default_factory=list)
    model : str = None
    gae_lambda: float = 0.9
    gamma: float = 0.9

    def append_experiences(self, state, action, reward, next_state, done):
        self.state.append(state)
        self.action.append(action)
        self.reward.append(reward)
        self.next_state.append(next_state)
        self.done.append(done)

    def random_experiences(self, batch_size):
        max_size = len(self.state) - 1
        self._make_advantage()
        batch_num = self._random_num(1, max_size, batch_size)
        experiences = []
        for i in batch_num:
            prob = self._probability(self.state[i])
            prob = prob.numpy()
            prob = prob[0]
            experiences.append({"state": self.state[i], "action": self.action[i], 
                                "reward": self.reward[i], "next_state": self.next_state[i], 
                                "done": self.done[i], "prob": prob, "advantage": self.advantage[i]})
        return experiences

    def _random_num(self, a, b, k):
        ns = []
        while len(ns) < k:
            n = random.randint(a, b)
            if not n in ns:
                ns.append(n)
        return ns

    def _make_advantage(self):

        state = np.asarray([e for e in self.state])
        next_state = np.asarray([e for e in self.next_state])
        v     = self._evaluation_value(state)
        v_old = self._evaluation_value(next_state)
        v     =v.numpy()
        v_old =v_old.numpy()

        for i in range(len(self.reward)):
            gae = 0
            t = 0
            for j in range(i, len(self.reward)):
                delta = self.reward[j] + self.gamma * v_old[j][0] - v[j][0]
                gae += ((self.gae_lambda * self.gamma) ** t) * delta
                t += 1
            self.advantage.append(gae)

    def _probability(self, state):
        p, _ = self.model(state.reshape((1,-1)))
        return p

    def _evaluation_value(self, state):
        _, v = self.model(state, training=True)
        return v

# %%
class Main:
    def __init__(self, env, actor, critic, num, mdl_dir, name, batch_size = 128, episodes_times = 1000, mode = 'test'):
        self.env = env
        self.actor = actor
        self.critic = critic
        self.num = str(num)
        self.mdl_dir = mdl_dir
        self.scaler = self._standard_scaler(self.env)
        self.episodes_times = episodes_times
        self.batch_size = batch_size
        self.mode = mode
        self.name = name

        if self.mode == 'test':
            self._load()
            self.actor.epsilon = 0.01
            with open(csv_path, 'w') as f:
                row = 'FixedProfit,TradeTimes,TradeWin'
                print(row, file=f)
        else:
            with open(csv_path, 'w') as f:
                row = 'FixedProfit'
                print(row, file=f)

    def play_game(self):

        for episode in range(self.episodes_times):
            state = self.env.reset()
            state = self.scaler.transform([state])
            state = state.flatten()
            done = False
            start_time = datetime.now()
            memory = ExperiencesMemory(model = self.actor.model)
    
            while not done:
                
                action     = self.actor.policynetwork(state)
                next_state, reward, done, info = self.env.step(action)
                next_state = self.scaler.transform([next_state])
                next_state = next_state.flatten()

                if self.mode == 'train':
                    memory.append_experiences(state, action, reward, next_state, done)

                state = next_state

            if self.mode == 'train':
                experiences = memory.random_experiences(self.batch_size)
                self.critic.valuenetwork(experiences)

            play_time = datetime.now() - start_time
            if self.mode == 'test':
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f} TradeTimes: {} TradeWin: {}"
                .format(episode + 1, episodes_times, play_time, info['cur_revenue'], 
                        info['trade_time'], info['trade_win']))
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue']) + ',' + str(info['trade_time']) + ',' + str(info['trade_win'])
                    print(row, file=f)
            else:
                print("Episode: {}/{} RapTime: {} FixedProfit: {:.0f}"
                .format(episode + 1, episodes_times, play_time, info['cur_revenue']))
                with open(csv_path, 'a') as f:
                    row = str(info['cur_revenue'])
                    print(row, file=f)

        if self.mode == 'train':
            self._save()

    def _standard_scaler(self, env):
        states = []
        for _ in range(env.df_total_steps):
            action = np.random.choice(env.action_space)
            state, reward, done, info = env.step(action)
            states.append(state)
            if done:
                break
        
        scaler = StandardScaler()
        scaler.fit(states)
        return scaler

    def _load(self):
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, self.num), 'rb') as f:
            self.scaler = pickle.load(f)
        self.actor.load('{}/{}.h5'.format(self.mdl_dir, self.name))

    def _save(self):
        self.actor.save('{}/{}.h5'.format(self.mdl_dir, self.name))
        with open('{}/{}_{}.pkl'.format(self.mdl_dir, self.name, self.num), 'wb') as f:
            pickle.dump(self.scaler, f)

# %%
initial_money=1000000
episodes_times = 100
batch_size = 128

brain = ParameterServer()

thread_num = 4
envs = []
for i in range(thread_num):
    env = Environment(df, initial_money=initial_money,mode = mode)
    model = brain.model
    actor = Actor(brain)
    critic = Critic(model)
    main = Main(env, actor, critic, i, mdl_dir, name, batch_size, episodes_times, mode)
    envs.append(main)

datas = []
with ThreadPoolExecutor(max_workers=thread_num) as executor:
    for env in envs:
        job = lambda: env.play_game()
        datas.append(executor.submit(job))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 3)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          512         input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 3)            387         dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            129         dense[0][0]
# ==================================================================================================
# Total params: 1,028
# Trainable params: 1,028
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Episode: 1/100 RapTime: 0:00:09.385515 FixedProfit: 1064009
# Episode: 1/100 RapTime: 0:00:09.504844 FixedProfit: 1070414
# Episode: 1/100 RapTime: 0:00:09.520269 FixedProfit: 1109173
# Episode: 1/100 RapTime: 0:00:09.694495 FixedProfit: 1091635
# Episode: 2/100 RapTime: 0:00:10.749493 FixedProfit: 1113391
# Episode: 2/100 RapTime: 0:00:10.723959 FixedProfit: 1069913
# Episode: 2/100 RapTime: 0:00:10.804220 FixedProfit: 1256168
# Episode: 2/100 RapTime: 0:00:10.740458 FixedProfit: 999210
# Episode: 3/100 RapTime: 0:00:10.797947 FixedProfit: 1161759
# Episode: 3/100 RapTime: 0:00:10.844688 FixedProfit: 1009593
# Episode: 3/100 RapTime: 0:00:10.785028 FixedProfit: 1044030
# Episode: 3/100 RapTime: 0:00:10.815378 FixedProfit: 1372767
# Episode: 4/100 RapTime: 0:00:10.861090 FixedProfit: 1071816
# Episode: 4/100 RapTime: 0:00:10.856422 FixedProfit: 1103850
# Episode: 4/100 RapTime: 0:00:10.864390 FixedProfit: 1208690
# Episode: 4/100 RapTime: 0:00:10.832003 FixedProfit: 1133634
# Episode: 5/100 RapTime: 0:00:10.795946 FixedProfit: 1052166
# Episode: 5/100 RapTime: 0:00:10.834650 FixedProfit: 1315002
# Episode: 5/100 RapTime: 0:00:10.833084 FixedProfit: 1100405
# Episode: 5/100 RapTime: 0:00:10.804245 FixedProfit: 1323523
# Episode: 6/100 RapTime: 0:00:10.815678 FixedProfit: 1262886
# Episode: 6/100 RapTime: 0:00:10.860066 FixedProfit: 1224643
# Episode: 6/100 RapTime: 0:00:10.784062 FixedProfit: 1176593
# Episode: 6/100 RapTime: 0:00:10.931860 FixedProfit: 1261622
# Episode: 7/100 RapTime: 0:00:10.776676 FixedProfit: 1215738
# Episode: 7/100 RapTime: 0:00:10.736399 FixedProfit: 1217779
# Episode: 7/100 RapTime: 0:00:10.765378 FixedProfit: 1182226
# Episode: 7/100 RapTime: 0:00:10.751308 FixedProfit: 1215776
# Episode: 8/100 RapTime: 0:00:10.818434 FixedProfit: 1229547
# Episode: 8/100 RapTime: 0:00:10.754449 FixedProfit: 1165037
# Episode: 8/100 RapTime: 0:00:10.793413 FixedProfit: 1247868
# Episode: 8/100 RapTime: 0:00:10.871114 FixedProfit: 1197231
# Episode: 9/100 RapTime: 0:00:10.690984 FixedProfit: 1166469
# Episode: 9/100 RapTime: 0:00:10.636629 FixedProfit: 1165195
# Episode: 9/100 RapTime: 0:00:10.657760 FixedProfit: 1204326
# Episode: 9/100 RapTime: 0:00:10.740686 FixedProfit: 1118936
# Episode: 10/100 RapTime: 0:00:10.706322 FixedProfit: 1206949
# Episode: 10/100 RapTime: 0:00:10.692280 FixedProfit: 1239556
# Episode: 10/100 RapTime: 0:00:10.670801 FixedProfit: 1247263
# Episode: 10/100 RapTime: 0:00:10.719152 FixedProfit: 1217194
# Episode: 11/100 RapTime: 0:00:10.583318 FixedProfit: 1196387
# Episode: 11/100 RapTime: 0:00:10.649435 FixedProfit: 1187117
# Episode: 11/100 RapTime: 0:00:10.582315 FixedProfit: 1154336
# Episode: 11/100 RapTime: 0:00:10.583979 FixedProfit: 1208433
# Episode: 12/100 RapTime: 0:00:10.716699 FixedProfit: 1186296
# Episode: 12/100 RapTime: 0:00:10.765502 FixedProfit: 1250199
# Episode: 12/100 RapTime: 0:00:10.723445 FixedProfit: 1214391
# Episode: 12/100 RapTime: 0:00:10.736538 FixedProfit: 1216694
# Episode: 13/100 RapTime: 0:00:10.715648 FixedProfit: 1188381
# Episode: 13/100 RapTime: 0:00:10.761052 FixedProfit: 1196098
# Episode: 13/100 RapTime: 0:00:10.758408 FixedProfit: 1199154
# Episode: 13/100 RapTime: 0:00:10.760718 FixedProfit: 1223935
# Episode: 14/100 RapTime: 0:00:10.744395 FixedProfit: 1185187
# Episode: 14/100 RapTime: 0:00:10.766341 FixedProfit: 1196194
# Episode: 14/100 RapTime: 0:00:10.757600 FixedProfit: 1183239
# Episode: 14/100 RapTime: 0:00:10.777368 FixedProfit: 1210855
# Episode: 15/100 RapTime: 0:00:10.887216 FixedProfit: 1201413
# Episode: 15/100 RapTime: 0:00:10.912118 FixedProfit: 1173581
# Episode: 15/100 RapTime: 0:00:10.865050 FixedProfit: 1222875
# Episode: 15/100 RapTime: 0:00:10.876935 FixedProfit: 1194534
# Episode: 16/100 RapTime: 0:00:10.807191 FixedProfit: 1215948
# Episode: 16/100 RapTime: 0:00:10.796536 FixedProfit: 1201957
# Episode: 16/100 RapTime: 0:00:10.861819 FixedProfit: 1222305
# Episode: 16/100 RapTime: 0:00:10.856357 FixedProfit: 1202614
# Episode: 17/100 RapTime: 0:00:10.891924 FixedProfit: 1242976
# Episode: 17/100 RapTime: 0:00:10.912470 FixedProfit: 1190506
# Episode: 17/100 RapTime: 0:00:10.902401 FixedProfit: 1186915Episode: 17/100 RapTime: 0:00:10.935332 FixedProfit: 1207830
#
# Episode: 18/100 RapTime: 0:00:10.755582 FixedProfit: 1216336
# Episode: 18/100 RapTime: 0:00:10.776847 FixedProfit: 1184672
# Episode: 18/100 RapTime: 0:00:10.830907 FixedProfit: 1191140
# Episode: 18/100 RapTime: 0:00:10.885372 FixedProfit: 1195495
# Episode: 19/100 RapTime: 0:00:10.900566 FixedProfit: 1197393
# Episode: 19/100 RapTime: 0:00:10.867108 FixedProfit: 1215481
# Episode: 19/100 RapTime: 0:00:10.880653 FixedProfit: 1185103
# Episode: 19/100 RapTime: 0:00:10.859766 FixedProfit: 1212974
# Episode: 20/100 RapTime: 0:00:10.862791 FixedProfit: 1192449
# Episode: 20/100 RapTime: 0:00:10.833906 FixedProfit: 1152912
# Episode: 20/100 RapTime: 0:00:10.888008 FixedProfit: 1199571
# Episode: 20/100 RapTime: 0:00:10.872717 FixedProfit: 1198355
# Episode: 21/100 RapTime: 0:00:10.874008 FixedProfit: 1189458
# Episode: 21/100 RapTime: 0:00:10.866059 FixedProfit: 1218786
# Episode: 21/100 RapTime: 0:00:10.897792 FixedProfit: 1172738
# Episode: 21/100 RapTime: 0:00:10.941982 FixedProfit: 1198309
# Episode: 22/100 RapTime: 0:00:10.978073 FixedProfit: 1133524
# Episode: 22/100 RapTime: 0:00:11.023090 FixedProfit: 1177411
# Episode: 22/100 RapTime: 0:00:10.938746 FixedProfit: 1217197
# Episode: 22/100 RapTime: 0:00:11.033803 FixedProfit: 1197798
# Episode: 23/100 RapTime: 0:00:10.910049 FixedProfit: 1203151
# Episode: 23/100 RapTime: 0:00:10.983526 FixedProfit: 1198517
# Episode: 23/100 RapTime: 0:00:11.018600 FixedProfit: 1197165
# Episode: 23/100 RapTime: 0:00:11.034931 FixedProfit: 1196232
# Episode: 24/100 RapTime: 0:00:11.195900 FixedProfit: 1189851
# Episode: 24/100 RapTime: 0:00:11.276949 FixedProfit: 1199210
# Episode: 24/100 RapTime: 0:00:11.191076 FixedProfit: 1184678
# Episode: 24/100 RapTime: 0:00:11.191672 FixedProfit: 1209057
# Episode: 25/100 RapTime: 0:00:10.875754 FixedProfit: 1172306
# Episode: 25/100 RapTime: 0:00:10.910885 FixedProfit: 1198982
# Episode: 25/100 RapTime: 0:00:10.898301 FixedProfit: 1206808
# Episode: 25/100 RapTime: 0:00:10.874957 FixedProfit: 1224587
# Episode: 26/100 RapTime: 0:00:10.939833 FixedProfit: 1201158
# Episode: 26/100 RapTime: 0:00:10.978812 FixedProfit: 1188450
# Episode: 26/100 RapTime: 0:00:10.929823 FixedProfit: 1173686
# Episode: 26/100 RapTime: 0:00:10.942951 FixedProfit: 1196330
# Episode: 27/100 RapTime: 0:00:10.965390 FixedProfit: 1184083
# Episode: 27/100 RapTime: 0:00:10.973802 FixedProfit: 1213877
# Episode: 27/100 RapTime: 0:00:11.000597 FixedProfit: 1197165
# Episode: 27/100 RapTime: 0:00:10.954360 FixedProfit: 1190395
# Episode: 28/100 RapTime: 0:00:10.816067 FixedProfit: 1212940
# Episode: 28/100 RapTime: 0:00:10.815964 FixedProfit: 1178641
# Episode: 28/100 RapTime: 0:00:10.818418 FixedProfit: 1191851
# Episode: 28/100 RapTime: 0:00:10.937528 FixedProfit: 1197165
# Episode: 29/100 RapTime: 0:00:10.718172 FixedProfit: 1172327
# Episode: 29/100 RapTime: 0:00:10.857120 FixedProfit: 1197165
# Episode: 29/100 RapTime: 0:00:10.838206 FixedProfit: 1266730
# Episode: 29/100 RapTime: 0:00:10.792510 FixedProfit: 1184355
# Episode: 30/100 RapTime: 0:00:10.876210 FixedProfit: 1166748
# Episode: 30/100 RapTime: 0:00:10.854852 FixedProfit: 1196774
# Episode: 30/100 RapTime: 0:00:10.820532 FixedProfit: 1206036
# Episode: 30/100 RapTime: 0:00:10.814529 FixedProfit: 1221225
# Episode: 31/100 RapTime: 0:00:10.884515 FixedProfit: 1206126
# Episode: 31/100 RapTime: 0:00:10.791469 FixedProfit: 1234074
# Episode: 31/100 RapTime: 0:00:10.882146 FixedProfit: 1194784
# Episode: 31/100 RapTime: 0:00:10.806004 FixedProfit: 1195674
# Episode: 32/100 RapTime: 0:00:11.043175 FixedProfit: 1197165
# Episode: 32/100 RapTime: 0:00:11.054874 FixedProfit: 1185640
# Episode: 32/100 RapTime: 0:00:11.041299 FixedProfit: 1176123
# Episode: 32/100 RapTime: 0:00:11.069844 FixedProfit: 1197323
# Episode: 33/100 RapTime: 0:00:11.098379 FixedProfit: 1200542
# Episode: 33/100 RapTime: 0:00:11.097695 FixedProfit: 1208236
# Episode: 33/100 RapTime: 0:00:11.077527 FixedProfit: 1201552
# Episode: 33/100 RapTime: 0:00:11.187543 FixedProfit: 1193580
# Episode: 34/100 RapTime: 0:00:11.099217 FixedProfit: 1222031
# Episode: 34/100 RapTime: 0:00:11.129385 FixedProfit: 1214987
# Episode: 34/100 RapTime: 0:00:11.110140 FixedProfit: 1239548
# Episode: 34/100 RapTime: 0:00:11.212351 FixedProfit: 1191823
# Episode: 35/100 RapTime: 0:00:11.212489 FixedProfit: 1181364
# Episode: 35/100 RapTime: 0:00:11.135133 FixedProfit: 1180826
# Episode: 35/100 RapTime: 0:00:11.140115 FixedProfit: 1187039
# Episode: 35/100 RapTime: 0:00:11.096004 FixedProfit: 1203591
# Episode: 36/100 RapTime: 0:00:10.966349 FixedProfit: 1198049
# Episode: 36/100 RapTime: 0:00:10.966296 FixedProfit: 1199131
# Episode: 36/100 RapTime: 0:00:11.054141 FixedProfit: 1189081
# Episode: 36/100 RapTime: 0:00:10.977921 FixedProfit: 1211528
# Episode: 37/100 RapTime: 0:00:11.126344 FixedProfit: 1197931
# Episode: 37/100 RapTime: 0:00:11.080289 FixedProfit: 1192952
# Episode: 37/100 RapTime: 0:00:10.999641 FixedProfit: 1193849
# Episode: 37/100 RapTime: 0:00:11.048718 FixedProfit: 1211911
# Episode: 38/100 RapTime: 0:00:11.013272 FixedProfit: 1195933
# Episode: 38/100 RapTime: 0:00:11.043133 FixedProfit: 1194818
# Episode: 38/100 RapTime: 0:00:11.008097 FixedProfit: 1198880
# Episode: 38/100 RapTime: 0:00:10.961347 FixedProfit: 1180505
# Episode: 39/100 RapTime: 0:00:10.993663 FixedProfit: 1207893
# Episode: 39/100 RapTime: 0:00:11.034730 FixedProfit: 1194029
# Episode: 39/100 RapTime: 0:00:11.053091 FixedProfit: 1198703
# Episode: 39/100 RapTime: 0:00:11.098452 FixedProfit: 1179786
# Episode: 40/100 RapTime: 0:00:11.045250 FixedProfit: 1209973
# Episode: 40/100 RapTime: 0:00:11.035780 FixedProfit: 1209341
# Episode: 40/100 RapTime: 0:00:10.952777 FixedProfit: 1199100
# Episode: 40/100 RapTime: 0:00:11.073903 FixedProfit: 1192798
# Episode: 41/100 RapTime: 0:00:10.944511 FixedProfit: 1189016
# Episode: 41/100 RapTime: 0:00:10.992244 FixedProfit: 1197165
# Episode: 41/100 RapTime: 0:00:11.055969 FixedProfit: 1201901
# Episode: 41/100 RapTime: 0:00:11.061977 FixedProfit: 1193300
# Episode: 42/100 RapTime: 0:00:11.012346 FixedProfit: 1181057
# Episode: 42/100 RapTime: 0:00:10.914435 FixedProfit: 1184232
# Episode: 42/100 RapTime: 0:00:10.971976 FixedProfit: 1189800
# Episode: 42/100 RapTime: 0:00:11.044731 FixedProfit: 1191831
# Episode: 43/100 RapTime: 0:00:11.011982 FixedProfit: 1200276
# Episode: 43/100 RapTime: 0:00:10.971601 FixedProfit: 1193617
# Episode: 43/100 RapTime: 0:00:11.053342 FixedProfit: 1215591
# Episode: 43/100 RapTime: 0:00:10.890707 FixedProfit: 1188029
# Episode: 44/100 RapTime: 0:00:10.851906 FixedProfit: 1197165
# Episode: 44/100 RapTime: 0:00:10.885603 FixedProfit: 1211357
# Episode: 44/100 RapTime: 0:00:10.869890 FixedProfit: 1163379
# Episode: 44/100 RapTime: 0:00:10.803492 FixedProfit: 1231853
# Episode: 45/100 RapTime: 0:00:10.766185 FixedProfit: 1185754
# Episode: 45/100 RapTime: 0:00:10.757089 FixedProfit: 1198777
# Episode: 45/100 RapTime: 0:00:10.896297 FixedProfit: 1196083
# Episode: 45/100 RapTime: 0:00:10.827802 FixedProfit: 1189540
# Episode: 46/100 RapTime: 0:00:10.843128 FixedProfit: 1196849
# Episode: 46/100 RapTime: 0:00:10.897969 FixedProfit: 1174312
# Episode: 46/100 RapTime: 0:00:10.799098 FixedProfit: 1205679
# Episode: 46/100 RapTime: 0:00:10.758624 FixedProfit: 1196217
# Episode: 47/100 RapTime: 0:00:11.085854 FixedProfit: 1203096
# Episode: 47/100 RapTime: 0:00:11.088888 FixedProfit: 1208271
# Episode: 47/100 RapTime: 0:00:11.046739 FixedProfit: 1192948
# Episode: 47/100 RapTime: 0:00:11.059375 FixedProfit: 1195710
# Episode: 48/100 RapTime: 0:00:10.896124 FixedProfit: 1198241
# Episode: 48/100 RapTime: 0:00:10.976899 FixedProfit: 1191552
# Episode: 48/100 RapTime: 0:00:10.878897 FixedProfit: 1197165
# Episode: 48/100 RapTime: 0:00:10.877604 FixedProfit: 1208128
# Episode: 49/100 RapTime: 0:00:10.895130 FixedProfit: 1173465
# Episode: 49/100 RapTime: 0:00:10.850556 FixedProfit: 1189206
# Episode: 49/100 RapTime: 0:00:10.845961 FixedProfit: 1181315
# Episode: 49/100 RapTime: 0:00:10.867728 FixedProfit: 1197835
# Episode: 50/100 RapTime: 0:00:10.890796 FixedProfit: 1197165
# Episode: 50/100 RapTime: 0:00:10.829301 FixedProfit: 1210031
# Episode: 50/100 RapTime: 0:00:10.863090 FixedProfit: 1178037
# Episode: 50/100 RapTime: 0:00:10.865372 FixedProfit: 1195955
# Episode: 51/100 RapTime: 0:00:10.740506 FixedProfit: 1197299
# Episode: 51/100 RapTime: 0:00:10.811595 FixedProfit: 1193339
# Episode: 51/100 RapTime: 0:00:10.842846 FixedProfit: 1216366
# Episode: 51/100 RapTime: 0:00:10.736541 FixedProfit: 1189235
# Episode: 52/100 RapTime: 0:00:11.155917 FixedProfit: 1179720
# Episode: 52/100 RapTime: 0:00:11.173233 FixedProfit: 1198753
# Episode: 52/100 RapTime: 0:00:11.127906 FixedProfit: 1184341
# Episode: 52/100 RapTime: 0:00:11.183421 FixedProfit: 1192672
# Episode: 53/100 RapTime: 0:00:10.824615 FixedProfit: 1197165
# Episode: 53/100 RapTime: 0:00:10.666503 FixedProfit: 1199313
# Episode: 53/100 RapTime: 0:00:10.709034 FixedProfit: 1193300
# Episode: 53/100 RapTime: 0:00:10.718788 FixedProfit: 1184394
# Episode: 54/100 RapTime: 0:00:10.736795 FixedProfit: 1225880
# Episode: 54/100 RapTime: 0:00:10.777984 FixedProfit: 1180554
# Episode: 54/100 RapTime: 0:00:10.780567 FixedProfit: 1192081
# Episode: 54/100 RapTime: 0:00:10.823486 FixedProfit: 1217410
# Episode: 55/100 RapTime: 0:00:10.725332 FixedProfit: 1195614
# Episode: 55/100 RapTime: 0:00:10.751072 FixedProfit: 1207663
# Episode: 55/100 RapTime: 0:00:10.675127 FixedProfit: 1185939
# Episode: 55/100 RapTime: 0:00:10.729026 FixedProfit: 1191196
# Episode: 56/100 RapTime: 0:00:10.833431 FixedProfit: 1199475
# Episode: 56/100 RapTime: 0:00:10.783050 FixedProfit: 1182713
# Episode: 56/100 RapTime: 0:00:10.775915 FixedProfit: 1198589
# Episode: 56/100 RapTime: 0:00:10.871324 FixedProfit: 1207474
# Episode: 57/100 RapTime: 0:00:10.742082 FixedProfit: 1187700
# Episode: 57/100 RapTime: 0:00:10.858748 FixedProfit: 1193655
# Episode: 57/100 RapTime: 0:00:10.790928 FixedProfit: 1203020
# Episode: 57/100 RapTime: 0:00:10.787667 FixedProfit: 1194427
# Episode: 58/100 RapTime: 0:00:10.861787 FixedProfit: 1197165
# Episode: 58/100 RapTime: 0:00:10.850320 FixedProfit: 1209021
# Episode: 58/100 RapTime: 0:00:10.800137 FixedProfit: 1209971
# Episode: 58/100 RapTime: 0:00:10.876145 FixedProfit: 1198363
# Episode: 59/100 RapTime: 0:00:10.766193 FixedProfit: 1185817
# Episode: 59/100 RapTime: 0:00:10.707176 FixedProfit: 1190837
# Episode: 59/100 RapTime: 0:00:10.769407 FixedProfit: 1206657
# Episode: 59/100 RapTime: 0:00:10.678296 FixedProfit: 1212572
# Episode: 60/100 RapTime: 0:00:10.741112 FixedProfit: 1185998
# Episode: 60/100 RapTime: 0:00:10.745675 FixedProfit: 1199247
# Episode: 60/100 RapTime: 0:00:10.745095 FixedProfit: 1197663
# Episode: 60/100 RapTime: 0:00:10.707610 FixedProfit: 1194186
# Episode: 61/100 RapTime: 0:00:10.786928 FixedProfit: 1209290
# Episode: 61/100 RapTime: 0:00:10.778992 FixedProfit: 1197923
# Episode: 61/100 RapTime: 0:00:10.793862 FixedProfit: 1181866
# Episode: 61/100 RapTime: 0:00:10.834524 FixedProfit: 1198303
# Episode: 62/100 RapTime: 0:00:10.751308 FixedProfit: 1186839
# Episode: 62/100 RapTime: 0:00:10.766848 FixedProfit: 1202622
# Episode: 62/100 RapTime: 0:00:10.820803 FixedProfit: 1197165
# Episode: 62/100 RapTime: 0:00:10.726099 FixedProfit: 1172430
# Episode: 63/100 RapTime: 0:00:10.721993 FixedProfit: 1189117
# Episode: 63/100 RapTime: 0:00:10.784728 FixedProfit: 1196044
# Episode: 63/100 RapTime: 0:00:10.762805 FixedProfit: 1201175
# Episode: 63/100 RapTime: 0:00:10.752103 FixedProfit: 1197165
# Episode: 64/100 RapTime: 0:00:10.722163 FixedProfit: 1183502
# Episode: 64/100 RapTime: 0:00:10.739646 FixedProfit: 1179762
# Episode: 64/100 RapTime: 0:00:10.720222 FixedProfit: 1202902
# Episode: 64/100 RapTime: 0:00:10.778865 FixedProfit: 1215614
# Episode: 65/100 RapTime: 0:00:10.640592 FixedProfit: 1195470
# Episode: 65/100 RapTime: 0:00:10.734387 FixedProfit: 1194828
# Episode: 65/100 RapTime: 0:00:10.699819 FixedProfit: 1220326
# Episode: 65/100 RapTime: 0:00:10.650807 FixedProfit: 1220633
# Episode: 66/100 RapTime: 0:00:10.691405 FixedProfit: 1197165
# Episode: 66/100 RapTime: 0:00:10.685043 FixedProfit: 1197165
# Episode: 66/100 RapTime: 0:00:10.624676 FixedProfit: 1196523
# Episode: 66/100 RapTime: 0:00:10.649508 FixedProfit: 1186459
# Episode: 67/100 RapTime: 0:00:10.701845 FixedProfit: 1190187
# Episode: 67/100 RapTime: 0:00:10.690062 FixedProfit: 1218310
# Episode: 67/100 RapTime: 0:00:10.813617 FixedProfit: 1183435
# Episode: 67/100 RapTime: 0:00:10.723307 FixedProfit: 1198382
# Episode: 68/100 RapTime: 0:00:10.585134 FixedProfit: 1197165
# Episode: 68/100 RapTime: 0:00:10.672858 FixedProfit: 1183766
# Episode: 68/100 RapTime: 0:00:10.637621 FixedProfit: 1186846
# Episode: 68/100 RapTime: 0:00:10.694182 FixedProfit: 1193870
# Episode: 69/100 RapTime: 0:00:10.790227 FixedProfit: 1193671
# Episode: 69/100 RapTime: 0:00:10.723799 FixedProfit: 1194914
# Episode: 69/100 RapTime: 0:00:10.679898 FixedProfit: 1200183
# Episode: 69/100 RapTime: 0:00:10.792794 FixedProfit: 1195767
# Episode: 70/100 RapTime: 0:00:10.666604 FixedProfit: 1251818
# Episode: 70/100 RapTime: 0:00:10.725901 FixedProfit: 1187198
# Episode: 70/100 RapTime: 0:00:10.738791 FixedProfit: 1184355
# Episode: 70/100 RapTime: 0:00:10.727043 FixedProfit: 1208081
# Episode: 71/100 RapTime: 0:00:10.774903 FixedProfit: 1143454
# Episode: 71/100 RapTime: 0:00:10.822095 FixedProfit: 1194203
# Episode: 71/100 RapTime: 0:00:10.735814 FixedProfit: 1191541
# Episode: 71/100 RapTime: 0:00:10.896060 FixedProfit: 1186732
# Episode: 72/100 RapTime: 0:00:10.672220 FixedProfit: 1192262
# Episode: 72/100 RapTime: 0:00:10.698666 FixedProfit: 1138881
# Episode: 72/100 RapTime: 0:00:10.690206 FixedProfit: 1241703
# Episode: 72/100 RapTime: 0:00:10.743792 FixedProfit: 1182849
# Episode: 73/100 RapTime: 0:00:10.690860 FixedProfit: 1110699
# Episode: 73/100 RapTime: 0:00:10.772667 FixedProfit: 1136837
# Episode: 73/100 RapTime: 0:00:10.798660 FixedProfit: 1185130
# Episode: 73/100 RapTime: 0:00:10.758214 FixedProfit: 1142799
# Episode: 74/100 RapTime: 0:00:10.834547 FixedProfit: 1116730
# Episode: 74/100 RapTime: 0:00:10.735993 FixedProfit: 1158011
# Episode: 74/100 RapTime: 0:00:10.738027 FixedProfit: 1212748
# Episode: 74/100 RapTime: 0:00:10.764025 FixedProfit: 1211372
# Episode: 75/100 RapTime: 0:00:10.695553 FixedProfit: 1206204
# Episode: 75/100 RapTime: 0:00:10.717902 FixedProfit: 1150850
# Episode: 75/100 RapTime: 0:00:10.771921 FixedProfit: 1202148
# Episode: 75/100 RapTime: 0:00:10.755577 FixedProfit: 1190464
# Episode: 76/100 RapTime: 0:00:10.630710 FixedProfit: 1201427
# Episode: 76/100 RapTime: 0:00:10.687996 FixedProfit: 1187241
# Episode: 76/100 RapTime: 0:00:10.702505 FixedProfit: 1187262
# Episode: 76/100 RapTime: 0:00:10.630792 FixedProfit: 1163115
# Episode: 77/100 RapTime: 0:00:10.682524 FixedProfit: 1215546
# Episode: 77/100 RapTime: 0:00:10.725084 FixedProfit: 1188485
# Episode: 77/100 RapTime: 0:00:10.745443 FixedProfit: 1215148
# Episode: 77/100 RapTime: 0:00:10.706863 FixedProfit: 1209998
# Episode: 78/100 RapTime: 0:00:10.764950 FixedProfit: 1191396
# Episode: 78/100 RapTime: 0:00:10.745081 FixedProfit: 1161806
# Episode: 78/100 RapTime: 0:00:10.784874 FixedProfit: 1201515
# Episode: 78/100 RapTime: 0:00:10.758069 FixedProfit: 1200575
# Episode: 79/100 RapTime: 0:00:10.722996 FixedProfit: 1197184
# Episode: 79/100 RapTime: 0:00:10.734998 FixedProfit: 1210741
# Episode: 79/100 RapTime: 0:00:10.673754 FixedProfit: 1202119
# Episode: 79/100 RapTime: 0:00:10.750874 FixedProfit: 1188888
# Episode: 80/100 RapTime: 0:00:10.674524 FixedProfit: 1216175
# Episode: 80/100 RapTime: 0:00:10.781859 FixedProfit: 1197165
# Episode: 80/100 RapTime: 0:00:10.760030 FixedProfit: 1195493
# Episode: 80/100 RapTime: 0:00:10.819955 FixedProfit: 1198178
# Episode: 81/100 RapTime: 0:00:10.465767 FixedProfit: 1181254
# Episode: 81/100 RapTime: 0:00:11.081730 FixedProfit: 1196795
# Episode: 81/100 RapTime: 0:00:10.977309 FixedProfit: 1195908
# Episode: 81/100 RapTime: 0:00:11.077453 FixedProfit: 1201902
# Episode: 82/100 RapTime: 0:00:10.438208 FixedProfit: 1182523
# Episode: 82/100 RapTime: 0:00:10.713840 FixedProfit: 1219692
# Episode: 82/100 RapTime: 0:00:10.733868 FixedProfit: 1167331
# Episode: 82/100 RapTime: 0:00:10.749759 FixedProfit: 1200803
# Episode: 83/100 RapTime: 0:00:10.931846 FixedProfit: 1165666
# Episode: 83/100 RapTime: 0:00:10.777186 FixedProfit: 1197714
# Episode: 83/100 RapTime: 0:00:10.653307 FixedProfit: 1165240
# Episode: 83/100 RapTime: 0:00:10.713814 FixedProfit: 1181997
# Episode: 84/100 RapTime: 0:00:11.064003 FixedProfit: 1194043
# Episode: 84/100 RapTime: 0:00:10.593951 FixedProfit: 1168732
# Episode: 84/100 RapTime: 0:00:10.657713 FixedProfit: 1187993
# Episode: 84/100 RapTime: 0:00:10.663231 FixedProfit: 1197165
# Episode: 85/100 RapTime: 0:00:10.549324 FixedProfit: 1174630
# Episode: 85/100 RapTime: 0:00:10.647960 FixedProfit: 1194601
# Episode: 85/100 RapTime: 0:00:10.732116 FixedProfit: 1194828
# Episode: 85/100 RapTime: 0:00:10.640320 FixedProfit: 1194917
# Episode: 86/100 RapTime: 0:00:10.741596 FixedProfit: 1200836
# Episode: 86/100 RapTime: 0:00:10.707134 FixedProfit: 1197165
# Episode: 86/100 RapTime: 0:00:10.763455 FixedProfit: 1186055
# Episode: 86/100 RapTime: 0:00:10.791537 FixedProfit: 1194016
# Episode: 87/100 RapTime: 0:00:10.836112 FixedProfit: 1206931
# Episode: 87/100 RapTime: 0:00:10.676948 FixedProfit: 1204304
# Episode: 87/100 RapTime: 0:00:10.708762 FixedProfit: 1200803
# Episode: 87/100 RapTime: 0:00:10.642973 FixedProfit: 1183435
# Episode: 88/100 RapTime: 0:00:10.543323 FixedProfit: 1209857
# Episode: 88/100 RapTime: 0:00:10.627585 FixedProfit: 1201222
# Episode: 88/100 RapTime: 0:00:10.631449 FixedProfit: 1196572
# Episode: 88/100 RapTime: 0:00:10.689910 FixedProfit: 1191620
# Episode: 89/100 RapTime: 0:00:10.486846 FixedProfit: 1205821
# Episode: 89/100 RapTime: 0:00:10.601542 FixedProfit: 1180154
# Episode: 89/100 RapTime: 0:00:10.674391 FixedProfit: 1205221
# Episode: 89/100 RapTime: 0:00:10.667501 FixedProfit: 1199790
# Episode: 90/100 RapTime: 0:00:10.704554 FixedProfit: 1180521
# Episode: 90/100 RapTime: 0:00:10.684224 FixedProfit: 1159997
# Episode: 90/100 RapTime: 0:00:10.627592 FixedProfit: 1208211
# Episode: 90/100 RapTime: 0:00:10.627169 FixedProfit: 1197165
# Episode: 91/100 RapTime: 0:00:10.500430 FixedProfit: 1167318
# Episode: 91/100 RapTime: 0:00:10.809709 FixedProfit: 1198479
# Episode: 91/100 RapTime: 0:00:10.867243 FixedProfit: 1198219
# Episode: 91/100 RapTime: 0:00:10.858893 FixedProfit: 1215593
# Episode: 92/100 RapTime: 0:00:11.250010 FixedProfit: 1186834
# Episode: 92/100 RapTime: 0:00:10.870473 FixedProfit: 1197165
# Episode: 92/100 RapTime: 0:00:10.934078 FixedProfit: 1208636
# Episode: 92/100 RapTime: 0:00:10.896047 FixedProfit: 1174286
# Episode: 93/100 RapTime: 0:00:10.753154 FixedProfit: 1195777
# Episode: 93/100 RapTime: 0:00:10.736469 FixedProfit: 1186533
# Episode: 93/100 RapTime: 0:00:10.708474 FixedProfit: 1197165
# Episode: 93/100 RapTime: 0:00:10.608772 FixedProfit: 1193849
# Episode: 94/100 RapTime: 0:00:10.750701 FixedProfit: 1167624
# Episode: 94/100 RapTime: 0:00:10.759306 FixedProfit: 1181832
# Episode: 94/100 RapTime: 0:00:10.737089 FixedProfit: 1208890
# Episode: 94/100 RapTime: 0:00:10.718672 FixedProfit: 1182904
# Episode: 95/100 RapTime: 0:00:10.683853 FixedProfit: 1208151
# Episode: 95/100 RapTime: 0:00:10.763237 FixedProfit: 1205433
# Episode: 95/100 RapTime: 0:00:10.719268 FixedProfit: 1197165
# Episode: 95/100 RapTime: 0:00:10.764802 FixedProfit: 1197165
# Episode: 96/100 RapTime: 0:00:10.742241 FixedProfit: 1197858
# Episode: 96/100 RapTime: 0:00:10.701893 FixedProfit: 1198225
# Episode: 96/100 RapTime: 0:00:10.728947 FixedProfit: 1211734
# Episode: 96/100 RapTime: 0:00:10.703690 FixedProfit: 1210873
# Episode: 97/100 RapTime: 0:00:10.780856 FixedProfit: 1181303
# Episode: 97/100 RapTime: 0:00:10.839565 FixedProfit: 1179856
# Episode: 97/100 RapTime: 0:00:10.759419 FixedProfit: 1222451
# Episode: 97/100 RapTime: 0:00:10.820655 FixedProfit: 1220152
# Episode: 98/100 RapTime: 0:00:10.947817 FixedProfit: 1200313
# Episode: 98/100 RapTime: 0:00:10.899020 FixedProfit: 1279378
# Episode: 98/100 RapTime: 0:00:10.924117 FixedProfit: 1211039
# Episode: 98/100 RapTime: 0:00:10.881613 FixedProfit: 1195591
# Episode: 99/100 RapTime: 0:00:11.058168 FixedProfit: 1210873
# Episode: 99/100 RapTime: 0:00:10.986035 FixedProfit: 1214438
# Episode: 99/100 RapTime: 0:00:10.956859 FixedProfit: 1186431
# Episode: 99/100 RapTime: 0:00:10.990980 FixedProfit: 1193454
# Episode: 100/100 RapTime: 0:00:10.947554 FixedProfit: 1164089
# Episode: 100/100 RapTime: 0:00:10.925269 FixedProfit: 1179024
# Episode: 100/100 RapTime: 0:00:10.872330 FixedProfit: 1186538
# Episode: 100/100 RapTime: 0:00:10.744761 FixedProfit: 1194828
